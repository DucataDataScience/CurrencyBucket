# %%
"""
Description: Perform (backward) selection in currency selection for final Duca basket.
Author: Jeroen van Dijk
Date: 04-11-2020
Maintainer: Jeroen van Dijk
Email: jeroen.vandijk@d-data.nl
Status: Dev
"""
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import yfinance as yf

from collections import defaultdict
from currency_converter import CurrencyConverter
from datetime import timedelta, date, datetime
from scipy.optimize import minimize

# Set notebook options
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 43)
pd.set_option('display.width', 800)
pd.set_option('display.max_colwidth', 15)
pd.set_option('display.precision', 3)

# %%
def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

def create_original_df(base_currency="EUR"):
    """Create the original dataframe based on ECB data.
   
    Parameters
    ----------
    base_currency : str
        The currency that is used to express other currency exchange rates."""
    c = CurrencyConverter("http://www.ecb.int/stats/eurofxref/eurofxref-hist.zip", 
                          fallback_on_wrong_date=True, 
                          fallback_on_missing_rate=True,
                          decimal=True)

    start_date = date(2000, 1, 1)
    end_date = date.today()

    date_list = []

    for single_date in daterange(start_date, end_date):

        cur_list = []
        cur_list.append(single_date)

        for currency in c.currencies:

            value = c.convert(1, base_currency, currency, date=single_date)
            cur_list.append(float(value))

        date_list.append(cur_list)

    columns_list = ["date"] + list(c.currencies)

    df = pd.DataFrame(date_list, columns=columns_list)
    df = df.sort_values(by="date", ascending=False)
    
    df["date"] = df["date"].map(lambda x: datetime(x.year, x.month, x.day, 0, 0))
    
    return df.sort_values("date").set_index("date")

# %%
# Define currencies of interest
p13_currencies = ['USD','EUR','GBP',
                  'CHF','CNY','JPY',
                  'CAD','SEK','NOK',
                  'SGD','AUD','NZD',
                  'ZAR']

# Create dataframe with pre-defined base currency
df = create_original_df("EUR")

# %%
obsolete_currencies = ["ISK", "MXN", "ROL", "BRL", "CYP", "EEK", "INR", "ILS", "SIT", "BGN", "LTL", "MTL", "TRL", "LVL", "SKK"]
all_currencies = [c for c in df.columns if c not in obsolete_currencies]

# %%
# Determine splits for dev- (train and test) and validation set
train_start = date(2005, 4, 1)
test_start = date(2012, 1, 1)
validation_start = date(2015, 1, 1)
validation_end = date(2020, 10, 1)

# Create dev (train and test) and validation set
train = df.query("date >= @train_start and date < @test_start")
test = df.query("date >= @test_start and date < @validation_start")
dev = pd.concat([train, test])
val = df.query("date >= @validation_start and date < @validation_end")

# %%
results = pd.DataFrame()

# Calculate loss function score per currency
for base_currency in all_currencies:
    for currency in all_currencies:
        if currency == base_currency:
            continue
            
        rates = dev[base_currency] / dev[currency]
        normalized_rates = rates / rates.iloc[0]
        
        deviation = np.log(normalized_rates)
        loss_function_score = (deviation**2).mean()

        results = results.append({"currency": currency,
                                  "base_currency": base_currency,
                                  "loss_function_score": loss_function_score},
                                 ignore_index=True)
    
results = results.groupby("currency").median()
results.sort_values("loss_function_score", ascending=True)
# Out:
#           loss_function_score
# currency
# CAD                0.015
# MYR                0.016
# NOK                0.017
# HRK                0.020
# SEK                0.020
# CZK                0.021
# EUR                0.021
# DKK                0.021
# USD                0.021
# HKD                0.022
# PLN                0.022
# HUF                0.022
# IDR                0.023
# NZD                0.025
# AUD                0.025
# THB                0.026
# CHF                0.026
# RUB                0.026
# JPY                0.027
# RON                0.028
# PHP                0.028
# KRW                0.028
# SGD                0.031
# CNY                0.035
# GBP                0.036
# TRY                0.068
# ZAR                0.117

# %%
exchange_table = dict()

for base_currency in all_currencies:
    exchange_table[base_currency] = 1/train[all_currencies].divide(train[base_currency], axis=0)

exchange_table["USD"]
# Out:
#                   IDR    HRK        KRW    DKK    SGD    TRY    NOK    THB    GBP    JPY    HUF    CAD    HKD    MYR  USD    CHF    EUR    CNY    NZD    AUD    SEK    RUB    CZK    PLN    RON    PHP    ZAR
# date
# 2005-04-01  1.056e-04  0.175  9.923e-04  0.174  0.604  0.740  0.158  0.026  1.887  0.009  0.005  0.824  0.128  0.263  1.0  0.835  1.296  0.121  0.711  0.771  0.141  0.036  0.043  0.317  0.360  0.018  0.162
# 2005-04-02  1.055e-04  0.174  9.904e-04  0.174  0.603  0.738  0.158  0.025  1.883  0.009  0.005  0.823  0.128  0.263  1.0  0.833  1.293  0.121  0.709  0.770  0.141  0.036  0.043  0.316  0.359  0.018  0.162
# 2005-04-03  1.055e-04  0.174  9.886e-04  0.173  0.602  0.736  0.157  0.025  1.879  0.009  0.005  0.822  0.128  0.263  1.0  0.831  1.291  0.121  0.708  0.769  0.141  0.036  0.043  0.315  0.358  0.018  0.161
# 2005-04-04  1.054e-04  0.174  9.867e-04  0.173  0.600  0.733  0.157  0.025  1.875  0.009  0.005  0.821  0.128  0.263  1.0  0.829  1.288  0.121  0.707  0.768  0.140  0.036  0.043  0.313  0.358  0.018  0.161
# 2005-04-05  1.053e-04  0.173  9.828e-04  0.172  0.601  0.731  0.157  0.025  1.873  0.009  0.005  0.817  0.128  0.263  1.0  0.824  1.281  0.121  0.704  0.764  0.140  0.036  0.043  0.310  0.356  0.018  0.160
# ...               ...    ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...  ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2011-12-27  1.086e-04  0.174  8.652e-04  0.176  0.771  0.526  0.168  0.032  1.568  0.013  0.004  0.981  0.129  0.315  1.0  1.070  1.307  0.158  0.774  1.016  0.146  0.032  0.051  0.297  0.305  0.023  0.123
# 2011-12-28  1.087e-04  0.174  8.651e-04  0.176  0.772  0.526  0.168  0.032  1.567  0.013  0.004  0.985  0.129  0.316  1.0  1.072  1.307  0.158  0.778  1.020  0.146  0.032  0.051  0.297  0.305  0.023  0.123
# 2011-12-29  1.087e-04  0.171  8.658e-04  0.173  0.767  0.523  0.166  0.031  1.542  0.013  0.004  0.977  0.129  0.315  1.0  1.058  1.289  0.158  0.767  1.007  0.144  0.031  0.050  0.290  0.300  0.023  0.123
# 2011-12-30  1.103e-04  0.172  8.634e-04  0.174  0.769  0.530  0.167  0.032  1.549  0.013  0.004  0.979  0.129  0.315  1.0  1.064  1.294  0.159  0.773  1.017  0.145  0.031  0.050  0.290  0.299  0.023  0.123
# 2011-12-31  1.102e-04  0.172  8.641e-04  0.174  0.770  0.530  0.167  0.032  1.549  0.013  0.004  0.980  0.129  0.315  1.0  1.064  1.294  0.159  0.775  1.019  0.145  0.031  0.050  0.290  0.299  0.023  0.124
#
# [2466 rows x 27 columns]

# %%
reference_date_exhange_rate = train[all_currencies].iloc[0]

def calculate_loss_function_around_one(weights):
    weights = weights / weights.sum()
    amounts = weights * reference_date_exhange_rate

    # TODO: penalize large coefficients?
    # JD: we do not face the problem of large coefficients (yet)
    loss_function_score = 0

    for base_currency in currencies:
        amounts_through_time = amounts * exchange_table[base_currency]
        normalized_amounts_through_time = amounts_through_time.sum(axis=1) / reference_date_exhange_rate[base_currency]
        
        # TODO: other possibilities for loss functions:
        # - Mean Absolute Error MAE
        # - Root Mean Squared Error RMSE
        # - Time-series related loss functions (research)
        
        deviation = np.log(normalized_amounts_through_time)
        loss_function_score += (deviation**2).mean()
    
    return loss_function_score

# %%
def calculate_loss_function_vs_t_minus_one(weights):
    weights = weights / weights.sum()
    amounts = weights * reference_date_exhange_rate.loc[p13_currencies]

    loss_function_score = 0

    for base_currency in p13_currencies:
        amounts_through_time = (amounts * exchange_table[base_currency]).sum(axis=1)
        loss_function_score += (np.abs(amounts_through_time - amounts_through_time.shift(1))/amounts_through_time).mean()

    return loss_function_score

starting_point = np.ones(13)/13

result = minimize(calculate_loss_function_vs_t_minus_one, starting_point, options={"disp": True, "maxiter": 100})
duca_mix = pd.Series(result.x/result.x.sum(), index=reference_date_exhange_rate.loc[p13_currencies].index)
print(calculate_loss_function_vs_t_minus_one(duca_mix))
duca_mix.sort_values(ascending=False)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.035071
#          Iterations: 68
#          Function evaluations: 1050
#          Gradient evaluations: 75
# 0.03507095558894311
# EUR    0.164
# SGD    0.131
# GBP    0.102
# CNY    0.084
# NOK    0.082
# SEK    0.075
# AUD    0.069
# JPY    0.055
# CAD    0.053
# NZD    0.052
# CHF    0.046
# USD    0.045
# ZAR    0.043
# dtype: float64

# %%
bounds = [(0,1) for _ in range(len(all_currencies))]

# %%
def calculate_loss_function_vs_t_minus_one_with_balancing(weights):
    print("evaluate")
    
    # Ensure we never deviate from 100% total, and only use positive numbers
    weights = np.abs(weights) / np.abs(weights).sum()  
    
    # Calculate the weights after rebalancing for each month
    amounts_by_month = {month: weights / this_day_by_month["EUR"][month].iloc[0][p13_currencies] for month in months}
    
    # Calculate the loss function per base currency, per month
    return sum([sum([(amounts_by_month[month] * diff_by_month[base_currency][month]).sum(axis=1).sum() for month in months]) 
                for base_currency in p13_currencies])

starting_point = np.ones(13)/13
result = minimize(calculate_loss_function_vs_t_minus_one_with_balancing, starting_point, bounds=bounds, options={"disp": True, 
                                                                                                                 "maxiter": 2,
                                                                                                                 })
duca_mix = pd.Series(result.x/result.x.sum(), index=reference_date_exhange_rate.loc[p13_currencies].index)
# print(calculate_loss_function_vs_t_minus_one_with_balancing(duca_mix))
duca_mix.sort_values(ascending=False)
# Out:
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# evaluate
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-acab90d084f8> in <module>
#      15
#      16 # TODO: can we restrict to positive values here?
# ---> 17 result = minimize(calculate_loss_function_vs_t_minus_one_with_balancing, starting_point, bounds=bounds, options={"disp": True,
#      18                                                                                                                  "maxiter": 2,
#      19                                                                                                                  })
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     615                                   **options)
#     616     elif meth == 'l-bfgs-b':
# --> 617         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     618                                 callback=callback, **options)
#     619     elif meth == 'tnc':
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     199             self._update_x_impl(x)
#     200         self._update_fun()
# --> 201         self._update_grad()
#     202         return self.f, self.g
#     203
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     169     def _update_grad(self):
#     170         if not self.g_updated:
# --> 171             self._update_grad_impl()
#     172             self.g_updated = True
#     173
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#      89                 self._update_fun()
#      90                 self.ngev += 1
# ---> 91                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#      92                                            **finite_diff_options)
#      93
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     424
#     425         if sparsity is None:
# --> 426             return _dense_difference(fun_wrapped, x0, f0, h,
#     427                                      use_one_sided, method)
#     428         else:
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     495             x = x0 + h_vecs[i]
#     496             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 497             df = fun(x) - f0
#     498         elif method == '3-point' and use_one_sided[i]:
#     499             x1 = x0 + h_vecs[i]
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in fun_wrapped(x)
#     375
#     376     def fun_wrapped(x):
# --> 377         f = np.atleast_1d(fun(x, *args, **kwargs))
#     378         if f.ndim > 1:
#     379             raise RuntimeError("`fun` return value has "
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# <ipython-input-18-acab90d084f8> in calculate_loss_function_vs_t_minus_one_with_balancing(weights)
#       9
#      10     # Calculate the loss function per base currency, per month
# ---> 11     return sum([sum([(amounts_by_month[month] * diff_by_month[base_currency][month]).sum(axis=1).sum() for month in months])
#      12                 for base_currency in p13_currencies])
#      13
#
# <ipython-input-18-acab90d084f8> in <listcomp>(.0)
#       9
#      10     # Calculate the loss function per base currency, per month
# ---> 11     return sum([sum([(amounts_by_month[month] * diff_by_month[base_currency][month]).sum(axis=1).sum() for month in months])
#      12                 for base_currency in p13_currencies])
#      13
#
# <ipython-input-18-acab90d084f8> in <listcomp>(.0)
#       9
#      10     # Calculate the loss function per base currency, per month
# ---> 11     return sum([sum([(amounts_by_month[month] * diff_by_month[base_currency][month]).sum(axis=1).sum() for month in months])
#      12                 for base_currency in p13_currencies])
#      13
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11420                 name, axis=axis, level=level, skipna=skipna, min_count=min_count
#   11421             )
# > 11422         return self._reduce(
#   11423             func,
#   11424             name=name,
#
# /usr/local/lib/python3.9/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4234                 )
#    4235             with np.errstate(all="ignore"):
# -> 4236                 return op(delegate, skipna=skipna, **kwds)
#    4237
#    4238     def _reindex_indexer(self, new_index, indexer, copy):
#
# /usr/local/lib/python3.9/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# /usr/local/lib/python3.9/site-packages/pandas/core/nanops.py in nansum(values, axis, skipna, min_count, mask)
#     499     3.0
#     500     """
# --> 501     values, mask, dtype, dtype_max, _ = _get_values(
#     502         values, skipna, fill_value=0, mask=mask
#     503     )
#
# /usr/local/lib/python3.9/site-packages/pandas/core/nanops.py in _get_values(values, skipna, fill_value, fill_value_typ, mask)
#     284     values = extract_array(values, extract_numpy=True)
#     285
# --> 286     mask = _maybe_get_mask(values, skipna, mask)
#     287
#     288     dtype = values.dtype
#
# /usr/local/lib/python3.9/site-packages/pandas/core/nanops.py in _maybe_get_mask(values, skipna, mask)
#     230
#     231         if skipna:
# --> 232             mask = isna(values)
#     233
#     234     return mask
#
# /usr/local/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in isna(obj)
#     122     Name: 1, dtype: bool
#     123     """
# --> 124     return _isna(obj)
#     125
#     126
#
# /usr/local/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in _isna(obj, inf_as_na)
#     155         return False
#     156     elif isinstance(obj, (ABCSeries, np.ndarray, ABCIndexClass, ABCExtensionArray)):
# --> 157         return _isna_ndarraylike(obj, inf_as_na=inf_as_na)
#     158     elif isinstance(obj, ABCDataFrame):
#     159         return obj.isna()
#
# /usr/local/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in _isna_ndarraylike(obj, inf_as_na)
#     224             result = ~np.isfinite(values)
#     225         else:
# --> 226             result = np.isnan(values)
#     227
#     228     # box
#
# KeyboardInterrupt:

# %%
def calculate_loss_function_vs_t_minus_one_for_period(weights, max_date):
    weights = weights / weights.sum()
    amounts = weights * reference_date_exhange_rate.loc[p13_currencies]

    loss_function_score= 0

    for base_currency in p13_currencies:
        amounts_through_time = (amounts * exchange_table[base_currency].loc[:max_date]).sum(axis=1)
        loss_function_score += (np.abs(amounts_through_time - amounts_through_time.shift(1))/amounts_through_time).mean()

    return loss_function_score

# %%
# Everything contains all currencies now
this_day_by_month = {}
previous_day_by_month = {}
diff_by_month = defaultdict(dict)

for base_currency, table in exchange_table.items():
    if base_currency not in all_currencies:
        continue
        
    exchange_table[base_currency]["month"] = exchange_table[base_currency].index.map(lambda x: int(x.strftime("%Y%m")))

    this_day = exchange_table[base_currency]
    previous_day = pd.DataFrame(exchange_table[base_currency].shift(1), 
                                index=exchange_table[base_currency].index)
    previous_day["month"] = previous_day.index.map(lambda x: int(x.strftime("%Y%m")))
    
    this_day_by_month[base_currency] = {month: values[all_currencies] for month, values in this_day.groupby("month")}
    previous_day_by_month[base_currency] = {month: values[all_currencies] for month, values in previous_day.groupby("month")}
    
    for month in this_day_by_month[base_currency].keys():
        diff_by_month[base_currency][month] = np.abs((this_day_by_month[base_currency][month] - previous_day_by_month[base_currency][month]) / 
                                                      previous_day_by_month[base_currency][month])
    
months = list(exchange_table["EUR"]["month"].unique())

# %%
def calculate_loss_function_vs_t_minus_one_with_balancing(weights):
    
    # Ensure we never deviate from 100% total, and only use positive numbers
    weights = np.abs(weights) / np.abs(weights).sum()  
    
    # Calculate the weights after rebalancing for each month
    amounts_by_month = {month: weights / this_day_by_month["EUR"][month].iloc[0][all_currencies] for month in months}
    
    # Calculate the loss function per base currency, per month
    return sum([sum([(amounts_by_month[month] * diff_by_month[base_currency][month]).sum(axis=1).sum() for month in months]) 
                for base_currency in all_currencies])

# %%
def recalculate_weights(weights):
    """Helper function to recalculate weigths (baseline principle).
   
    Parameters
    ----------
    weights : array
        The initial weights given to all currencies."""
    weights[weights>0] = 1
    weights = weights/weights.sum()
    return weights

# %%
def evaluate_exclusion_of_currency(weights, 
                                   currency_set):
    """Perform backward selection of currencies.
   
    Parameters
    ----------
    weights : array
        The initial weights given to all currencies.
    currency_set : set
        The set containing all currencies of interest."""
    # Initialize string giving best currency to exclude
    best_to_exclude = "None"
    # Calculate initial loss function value
    starting_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(weights)
    
    # So far, this is the best solution
    best_loss_function_value = starting_loss_function_value
    print(f"starting loss function value: {best_loss_function_value}")
    print("")

    # Each time we eliminate one currency
    for excluded_currency in currency_set:
        print(f"evaluating {excluded_currency}")

        # We create the new weights,
        new_weights = weights.copy()
        new_weights[new_weights.index==excluded_currency] = 0
        new_weights = recalculate_weights(new_weights)
        
        # and calculate the new loss function value
        new_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(new_weights)
        print(f"new loss function value: {new_loss_function_value}")

        # Check whether the new loss function value is lower than the (so far) best one, and
        # the improvement needs to be > .5%
        if new_loss_function_value <= best_loss_function_value and new_loss_function_value < .995*starting_loss_function_value:
            print(f"better solution found by excluding {excluded_currency}")
            print(f"loss function decreased by {(best_loss_function_value-new_loss_function_value)/best_loss_function_value*100:.2f}% compared to current best solution")
            # If so, save these results
            best_loss_function_value = new_loss_function_value
            best_to_exclude = excluded_currency
        print("")
        
    if best_to_exclude == "None":
        print("No currency needed to be removed.")
    else:
        print(f"{best_to_exclude} is removed from currency set")
    print("")
    print(f"--------- new iteration ---------")
    print("")
    
    # Exclude the currency
    currency_set.remove(best_to_exclude)
    return starting_loss_function_value, best_loss_function_value, best_to_exclude, currency_set

# %%
weights = pd.Series(np.ones(len(all_currencies))/len(all_currencies), index=reference_date_exhange_rate.loc[all_currencies].index)
currency_set = set(all_currencies)
max_excluded_currencies = 27

for i in range(0, max_excluded_currencies):
    _, _, best_to_exclude, currencies = evaluate_exclusion_of_currency(weights, currency_set)
    if best_to_exclude == "None":
        continue
    weights[weights.index==best_to_exclude] = 0
    weights = recalculate_weights(weights)
# Out:
# starting loss function value: 143338.79797809376
#
# evaluating IDR
# new loss function value: 23172.962980856497
# better solution found by excluding IDR
# loss function decreased by 83.83% compared to current best solution
#
# evaluating HRK
# new loss function value: 148794.93714275828
#
# evaluating KRW
# new loss function value: 132699.4163045596
#
# evaluating DKK
# new loss function value: 148796.06917962988
#
# evaluating SGD
# new loss function value: 148837.15387720184
#
# evaluating TRY
# new loss function value: 148829.9144931999
#
# evaluating NOK
# new loss function value: 148774.93370797014
#
# evaluating THB
# new loss function value: 148423.37783083392
#
# evaluating GBP
# new loss function value: 148844.59799098692
#
# evaluating JPY
# new loss function value: 147215.5684671395
#
# evaluating HUF
# new loss function value: 145844.7285456512
#
# evaluating CAD
# new loss function value: 148837.22579296524
#
# evaluating HKD
# new loss function value: 148760.2570556347
#
# evaluating MYR
# new loss function value: 148814.12712404705
#
# evaluating USD
# new loss function value: 148839.9259043634
#
# evaluating CHF
# new loss function value: 148837.86436479178
#
# evaluating EUR
# new loss function value: 148844.34486822714
#
# evaluating CNY
# new loss function value: 148768.67051414156
#
# evaluating NZD
# new loss function value: 148829.99458293835
#
# evaluating AUD
# new loss function value: 148835.39485098465
#
# evaluating SEK
# new loss function value: 148762.71451343963
#
# evaluating RUB
# new loss function value: 148542.29966692533
#
# evaluating CZK
# new loss function value: 148613.12533151105
#
# evaluating PLN
# new loss function value: 148808.87698931832
#
# evaluating RON
# new loss function value: 148816.68141760238
#
# evaluating PHP
# new loss function value: 148283.47015382358
#
# evaluating ZAR
# new loss function value: 148718.9117570296
#
# IDR is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 23172.962980856497
#
# evaluating HRK
# new loss function value: 24040.714312218115
#
# evaluating KRW
# new loss function value: 7301.372640491479
# better solution found by excluding KRW
# loss function decreased by 68.49% compared to current best solution
#
# evaluating DKK
# new loss function value: 24041.891630564576
#
# evaluating SGD
# new loss function value: 24084.6197160394
#
# evaluating TRY
# new loss function value: 24077.09075667737
#
# evaluating NOK
# new loss function value: 24019.91074003843
#
# evaluating THB
# new loss function value: 23654.292627816772
#
# evaluating GBP
# new loss function value: 24092.361594375907
#
# evaluating JPY
# new loss function value: 22398.170889574576
#
# evaluating HUF
# new loss function value: 20972.49737122673
#
# evaluating CAD
# new loss function value: 24084.694508433375
#
# evaluating HKD
# new loss function value: 24004.64702160961
#
# evaluating MYR
# new loss function value: 24060.67189275847
#
# evaluating USD
# new loss function value: 24087.502624287445
#
# evaluating CHF
# new loss function value: 24085.35862313295
#
# evaluating EUR
# new loss function value: 24092.09834670576
#
# evaluating CNY
# new loss function value: 24013.39701845672
#
# evaluating NZD
# new loss function value: 24077.174050005426
#
# evaluating AUD
# new loss function value: 24082.790328773517
#
# evaluating SEK
# new loss function value: 24007.202777726747
#
# evaluating RUB
# new loss function value: 23777.97133735185
#
# evaluating CZK
# new loss function value: 23851.630028520976
#
# evaluating PLN
# new loss function value: 24055.211752640567
#
# evaluating RON
# new loss function value: 24063.328358055966
#
# evaluating PHP
# new loss function value: 23508.78864372604
#
# evaluating ZAR
# new loss function value: 23961.647911060292
#
# KRW is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 7301.372640491479
#
# evaluating HRK
# new loss function value: 7543.964013144614
#
# evaluating DKK
# new loss function value: 7545.190386422184
#
# evaluating SGD
# new loss function value: 7589.69880879179
#
# evaluating TRY
# new loss function value: 7581.856142789668
#
# evaluating NOK
# new loss function value: 7522.293625457443
#
# evaluating THB
# new loss function value: 7141.441425226549
# better solution found by excluding THB
# loss function decreased by 2.19% compared to current best solution
#
# evaluating GBP
# new loss function value: 7597.763265392313
#
# evaluating JPY
# new loss function value: 5832.981281224269
# better solution found by excluding JPY
# loss function decreased by 18.32% compared to current best solution
#
# evaluating HUF
# new loss function value: 4347.904699611918
# better solution found by excluding HUF
# loss function decreased by 25.46% compared to current best solution
#
# evaluating CAD
# new loss function value: 7589.776717535518
#
# evaluating HKD
# new loss function value: 7506.393918760753
#
# evaluating MYR
# new loss function value: 7564.753159540818
#
# evaluating USD
# new loss function value: 7592.701838216834
#
# evaluating CHF
# new loss function value: 7590.4685036809005
#
# evaluating EUR
# new loss function value: 7597.48904906925
#
# evaluating CNY
# new loss function value: 7515.508498809831
#
# evaluating NZD
# new loss function value: 7581.942906673058
#
# evaluating AUD
# new loss function value: 7587.793197056489
#
# evaluating SEK
# new loss function value: 7509.0561647161
#
# evaluating RUB
# new loss function value: 7270.273414325595
#
# evaluating CZK
# new loss function value: 7347.00121762676
#
# evaluating PLN
# new loss function value: 7559.06551358467
#
# evaluating RON
# new loss function value: 7567.520310892374
#
# evaluating PHP
# new loss function value: 6989.874775132039
#
# evaluating ZAR
# new loss function value: 7461.603178605213
#
# HUF is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 4347.904699611918
#
# evaluating HRK
# new loss function value: 4472.6318736465155
#
# evaluating DKK
# new loss function value: 4473.91156750137
#
# evaluating SGD
# new loss function value: 4520.355138669654
#
# evaluating TRY
# new loss function value: 4512.17148718918
#
# evaluating NOK
# new loss function value: 4450.0192951903355
#
# evaluating THB
# new loss function value: 4052.608303645055
# better solution found by excluding THB
# loss function decreased by 6.79% compared to current best solution
#
# evaluating GBP
# new loss function value: 4528.770223818026
#
# evaluating JPY
# new loss function value: 2687.258588164414
# better solution found by excluding JPY
# loss function decreased by 33.69% compared to current best solution
#
# evaluating CAD
# new loss function value: 4520.436434750066
#
# evaluating HKD
# new loss function value: 4433.428296898136
#
# evaluating MYR
# new loss function value: 4494.324895972988
#
# evaluating USD
# new loss function value: 4523.48873459144
#
# evaluating CHF
# new loss function value: 4521.158298553944
#
# evaluating EUR
# new loss function value: 4528.484085046132
#
# evaluating CNY
# new loss function value: 4442.939163036304
#
# evaluating NZD
# new loss function value: 4512.2620234153255
#
# evaluating AUD
# new loss function value: 4518.366674250211
#
# evaluating SEK
# new loss function value: 4436.20629267763
#
# evaluating RUB
# new loss function value: 4187.041683574495
#
# evaluating CZK
# new loss function value: 4267.105478323538
#
# evaluating PLN
# new loss function value: 4488.389961062227
#
# evaluating RON
# new loss function value: 4497.212358252873
#
# evaluating PHP
# new loss function value: 3894.4517991986113
#
# evaluating ZAR
# new loss function value: 4386.690133257573
#
# JPY is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 2687.258588164414
#
# evaluating HRK
# new loss function value: 2742.171265043879
#
# evaluating DKK
# new loss function value: 2743.509126801227
#
# evaluating SGD
# new loss function value: 2792.0637693862504
#
# evaluating TRY
# new loss function value: 2783.5081337475735
#
# evaluating NOK
# new loss function value: 2718.530842112418
#
# evaluating THB
# new loss function value: 2303.0557145878065
# better solution found by excluding THB
# loss function decreased by 14.30% compared to current best solution
#
# evaluating GBP
# new loss function value: 2800.861358405004
#
# evaluating CAD
# new loss function value: 2792.1487607430445
#
# evaluating HKD
# new loss function value: 2701.1857075342105
#
# evaluating MYR
# new loss function value: 2764.850333839737
#
# evaluating USD
# new loss function value: 2795.3398014862996
#
# evaluating CHF
# new loss function value: 2792.9034365380085
#
# evaluating EUR
# new loss function value: 2800.5622133252964
#
# evaluating CNY
# new loss function value: 2711.128885769567
#
# evaluating NZD
# new loss function value: 2783.6027852567245
#
# evaluating AUD
# new loss function value: 2789.9849202204696
#
# evaluating SEK
# new loss function value: 2704.0899758491337
#
# evaluating RUB
# new loss function value: 2443.5997026958585
#
# evaluating CZK
# new loss function value: 2527.3027608425828
#
# evaluating PLN
# new loss function value: 2758.6456291603035
#
# evaluating RON
# new loss function value: 2767.8690444050703
#
# evaluating PHP
# new loss function value: 2137.7102781210697
# better solution found by excluding PHP
# loss function decreased by 7.18% compared to current best solution
#
# evaluating ZAR
# new loss function value: 2652.3230819099845
#
# PHP is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 2137.7102781210697
#
# evaluating HRK
# new loss function value: 2169.068877230825
#
# evaluating DKK
# new loss function value: 2170.470446690904
#
# evaluating SGD
# new loss function value: 2221.33721511331
#
# evaluating TRY
# new loss function value: 2212.374168253743
#
# evaluating NOK
# new loss function value: 2144.3027198740565
#
# evaluating THB
# new loss function value: 1709.0430624673213
# better solution found by excluding THB
# loss function decreased by 20.05% compared to current best solution
#
# evaluating GBP
# new loss function value: 2230.55373694248
#
# evaluating CAD
# new loss function value: 2221.42625367757
#
# evaluating HKD
# new loss function value: 2126.131626506411
#
# evaluating MYR
# new loss function value: 2192.8279016836286
#
# evaluating USD
# new loss function value: 2224.769248741933
#
# evaluating CHF
# new loss function value: 2222.2168664151504
#
# evaluating EUR
# new loss function value: 2230.2403468589773
#
# evaluating CNY
# new loss function value: 2136.548289419642
#
# evaluating NZD
# new loss function value: 2212.4733269776157
#
# evaluating AUD
# new loss function value: 2219.1593731301105
#
# evaluating SEK
# new loss function value: 2129.1741933125213
#
# evaluating RUB
# new loss function value: 1856.2796214376608
#
# evaluating CZK
# new loss function value: 1943.968539496134
#
# evaluating PLN
# new loss function value: 2186.3277348766037
#
# evaluating RON
# new loss function value: 2195.9903603711205
#
# evaluating ZAR
# new loss function value: 2074.9422091857928
#
# THB is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 1709.0430624673213
#
# evaluating HRK
# new loss function value: 1720.5362307498776
#
# evaluating DKK
# new loss function value: 1722.0078786829602
#
# evaluating SGD
# new loss function value: 1775.4179855264867
#
# evaluating TRY
# new loss function value: 1766.0067863239426
#
# evaluating NOK
# new loss function value: 1694.5317655252707
# better solution found by excluding NOK
# loss function decreased by 0.85% compared to current best solution
#
# evaluating GBP
# new loss function value: 1785.0953334471158
#
# evaluating CAD
# new loss function value: 1775.5114760189606
#
# evaluating HKD
# new loss function value: 1675.4521174892434
# better solution found by excluding HKD
# loss function decreased by 1.13% compared to current best solution
#
# evaluating MYR
# new loss function value: 1745.4832064253214
#
# evaluating USD
# new loss function value: 1779.0216208365412
#
# evaluating CHF
# new loss function value: 1776.3416193934197
#
# evaluating EUR
# new loss function value: 1784.766273859437
#
# evaluating CNY
# new loss function value: 1686.3896135481355
#
# evaluating NZD
# new loss function value: 1766.1109029840081
#
# evaluating AUD
# new loss function value: 1773.1312514441272
#
# evaluating SEK
# new loss function value: 1678.6468126356588
#
# evaluating RUB
# new loss function value: 1392.1075121670556
# better solution found by excluding RUB
# loss function decreased by 16.91% compared to current best solution
#
# evaluating CZK
# new loss function value: 1484.1808761284526
#
# evaluating PLN
# new loss function value: 1738.6580312779458
#
# evaluating RON
# new loss function value: 1748.8037880471877
#
# evaluating ZAR
# new loss function value: 1621.7032293025943
#
# RUB is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 1392.1075121670556
#
# evaluating HRK
# new loss function value: 1387.5247656065753
#
# evaluating DKK
# new loss function value: 1389.0738686940304
#
# evaluating SGD
# new loss function value: 1445.2950337924785
#
# evaluating TRY
# new loss function value: 1435.388508316117
#
# evaluating NOK
# new loss function value: 1360.1516443175153
# better solution found by excluding NOK
# loss function decreased by 2.30% compared to current best solution
#
# evaluating GBP
# new loss function value: 1455.481715814194
#
# evaluating CAD
# new loss function value: 1445.3934448371883
#
# evaluating HKD
# new loss function value: 1340.0678042795912
# better solution found by excluding HKD
# loss function decreased by 1.48% compared to current best solution
#
# evaluating MYR
# new loss function value: 1413.784740001779
#
# evaluating USD
# new loss function value: 1449.0883341188521
#
# evaluating CHF
# new loss function value: 1446.267279968198
#
# evaluating EUR
# new loss function value: 1455.1353373008476
#
# evaluating CNY
# new loss function value: 1351.5809580257942
#
# evaluating NZD
# new loss function value: 1435.4981048003965
#
# evaluating AUD
# new loss function value: 1442.8879452847327
#
# evaluating SEK
# new loss function value: 1343.4306412758183
#
# evaluating CZK
# new loss function value: 1138.7296554787588
# better solution found by excluding CZK
# loss function decreased by 15.02% compared to current best solution
#
# evaluating PLN
# new loss function value: 1406.600345109804
#
# evaluating RON
# new loss function value: 1417.2800890774279
#
# evaluating ZAR
# new loss function value: 1283.4900272410127
#
# CZK is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 1138.7296554787588
#
# evaluating HRK
# new loss function value: 1119.8157642933463
# better solution found by excluding HRK
# loss function decreased by 1.66% compared to current best solution
#
# evaluating DKK
# new loss function value: 1121.4509286634377
#
# evaluating SGD
# new loss function value: 1180.795491822911
#
# evaluating TRY
# new loss function value: 1170.3386038200845
#
# evaluating NOK
# new loss function value: 1090.9219140437829
# better solution found by excluding NOK
# loss function decreased by 2.58% compared to current best solution
#
# evaluating GBP
# new loss function value: 1191.5481006236105
#
# evaluating CAD
# new loss function value: 1180.8993701478828
#
# evaluating HKD
# new loss function value: 1069.7223051148628
# better solution found by excluding HKD
# loss function decreased by 1.94% compared to current best solution
#
# evaluating MYR
# new loss function value: 1147.5346261549498
#
# evaluating USD
# new loss function value: 1184.799531056305
#
# evaluating CHF
# new loss function value: 1181.8217516750587
#
# evaluating EUR
# new loss function value: 1191.1824788595231
#
# evaluating CNY
# new loss function value: 1081.8750785136326
#
# evaluating NZD
# new loss function value: 1170.4542889979357
#
# evaluating AUD
# new loss function value: 1178.2546761758458
#
# evaluating SEK
# new loss function value: 1073.271966388658
#
# evaluating PLN
# new loss function value: 1139.9510982134213
#
# evaluating RON
# new loss function value: 1151.2241612903574
#
# evaluating ZAR
# new loss function value: 1010.0013182408086
# better solution found by excluding ZAR
# loss function decreased by 5.58% compared to current best solution
#
# ZAR is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 1010.0013182408086
#
# evaluating HRK
# new loss function value: 982.402590089316
# better solution found by excluding HRK
# loss function decreased by 2.73% compared to current best solution
#
# evaluating DKK
# new loss function value: 984.1339405988252
#
# evaluating SGD
# new loss function value: 1046.9693604147374
#
# evaluating TRY
# new loss function value: 1035.8973613529213
#
# evaluating NOK
# new loss function value: 951.8091015897784
# better solution found by excluding NOK
# loss function decreased by 3.11% compared to current best solution
#
# evaluating GBP
# new loss function value: 1058.3544756154786
#
# evaluating CAD
# new loss function value: 1047.0793492294133
#
# evaluating HKD
# new loss function value: 929.3624568415104
# better solution found by excluding HKD
# loss function decreased by 2.36% compared to current best solution
#
# evaluating MYR
# new loss function value: 1011.7519732368963
#
# evaluating USD
# new loss function value: 1051.2089313677434
#
# evaluating CHF
# new loss function value: 1048.0559884934826
#
# evaluating EUR
# new loss function value: 1057.967346688798
#
# evaluating CNY
# new loss function value: 942.2300992637367
#
# evaluating NZD
# new loss function value: 1036.0198515412344
#
# evaluating AUD
# new loss function value: 1044.2790850237272
#
# evaluating SEK
# new loss function value: 933.120921719646
#
# evaluating PLN
# new loss function value: 1003.7223554164543
#
# evaluating RON
# new loss function value: 1015.6585398508572
#
# HKD is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 929.3624568415104
#
# evaluating HRK
# new loss function value: 894.9988793430933
# better solution found by excluding HRK
# loss function decreased by 3.70% compared to current best solution
#
# evaluating DKK
# new loss function value: 896.8384392594462
#
# evaluating SGD
# new loss function value: 963.6010728138534
#
# evaluating TRY
# new loss function value: 951.8370738106738
#
# evaluating NOK
# new loss function value: 862.4932978123345
# better solution found by excluding NOK
# loss function decreased by 3.63% compared to current best solution
#
# evaluating GBP
# new loss function value: 975.6977577146405
#
# evaluating CAD
# new loss function value: 963.7179359294468
#
# evaluating MYR
# new loss function value: 926.1825989373976
#
# evaluating USD
# new loss function value: 968.1056169514225
#
# evaluating CHF
# new loss function value: 964.7556151475203
#
# evaluating EUR
# new loss function value: 975.2864332300425
#
# evaluating CNY
# new loss function value: 852.3156078409153
# better solution found by excluding CNY
# loss function decreased by 1.18% compared to current best solution
#
# evaluating NZD
# new loss function value: 951.9672196357562
#
# evaluating AUD
# new loss function value: 960.742655210905
#
# evaluating SEK
# new loss function value: 842.6371067003192
# better solution found by excluding SEK
# loss function decreased by 1.14% compared to current best solution
#
# evaluating PLN
# new loss function value: 917.6511300031777
#
# evaluating RON
# new loss function value: 930.3333259647308
#
# SEK is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 842.6371067003192
#
# evaluating HRK
# new loss function value: 800.2009340259278
# better solution found by excluding HRK
# loss function decreased by 5.04% compared to current best solution
#
# evaluating DKK
# new loss function value: 802.1631312700381
#
# evaluating SGD
# new loss function value: 873.3766070614058
#
# evaluating TRY
# new loss function value: 860.828341458014
#
# evaluating NOK
# new loss function value: 765.5283137264521
# better solution found by excluding NOK
# loss function decreased by 4.33% compared to current best solution
#
# evaluating GBP
# new loss function value: 886.2797376222454
#
# evaluating CAD
# new loss function value: 873.5012610513718
#
# evaluating MYR
# new loss function value: 833.4635682598528
#
# evaluating USD
# new loss function value: 878.1814541414791
#
# evaluating CHF
# new loss function value: 874.6081188839836
#
# evaluating EUR
# new loss function value: 885.8409915053408
#
# evaluating CNY
# new loss function value: 754.6721110902716
# better solution found by excluding CNY
# loss function decreased by 1.42% compared to current best solution
#
# evaluating NZD
# new loss function value: 860.9671636714352
#
# evaluating AUD
# new loss function value: 870.3276282849276
#
# evaluating PLN
# new loss function value: 824.3633347300186
#
# evaluating RON
# new loss function value: 837.8910104223417
#
# CNY is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 754.6721110902716
#
# evaluating HRK
# new loss function value: 702.9215692527065
# better solution found by excluding HRK
# loss function decreased by 6.86% compared to current best solution
#
# evaluating DKK
# new loss function value: 705.0239234428242
#
# evaluating SGD
# new loss function value: 781.3240760764326
#
# evaluating TRY
# new loss function value: 767.8795057870844
#
# evaluating NOK
# new loss function value: 665.7723332175538
# better solution found by excluding NOK
# loss function decreased by 5.28% compared to current best solution
#
# evaluating GBP
# new loss function value: 795.148858820189
#
# evaluating CAD
# new loss function value: 781.4576339228246
#
# evaluating MYR
# new loss function value: 738.5601059319114
#
# evaluating USD
# new loss function value: 786.4721265193682
#
# evaluating CHF
# new loss function value: 782.6435530291944
#
# evaluating EUR
# new loss function value: 794.6787736949341
#
# evaluating NZD
# new loss function value: 768.0282438728927
#
# evaluating AUD
# new loss function value: 778.0573131016343
#
# evaluating PLN
# new loss function value: 728.8098557213747
#
# evaluating RON
# new loss function value: 743.3037939631495
#
# NOK is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 665.7723332175538
#
# evaluating HRK
# new loss function value: 603.202536017659
# better solution found by excluding HRK
# loss function decreased by 9.40% compared to current best solution
#
# evaluating DKK
# new loss function value: 605.466609760863
#
# evaluating SGD
# new loss function value: 687.6360049047488
#
# evaluating TRY
# new loss function value: 673.1572369008354
#
# evaluating GBP
# new loss function value: 702.524232474948
#
# evaluating CAD
# new loss function value: 687.7798364316324
#
# evaluating MYR
# new loss function value: 641.5824985952643
#
# evaluating USD
# new loss function value: 693.1800592279101
#
# evaluating CHF
# new loss function value: 689.0569800846462
#
# evaluating EUR
# new loss function value: 702.0179869554428
#
# evaluating NZD
# new loss function value: 673.3174163778598
#
# evaluating AUD
# new loss function value: 684.1179524703506
#
# evaluating PLN
# new loss function value: 631.0822291377634
#
# evaluating RON
# new loss function value: 646.6910857058284
#
# HRK is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 603.202536017659
#
# evaluating DKK
# new loss function value: 532.6571858395858
# better solution found by excluding DKK
# loss function decreased by 11.70% compared to current best solution
#
# evaluating SGD
# new loss function value: 621.6740305787955
#
# evaluating TRY
# new loss function value: 605.9886985745561
#
# evaluating GBP
# new loss function value: 637.8029437798449
#
# evaluating CAD
# new loss function value: 621.8298480662528
#
# evaluating MYR
# new loss function value: 571.7827320768541
#
# evaluating USD
# new loss function value: 627.680089428887
#
# evaluating CHF
# new loss function value: 623.2134203570176
#
# evaluating EUR
# new loss function value: 637.2545111337141
#
# evaluating NZD
# new loss function value: 606.1622263413325
#
# evaluating AUD
# new loss function value: 617.8628071081974
#
# evaluating PLN
# new loss function value: 560.4074401645615
#
# evaluating RON
# new loss function value: 577.3170347799653
#
# DKK is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 532.6571858395858
#
# evaluating SGD
# new loss function value: 546.3946935264556
#
# evaluating TRY
# new loss function value: 529.2834222491036
# better solution found by excluding TRY
# loss function decreased by 0.63% compared to current best solution
#
# evaluating GBP
# new loss function value: 563.989871563964
#
# evaluating CAD
# new loss function value: 546.5646762400455
#
# evaluating MYR
# new loss function value: 491.96782243342886
# better solution found by excluding MYR
# loss function decreased by 7.05% compared to current best solution
#
# evaluating USD
# new loss function value: 552.9467577265555
#
# evaluating CHF
# new loss function value: 548.0740278299709
#
# evaluating EUR
# new loss function value: 563.3915814045488
#
# evaluating NZD
# new loss function value: 529.472725267405
#
# evaluating AUD
# new loss function value: 542.2369951948943
#
# evaluating PLN
# new loss function value: 479.55841307456416
# better solution found by excluding PLN
# loss function decreased by 2.52% compared to current best solution
#
# evaluating RON
# new loss function value: 498.0052435640954
#
# PLN is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 479.55841307456416
#
# evaluating SGD
# new loss function value: 489.3597942536186
#
# evaluating TRY
# new loss function value: 470.53739584853116
# better solution found by excluding TRY
# loss function decreased by 1.88% compared to current best solution
#
# evaluating GBP
# new loss function value: 508.71449009487776
#
# evaluating CAD
# new loss function value: 489.5467752385673
#
# evaluating MYR
# new loss function value: 429.4902360512889
# better solution found by excluding MYR
# loss function decreased by 8.72% compared to current best solution
#
# evaluating USD
# new loss function value: 496.5670648737283
#
# evaluating CHF
# new loss function value: 491.2070619874852
#
# evaluating EUR
# new loss function value: 508.056370919521
#
# evaluating NZD
# new loss function value: 470.7456291686629
#
# evaluating AUD
# new loss function value: 484.7863260889009
#
# evaluating RON
# new loss function value: 436.1313992950221
#
# MYR is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 429.4902360512889
#
# evaluating SGD
# new loss function value: 434.81752880320784
#
# evaluating TRY
# new loss function value: 413.9037527975552
# better solution found by excluding TRY
# loss function decreased by 3.63% compared to current best solution
#
# evaluating GBP
# new loss function value: 456.32274640460696
#
# evaluating CAD
# new loss function value: 435.025285453151
#
# evaluating USD
# new loss function value: 442.82560726999645
#
# evaluating CHF
# new loss function value: 436.8700485075042
#
# evaluating EUR
# new loss function value: 455.59150287643257
#
# evaluating NZD
# new loss function value: 414.135123153257
#
# evaluating AUD
# new loss function value: 429.73589750907735
#
# evaluating RON
# new loss function value: 375.6748677381007
# better solution found by excluding RON
# loss function decreased by 9.24% compared to current best solution
#
# RON is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 375.6748677381007
#
# evaluating SGD
# new loss function value: 374.94115104486104
#
# evaluating TRY
# new loss function value: 351.413153038502
# better solution found by excluding TRY
# loss function decreased by 6.46% compared to current best solution
#
# evaluating GBP
# new loss function value: 399.13452084643507
#
# evaluating CAD
# new loss function value: 375.174877276047
#
# evaluating USD
# new loss function value: 383.95023931999833
#
# evaluating CHF
# new loss function value: 377.25023571219435
#
# evaluating EUR
# new loss function value: 398.3118718772389
#
# evaluating NZD
# new loss function value: 351.6734446886664
#
# evaluating AUD
# new loss function value: 369.22431583896406
#
# TRY is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 351.413153038502
#
# evaluating SGD
# new loss function value: 347.1086604319994
# better solution found by excluding SGD
# loss function decreased by 1.22% compared to current best solution
#
# evaluating GBP
# new loss function value: 374.7582259195126
#
# evaluating CAD
# new loss function value: 347.3757761247834
#
# evaluating USD
# new loss function value: 357.4047613178706
#
# evaluating CHF
# new loss function value: 349.74761433752326
#
# evaluating EUR
# new loss function value: 373.81805566900266
#
# evaluating NZD
# new loss function value: 320.5169960249199
# better solution found by excluding NZD
# loss function decreased by 7.66% compared to current best solution
#
# evaluating AUD
# new loss function value: 340.5751344824029
#
# NZD is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 320.5169960249199
#
# evaluating SGD
# new loss function value: 310.3457284817366
# better solution found by excluding SGD
# loss function decreased by 3.17% compared to current best solution
#
# evaluating GBP
# new loss function value: 342.60355488383544
#
# evaluating CAD
# new loss function value: 310.6573634566514
#
# evaluating USD
# new loss function value: 322.3578461819197
#
# evaluating CHF
# new loss function value: 313.42450803818116
#
# evaluating EUR
# new loss function value: 341.50668959157395
#
# evaluating AUD
# new loss function value: 302.7232815405408
# better solution found by excluding AUD
# loss function decreased by 2.46% compared to current best solution
#
# AUD is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 302.7232815405408
#
# evaluating SGD
# new loss function value: 286.9590175918452
# better solution found by excluding SGD
# loss function decreased by 5.21% compared to current best solution
#
# evaluating GBP
# new loss function value: 325.66840927436385
#
# evaluating CAD
# new loss function value: 287.33297956174295
#
# evaluating USD
# new loss function value: 301.3735588320649
#
# evaluating CHF
# new loss function value: 290.65355305957854
#
# evaluating EUR
# new loss function value: 324.35217092364996
#
# SGD is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 286.9590175918452
#
# evaluating GBP
# new loss function value: 311.69936127194984
#
# evaluating CAD
# new loss function value: 263.7800741311738
# better solution found by excluding CAD
# loss function decreased by 8.08% compared to current best solution
#
# evaluating USD
# new loss function value: 281.3307982190762
#
# evaluating CHF
# new loss function value: 267.9307910034684
#
# evaluating EUR
# new loss function value: 310.0540633335576
#
# CAD is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 263.7800741311738
#
# evaluating GBP
# new loss function value: 289.0408845510895
#
# evaluating USD
# new loss function value: 248.54946714725799
# better solution found by excluding USD
# loss function decreased by 5.77% compared to current best solution
#
# evaluating CHF
# new loss function value: 230.68279085978085
# better solution found by excluding CHF
# loss function decreased by 7.19% compared to current best solution
#
# evaluating EUR
# new loss function value: 286.8471539665666
#
# CHF is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 230.68279085978085
#
# evaluating GBP
# new loss function value: 252.0253648539581
#
# evaluating USD
# new loss function value: 191.2882387482108
# better solution found by excluding USD
# loss function decreased by 17.08% compared to current best solution
#
# evaluating EUR
# new loss function value: 248.7347689771737
#
# USD is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 191.2882387482108
#
# evaluating GBP
# new loss function value: 194.57883462499527
#
# evaluating EUR
# new loss function value: 187.99764287142642
# better solution found by excluding EUR
# loss function decreased by 1.72% compared to current best solution
#
# EUR is removed from currency set
#
# --------- new iteration ---------
#
# starting loss function value: 187.99764287142642
#
# evaluating GBP
# new loss function value: 0.0
# better solution found by excluding GBP
# loss function decreased by 100.00% compared to current best solution
#
# GBP is removed from currency set
#
# --------- new iteration ---------

# %%
# TODO: Different steps for creating new weights
new_weights[new_weights>0] = (1-possible_weights_included_currency[0])/(no_currencies-1)
new_weights[included_currency] = possible_weights_included_currency[0]
new_weights
# Out:
# IDR    0.00
# HRK    0.00
# KRW    0.00
# DKK    0.00
# SGD    0.00
# TRY    0.00
# NOK    0.00
# THB    0.00
# GBP    0.95
# JPY    0.00
# HUF    0.00
# CAD    0.00
# HKD    0.00
# MYR    0.00
# USD    0.00
# CHF    0.00
# EUR    0.05
# CNY    0.00
# NZD    0.00
# AUD    0.00
# SEK    0.00
# RUB    0.00
# CZK    0.00
# PLN    0.00
# RON    0.00
# PHP    0.00
# ZAR    0.00
# dtype: float64

# %%
no_currencies = (new_weights>0).sum()
possible_weights_included_currency = np.arange(0, 1/no_currencies, 1/no_currencies/10) + 1/no_currencies/10
possible_weights_included_currency
for possible_weight in possible_weights_included_currency:
    new_weights[new_weights>0] = (1-possible_weight)/(no_currencies-1)
    new_weights[included_currency] = possible_weight
# Out:
# 0.05
# others have weight: 0.95
#
# 0.1
# others have weight: 0.9
#
# 0.15000000000000002
# others have weight: 0.85
#
# 0.2
# others have weight: 0.8
#
# 0.25
# others have weight: 0.75
#
# 0.3
# others have weight: 0.7
#
# 0.35000000000000003
# others have weight: 0.6499999999999999
#
# 0.4
# others have weight: 0.6
#
# 0.45
# others have weight: 0.55
#
# 0.5
# others have weight: 0.5

# %%
def evaluate_inclusion_of_currency(weights, 
                                   currency_set):
    """Perform forward selection of currencies.
   
    Parameters
    ----------
    weights : array
        The initial weights given to all currencies.
    currency_set : set
        The set containing all currencies of interest."""

    # Initialize string giving best currency to exclude
    best_to_include = "None"
    # Calculate initial loss function value
    starting_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(weights)

    # So far, this is the best solution
    best_loss_function_value = starting_loss_function_value
    print(f"starting loss function value: {best_loss_function_value}")

    # Each time we include one currency
    for included_currency in currency_set:
        print(f"\nincluding {included_currency}")

        # We create the new weights,
        new_weights = weights.copy()
        new_weights[new_weights.index==included_currency] = 1
        new_weights = recalculate_weights(new_weights)

        # and calculate the new loss function value
        new_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(new_weights)
        print(f"new loss function value: {new_loss_function_value}")
        
        # TODO: Check boundaries
        # Check whether the new loss function value is lower than the (so far) best one, and
        # the improvement needs to be > .5%
        if new_loss_function_value <= 1.05*best_loss_function_value and new_loss_function_value < 1.05*starting_loss_function_value:
            print(f"\nbetter solution found by including {included_currency}")
            print(f"loss function decreased by {(best_loss_function_value-new_loss_function_value)/best_loss_function_value*100:.2f}% compared to current best solution\n")
            # If so, save these results
            best_loss_function_value = new_loss_function_value
            best_to_include = included_currency
        print("")

    if best_to_include == "None":
        print("No currency needed to be included.")
    else:
        print(f"{best_to_include} is added to currency set\n")
        # Exclude the currency
        currency_set.remove(best_to_include)
    return starting_loss_function_value, best_loss_function_value, best_to_include, currency_set

# %%
# Create weights series and specificy first currency to include
weights = pd.Series(0, index=reference_date_exhange_rate.loc[all_currencies].index)
first_currency = "GBP"
weights[first_currency] = 1
currency_set = set(all_currencies)
currency_set.remove(first_currency)

# Set maximum number of currencies to include
max_currencies_to_include = 14

for i in range(0, max_currencies_to_include):
    _, _, best_to_include, currencies = evaluate_inclusion_of_currency(weights, currency_set)
    if best_to_include == "None":
        break
    weights[weights.index==best_to_include] = 0
    weights = recalculate_weights(weights)
# Out:
# starting loss function value: 187.99764287142642
#
# including IDR
# new loss function value: 1633919.2527745673
#
# including HRK
# new loss function value: 833.5886698438062
#
# including KRW
# new loss function value: 210075.35956642678
#
# including DKK
# new loss function value: 818.8721905129803
#
# including SGD
# new loss function value: 284.7711220777229
#
# including TRY
# new loss function value: 378.88311410315947
#
# including NOK
# new loss function value: 1093.633322089875
#
# including THB
# new loss function value: 5663.859724860598
#
# including JPY
# new loss function value: 21365.38145288797
#
# including HUF
# new loss function value: 39186.30043223617
#
# including CAD
# new loss function value: 283.8362171529786
#
# including HKD
# new loss function value: 1284.4298024501534
#
# including MYR
# new loss function value: 584.1189130893704
#
# including USD
# new loss function value: 248.7347689771737
#
# including CHF
# new loss function value: 275.53478340838944
#
# including EUR
# new loss function value: 191.2882387482108
#
# better solution found by including EUR
# loss function decreased by -1.75% compared to current best solution
#
# including CNY
# new loss function value: 1175.0548418612282
#
# including NZD
# new loss function value: 377.841947502501
#
# including AUD
# new loss function value: 307.63846290131016
#
# including SEK
# new loss function value: 1252.4828509859979
#
# including RUB
# new loss function value: 4117.875855672031
#
# including CZK
# new loss function value: 3197.142216058059
#
# including PLN
# new loss function value: 652.3706645631268
#
# including RON
# new loss function value: 550.9130968707044
#
# including PHP
# new loss function value: 7482.659525994711
#
# including ZAR
# new loss function value: 1821.9186843166435
#
# EUR is added to currency set
#
# starting loss function value: 187.99764287142642
#
# including IDR
# new loss function value: 1633919.2527745673
#
# including HRK
# new loss function value: 833.5886698438062
#
# including KRW
# new loss function value: 210075.35956642678
#
# including DKK
# new loss function value: 818.8721905129803
#
# including SGD
# new loss function value: 284.7711220777229
#
# including TRY
# new loss function value: 378.88311410315947
#
# including NOK
# new loss function value: 1093.633322089875
#
# including THB
# new loss function value: 5663.859724860598
#
# including JPY
# new loss function value: 21365.38145288797
#
# including HUF
# new loss function value: 39186.30043223617
#
# including CAD
# new loss function value: 283.8362171529786
#
# including HKD
# new loss function value: 1284.4298024501534
#
# including MYR
# new loss function value: 584.1189130893704
#
# including USD
# new loss function value: 248.7347689771737
#
# including CHF
# new loss function value: 275.53478340838944
#
# including CNY
# new loss function value: 1175.0548418612282
#
# including NZD
# new loss function value: 377.841947502501
#
# including AUD
# new loss function value: 307.63846290131016
#
# including SEK
# new loss function value: 1252.4828509859979
#
# including RUB
# new loss function value: 4117.875855672031
#
# including CZK
# new loss function value: 3197.142216058059
#
# including PLN
# new loss function value: 652.3706645631268
#
# including RON
# new loss function value: 550.9130968707044
#
# including PHP
# new loss function value: 7482.659525994711
#
# including ZAR
# new loss function value: 1821.9186843166435
#
# No currency needed to be included.

# %%
def evaluate_inclusion_of_currency_difference_weights(weights, 
                                                      currency_set):
    """Perform forward selection of currencies.
   
    Parameters
    ----------
    weights : array
        The initial weights given to all currencies.
    currency_set : set
        The set containing all currencies of interest."""

    # Initialize string giving best currency to exclude
    best_to_include = "None"
    # Initialize string giving best currency weights
    best_weights = weights.copy()
    # Calculate initial loss function value
    starting_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(weights)

    # So far, this is the best solution
    best_loss_function_value = starting_loss_function_value
    print(f"starting loss function value: {best_loss_function_value}")

    # Each time we include one currency
    for included_currency in currency_set:
        print(f"\nincluding {included_currency}\n")
        
        new_weights = weights.copy()
        no_currencies = (new_weights>0).sum()+1
        possible_weights_included_currency = np.arange(0, 1/no_currencies, 1/no_currencies/10) + 1/no_currencies/10
        
        for possible_weight in possible_weights_included_currency:
            new_weights[new_weights>0] = (1-possible_weight)/(no_currencies-1)
            new_weights[included_currency] = possible_weight
        
            # We create the new weights,
#             new_weights = weights.copy()
#             new_weights[new_weights.index==included_currency] = 1
#             new_weights = recalculate_weights(new_weights)

            # and calculate the new loss function value
            new_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(new_weights)
            print(f"weight {included_currency}: {possible_weight}")
            print(f"other weight(s): {(1-possible_weight)/(no_currencies-1)}")
            print(f"new loss function value: {new_loss_function_value}\n")

            # TODO: Check boundaries
            # Check whether the new loss function value is lower than the (so far) best one, and
            # the improvement needs to be > .5%
            if new_loss_function_value <= 1.05*best_loss_function_value and new_loss_function_value < 1.05*starting_loss_function_value:
                print(f"\nbetter solution found by including {included_currency}")
                print(f"loss function decreased by {(best_loss_function_value-new_loss_function_value)/best_loss_function_value*100:.2f}% compared to current best solution\n")
                print(best_weights)
                # If so, save these results
                best_weights = new_weights
                best_loss_function_value = new_loss_function_value
                best_to_include = included_currency

    if best_to_include == "None":
        print("No currency needed to be included.")
    else:
        print(f"{best_to_include} is added to currency set\n")
        # Exclude the currency
        currency_set.remove(best_to_include)
    return starting_loss_function_value, best_loss_function_value, best_to_include, best_weights, currency_set

# %%
# Create weights series and specificy first currency to include
weights = pd.Series(0, index=reference_date_exhange_rate.loc[all_currencies].index)
first_currency = "GBP"
weights[first_currency] = 1
currency_set = set(all_currencies)
currency_set.remove(first_currency)

# Set maximum number of currencies to include
max_currencies_to_include = 14

for i in range(0, max_currencies_to_include):
    _, _, best_to_include, currencies = evaluate_inclusion_of_currency_difference_weights(weights, currency_set)
    if best_to_include == "None":
        break
    weights[weights.index==best_to_include] = 0
    weights = recalculate_weights(weights)
# Out:
# starting loss function value: 187.99764287142642
#
# including IDR
#
# weight IDR: 0.05
# other weight(s): 0.95
# new loss function value: 163561.12315604097
#
# weight IDR: 0.1
# other weight(s): 0.9
# new loss function value: 326934.24866921053
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-331-438bf7401020> in <module>
#      10
#      11 for i in range(0, max_currencies_to_include):
# ---> 12     _, _, best_to_include, currencies = evaluate_inclusion_of_currency_difference_weights(weights, currency_set)
#      13     if best_to_include == "None":
#      14         break
#
# <ipython-input-330-8c1c09a1f40d> in evaluate_inclusion_of_currency_difference_weights(weights, currency_set)
#      39
#      40             # and calculate the new loss function value
# ---> 41             new_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(new_weights)
#      42             print(f"weight {included_currency}: {possible_weight}")
#      43             print(f"other weight(s): {(1-possible_weight)/(no_currencies-1)}")
#
# <ipython-input-133-d0bd2e77019b> in calculate_loss_function_vs_t_minus_one_with_balancing(weights)
#       9
#      10     # Calculate the loss function per base currency, per month
# ---> 11     return sum([sum([(amounts_by_month[month] * diff_by_month[base_currency][month]).sum(axis=1).sum() for month in months])
#      12                 for base_currency in all_currencies])
#
# <ipython-input-133-d0bd2e77019b> in <listcomp>(.0)
#       9
#      10     # Calculate the loss function per base currency, per month
# ---> 11     return sum([sum([(amounts_by_month[month] * diff_by_month[base_currency][month]).sum(axis=1).sum() for month in months])
#      12                 for base_currency in all_currencies])
#
# <ipython-input-133-d0bd2e77019b> in <listcomp>(.0)
#       9
#      10     # Calculate the loss function per base currency, per month
# ---> 11     return sum([sum([(amounts_by_month[month] * diff_by_month[base_currency][month]).sum(axis=1).sum() for month in months])
#      12                 for base_currency in all_currencies])
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11420                 name, axis=axis, level=level, skipna=skipna, min_count=min_count
#   11421             )
# > 11422         return self._reduce(
#   11423             func,
#   11424             name=name,
#
# /usr/local/lib/python3.9/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4234                 )
#    4235             with np.errstate(all="ignore"):
# -> 4236                 return op(delegate, skipna=skipna, **kwds)
#    4237
#    4238     def _reindex_indexer(self, new_index, indexer, copy):
#
# /usr/local/lib/python3.9/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# /usr/local/lib/python3.9/site-packages/pandas/core/nanops.py in nansum(values, axis, skipna, min_count, mask)
#     499     3.0
#     500     """
# --> 501     values, mask, dtype, dtype_max, _ = _get_values(
#     502         values, skipna, fill_value=0, mask=mask
#     503     )
#
# /usr/local/lib/python3.9/site-packages/pandas/core/nanops.py in _get_values(values, skipna, fill_value, fill_value_typ, mask)
#     288     dtype = values.dtype
#     289
# --> 290     if needs_i8_conversion(values.dtype):
#     291         # changing timedelta64/datetime64 to int64 needs to happen after
#     292         #  finding `mask` above
#
# KeyboardInterrupt:

# %%
def get_libra_mix(reference_date_exhange_rate):
    result = pd.Series(np.zeros(len(reference_date_exhange_rate)), index=reference_date_exhange_rate.index)
    
    result["USD"] = .5
    result["EUR"] = .18
    result["JPY"] = .14
    result["GBP"] = .11
    result["SGD"] = .07
    
    return result

def get_sdr_mix(reference_date_exhange_rate):
    result = pd.Series(np.zeros(len(reference_date_exhange_rate)), index=reference_date_exhange_rate.index)
    
    result["USD"] = .4173
    result["EUR"] = .3093
    result["CNY"] = .1092
    result["JPY"] = .0833
    result["GBP"] = .0809
    
    return result

assert get_libra_mix(reference_date_exhange_rate).sum() == 1
assert get_sdr_mix(reference_date_exhange_rate).sum() == 1
