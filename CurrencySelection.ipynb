# %%
"""
Description: Perform (backward) selection in currency selection for final Duca basket.
Author: Jeroen van Dijk
Date: 11-11-2020
Maintainer: Jeroen van Dijk
Email: jeroen.vandijk@d-data.nl
Status: Dev
"""

# %%
# Load common imports
# %run ./CommonImports.ipynb

# %%
# Load common functions and currencies lists:
# - all_currencies
# - obsolete_currencies
# - p13_currencies
# - f_currencies
# - ff_currencies
# - currencies_per_continent
# %run ./Utilities.ipynb

# %%
# Load loss functions
# - calculate_loss_function_around_one(weights)
# - calculate_loss_function_vs_t_minus_one(weights)
# - calculate_loss_function_vs_t_minus_one_with_balancing(weights)
# - calculate_loss_function_vs_t_minus_one_for_period(weights, max_date)
# %run ./LossFunctions.ipynb

# %%
# Create dataframe with pre-defined base currency
df = create_original_df("EUR")

# %%
# Determine splits for dev- (train and test) and validation set
train_start = date(2005, 4, 1)
test_start = date(2012, 1, 1)
validation_start = date(2015, 1, 1)
validation_end = date(2020, 10, 1)

# Create dev (train and test) and validation set
train, test, dev, val = split_data(df, train_start, test_start, validation_start, validation_end)

# %%
results = pd.DataFrame()

# Calculate loss function score per currency
for base_currency in all_currencies:
    for currency in all_currencies:
        if currency == base_currency:
            continue
            
        rates = dev[base_currency] / dev[currency]
        normalized_rates = rates / rates.iloc[0]
        
        deviation = np.log(normalized_rates)
        loss_function_score = (deviation**2).mean()

        results = results.append({"currency": currency,
                                  "base_currency": base_currency,
                                  "loss_function_score": loss_function_score},
                                 ignore_index=True)
    
results = results.groupby("currency").median()
results.sort_values("loss_function_score", ascending=True)
# Out:
#           loss_function_score
# currency
# CAD                0.015
# MYR                0.016
# NOK                0.017
# HRK                0.020
# SEK                0.020
# CZK                0.021
# EUR                0.021
# DKK                0.021
# USD                0.021
# HKD                0.022
# PLN                0.022
# HUF                0.022
# IDR                0.023
# NZD                0.025
# AUD                0.025
# THB                0.026
# CHF                0.026
# RUB                0.026
# JPY                0.027
# RON                0.028
# PHP                0.028
# KRW                0.028
# SGD                0.031
# CNY                0.035
# GBP                0.036
# TRY                0.068
# ZAR                0.117

# %%
exchange_table = dict()

for base_currency in all_currencies:
    exchange_table[base_currency] = 1/train[all_currencies].divide(train[base_currency], axis=0)
    
reference_date_exhange_rate = train[all_currencies].iloc[0]

# %%
# Everything contains all currencies now
this_day_by_month = {}
previous_day_by_month = {}
diff_by_month = defaultdict(dict)

for base_currency, table in exchange_table.items():
    if base_currency not in all_currencies:
        continue
        
    exchange_table[base_currency]["month"] = exchange_table[base_currency].index.map(lambda x: int(x.strftime("%Y%m")))

    this_day = exchange_table[base_currency]
    previous_day = pd.DataFrame(exchange_table[base_currency].shift(1), 
                                index=exchange_table[base_currency].index)
    previous_day["month"] = previous_day.index.map(lambda x: int(x.strftime("%Y%m")))
    
    this_day_by_month[base_currency] = {month: values[all_currencies] for month, values in this_day.groupby("month")}
    previous_day_by_month[base_currency] = {month: values[all_currencies] for month, values in previous_day.groupby("month")}
    
    for month in this_day_by_month[base_currency].keys():
        diff_by_month[base_currency][month] = np.abs((this_day_by_month[base_currency][month] - previous_day_by_month[base_currency][month]) / 
                                                      previous_day_by_month[base_currency][month])
    
months = list(exchange_table["EUR"]["month"].unique())

# %%
def recalculate_weights(weights):
    """Helper function to recalculate weigths (baseline principle).
   
    Parameters
    ----------
    weights : array
        The initial weights given to all currencies."""
    weights[weights>0] = 1
    weights = weights/weights.sum()
    return weights

# %%
def evaluate_exclusion_of_currency(weights, 
                                   currency_set):
    """Perform backward selection of currencies.
   
    Parameters
    ----------
    weights : array
        The initial weights given to all currencies.
    currency_set : set
        The set containing all currencies of interest."""
    # Initialize string giving best currency to exclude
    best_to_exclude = "None"
    # Calculate initial loss function value
    starting_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(weights, currency_set)
    
    # So far, this is the best solution
    best_loss_function_value = starting_loss_function_value
    print(f"starting loss function value: {best_loss_function_value}")
    print("")

    # Each time we eliminate one currency
    for excluded_currency in currency_set:
        print(f"evaluating {excluded_currency}")

        # We create the new weights,
        new_weights = weights.copy()
        new_weights[new_weights.index==excluded_currency] = 0
        new_weights = recalculate_weights(new_weights)
        
        # and calculate the new loss function value
        new_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(new_weights, currency_set)
        print(f"new loss function value: {new_loss_function_value}")

        # Check whether the new loss function value is lower than the (so far) best one, and
        # the improvement needs to be > .5%
        if new_loss_function_value <= best_loss_function_value and new_loss_function_value < .995*starting_loss_function_value:
            print(f"better solution found by excluding {excluded_currency}")
            print(f"loss function decreased by {(best_loss_function_value-new_loss_function_value)/best_loss_function_value*100:.2f}% compared to current best solution")
            # If so, save these results
            best_loss_function_value = new_loss_function_value
            best_to_exclude = excluded_currency
        print("")
        
    if best_to_exclude == "None":
        print("No currency needed to be removed.")
    else:
        print(f"\033[1m{best_to_exclude} is removed from currency set\n")
    
    # Exclude the currency
    currency_set.remove(best_to_exclude)
    return starting_loss_function_value, best_loss_function_value, best_to_exclude, currency_set

# %%
weights = pd.Series(np.ones(len(all_currencies))/len(all_currencies), index=reference_date_exhange_rate.loc[all_currencies].index)
currency_set = set(all_currencies)
max_excluded_currencies = 27

# Create list to save results
backward_selection_result = []

for i in range(0, max_excluded_currencies):
    starting_loss_function_value, best_loss_function_value, best_to_exclude, currencies = evaluate_exclusion_of_currency(weights, currency_set)
    if best_to_exclude == "None":
        continue
    weights[weights.index==best_to_exclude] = 0
    weights = recalculate_weights(weights)
    
    backward_selection_result.append((best_to_exclude, starting_loss_function_value, best_loss_function_value))
    
backward_selection_result = pd.DataFrame(backward_selection_result)
backward_selection_result.columns = ["Removed currency", "Previous loss function value", "New loss function value"]
# Out:
# starting loss function value: 143338.79797809373
#
# evaluating KRW
# new loss function value: 132699.4163045596
# better solution found by excluding KRW
# loss function decreased by 7.42% compared to current best solution
#
# evaluating THB
# new loss function value: 148423.3778308339
#
# evaluating EUR
# new loss function value: 148844.3448682272
#
# evaluating HRK
# new loss function value: 148794.93714275828
#
# evaluating NZD
# new loss function value: 148829.99458293835
#
# evaluating PHP
# new loss function value: 148283.47015382358
#
# evaluating JPY
# new loss function value: 147215.56846713947
#
# evaluating USD
# new loss function value: 148839.92590436336
#
# evaluating HKD
# new loss function value: 148760.25705563472
#
# evaluating AUD
# new loss function value: 148835.39485098462
#
# evaluating RON
# new loss function value: 148816.68141760235
#
# evaluating TRY
# new loss function value: 148829.91449319993
#
# evaluating MYR
# new loss function value: 148814.12712404708
#
# evaluating CNY
# new loss function value: 148768.6705141416
#
# evaluating CHF
# new loss function value: 148837.86436479178
#
# evaluating ZAR
# new loss function value: 148718.9117570296
#
# evaluating CZK
# new loss function value: 148613.12533151105
#
# evaluating SGD
# new loss function value: 148837.15387720184
#
# evaluating CAD
# new loss function value: 148837.22579296527
#
# evaluating NOK
# new loss function value: 148774.9337079701
#
# evaluating GBP
# new loss function value: 148844.5979909869
#
# evaluating PLN
# new loss function value: 148808.87698931832
#
# evaluating DKK
# new loss function value: 148796.06917962988
#
# evaluating RUB
# new loss function value: 148542.29966692533
#
# evaluating HUF
# new loss function value: 145844.7285456512
#
# evaluating IDR
# new loss function value: 23172.962980856508
# better solution found by excluding IDR
# loss function decreased by 82.54% compared to current best solution
#
# evaluating SEK
# new loss function value: 148762.71451343963
#
# IDR is removed from currency set
#
# starting loss function value: 22330.063129405327
#
# evaluating KRW
# new loss function value: 7004.558516328121
# better solution found by excluding KRW
# loss function decreased by 68.63% compared to current best solution
#
# evaluating THB
# new loss function value: 22791.792914387825
#
# evaluating EUR
# new loss function value: 23215.853796268068
#
# evaluating HRK
# new loss function value: 23166.881693477346
#
# evaluating NZD
# new loss function value: 23201.500915860077
#
# evaluating PHP
# new loss function value: 22648.968098191715
#
# evaluating JPY
# new loss function value: 21585.050318552323
#
# evaluating USD
# new loss function value: 23211.235390486236
#
# evaluating HKD
# new loss function value: 23130.72197339568
#
# evaluating AUD
# new loss function value: 23206.888414501864
#
# evaluating RON
# new loss function value: 23188.363854154333
#
# evaluating TRY
# new loss function value: 23201.33940507338
#
# evaluating MYR
# new loss function value: 23185.169112877287
#
# evaluating CNY
# new loss function value: 23139.306432490444
#
# evaluating CHF
# new loss function value: 23209.37757326443
#
# evaluating ZAR
# new loss function value: 23090.687286435048
#
# evaluating CZK
# new loss function value: 22986.51197921002
#
# evaluating SGD
# new loss function value: 23208.495153463267
#
# evaluating CAD
# new loss function value: 23208.65975830528
#
# evaluating NOK
# new loss function value: 23146.994517080224
#
# evaluating GBP
# new loss function value: 23216.044615266004
#
# evaluating PLN
# new loss function value: 23180.62590625844
#
# evaluating DKK
# new loss function value: 23168.04132518695
#
# evaluating RUB
# new loss function value: 22913.595035469876
#
# evaluating HUF
# new loss function value: 20240.09679475878
#
# evaluating SEK
# new loss function value: 23134.880583795344
#
# KRW is removed from currency set
#
# starting loss function value: 6687.950827794487
#
# evaluating THB
# new loss function value: 6535.929427815714
# better solution found by excluding THB
# loss function decreased by 2.27% compared to current best solution
#
# evaluating EUR
# new loss function value: 6959.312744640788
#
# evaluating HRK
# new loss function value: 6910.988642226828
#
# evaluating NZD
# new loss function value: 6944.936803289676
#
# evaluating PHP
# new loss function value: 6390.63916091791
# better solution found by excluding PHP
# loss function decreased by 2.22% compared to current best solution
#
# evaluating JPY
# new loss function value: 5335.729919585852
# better solution found by excluding JPY
# loss function decreased by 16.51% compared to current best solution
#
# evaluating USD
# new loss function value: 6954.608122683679
#
# evaluating HKD
# new loss function value: 6874.255939028699
#
# evaluating AUD
# new loss function value: 6950.273930013657
#
# evaluating RON
# new loss function value: 6932.080470484755
#
# evaluating TRY
# new loss function value: 6944.704965355119
#
# evaluating MYR
# new loss function value: 6928.428115807254
#
# evaluating CNY
# new loss function value: 6882.792456162253
#
# evaluating CHF
# new loss function value: 6952.875611424552
#
# evaluating ZAR
# new loss function value: 6834.269869304427
#
# evaluating CZK
# new loss function value: 6732.371355308302
#
# evaluating SGD
# new loss function value: 6951.864711745473
#
# evaluating CAD
# new loss function value: 6952.044031878418
#
# evaluating NOK
# new loss function value: 6890.980516165095
#
# evaluating GBP
# new loss function value: 6959.444714846621
#
# evaluating PLN
# new loss function value: 6924.2797012788205
#
# evaluating DKK
# new loss function value: 6912.203882219175
#
# evaluating RUB
# new loss function value: 6658.341215137793
#
# evaluating HUF
# new loss function value: 4006.3985021934295
# better solution found by excluding HUF
# loss function decreased by 24.91% compared to current best solution
#
# evaluating SEK
# new loss function value: 6879.015885347842
#
# HUF is removed from currency set
#
# starting loss function value: 3788.9783805869674
#
# evaluating THB
# new loss function value: 3532.0314031046682
# better solution found by excluding THB
# loss function decreased by 6.78% compared to current best solution
#
# evaluating EUR
# new loss function value: 3946.468111056519
#
# evaluating HRK
# new loss function value: 3898.458968528348
#
# evaluating NZD
# new loss function value: 3932.0710999972116
#
# evaluating PHP
# new loss function value: 3388.639807253973
# better solution found by excluding PHP
# loss function decreased by 4.06% compared to current best solution
#
# evaluating JPY
# new loss function value: 2346.321440710559
# better solution found by excluding JPY
# loss function decreased by 30.76% compared to current best solution
#
# evaluating USD
# new loss function value: 3942.021443761344
#
# evaluating HKD
# new loss function value: 3863.782142302384
#
# evaluating AUD
# new loss function value: 3937.406705656902
#
# evaluating RON
# new loss function value: 3919.0851286314332
#
# evaluating TRY
# new loss function value: 3931.8349335480807
#
# evaluating MYR
# new loss function value: 3916.3386441217926
#
# evaluating CNY
# new loss function value: 3872.0346568423142
#
# evaluating CHF
# new loss function value: 3940.1224126960956
#
# evaluating ZAR
# new loss function value: 3820.8501535663418
#
# evaluating CZK
# new loss function value: 3718.16121296866
#
# evaluating SGD
# new loss function value: 3939.3000715411536
#
# evaluating CAD
# new loss function value: 3939.276425815681
#
# evaluating NOK
# new loss function value: 3878.025877447356
#
# evaluating GBP
# new loss function value: 3946.62713071972
#
# evaluating PLN
# new loss function value: 3910.716231962611
#
# evaluating DKK
# new loss function value: 3899.7118572220115
#
# evaluating RUB
# new loss function value: 3650.2553561424324
#
# evaluating SEK
# new loss function value: 3865.93991848963
#
# JPY is removed from currency set
#
# starting loss function value: 2218.3888854451684
#
# evaluating THB
# new loss function value: 1898.5766567948285
# better solution found by excluding THB
# loss function decreased by 14.42% compared to current best solution
#
# evaluating EUR
# new loss function value: 2312.1201499104277
#
# evaluating HRK
# new loss function value: 2264.9946155858975
#
# evaluating NZD
# new loss function value: 2297.9508524251773
#
# evaluating PHP
# new loss function value: 1759.4267949441191
# better solution found by excluding PHP
# loss function decreased by 7.33% compared to current best solution
#
# evaluating USD
# new loss function value: 2307.540016623012
#
# evaluating HKD
# new loss function value: 2229.4009351797667
#
# evaluating AUD
# new loss function value: 2303.240468968637
#
# evaluating RON
# new loss function value: 2285.2932151600307
#
# evaluating TRY
# new loss function value: 2297.7316226034877
#
# evaluating MYR
# new loss function value: 2282.3221778590005
#
# evaluating CNY
# new loss function value: 2237.678512247013
#
# evaluating CHF
# new loss function value: 2305.645971220565
#
# evaluating ZAR
# new loss function value: 2188.593461349022
#
# evaluating CZK
# new loss function value: 2087.7107061046036
#
# evaluating SGD
# new loss function value: 2304.951291734252
#
# evaluating CAD
# new loss function value: 2305.020162166126
#
# evaluating NOK
# new loss function value: 2244.9933307944175
#
# evaluating GBP
# new loss function value: 2312.224748574348
#
# evaluating PLN
# new loss function value: 2277.0471795008743
#
# evaluating DKK
# new loss function value: 2266.2898498166724
#
# evaluating RUB
# new loss function value: 2020.9262875300967
#
# evaluating SEK
# new loss function value: 2233.265358146494
#
# PHP is removed from currency set
#
# starting loss function value: 1685.0011942287706
#
# evaluating THB
# new loss function value: 1338.6736116203326
# better solution found by excluding THB
# loss function decreased by 20.55% compared to current best solution
#
# evaluating EUR
# new loss function value: 1758.1967111532617
#
# evaluating HRK
# new loss function value: 1711.452378837308
#
# evaluating NZD
# new loss function value: 1744.0488610015364
#
# evaluating USD
# new loss function value: 1328.9982624286968
#
# evaluating PLN
# new loss function value: 1294.6954683194074
#
# evaluating DKK
# new loss function value: 1284.1837442022272
#
# evaluating RUB
# new loss function value: 1035.6981032834697
# better solution found by excluding RUB
# loss function decreased by 6.62% compared to current best solution
#
# evaluating SEK
# new loss function value: 1251.9087496837592
#
# RUB is removed from currency set
#
# starting loss function value: 990.6598888688727
#
# evaluating EUR
# new loss function value: 1035.7822364416804
#
# evaluating HRK
# new loss function value: 989.2007219284302
#
# evaluating NZD
# new loss function value: 1021.7348962189459
#
# evaluating USD
# new loss function value: 1030.478716605449
#
# evaluating HKD
# new loss function value: 948.0502437781629
# better solution found by excluding HKD
# loss function decreased by 4.30% compared to current best solution
#
# evaluating AUD
# new loss function value: 1026.9638813741258
#
# evaluating RON
# new loss function value: 1009.3529599318409
#
# evaluating TRY
# new loss function value: 1021.2111002721215
#
# evaluating MYR
# new loss function value: 1004.0643860522856
#
# evaluating CNY
# new loss function value: 956.8140531332631
#
# evaluating CHF
# new loss function value: 1029.2131589443277
#
# evaluating ZAR
# new loss function value: 913.2258554388226
# better solution found by excluding ZAR
# loss function decreased by 3.67% compared to current best solution
#
# evaluating CZK
# new loss function value: 814.8800975562314
# better solution found by excluding CZK
# loss function decreased by 10.77% compared to current best solution
#
# evaluating SGD
# new loss function value: 1027.8629614467163
#
# evaluating CAD
# new loss function value: 1028.4581735134232
#
# evaluating NOK
# new loss function value: 969.7989086610204
#
# evaluating GBP
# new loss function value: 1035.7509923656592
#
# evaluating PLN
# new loss function value: 1001.4489990880955
#
# evaluating DKK
# new loss function value: 990.5111192795281
#
# evaluating SEK
# new loss function value: 958.3943153473255
#
# CZK is removed from currency set
#
# starting loss function value: 774.3931465491977
#
# evaluating EUR
# new loss function value: 810.2915060174736
#
# evaluating HRK
# new loss function value: 763.0602729414716
# better solution found by excluding HRK
# loss function decreased by 1.46% compared to current best solution
#
# evaluating NZD
# new loss function value: 796.3357867551562
#
# evaluating USD
# new loss function value: 805.2184839388539
#
# evaluating HKD
# new loss function value: 723.6177572641247
# better solution found by excluding HKD
# loss function decreased by 5.17% compared to current best solution
#
# evaluating AUD
# new loss function value: 801.556804402419
#
# evaluating RON
# new loss function value: 783.5485402894087
#
# evaluating TRY
# new loss function value: 795.8319260109356
#
# evaluating MYR
# new loss function value: 778.9580029434416
#
# evaluating CNY
# new loss function value: 732.2113371522427
#
# evaluating CHF
# new loss function value: 803.7276119042668
#
# evaluating ZAR
# new loss function value: 687.6047967887466
# better solution found by excluding ZAR
# loss function decreased by 4.98% compared to current best solution
#
# evaluating SGD
# new loss function value: 802.5494686047849
#
# evaluating CAD
# new loss function value: 803.1192350648258
#
# evaluating NOK
# new loss function value: 743.732280622214
#
# evaluating GBP
# new loss function value: 810.3562758596995
#
# evaluating PLN
# new loss function value: 775.4068695206759
#
# evaluating DKK
# new loss function value: 764.3431153182722
#
# evaluating SEK
# new loss function value: 731.999713035746
#
# ZAR is removed from currency set
#
# starting loss function value: 631.1843373063135
#
# evaluating EUR
# new loss function value: 661.4987032293706
#
# evaluating HRK
# new loss function value: 616.0873117876312
# better solution found by excluding HRK
# loss function decreased by 2.39% compared to current best solution
#
# evaluating NZD
# new loss function value: 647.4135162625313
#
# evaluating USD
# new loss function value: 656.5724038639835
#
# evaluating HKD
# new loss function value: 578.065750204328
# better solution found by excluding HKD
# loss function decreased by 6.17% compared to current best solution
#
# evaluating AUD
# new loss function value: 652.6235065596162
#
# evaluating RON
# new loss function value: 635.1457408225347
#
# evaluating TRY
# new loss function value: 646.647851966074
#
# evaluating MYR
# new loss function value: 631.1079560907476
#
# evaluating CNY
# new loss function value: 586.4045426926552
#
# evaluating CHF
# new loss function value: 655.1000217649796
#
# evaluating SGD
# new loss function value: 654.028144612955
#
# evaluating CAD
# new loss function value: 654.278187311152
#
# evaluating NOK
# new loss function value: 596.1061133838409
#
# evaluating GBP
# new loss function value: 661.4412675461238
#
# evaluating PLN
# new loss function value: 626.5562743220339
#
# evaluating DKK
# new loss function value: 617.5499792104166
#
# evaluating SEK
# new loss function value: 584.6907998826699
#
# HKD is removed from currency set
#
# starting loss function value: 544.4578695886925
#
# evaluating EUR
# new loss function value: 571.7750713526675
#
# evaluating HRK
# new loss function value: 527.0011023092643
# better solution found by excluding HRK
# loss function decreased by 3.21% compared to current best solution
#
# evaluating NZD
# new loss function value: 557.8352409898347
#
# evaluating USD
# new loss function value: 566.0449243473117
#
# evaluating AUD
# new loss function value: 563.0001577207391
#
# evaluating RON
# new loss function value: 545.822906074577
#
# evaluating TRY
# new loss function value: 556.8605703068225
#
# evaluating MYR
# new loss function value: 540.2469304396504
#
# evaluating CNY
# new loss function value: 492.1698109777059
# better solution found by excluding CNY
# loss function decreased by 6.61% compared to current best solution
#
# evaluating CHF
# new loss function value: 565.2893392517833
#
# evaluating SGD
# new loss function value: 563.8587110588807
#
# evaluating CAD
# new loss function value: 564.436060864723
#
# evaluating NOK
# new loss function value: 507.4976111589984
#
# evaluating GBP
# new loss function value: 571.6082561317962
#
# evaluating PLN
# new loss function value: 537.4645390638867
#
# evaluating DKK
# new loss function value: 528.4880525273753
#
# evaluating SEK
# new loss function value: 496.3844984317538
#
# CNY is removed from currency set
#
# starting loss function value: 457.55635103695965
#
# evaluating EUR
# new loss function value: 481.4544733028049
#
# evaluating HRK
# new loss function value: 437.3457794600469
# better solution found by excluding HRK
# loss function decreased by 4.42% compared to current best solution
#
# evaluating NZD
# new loss function value: 467.6763836588771
#
# evaluating USD
# new loss function value: 474.89331228680624
#
# evaluating AUD
# new loss function value: 472.78873212111404
#
# evaluating RON
# new loss function value: 455.9429579987041
#
# evaluating TRY
# new loss function value: 466.47395073476946
#
# evaluating MYR
# new loss function value: 448.637771677735
#
# evaluating CHF
# new loss function value: 474.8706483951354
#
# evaluating SGD
# new loss function value: 473.03682067400354
#
# evaluating CAD
# new loss function value: 473.99026817488283
#
# evaluating NOK
# new loss function value: 418.37452429671816
# better solution found by excluding NOK
# loss function decreased by 4.34% compared to current best solution
#
# evaluating GBP
# new loss function value: 481.16875038278744
#
# evaluating PLN
# new loss function value: 447.8206846561425
#
# evaluating DKK
# new loss function value: 438.8487084255661
#
# evaluating SEK
# new loss function value: 407.5778503452601
# better solution found by excluding SEK
# loss function decreased by 2.58% compared to current best solution
#
# SEK is removed from currency set
#
# starting loss function value: 383.18984817222935
#
# evaluating EUR
# new loss function value: 403.88369281556925
#
# evaluating HRK
# new loss function value: 359.2910093604723
# better solution found by excluding HRK
# loss function decreased by 6.24% compared to current best solution
#
# evaluating NZD
# new loss function value: 390.1215858358784
#
# evaluating USD
# new loss function value: 397.5443564406368
#
# evaluating AUD
# new loss function value: 395.2242792725832
#
# evaluating RON
# new loss function value: 378.16876582498867
#
# evaluating TRY
# new loss function value: 389.02843792857965
#
# evaluating MYR
# new loss function value: 371.524366127941
#
# evaluating CHF
# new loss function value: 397.31572491068226
#
# evaluating SGD
# new loss function value: 395.66918554236895
#
# evaluating CAD
# new loss function value: 396.5078906786643
#
# evaluating NOK
# new loss function value: 339.293041846621
# better solution found by excluding NOK
# loss function decreased by 5.57% compared to current best solution
#
# evaluating GBP
# new loss function value: 403.66703738777727
#
# evaluating PLN
# new loss function value: 369.78771856353745
#
# evaluating DKK
# new loss function value: 360.82063004714047
#
# NOK is removed from currency set
#
# starting loss function value: 315.73029658041685
#
# evaluating EUR
# new loss function value: 333.2921302526043
#
# evaluating HRK
# new loss function value: 288.3679276197876
# better solution found by excluding HRK
# loss function decreased by 8.67% compared to current best solution
#
# evaluating NZD
# new loss function value: 319.55081982798134
#
# evaluating USD
# new loss function value: 327.1804738868143
#
# evaluating AUD
# new loss function value: 324.61769163997644
#
# evaluating RON
# new loss function value: 307.4067632346566
#
# evaluating TRY
# new loss function value: 318.53657349706305
#
# evaluating MYR
# new loss function value: 301.43395268228016
#
# evaluating CHF
# new loss function value: 326.71745976578745
#
# evaluating SGD
# new loss function value: 325.30348930228365
#
# evaluating CAD
# new loss function value: 325.97190298264707
#
# evaluating GBP
# new loss function value: 333.1281255919511
#
# evaluating PLN
# new loss function value: 298.7957601826986
#
# evaluating DKK
# new loss function value: 289.9210816593038
#
# HRK is removed from currency set
#
# starting loss function value: 272.13661940512816
#
# evaluating EUR
# new loss function value: 287.66444938810645
#
# evaluating NZD
# new loss function value: 274.2794541465697
#
# evaluating USD
# new loss function value: 281.91366589382415
#
# evaluating AUD
# new loss function value: 279.3372660817826
#
# evaluating RON
# new loss function value: 261.21219331403967
# better solution found by excluding RON
# loss function decreased by 4.01% compared to current best solution
#
# evaluating TRY
# new loss function value: 273.2991981626821
#
# evaluating MYR
# new loss function value: 256.0217503284564
# better solution found by excluding MYR
# loss function decreased by 1.99% compared to current best solution
#
# evaluating CHF
# new loss function value: 281.0937103842875
#
# evaluating SGD
# new loss function value: 279.9293229586584
#
# evaluating CAD
# new loss function value: 280.7090804568341
#
# evaluating GBP
# new loss function value: 287.8150757954041
#
# evaluating PLN
# new loss function value: 252.93864333635878
# better solution found by excluding PLN
# loss function decreased by 1.20% compared to current best solution
#
# evaluating DKK
# new loss function value: 241.5622420196629
# better solution found by excluding DKK
# loss function decreased by 4.50% compared to current best solution
#
# DKK is removed from currency set
#
# starting loss function value: 225.6931399728814
#
# evaluating EUR
# new loss function value: 238.42567639144664
#
# evaluating NZD
# new loss function value: 225.56704084977554
#
# evaluating USD
# new loss function value: 233.19688310131403
#
# evaluating AUD
# new loss function value: 230.61593746315788
#
# evaluating RON
# new loss function value: 211.3094147957168
# better solution found by excluding RON
# loss function decreased by 6.37% compared to current best solution
#
# evaluating TRY
# new loss function value: 224.62197908998903
#
# evaluating MYR
# new loss function value: 207.03596062503354
# better solution found by excluding MYR
# loss function decreased by 2.02% compared to current best solution
#
# evaluating CHF
# new loss function value: 231.9194662876785
#
# evaluating SGD
# new loss function value: 231.0569094153398
#
# evaluating CAD
# new loss function value: 232.00878854298065
#
# evaluating GBP
# new loss function value: 239.06926246974638
#
# evaluating PLN
# new loss function value: 203.49036064239803
# better solution found by excluding PLN
# loss function decreased by 1.71% compared to current best solution
#
# PLN is removed from currency set
#
# starting loss function value: 182.01174245876197
#
# evaluating EUR
# new loss function value: 192.46448021045722
#
# evaluating NZD
# new loss function value: 179.68266873849578
# better solution found by excluding NZD
# loss function decreased by 1.28% compared to current best solution
#
# evaluating USD
# new loss function value: 187.73753273692165
#
# evaluating AUD
# new loss function value: 184.7159252421298
#
# evaluating RON
# new loss function value: 165.033608122137
# better solution found by excluding RON
# loss function decreased by 8.15% compared to current best solution
#
# evaluating TRY
# new loss function value: 178.70199061174924
#
# evaluating MYR
# new loss function value: 162.52658238318242
# better solution found by excluding MYR
# loss function decreased by 1.52% compared to current best solution
#
# evaluating CHF
# new loss function value: 186.14936402807876
#
# evaluating SGD
# new loss function value: 185.64567565593407
#
# evaluating CAD
# new loss function value: 186.25669844146873
#
# evaluating GBP
# new loss function value: 193.21464087582655
#
# MYR is removed from currency set
#
# starting loss function value: 147.87502613020897
#
# evaluating EUR
# new loss function value: 156.5324557938778
#
# evaluating NZD
# new loss function value: 143.90417513210068
# better solution found by excluding NZD
# loss function decreased by 2.69% compared to current best solution
#
# evaluating USD
# new loss function value: 151.14023612987634
#
# evaluating AUD
# new loss function value: 148.8678040790208
#
# evaluating RON
# new loss function value: 129.20047850497963
# better solution found by excluding RON
# loss function decreased by 10.22% compared to current best solution
#
# evaluating TRY
# new loss function value: 142.59094865928898
#
# evaluating CHF
# new loss function value: 150.16829535119794
#
# evaluating SGD
# new loss function value: 148.948049774253
#
# evaluating CAD
# new loss function value: 150.15006263596763
#
# evaluating GBP
# new loss function value: 157.2477552415264
#
# RON is removed from currency set
#
# starting loss function value: 115.09164050315661
#
# evaluating EUR
# new loss function value: 121.37129666785498
#
# evaluating NZD
# new loss function value: 109.06162480273079
# better solution found by excluding NZD
# loss function decreased by 5.24% compared to current best solution
#
# evaluating USD
# new loss function value: 116.49985427522476
#
# evaluating AUD
# new loss function value: 114.0043381207325
#
# evaluating TRY
# new loss function value: 107.62280481720903
# better solution found by excluding TRY
# loss function decreased by 1.32% compared to current best solution
#
# evaluating CHF
# new loss function value: 115.15122810399744
#
# evaluating SGD
# new loss function value: 114.24190249078404
#
# evaluating CAD
# new loss function value: 115.45869884227216
#
# evaluating GBP
# new loss function value: 122.41301640760393
#
# TRY is removed from currency set
#
# starting loss function value: 91.29416890305858
#
# evaluating EUR
# new loss function value: 96.59741546493865
#
# evaluating NZD
# new loss function value: 84.21177901910951
# better solution found by excluding NZD
# loss function decreased by 7.76% compared to current best solution
#
# evaluating USD
# new loss function value: 91.73554272071141
#
# evaluating AUD
# new loss function value: 89.1581439958075
#
# evaluating CHF
# new loss function value: 90.77510283135511
#
# evaluating SGD
# new loss function value: 89.72471153403183
#
# evaluating CAD
# new loss function value: 90.62657305031233
#
# evaluating GBP
# new loss function value: 97.52408260820208
#
# NZD is removed from currency set
#
# starting loss function value: 70.04991133676548
#
# evaluating EUR
# new loss function value: 74.34891505473784
#
# evaluating USD
# new loss function value: 69.91216380099783
#
# evaluating AUD
# new loss function value: 65.8489156861656
# better solution found by excluding AUD
# loss function decreased by 6.00% compared to current best solution
#
# evaluating CHF
# new loss function value: 68.86502847239278
#
# evaluating SGD
# new loss function value: 67.98802733899218
#
# evaluating CAD
# new loss function value: 68.26005699656812
#
# evaluating GBP
# new loss function value: 75.12627200750406
#
# AUD is removed from currency set
#
# starting loss function value: 52.673848795467165
#
# evaluating EUR
# new loss function value: 56.10711539100729
#
# evaluating USD
# new loss function value: 52.23034332775978
# better solution found by excluding USD
# loss function decreased by 0.84% compared to current best solution
#
# evaluating CHF
# new loss function value: 51.06460931915218
# better solution found by excluding CHF
# loss function decreased by 2.23% compared to current best solution
#
# evaluating SGD
# new loss function value: 50.21828317058171
# better solution found by excluding SGD
# loss function decreased by 1.66% compared to current best solution
#
# evaluating CAD
# new loss function value: 49.629005731505224
# better solution found by excluding CAD
# loss function decreased by 1.17% compared to current best solution
#
# evaluating GBP
# new loss function value: 56.79373583279677
#
# CAD is removed from currency set
#
# starting loss function value: 37.563015068604145
#
# evaluating EUR
# new loss function value: 40.29710128341873
#
# evaluating USD
# new loss function value: 36.43615936393107
# better solution found by excluding USD
# loss function decreased by 3.00% compared to current best solution
#
# evaluating CHF
# new loss function value: 35.772457445931316
# better solution found by excluding CHF
# loss function decreased by 1.82% compared to current best solution
#
# evaluating SGD
# new loss function value: 34.542841786440626
# better solution found by excluding SGD
# loss function decreased by 3.44% compared to current best solution
#
# evaluating GBP
# new loss function value: 40.766515463298944
#
# SGD is removed from currency set
#
# starting loss function value: 27.213434854250387
#
# evaluating EUR
# new loss function value: 29.44634759317993
#
# evaluating USD
# new loss function value: 24.360874094710514
# better solution found by excluding USD
# loss function decreased by 10.48% compared to current best solution
#
# evaluating CHF
# new loss function value: 25.139163522552575
#
# evaluating GBP
# new loss function value: 29.907354206558512
#
# USD is removed from currency set
#
# starting loss function value: 14.679963955009278
#
# evaluating EUR
# new loss function value: 16.06067539809326
#
# evaluating CHF
# new loss function value: 12.100899119399996
# better solution found by excluding CHF
# loss function decreased by 17.57% compared to current best solution
#
# evaluating GBP
# new loss function value: 15.87831734753458
#
# CHF is removed from currency set
#
# starting loss function value: 6.068429679407858
#
# evaluating EUR
# new loss function value: 5.443951975636633
# better solution found by excluding EUR
# loss function decreased by 10.29% compared to current best solution
#
# evaluating GBP
# new loss function value: 6.692907383179082
#
# EUR is removed from currency set
#
# starting loss function value: 0.0
#
# evaluating GBP
# new loss function value: 0.0
#
# No currency needed to be removed.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-e6e46ba41d4f> in <module>
#       7
#       8 for i in range(0, max_excluded_currencies):
# ----> 9     starting_loss_function_value, best_loss_function_value, best_to_exclude, currencies = evaluate_exclusion_of_currency(weights, currency_set)
#      10     if best_to_exclude == "None":
#      11         continue
#
# <ipython-input-78-8bb0604de98e> in evaluate_exclusion_of_currency(weights, currency_set)
#      48
#      49     # Exclude the currency
# ---> 50     currency_set.remove(best_to_exclude)
#      51     return starting_loss_function_value, best_loss_function_value, best_to_exclude, currency_set
#
# KeyError: 'None'

# %%
def evaluate_inclusion_of_currency(weights, 
                                   currency_set):
    """Perform forward selection of currencies.
   
    Parameters
    ----------
    weights : array
        The initial weights given to all currencies.
    currency_set : set
        The set containing all currencies of interest."""

    # Initialize string giving best currency to exclude
    best_to_include = "None"
    # Calculate initial loss function value
    starting_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(weights)

    # So far, this is the best solution
    best_loss_function_value = starting_loss_function_value
    print(f"starting loss function value: {best_loss_function_value}")

    # Each time we include one currency
    for included_currency in currency_set:
        print(f"\nincluding {included_currency}")

        # We create the new weights,
        new_weights = weights.copy()
        new_weights[new_weights.index==included_currency] = 1
        new_weights = recalculate_weights(new_weights)

        # and calculate the new loss function value
        new_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(new_weights)
        print(f"new loss function value: {new_loss_function_value}")
        
        # Check whether the new loss function value is lower than the (so far) best one, and
        # the improvement needs to be > .5%
        if new_loss_function_value <= best_loss_function_value and new_loss_function_value < 0.995*starting_loss_function_value:
            print(f"\nbetter solution found by including {included_currency}")
            print(f"loss function decreased by {(starting_loss_function_value-new_loss_function_value)/starting_loss_function_value*100:.2f}% compared to starting value")
            # If so, save these results
            best_loss_function_value = new_loss_function_value
            best_to_include = included_currency
        print("")

    if best_to_include == "None":
        print("No currency needed to be included.")
    else:
        print(f"\033[1m{best_to_include} is added to currency set\n")
        # Exclude the currency
        currency_set.remove(best_to_include)
    return starting_loss_function_value, best_loss_function_value, best_to_include, currency_set

# %%
# Create weights series and specificy first currency to include
weights = pd.Series(0, index=reference_date_exhange_rate.loc[all_currencies].index)
first_currency = "SEK"
weights[first_currency] = 1
currency_set = set(all_currencies)
currency_set.remove(first_currency)

# Create list to save results
forward_selection_result = []
forward_selection_result.append((first_currency, "-", "-"))

# Set maximum number of currencies to include
max_currencies_to_include = 14

for i in range(0, max_currencies_to_include):
    starting_loss_function_value, best_loss_function_value, best_to_include, currencies = evaluate_inclusion_of_currency(weights, currency_set)
    if best_to_include == "None":
        break
    weights[weights.index==best_to_include] = 1
    weights = recalculate_weights(weights)
    forward_selection_result.append((best_to_include, starting_loss_function_value, best_loss_function_value))
    
forward_selection_result = pd.DataFrame(forward_selection_result)
forward_selection_result.columns = ["Added currency", "Previous loss function value", "New loss function value"]
# Out:
# starting loss function value: 2316.9680591005704
#
# including KRW
# new loss function value: 211139.84477454133
#
#
# including THB
# new loss function value: 6728.344932975171
#
#
# including EUR
# new loss function value: 1255.7734468627825
#
# better solution found by including EUR
# loss function decreased by 45.80% compared to starting value
#
#
#
# including HRK
# new loss function value: 1898.073877958378
#
#
# including NZD
# new loss function value: 1442.3271556170725
#
#
# including PHP
# new loss function value: 8547.144734109283
#
#
# including JPY
# new loss function value: 22429.866661002554
#
#
# including USD
# new loss function value: 1313.2199770917455
#
#
# including HKD
# new loss function value: 2348.915010564725
#
#
# including AUD
# new loss function value: 1372.1236710158819
#
#
# including RON
# new loss function value: 1615.3983049852766
#
#
# including TRY
# new loss function value: 1443.368322217731
#
#
# including MYR
# new loss function value: 1648.6041212039418
#
#
# including CNY
# new loss function value: 2239.5400499758002
#
#
# including CHF
# new loss function value: 1340.019991522961
#
#
# including ZAR
# new loss function value: 2886.4038924312154
#
#
# including CZK
# new loss function value: 4261.6274241726305
#
#
# including SGD
# new loss function value: 1349.2563301922946
#
#
# including CAD
# new loss function value: 1348.3214252675502
#
#
# including NOK
# new loss function value: 2158.1185302044464
#
#
# including GBP
# new loss function value: 1252.4828509859985
#
# better solution found by including GBP
# loss function decreased by 45.94% compared to starting value
#
#
#
# including PLN
# new loss function value: 1716.8558726776992
#
#
# including DKK
# new loss function value: 1883.3573986275526
#
#
# including RUB
# new loss function value: 5182.361063786604
#
#
# including HUF
# new loss function value: 40250.78564035073
#
#
# including IDR
# new loss function value: 1634983.7379826815
#
# GBP is added to currency set
#
# starting loss function value: 1252.4828509859985
#
# including KRW
# new loss function value: 140822.562397318
#
#
# including THB
# new loss function value: 4548.229169607255
#
#
# including EUR
# new loss function value: 899.8481788656636
#
# better solution found by including EUR
# loss function decreased by 28.15% compared to starting value
#
#
#
# including HRK
# new loss function value: 1328.0484662627273
#
#
# including NZD
# new loss function value: 1024.2173180351906
#
#
# including PHP
# new loss function value: 5760.762370363327
#
#
# including JPY
# new loss function value: 15015.91032162551
#
#
# including USD
# new loss function value: 938.1458656849725
#
#
# including HKD
# new loss function value: 1628.6092213336262
#
#
# including AUD
# new loss function value: 977.41499496773
#
#
# including RON
# new loss function value: 1139.5980842806596
#
#
# including TRY
# new loss function value: 1024.9114291022966
#
#
# including MYR
# new loss function value: 1161.7352950931033
#
#
# including CNY
# new loss function value: 1555.6925809410088
#
#
# including CHF
# new loss function value: 956.0125419724493
#
#
# including ZAR
# new loss function value: 1986.935142577952
#
#
# including CZK
# new loss function value: 2903.750830405563
#
#
# including SGD
# new loss function value: 962.1701010853387
#
#
# including CAD
# new loss function value: 961.5468311355093
#
#
# including NOK
# new loss function value: 1501.411567760107
#
#
# including PLN
# new loss function value: 1207.2364627422746
#
#
# including DKK
# new loss function value: 1318.2374800421771
#
#
# including RUB
# new loss function value: 3517.5732568148774
#
#
# including HUF
# new loss function value: 26896.522974524298
#
#
# including IDR
# new loss function value: 1090051.824536078
#
# EUR is added to currency set
#
# starting loss function value: 899.8481788656636
#
# including KRW
# new loss function value: 105665.56650664475
#
#
# including THB
# new loss function value: 3459.816585861691
#
#
# including HRK
# new loss function value: 1044.6810583532945
#
#
# including NZD
# new loss function value: 816.8076971826417
#
# better solution found by including NZD
# loss function decreased by 9.23% compared to starting value
#
#
#
# including PHP
# new loss function value: 4369.216486428745
#
#
# including JPY
# new loss function value: 11310.577449875378
#
#
# including USD
# new loss function value: 752.2541079199781
#
# better solution found by including USD
# loss function decreased by 16.40% compared to starting value
#
#
#
# including HKD
# new loss function value: 1270.101624656468
#
#
# including AUD
# new loss function value: 781.7059548820463
#
#
# including RON
# new loss function value: 903.3432718667435
#
#
# including TRY
# new loss function value: 817.3282804829709
#
#
# including MYR
# new loss function value: 919.9461799760766
#
#
# including CNY
# new loss function value: 1215.4141443620056
#
#
# including CHF
# new loss function value: 765.654115135586
#
#
# including ZAR
# new loss function value: 1538.8460655897131
#
#
# including CZK
# new loss function value: 2226.457831460421
#
#
# including SGD
# new loss function value: 770.2722844702524
#
#
# including CAD
# new loss function value: 769.8048320078806
#
#
# including NOK
# new loss function value: 1174.7033844763287
#
#
# including PLN
# new loss function value: 954.0720557129547
#
#
# including DKK
# new loss function value: 1037.3228186878816
#
#
# including RUB
# new loss function value: 2686.824651267407
#
#
# including HUF
# new loss function value: 20221.03693954947
#
#
# including IDR
# new loss function value: 817587.5131107147
#
# USD is added to currency set
#
# starting loss function value: 752.2541079199781
#
# including KRW
# new loss function value: 84594.34758433241
#
#
# including THB
# new loss function value: 2829.7476477059363
#
#
# including HRK
# new loss function value: 897.6392256992197
#
#
# including NZD
# new loss function value: 715.3405367626978
#
# better solution found by including NZD
# loss function decreased by 4.91% compared to starting value
#
#
#
# including PHP
# new loss function value: 3557.267568159581
#
#
# including JPY
# new loss function value: 9110.356338916888
#
#
# including HKD
# new loss function value: 1077.975678741759
#
#
# including AUD
# new loss function value: 687.2591429222211
#
# better solution found by including AUD
# loss function decreased by 8.64% compared to starting value
#
#
#
# including RON
# new loss function value: 784.5689965099789
#
#
# including TRY
# new loss function value: 715.7570034029611
#
#
# including MYR
# new loss function value: 797.8513229974455
#
#
# including CNY
# new loss function value: 1034.2256945061888
#
#
# including CHF
# new loss function value: 674.4176711250528
#
# better solution found by including CHF
# loss function decreased by 10.35% compared to starting value
#
#
#
# including ZAR
# new loss function value: 1292.9712314883543
#
#
# including CZK
# new loss function value: 1843.0606441849213
#
#
# including SGD
# new loss function value: 678.1122065927865
#
#
# including CAD
# new loss function value: 677.7382446228885
#
#
# including NOK
# new loss function value: 1001.6570865976474
#
#
# including PLN
# new loss function value: 825.1520235869478
#
#
# including DKK
# new loss function value: 891.7526339668892
#
#
# including RUB
# new loss function value: 2211.35410003051
#
#
# including HUF
# new loss function value: 16238.723930656164
#
#
# including IDR
# new loss function value: 654131.9048675884
#
# CHF is added to currency set
#
# starting loss function value: 674.4176711250528
#
# including KRW
# new loss function value: 70555.80164093457
#
#
# including THB
# new loss function value: 2418.6350270791722
#
#
# including HRK
# new loss function value: 808.5446754069085
#
#
# including NZD
# new loss function value: 656.62910129314
#
# better solution found by including NZD
# loss function decreased by 2.64% compared to starting value
#
#
#
# including PHP
# new loss function value: 3024.901627457209
#
#
# including JPY
# new loss function value: 7652.475603088296
#
#
# including HKD
# new loss function value: 958.8250529423577
#
#
# including AUD
# new loss function value: 633.2279397594097
#
# better solution found by including AUD
# loss function decreased by 6.11% compared to starting value
#
#
#
# including RON
# new loss function value: 714.3194844158746
#
#
# including TRY
# new loss function value: 656.9761568266927
#
#
# including MYR
# new loss function value: 725.3880898220965
#
#
# including CNY
# new loss function value: 922.3667327460493
#
#
# including ZAR
# new loss function value: 1137.9880135645205
#
#
# including CZK
# new loss function value: 1596.3958574783264
#
#
# including SGD
# new loss function value: 625.6054928182141
#
# better solution found by including SGD
# loss function decreased by 7.24% compared to starting value
#
#
#
# including CAD
# new loss function value: 625.2938578432994
#
# better solution found by including CAD
# loss function decreased by 7.28% compared to starting value
#
#
#
# including NOK
# new loss function value: 895.226226155598
#
#
# including PLN
# new loss function value: 748.138673646682
#
#
# including DKK
# new loss function value: 803.6391822966331
#
#
# including RUB
# new loss function value: 1903.307070682984
#
#
# including HUF
# new loss function value: 13592.781929537698
#
#
# including IDR
# new loss function value: 545170.4327103145
#
# CAD is added to currency set
#
# starting loss function value: 625.2938578432994
#
# including KRW
# new loss function value: 60530.640662434555
#
#
# including THB
# new loss function value: 2127.354993415652
#
#
# including HRK
# new loss function value: 747.2775491251404
#
#
# including NZD
# new loss function value: 617.0641998847673
#
# better solution found by including NZD
# loss function decreased by 1.32% compared to starting value
#
#
#
# including PHP
# new loss function value: 2647.01207945397
#
#
# including JPY
# new loss function value: 6613.504058566332
#
#
# including HKD
# new loss function value: 876.0893012983822
#
#
# including AUD
# new loss function value: 597.0060614272842
#
# better solution found by including AUD
# loss function decreased by 4.52% compared to starting value
#
#
#
# including RON
# new loss function value: 666.513099704254
#
#
# including TRY
# new loss function value: 617.3616760563841
#
#
# including MYR
# new loss function value: 676.0004757667299
#
#
# including CNY
# new loss function value: 844.8393125586894
#
#
# including ZAR
# new loss function value: 1029.6575532602365
#
#
# including CZK
# new loss function value: 1422.578562329212
#
#
# including SGD
# new loss function value: 590.4725354776879
#
# better solution found by including SGD
# loss function decreased by 5.57% compared to starting value
#
#
#
# including NOK
# new loss function value: 821.5760211954455
#
#
# including PLN
# new loss function value: 695.5009761878034
#
#
# including DKK
# new loss function value: 743.0728407449044
#
#
# including RUB
# new loss function value: 1685.6453165046332
#
#
# including HUF
# new loss function value: 11705.195195522962
#
#
# including IDR
# new loss function value: 467343.18157904607
#
# SGD is added to currency set
#
# starting loss function value: 590.4725354776879
#
# including KRW
# new loss function value: 53012.00365479074
#
#
# including THB
# new loss function value: 1909.1286943991984
#
#
# including HRK
# new loss function value: 701.5609306450001
#
#
# including NZD
# new loss function value: 587.6242500596737
#
#
# including PHP
# new loss function value: 2363.828644682726
#
#
# including JPY
# new loss function value: 5834.509126406044
#
#
# including HKD
# new loss function value: 814.2712137965872
#
#
# including AUD
# new loss function value: 570.0733789093762
#
# better solution found by including AUD
# loss function decreased by 3.45% compared to starting value
#
#
#
# including RON
# new loss function value: 630.8920374017248
#
#
# including TRY
# new loss function value: 587.8845417098383
#
#
# including MYR
# new loss function value: 639.1934914563911
#
#
# including CNY
# new loss function value: 786.9274736493555
#
#
# including ZAR
# new loss function value: 948.6434342632093
#
#
# including CZK
# new loss function value: 1292.4493171985632
#
#
# including NOK
# new loss function value: 766.5720937065174
#
#
# including PLN
# new loss function value: 656.2564293248304
#
#
# including DKK
# new loss function value: 697.8818108122938
#
#
# including RUB
# new loss function value: 1522.6327271020562
#
#
# including HUF
# new loss function value: 10289.738871243091
#
#
# including IDR
# new loss function value: 408972.97695682576
#
# AUD is added to currency set
#
# starting loss function value: 570.0733789093762
#
# including KRW
# new loss function value: 47169.2565023619
#
#
# including THB
# new loss function value: 1744.478759791642
#
#
# including HRK
# new loss function value: 671.0851920101328
#
#
# including NZD
# new loss function value: 569.8081426009538
#
#
# including PHP
# new loss function value: 2148.6564933770005
#
#
# including JPY
# new loss function value: 5233.705810464393
#
#
# including HKD
# new loss function value: 771.2721103670988
#
#
# including RON
# new loss function value: 608.2683980161102
#
#
# including TRY
# new loss function value: 570.0395129566557
#
#
# including MYR
# new loss function value: 615.6474682869248
#
#
# including CNY
# new loss function value: 746.9665635695599
#
#
# including ZAR
# new loss function value: 890.7140841152078
#
#
# including CZK
# new loss function value: 1196.3193133910777
#
#
# including NOK
# new loss function value: 728.8728925092589
#
#
# including PLN
# new loss function value: 630.8145241699817
#
#
# including DKK
# new loss function value: 667.8148632699491
#
#
# including RUB
# new loss function value: 1400.9267888608492
#
#
# including HUF
# new loss function value: 9193.910028097323
#
#
# including IDR
# new loss function value: 363579.01054861513
#
# No currency needed to be included.

# %%
forward_selection_currencies = list(forward_selection_result["Added currency"].unique())
forward_selection_result
# Out:
#   Added currency Previous loss function value New loss function value
# 0            SEK               -                            -
# 1            GBP        2.32e+03                     1.25e+03
# 2            EUR        1.25e+03                          900
# 3            USD             900                          752
# 4            CHF             752                          674
# 5            CAD             674                          625
# 6            SGD             625                          590
# 7            AUD             590                          570

# %%
def evaluate_inclusion_of_currency_difference_weights(weights, 
                                                      currency_set):
    """Perform forward selection of currencies.
   
    Parameters
    ----------
    weights : array
        The initial weights given to all currencies.
    currency_set : set
        The set containing all currencies of interest."""

    # Initialize string giving best currency to exclude
    best_to_include = "None"
    # Initialize string giving best currency weights
    best_weights = weights.copy()
    # Calculate initial loss function value
    starting_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(weights)

    # So far, this is the best solution
    best_loss_function_value = starting_loss_function_value
    print(f"starting loss function value: {best_loss_function_value}")

    # Each time we include one currency
    for included_currency in currency_set:
        print(f"\nincluding {included_currency}\n")
        
        new_weights = weights.copy()
        no_currencies = (new_weights>0).sum()+1
        possible_weights_included_currency = np.arange(0, 1/no_currencies, 1/no_currencies/10) + 1/no_currencies/10
        
        # We create the new weights,
        for possible_weight in possible_weights_included_currency:
            new_weights[new_weights>0] = (1-possible_weight)/(no_currencies-1)
            new_weights[included_currency] = possible_weight
        
            # and calculate the new loss function value
            new_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(new_weights)
            print(f"weight {included_currency}: {possible_weight}")
            print(f"other weight(s): {(1-possible_weight)/(no_currencies-1)}")
            print(f"new loss function value: {new_loss_function_value}\n")

            # Check whether the new loss function value is lower than the (so far) best one, and
            # the improvement needs to be > .5%
            if new_loss_function_value <= best_loss_function_value and new_loss_function_value < 0.995*starting_loss_function_value:
                print(f"\nbetter solution found by including {included_currency}")
                print(f"loss function decreased by {(best_loss_function_value-new_loss_function_value)/best_loss_function_value*100:.2f}% compared to current best solution\n")
                # If so, save these results
                best_weights = new_weights
                print(best_weights)
                best_loss_function_value = new_loss_function_value
                best_to_include = included_currency

    if best_to_include == "None":
        print("No currency needed to be included.")
    else:
        print(f"\033[1m{best_to_include} is added to currency set\n")
        # Exclude the currency
        currency_set.remove(best_to_include)
    return starting_loss_function_value, best_loss_function_value, best_to_include, best_weights, currency_set

# %%
# Create weights series and specificy first currency to include
weights = pd.Series(0, index=reference_date_exhange_rate.loc[all_currencies].index)
# TODO: Change starting currency
first_currency = "SEK"
weights[first_currency] = 1
currency_set = set(all_currencies)
currency_set.remove(first_currency)

# Create list to save results
forward_selection_weights_result = []
forward_selection_weights_result.append((first_currency, "-", "-"))

# Set maximum number of currencies to include
max_currencies_to_include = 14

for i in range(0, max_currencies_to_include):
    _, _, best_to_include, best_weights, currencies = evaluate_inclusion_of_currency_difference_weights(weights, currency_set)
    if best_to_include == "None":
        break
    weights = best_weights
    forward_selection_weights_result.append((best_to_include, starting_loss_function_value, best_loss_function_value))
    
forward_selection_weights_result = pd.DataFrame(forward_selection_weights_result)
forward_selection_weights_result.columns = ["Added currency", "Previous loss function value", "New loss function value"]
# Out:
# starting loss function value: 2316.9680591005704
#
# including KRW
#
# weight KRW: 0.05
# other weight(s): 0.95
# new loss function value: 23199.25573064465
#
# weight KRW: 0.1
# other weight(s): 0.9
# new loss function value: 44081.54340218873
#
# weight KRW: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 64963.83107373281
#
# weight KRW: 0.2
# other weight(s): 0.8
# new loss function value: 85846.11874527688
#
# weight KRW: 0.25
# other weight(s): 0.75
# new loss function value: 106728.40641682094
#
# weight KRW: 0.3
# other weight(s): 0.7
# new loss function value: 127610.694088365
#
# weight KRW: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 148492.98175990913
#
# weight KRW: 0.4
# other weight(s): 0.6
# new loss function value: 169375.26943145323
#
# weight KRW: 0.45
# other weight(s): 0.55
# new loss function value: 190257.5571029973
#
# weight KRW: 0.5
# other weight(s): 0.5
# new loss function value: 211139.84477454133
#
#
# including THB
#
# weight THB: 0.05
# other weight(s): 0.95
# new loss function value: 2758.1057464880296
#
# weight THB: 0.1
# other weight(s): 0.9
# new loss function value: 3199.2434338754906
#
# weight THB: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 3640.3811212629507
#
# weight THB: 0.2
# other weight(s): 0.8
# new loss function value: 4081.518808650411
#
# weight THB: 0.25
# other weight(s): 0.75
# new loss function value: 4522.65649603787
#
# weight THB: 0.3
# other weight(s): 0.7
# new loss function value: 4963.794183425329
#
# weight THB: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 5404.93187081279
#
# weight THB: 0.4
# other weight(s): 0.6
# new loss function value: 5846.069558200248
#
# weight THB: 0.45
# other weight(s): 0.55
# new loss function value: 6287.207245587711
#
# weight THB: 0.5
# other weight(s): 0.5
# new loss function value: 6728.344932975171
#
#
# including EUR
#
# weight EUR: 0.05
# other weight(s): 0.95
# new loss function value: 2210.848597876791
#
#
# better solution found by including EUR
# loss function decreased by 4.58% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.05
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.95
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.00
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight EUR: 0.1
# other weight(s): 0.9
# new loss function value: 2104.729136653012
#
#
# better solution found by including EUR
# loss function decreased by 4.80% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.1
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.9
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
# weight EUR: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 1998.609675429233
#
#
# better solution found by including EUR
# loss function decreased by 5.04% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.15
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.85
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.00
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight EUR: 0.2
# other weight(s): 0.8
# new loss function value: 1892.490214205455
#
#
# better solution found by including EUR
# loss function decreased by 5.31% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.2
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.8
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
# weight EUR: 0.25
# other weight(s): 0.75
# new loss function value: 1786.3707529816766
#
#
# better solution found by including EUR
# loss function decreased by 5.61% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.25
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.75
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.00
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight EUR: 0.3
# other weight(s): 0.7
# new loss function value: 1680.2512917578974
#
#
# better solution found by including EUR
# loss function decreased by 5.94% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.3
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.7
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
# weight EUR: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1574.1318305341185
#
#
# better solution found by including EUR
# loss function decreased by 6.32% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.35
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.65
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.00
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight EUR: 0.4
# other weight(s): 0.6
# new loss function value: 1468.01236931034
#
#
# better solution found by including EUR
# loss function decreased by 6.74% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.4
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.6
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
# weight EUR: 0.45
# other weight(s): 0.55
# new loss function value: 1361.8929080865614
#
#
# better solution found by including EUR
# loss function decreased by 7.23% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.45
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.55
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.00
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight EUR: 0.5
# other weight(s): 0.5
# new loss function value: 1255.7734468627825
#
#
# better solution found by including EUR
# loss function decreased by 7.79% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.5
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.5
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
#
# including HRK
#
# weight HRK: 0.05
# other weight(s): 0.95
# new loss function value: 2275.0786409863504
#
# weight HRK: 0.1
# other weight(s): 0.9
# new loss function value: 2233.1892228721313
#
# weight HRK: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2191.299804757912
#
# weight HRK: 0.2
# other weight(s): 0.8
# new loss function value: 2149.410386643693
#
# weight HRK: 0.25
# other weight(s): 0.75
# new loss function value: 2107.520968529474
#
# weight HRK: 0.3
# other weight(s): 0.7
# new loss function value: 2065.6315504152544
#
# weight HRK: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 2023.7421323010353
#
# weight HRK: 0.4
# other weight(s): 0.6
# new loss function value: 1981.852714186816
#
# weight HRK: 0.45
# other weight(s): 0.55
# new loss function value: 1939.9632960725971
#
# weight HRK: 0.5
# other weight(s): 0.5
# new loss function value: 1898.073877958378
#
#
# including NZD
#
# weight NZD: 0.05
# other weight(s): 0.95
# new loss function value: 2229.5039687522203
#
# weight NZD: 0.1
# other weight(s): 0.9
# new loss function value: 2142.0398784038707
#
# weight NZD: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2054.5757880555207
#
# weight NZD: 0.2
# other weight(s): 0.8
# new loss function value: 1967.1116977071708
#
# weight NZD: 0.25
# other weight(s): 0.75
# new loss function value: 1879.6476073588215
#
# weight NZD: 0.3
# other weight(s): 0.7
# new loss function value: 1792.1835170104716
#
# weight NZD: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1704.719426662122
#
# weight NZD: 0.4
# other weight(s): 0.6
# new loss function value: 1617.255336313772
#
# weight NZD: 0.45
# other weight(s): 0.55
# new loss function value: 1529.7912459654228
#
# weight NZD: 0.5
# other weight(s): 0.5
# new loss function value: 1442.3271556170725
#
#
# including PHP
#
# weight PHP: 0.05
# other weight(s): 0.95
# new loss function value: 2939.9857266014415
#
# weight PHP: 0.1
# other weight(s): 0.9
# new loss function value: 3563.003394102312
#
# weight PHP: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 4186.021061603183
#
# weight PHP: 0.2
# other weight(s): 0.8
# new loss function value: 4809.038729104054
#
# weight PHP: 0.25
# other weight(s): 0.75
# new loss function value: 5432.056396604926
#
# weight PHP: 0.3
# other weight(s): 0.7
# new loss function value: 6055.074064105796
#
# weight PHP: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 6678.091731606668
#
# weight PHP: 0.4
# other weight(s): 0.6
# new loss function value: 7301.109399107537
#
# weight PHP: 0.45
# other weight(s): 0.55
# new loss function value: 7924.127066608411
#
# weight PHP: 0.5
# other weight(s): 0.5
# new loss function value: 8547.144734109283
#
#
# including JPY
#
# weight JPY: 0.05
# other weight(s): 0.95
# new loss function value: 4328.257919290768
#
# weight JPY: 0.1
# other weight(s): 0.9
# new loss function value: 6339.547779480966
#
# weight JPY: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 8350.837639671163
#
# weight JPY: 0.2
# other weight(s): 0.8
# new loss function value: 10362.12749986136
#
# weight JPY: 0.25
# other weight(s): 0.75
# new loss function value: 12373.417360051559
#
# weight JPY: 0.3
# other weight(s): 0.7
# new loss function value: 14384.707220241758
#
# weight JPY: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 16395.997080431953
#
# weight JPY: 0.4
# other weight(s): 0.6
# new loss function value: 18407.28694062215
#
# weight JPY: 0.45
# other weight(s): 0.55
# new loss function value: 20418.57680081235
#
# weight JPY: 0.5
# other weight(s): 0.5
# new loss function value: 22429.866661002554
#
#
# including USD
#
# weight USD: 0.05
# other weight(s): 0.95
# new loss function value: 2216.593250899687
#
# weight USD: 0.1
# other weight(s): 0.9
# new loss function value: 2116.218442698805
#
# weight USD: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2015.8436344979227
#
# weight USD: 0.2
# other weight(s): 0.8
# new loss function value: 1915.4688262970399
#
# weight USD: 0.25
# other weight(s): 0.75
# new loss function value: 1815.094018096158
#
# weight USD: 0.3
# other weight(s): 0.7
# new loss function value: 1714.719209895275
#
# weight USD: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1614.3444016943927
#
# weight USD: 0.4
# other weight(s): 0.6
# new loss function value: 1513.9695934935103
#
# weight USD: 0.45
# other weight(s): 0.55
# new loss function value: 1413.5947852926276
#
# weight USD: 0.5
# other weight(s): 0.5
# new loss function value: 1313.2199770917455
#
#
# better solution found by including USD
# loss function decreased by -4.57% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.0
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.5
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.5
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
#
# including HKD
#
# weight HKD: 0.05
# other weight(s): 0.95
# new loss function value: 2320.1627542469855
#
# weight HKD: 0.1
# other weight(s): 0.9
# new loss function value: 2323.3574493934007
#
# weight HKD: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2326.552144539816
#
# weight HKD: 0.2
# other weight(s): 0.8
# new loss function value: 2329.7468396862323
#
# weight HKD: 0.25
# other weight(s): 0.75
# new loss function value: 2332.9415348326474
#
# weight HKD: 0.3
# other weight(s): 0.7
# new loss function value: 2336.136229979063
#
# weight HKD: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 2339.330925125479
#
# weight HKD: 0.4
# other weight(s): 0.6
# new loss function value: 2342.5256202718942
#
# weight HKD: 0.45
# other weight(s): 0.55
# new loss function value: 2345.72031541831
#
# weight HKD: 0.5
# other weight(s): 0.5
# new loss function value: 2348.915010564725
#
#
# including AUD
#
# weight AUD: 0.05
# other weight(s): 0.95
# new loss function value: 2222.4836202921006
#
# weight AUD: 0.1
# other weight(s): 0.9
# new loss function value: 2127.9991814836326
#
# weight AUD: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2033.5147426751632
#
# weight AUD: 0.2
# other weight(s): 0.8
# new loss function value: 1939.0303038666946
#
# weight AUD: 0.25
# other weight(s): 0.75
# new loss function value: 1844.5458650582261
#
# weight AUD: 0.3
# other weight(s): 0.7
# new loss function value: 1750.0614262497566
#
# weight AUD: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1655.5769874412883
#
# weight AUD: 0.4
# other weight(s): 0.6
# new loss function value: 1561.092548632819
#
# weight AUD: 0.45
# other weight(s): 0.55
# new loss function value: 1466.6081098243505
#
# weight AUD: 0.5
# other weight(s): 0.5
# new loss function value: 1372.1236710158819
#
#
# better solution found by including AUD
# loss function decreased by -4.49% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.0
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.5
# RON    0.0
# SEK    0.5
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
#
# including RON
#
# weight RON: 0.05
# other weight(s): 0.95
# new loss function value: 2246.811083689041
#
# weight RON: 0.1
# other weight(s): 0.9
# new loss function value: 2176.6541082775116
#
# weight RON: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2106.497132865982
#
# weight RON: 0.2
# other weight(s): 0.8
# new loss function value: 2036.3401574544525
#
# weight RON: 0.25
# other weight(s): 0.75
# new loss function value: 1966.1831820429234
#
# weight RON: 0.3
# other weight(s): 0.7
# new loss function value: 1896.0262066313937
#
# weight RON: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1825.8692312198643
#
# weight RON: 0.4
# other weight(s): 0.6
# new loss function value: 1755.7122558083352
#
# weight RON: 0.45
# other weight(s): 0.55
# new loss function value: 1685.555280396806
#
# weight RON: 0.5
# other weight(s): 0.5
# new loss function value: 1615.3983049852766
#
#
# including TRY
#
# weight TRY: 0.05
# other weight(s): 0.95
# new loss function value: 2229.6080854122856
#
# weight TRY: 0.1
# other weight(s): 0.9
# new loss function value: 2142.248111724002
#
# weight TRY: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2054.888138035718
#
# weight TRY: 0.2
# other weight(s): 0.8
# new loss function value: 1967.5281643474343
#
# weight TRY: 0.25
# other weight(s): 0.75
# new loss function value: 1880.1681906591505
#
# weight TRY: 0.3
# other weight(s): 0.7
# new loss function value: 1792.8082169708664
#
# weight TRY: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1705.4482432825823
#
# weight TRY: 0.4
# other weight(s): 0.6
# new loss function value: 1618.0882695942992
#
# weight TRY: 0.45
# other weight(s): 0.55
# new loss function value: 1530.7282959060155
#
# weight TRY: 0.5
# other weight(s): 0.5
# new loss function value: 1443.368322217731
#
#
# including MYR
#
# weight MYR: 0.05
# other weight(s): 0.95
# new loss function value: 2250.131665310907
#
# weight MYR: 0.1
# other weight(s): 0.9
# new loss function value: 2183.2952715212446
#
# weight MYR: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2116.458877731581
#
# weight MYR: 0.2
# other weight(s): 0.8
# new loss function value: 2049.6224839419187
#
# weight MYR: 0.25
# other weight(s): 0.75
# new loss function value: 1982.7860901522558
#
# weight MYR: 0.3
# other weight(s): 0.7
# new loss function value: 1915.9496963625934
#
# weight MYR: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1849.1133025729305
#
# weight MYR: 0.4
# other weight(s): 0.6
# new loss function value: 1782.2769087832676
#
# weight MYR: 0.45
# other weight(s): 0.55
# new loss function value: 1715.4405149936051
#
# weight MYR: 0.5
# other weight(s): 0.5
# new loss function value: 1648.6041212039418
#
#
# including CNY
#
# weight CNY: 0.05
# other weight(s): 0.95
# new loss function value: 2309.2252581880925
#
# weight CNY: 0.1
# other weight(s): 0.9
# new loss function value: 2301.4824572756165
#
# weight CNY: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2293.739656363139
#
# weight CNY: 0.2
# other weight(s): 0.8
# new loss function value: 2285.996855450662
#
# weight CNY: 0.25
# other weight(s): 0.75
# new loss function value: 2278.2540545381858
#
# weight CNY: 0.3
# other weight(s): 0.7
# new loss function value: 2270.511253625708
#
# weight CNY: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 2262.7684527132305
#
# weight CNY: 0.4
# other weight(s): 0.6
# new loss function value: 2255.0256518007545
#
# weight CNY: 0.45
# other weight(s): 0.55
# new loss function value: 2247.282850888277
#
# weight CNY: 0.5
# other weight(s): 0.5
# new loss function value: 2239.5400499758002
#
#
# including CHF
#
# weight CHF: 0.05
# other weight(s): 0.95
# new loss function value: 2219.273252342809
#
# weight CHF: 0.1
# other weight(s): 0.9
# new loss function value: 2121.5784455850485
#
# weight CHF: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2023.883638827287
#
# weight CHF: 0.2
# other weight(s): 0.8
# new loss function value: 1926.1888320695266
#
# weight CHF: 0.25
# other weight(s): 0.75
# new loss function value: 1828.4940253117652
#
# weight CHF: 0.3
# other weight(s): 0.7
# new loss function value: 1730.7992185540047
#
# weight CHF: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1633.1044117962433
#
# weight CHF: 0.4
# other weight(s): 0.6
# new loss function value: 1535.4096050384826
#
# weight CHF: 0.45
# other weight(s): 0.55
# new loss function value: 1437.7147982807219
#
#
# better solution found by including CHF
# loss function decreased by -4.78% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.00
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.55
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.45
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.00
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight CHF: 0.5
# other weight(s): 0.5
# new loss function value: 1340.019991522961
#
#
# better solution found by including CHF
# loss function decreased by 6.80% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.0
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.5
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.5
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
#
# including ZAR
#
# weight ZAR: 0.05
# other weight(s): 0.95
# new loss function value: 2373.9116424336344
#
# weight ZAR: 0.1
# other weight(s): 0.9
# new loss function value: 2430.8552257666984
#
# weight ZAR: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2487.7988090997633
#
# weight ZAR: 0.2
# other weight(s): 0.8
# new loss function value: 2544.742392432828
#
# weight ZAR: 0.25
# other weight(s): 0.75
# new loss function value: 2601.6859757658926
#
# weight ZAR: 0.3
# other weight(s): 0.7
# new loss function value: 2658.629559098957
#
# weight ZAR: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 2715.573142432021
#
# weight ZAR: 0.4
# other weight(s): 0.6
# new loss function value: 2772.5167257650864
#
# weight ZAR: 0.45
# other weight(s): 0.55
# new loss function value: 2829.4603090981504
#
# weight ZAR: 0.5
# other weight(s): 0.5
# new loss function value: 2886.4038924312154
#
#
# including CZK
#
# weight CZK: 0.05
# other weight(s): 0.95
# new loss function value: 2511.4339956077765
#
# weight CZK: 0.1
# other weight(s): 0.9
# new loss function value: 2705.8999321149813
#
# weight CZK: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2900.365868622188
#
# weight CZK: 0.2
# other weight(s): 0.8
# new loss function value: 3094.8318051293936
#
# weight CZK: 0.25
# other weight(s): 0.75
# new loss function value: 3289.2977416366007
#
# weight CZK: 0.3
# other weight(s): 0.7
# new loss function value: 3483.763678143807
#
# weight CZK: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 3678.2296146510125
#
# weight CZK: 0.4
# other weight(s): 0.6
# new loss function value: 3872.6955511582187
#
# weight CZK: 0.45
# other weight(s): 0.55
# new loss function value: 4067.1614876654253
#
# weight CZK: 0.5
# other weight(s): 0.5
# new loss function value: 4261.6274241726305
#
#
# including SGD
#
# weight SGD: 0.05
# other weight(s): 0.95
# new loss function value: 2220.1968862097424
#
# weight SGD: 0.1
# other weight(s): 0.9
# new loss function value: 2123.425713318915
#
# weight SGD: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2026.6545404280869
#
# weight SGD: 0.2
# other weight(s): 0.8
# new loss function value: 1929.8833675372603
#
# weight SGD: 0.25
# other weight(s): 0.75
# new loss function value: 1833.1121946464323
#
# weight SGD: 0.3
# other weight(s): 0.7
# new loss function value: 1736.3410217556047
#
# weight SGD: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1639.5698488647765
#
# weight SGD: 0.4
# other weight(s): 0.6
# new loss function value: 1542.7986759739501
#
# weight SGD: 0.45
# other weight(s): 0.55
# new loss function value: 1446.0275030831224
#
# weight SGD: 0.5
# other weight(s): 0.5
# new loss function value: 1349.2563301922946
#
#
# better solution found by including SGD
# loss function decreased by -0.69% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.0
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.5
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.5
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
#
# including CAD
#
# weight CAD: 0.05
# other weight(s): 0.95
# new loss function value: 2220.1033957172676
#
# weight CAD: 0.1
# other weight(s): 0.9
# new loss function value: 2123.2387323339663
#
# weight CAD: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2026.374068950664
#
# weight CAD: 0.2
# other weight(s): 0.8
# new loss function value: 1929.5094055673628
#
# weight CAD: 0.25
# other weight(s): 0.75
# new loss function value: 1832.6447421840603
#
# weight CAD: 0.3
# other weight(s): 0.7
# new loss function value: 1735.780078800758
#
# weight CAD: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1638.9154154174555
#
# weight CAD: 0.4
# other weight(s): 0.6
# new loss function value: 1542.0507520341541
#
# weight CAD: 0.45
# other weight(s): 0.55
# new loss function value: 1445.1860886508525
#
# weight CAD: 0.5
# other weight(s): 0.5
# new loss function value: 1348.3214252675502
#
#
# better solution found by including CAD
# loss function decreased by 0.07% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.0
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.5
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.5
# dtype: float64
#
# including NOK
#
# weight NOK: 0.05
# other weight(s): 0.95
# new loss function value: 2301.0831062109573
#
# weight NOK: 0.1
# other weight(s): 0.9
# new loss function value: 2285.198153321346
#
# weight NOK: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2269.3132004317335
#
# weight NOK: 0.2
# other weight(s): 0.8
# new loss function value: 2253.4282475421205
#
# weight NOK: 0.25
# other weight(s): 0.75
# new loss function value: 2237.543294652508
#
# weight NOK: 0.3
# other weight(s): 0.7
# new loss function value: 2221.658341762896
#
# weight NOK: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 2205.7733888732837
#
# weight NOK: 0.4
# other weight(s): 0.6
# new loss function value: 2189.8884359836716
#
# weight NOK: 0.45
# other weight(s): 0.55
# new loss function value: 2174.0034830940594
#
# weight NOK: 0.5
# other weight(s): 0.5
# new loss function value: 2158.1185302044464
#
#
# including GBP
#
# weight GBP: 0.05
# other weight(s): 0.95
# new loss function value: 2210.5195382891125
#
# weight GBP: 0.1
# other weight(s): 0.9
# new loss function value: 2104.071017477656
#
# weight GBP: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 1997.6224966661985
#
# weight GBP: 0.2
# other weight(s): 0.8
# new loss function value: 1891.173975854741
#
# weight GBP: 0.25
# other weight(s): 0.75
# new loss function value: 1784.725455043284
#
# weight GBP: 0.3
# other weight(s): 0.7
# new loss function value: 1678.2769342318265
#
# weight GBP: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1571.8284134203693
#
# weight GBP: 0.4
# other weight(s): 0.6
# new loss function value: 1465.3798926089125
#
# weight GBP: 0.45
# other weight(s): 0.55
# new loss function value: 1358.9313717974558
#
#
# better solution found by including GBP
# loss function decreased by -0.79% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.00
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.55
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.45
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight GBP: 0.5
# other weight(s): 0.5
# new loss function value: 1252.4828509859985
#
#
# better solution found by including GBP
# loss function decreased by 7.83% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.0
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.5
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.5
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
#
# including PLN
#
# weight PLN: 0.05
# other weight(s): 0.95
# new loss function value: 2256.9568404582833
#
# weight PLN: 0.1
# other weight(s): 0.9
# new loss function value: 2196.9456218159953
#
# weight PLN: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2136.934403173709
#
# weight PLN: 0.2
# other weight(s): 0.8
# new loss function value: 2076.9231845314216
#
# weight PLN: 0.25
# other weight(s): 0.75
# new loss function value: 2016.9119658891343
#
# weight PLN: 0.3
# other weight(s): 0.7
# new loss function value: 1956.9007472468468
#
# weight PLN: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1896.88952860456
#
# weight PLN: 0.4
# other weight(s): 0.6
# new loss function value: 1836.8783099622726
#
# weight PLN: 0.45
# other weight(s): 0.55
# new loss function value: 1776.8670913199858
#
# weight PLN: 0.5
# other weight(s): 0.5
# new loss function value: 1716.8558726776992
#
#
# including DKK
#
# weight DKK: 0.05
# other weight(s): 0.95
# new loss function value: 2273.606993053268
#
# weight DKK: 0.1
# other weight(s): 0.9
# new loss function value: 2230.2459270059667
#
# weight DKK: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2186.8848609586644
#
# weight DKK: 0.2
# other weight(s): 0.8
# new loss function value: 2143.523794911363
#
# weight DKK: 0.25
# other weight(s): 0.75
# new loss function value: 2100.162728864061
#
# weight DKK: 0.3
# other weight(s): 0.7
# new loss function value: 2056.8016628167597
#
# weight DKK: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 2013.4405967694572
#
# weight DKK: 0.4
# other weight(s): 0.6
# new loss function value: 1970.079530722156
#
# weight DKK: 0.45
# other weight(s): 0.55
# new loss function value: 1926.7184646748542
#
# weight DKK: 0.5
# other weight(s): 0.5
# new loss function value: 1883.3573986275526
#
#
# including RUB
#
# weight RUB: 0.05
# other weight(s): 0.95
# new loss function value: 2603.5073595691733
#
# weight RUB: 0.1
# other weight(s): 0.9
# new loss function value: 2890.0466600377763
#
# weight RUB: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 3176.58596050638
#
# weight RUB: 0.2
# other weight(s): 0.8
# new loss function value: 3463.1252609749827
#
# weight RUB: 0.25
# other weight(s): 0.75
# new loss function value: 3749.664561443587
#
# weight RUB: 0.3
# other weight(s): 0.7
# new loss function value: 4036.2038619121904
#
# weight RUB: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 4322.7431623807925
#
# weight RUB: 0.4
# other weight(s): 0.6
# new loss function value: 4609.282462849397
#
# weight RUB: 0.45
# other weight(s): 0.55
# new loss function value: 4895.821763317999
#
# weight RUB: 0.5
# other weight(s): 0.5
# new loss function value: 5182.361063786604
#
#
# including HUF
#
# weight HUF: 0.05
# other weight(s): 0.95
# new loss function value: 6110.349817225589
#
# weight HUF: 0.1
# other weight(s): 0.9
# new loss function value: 9903.731575350605
#
# weight HUF: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 13697.113333475618
#
# weight HUF: 0.2
# other weight(s): 0.8
# new loss function value: 17490.49509160064
#
# weight HUF: 0.25
# other weight(s): 0.75
# new loss function value: 21283.876849725653
#
# weight HUF: 0.3
# other weight(s): 0.7
# new loss function value: 25077.25860785067
#
# weight HUF: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 28870.6403659757
#
# weight HUF: 0.4
# other weight(s): 0.6
# new loss function value: 32664.022124100706
#
# weight HUF: 0.45
# other weight(s): 0.55
# new loss function value: 36457.403882225735
#
# weight HUF: 0.5
# other weight(s): 0.5
# new loss function value: 40250.78564035073
#
#
# including IDR
#
# weight IDR: 0.05
# other weight(s): 0.95
# new loss function value: 165583.64505145865
#
# weight IDR: 0.1
# other weight(s): 0.9
# new loss function value: 328850.3220438168
#
# weight IDR: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 492116.99903617497
#
# weight IDR: 0.2
# other weight(s): 0.8
# new loss function value: 655383.6760285328
#
# weight IDR: 0.25
# other weight(s): 0.75
# new loss function value: 818650.3530208908
#
# weight IDR: 0.3
# other weight(s): 0.7
# new loss function value: 981917.0300132489
#
# weight IDR: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1145183.7070056072
#
# weight IDR: 0.4
# other weight(s): 0.6
# new loss function value: 1308450.3839979654
#
# weight IDR: 0.45
# other weight(s): 0.55
# new loss function value: 1471717.0609903235
#
# weight IDR: 0.5
# other weight(s): 0.5
# new loss function value: 1634983.7379826815
#
# GBP is added to currency set
#
# starting loss function value: 1252.4828509859985
#
# including KRW
#
# weight KRW: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 15209.490805619202
#
# weight KRW: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 29166.4987602524
#
# weight KRW: 0.1
# other weight(s): 0.45
# new loss function value: 43123.506714885596
#
# weight KRW: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 57080.514669518816
#
# weight KRW: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 71037.522624152
#
# weight KRW: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 84994.53057878523
#
# weight KRW: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 98951.53853341842
#
# weight KRW: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 112908.54648805161
#
# weight KRW: 0.3
# other weight(s): 0.35
# new loss function value: 126865.55444268485
#
# weight KRW: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 140822.562397318
#
#
# including THB
#
# weight THB: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1582.0574828481238
#
# weight THB: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1911.6321147102497
#
# weight THB: 0.1
# other weight(s): 0.45
# new loss function value: 2241.2067465723753
#
# weight THB: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 2570.781378434501
#
# weight THB: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 2900.356010296627
#
# weight THB: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 3229.9306421587526
#
# weight THB: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 3559.505274020878
#
# weight THB: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 3889.079905883004
#
# weight THB: 0.3
# other weight(s): 0.35
# new loss function value: 4218.65453774513
#
# weight THB: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 4548.229169607255
#
#
# including EUR
#
# weight EUR: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1217.2193837739646
#
#
# better solution found by including EUR
# loss function decreased by 2.82% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.033
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.483
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.483
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
# weight EUR: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1181.9559165619314
#
#
# better solution found by including EUR
# loss function decreased by 2.90% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.067
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.467
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.467
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
# weight EUR: 0.1
# other weight(s): 0.45
# new loss function value: 1146.6924493498982
#
#
# better solution found by including EUR
# loss function decreased by 2.98% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.10
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.45
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.45
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight EUR: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 1111.4289821378645
#
#
# better solution found by including EUR
# loss function decreased by 3.08% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.133
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.433
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.433
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
# weight EUR: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 1076.165514925831
#
#
# better solution found by including EUR
# loss function decreased by 3.17% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.167
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.417
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.417
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
# weight EUR: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 1040.9020477137976
#
#
# better solution found by including EUR
# loss function decreased by 3.28% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.2
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.4
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.4
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
# weight EUR: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 1005.6385805017643
#
#
# better solution found by including EUR
# loss function decreased by 3.39% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.233
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.383
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.383
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
# weight EUR: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 970.375113289731
#
#
# better solution found by including EUR
# loss function decreased by 3.51% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.267
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.367
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.367
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
# weight EUR: 0.3
# other weight(s): 0.35
# new loss function value: 935.1116460776974
#
#
# better solution found by including EUR
# loss function decreased by 3.63% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.30
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.35
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.35
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight EUR: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 899.8481788656636
#
#
# better solution found by including EUR
# loss function decreased by 3.77% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.333
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.333
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.333
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
#
# including HRK
#
# weight HRK: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1260.0394125136709
#
# weight HRK: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1267.595974041344
#
# weight HRK: 0.1
# other weight(s): 0.45
# new loss function value: 1275.1525355690171
#
# weight HRK: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 1282.7090970966901
#
# weight HRK: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 1290.265658624363
#
# weight HRK: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 1297.8222201520355
#
# weight HRK: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 1305.3787816797085
#
# weight HRK: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 1312.9353432073815
#
# weight HRK: 0.3
# other weight(s): 0.35
# new loss function value: 1320.4919047350545
#
# weight HRK: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 1328.0484662627275
#
#
# including NZD
#
# weight NZD: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1229.6562976909172
#
# weight NZD: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1206.8297443958363
#
# weight NZD: 0.1
# other weight(s): 0.45
# new loss function value: 1184.003191100756
#
# weight NZD: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 1161.1766378056752
#
# weight NZD: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 1138.3500845105943
#
# weight NZD: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 1115.5235312155137
#
# weight NZD: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 1092.6969779204328
#
# weight NZD: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 1069.8704246253521
#
# weight NZD: 0.3
# other weight(s): 0.35
# new loss function value: 1047.0438713302715
#
# weight NZD: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 1024.2173180351906
#
#
# including PHP
#
# weight PHP: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1703.3108029237314
#
# weight PHP: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 2154.138754861465
#
# weight PHP: 0.1
# other weight(s): 0.45
# new loss function value: 2604.9667067991973
#
# weight PHP: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 3055.7946587369306
#
# weight PHP: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 3506.622610674663
#
# weight PHP: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 3957.450562612396
#
# weight PHP: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 4408.278514550129
#
# weight PHP: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 4859.106466487863
#
# weight PHP: 0.3
# other weight(s): 0.35
# new loss function value: 5309.934418425597
#
# weight PHP: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 5760.762370363327
#
#
# including JPY
#
# weight JPY: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 2628.825598049949
#
# weight JPY: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 4005.1683451139
#
# weight JPY: 0.1
# other weight(s): 0.45
# new loss function value: 5381.511092177852
#
# weight JPY: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 6757.8538392417995
#
# weight JPY: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 8134.196586305752
#
# weight JPY: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 9510.539333369703
#
# weight JPY: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 10886.882080433652
#
# weight JPY: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 12263.224827497603
#
# weight JPY: 0.3
# other weight(s): 0.35
# new loss function value: 13639.567574561559
#
# weight JPY: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 15015.91032162551
#
#
# including USD
#
# weight USD: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1221.0491524558959
#
# weight USD: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1189.6154539257927
#
# weight USD: 0.1
# other weight(s): 0.45
# new loss function value: 1158.1817553956907
#
# weight USD: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 1126.7480568655878
#
# weight USD: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 1095.3143583354852
#
# weight USD: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 1063.8806598053827
#
# weight USD: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 1032.4469612752803
#
# weight USD: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 1001.0132627451775
#
# weight USD: 0.3
# other weight(s): 0.35
# new loss function value: 969.579564215075
#
# weight USD: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 938.1458656849725
#
#
# better solution found by including USD
# loss function decreased by -4.26% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.000
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.333
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.333
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.333
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
#
# including HKD
#
# weight HKD: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1290.0954880207605
#
# weight HKD: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1327.7081250555236
#
# weight HKD: 0.1
# other weight(s): 0.45
# new loss function value: 1365.3207620902863
#
# weight HKD: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 1402.933399125049
#
# weight HKD: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 1440.5460361598123
#
# weight HKD: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 1478.1586731945747
#
# weight HKD: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 1515.7713102293376
#
# weight HKD: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 1553.3839472641
#
# weight HKD: 0.3
# other weight(s): 0.35
# new loss function value: 1590.9965842988627
#
# weight HKD: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 1628.6092213336262
#
#
# including AUD
#
# weight AUD: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1224.9760653841713
#
# weight AUD: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1197.4692797823443
#
# weight AUD: 0.1
# other weight(s): 0.45
# new loss function value: 1169.9624941805178
#
# weight AUD: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 1142.4557085786907
#
# weight AUD: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 1114.9489229768644
#
# weight AUD: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 1087.4421373750372
#
# weight AUD: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 1059.9353517732102
#
# weight AUD: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 1032.4285661713836
#
# weight AUD: 0.3
# other weight(s): 0.35
# new loss function value: 1004.9217805695571
#
# weight AUD: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 977.41499496773
#
#
# better solution found by including AUD
# loss function decreased by -4.19% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.000
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.333
# RON    0.000
# SEK    0.333
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.333
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
#
# including RON
#
# weight RON: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1241.1943743154643
#
# weight RON: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1229.9058976449303
#
# weight RON: 0.1
# other weight(s): 0.45
# new loss function value: 1218.6174209743967
#
# weight RON: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 1207.3289443038627
#
# weight RON: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 1196.0404676333292
#
# weight RON: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 1184.7519909627952
#
# weight RON: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 1173.463514292261
#
# weight RON: 0.26666666666666666
# ...
# EUR    0.090
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.090
# HKD    0.000
# AUD    0.090
# RON    0.000
# SEK    0.090
# TRY    0.090
# CNY    0.000
# MYR    0.008
# CHF    0.090
# ZAR    0.000
# CZK    0.000
# SGD    0.090
# NOK    0.000
# GBP    0.090
# PLN    0.090
# DKK    0.090
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.090
# dtype: float64
# weight MYR: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 704.3887249038138
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.089
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.089
# HKD    0.000
# AUD    0.089
# RON    0.000
# SEK    0.089
# TRY    0.089
# CNY    0.000
# MYR    0.017
# CHF    0.089
# ZAR    0.000
# CZK    0.000
# SGD    0.089
# NOK    0.000
# GBP    0.089
# PLN    0.089
# DKK    0.089
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.089
# dtype: float64
# weight MYR: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 706.726449127572
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.089
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.089
# HKD    0.000
# AUD    0.089
# RON    0.000
# SEK    0.089
# TRY    0.089
# CNY    0.000
# MYR    0.025
# CHF    0.089
# ZAR    0.000
# CZK    0.000
# SGD    0.089
# NOK    0.000
# GBP    0.089
# PLN    0.089
# DKK    0.089
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.089
# dtype: float64
# weight MYR: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 709.0641733513305
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.088
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.088
# HKD    0.000
# AUD    0.088
# RON    0.000
# SEK    0.088
# TRY    0.088
# CNY    0.000
# MYR    0.033
# CHF    0.088
# ZAR    0.000
# CZK    0.000
# SGD    0.088
# NOK    0.000
# GBP    0.088
# PLN    0.088
# DKK    0.088
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.088
# dtype: float64
# weight MYR: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 711.4018975750892
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.087
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.087
# HKD    0.000
# AUD    0.087
# RON    0.000
# SEK    0.087
# TRY    0.087
# CNY    0.000
# MYR    0.042
# CHF    0.087
# ZAR    0.000
# CZK    0.000
# SGD    0.087
# NOK    0.000
# GBP    0.087
# PLN    0.087
# DKK    0.087
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.087
# dtype: float64
# weight MYR: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 713.7396217988473
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.086
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.086
# HKD    0.000
# AUD    0.086
# RON    0.000
# SEK    0.086
# TRY    0.086
# CNY    0.000
# MYR    0.050
# CHF    0.086
# ZAR    0.000
# CZK    0.000
# SGD    0.086
# NOK    0.000
# GBP    0.086
# PLN    0.086
# DKK    0.086
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.086
# dtype: float64
# weight MYR: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 716.077346022606
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.086
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.086
# HKD    0.000
# AUD    0.086
# RON    0.000
# SEK    0.086
# TRY    0.086
# CNY    0.000
# MYR    0.058
# CHF    0.086
# ZAR    0.000
# CZK    0.000
# SGD    0.086
# NOK    0.000
# GBP    0.086
# PLN    0.086
# DKK    0.086
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.086
# dtype: float64
# weight MYR: 0.06666666666666667
# other weight(s): 0.08484848484848485
# new loss function value: 718.4150702463644
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.085
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.085
# HKD    0.000
# AUD    0.085
# RON    0.000
# SEK    0.085
# TRY    0.085
# CNY    0.000
# MYR    0.067
# CHF    0.085
# ZAR    0.000
# CZK    0.000
# SGD    0.085
# NOK    0.000
# GBP    0.085
# PLN    0.085
# DKK    0.085
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.085
# dtype: float64
# weight MYR: 0.075
# other weight(s): 0.08409090909090909
# new loss function value: 720.7527944701229
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.084
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.084
# HKD    0.000
# AUD    0.084
# RON    0.000
# SEK    0.084
# TRY    0.084
# CNY    0.000
# MYR    0.075
# CHF    0.084
# ZAR    0.000
# CZK    0.000
# SGD    0.084
# NOK    0.000
# GBP    0.084
# PLN    0.084
# DKK    0.084
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.084
# dtype: float64
# weight MYR: 0.08333333333333333
# other weight(s): 0.08333333333333333
# new loss function value: 723.0905186938814
#
#
# better solution found by including MYR
# loss function decreased by -0.32% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.083
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.083
# HKD    0.000
# AUD    0.083
# RON    0.000
# SEK    0.083
# TRY    0.083
# CNY    0.000
# MYR    0.083
# CHF    0.083
# ZAR    0.000
# CZK    0.000
# SGD    0.083
# NOK    0.000
# GBP    0.083
# PLN    0.083
# DKK    0.083
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.083
# dtype: float64
#
# including CNY
#
# weight CNY: 0.008333333333333333
# other weight(s): 0.09015151515151515
# new loss function value: 711.8999328262526
#
#
# better solution found by including CNY
# loss function decreased by 1.55% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.090
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.090
# HKD    0.000
# AUD    0.090
# RON    0.000
# SEK    0.090
# TRY    0.090
# CNY    0.008
# MYR    0.000
# CHF    0.090
# ZAR    0.000
# CZK    0.000
# SGD    0.090
# NOK    0.000
# GBP    0.090
# PLN    0.090
# DKK    0.090
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.090
# dtype: float64
# weight CNY: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 724.0865891962089
#
#
# better solution found by including CNY
# loss function decreased by -1.71% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.089
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.089
# HKD    0.000
# AUD    0.089
# RON    0.000
# SEK    0.089
# TRY    0.089
# CNY    0.017
# MYR    0.000
# CHF    0.089
# ZAR    0.000
# CZK    0.000
# SGD    0.089
# NOK    0.000
# GBP    0.089
# PLN    0.089
# DKK    0.089
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.089
# dtype: float64
# weight CNY: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 736.2732455661649
#
# weight CNY: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 748.459901936121
#
# weight CNY: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 760.6465583060773
#
# weight CNY: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 772.8332146760332
#
# weight CNY: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 785.0198710459896
#
# weight CNY: 0.06666666666666667
# other weight(s): 0.08484848484848485
# new loss function value: 797.2065274159456
#
# weight CNY: 0.075
# other weight(s): 0.08409090909090909
# new loss function value: 809.3931837859016
#
# weight CNY: 0.08333333333333333
# other weight(s): 0.08333333333333333
# new loss function value: 821.5798401558578
#
#
# including ZAR
#
# weight ZAR: 0.008333333333333333
# other weight(s): 0.09015151515151515
# new loss function value: 722.6809968671762
#
#
# better solution found by including ZAR
# loss function decreased by 0.19% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.090
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.090
# HKD    0.000
# AUD    0.090
# RON    0.000
# SEK    0.090
# TRY    0.090
# CNY    0.000
# MYR    0.000
# CHF    0.090
# ZAR    0.008
# CZK    0.000
# SGD    0.090
# NOK    0.000
# GBP    0.090
# PLN    0.090
# DKK    0.090
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.090
# dtype: float64
# weight ZAR: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 745.6487172780559
#
# weight ZAR: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 768.6164376889358
#
# weight ZAR: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 791.5841580998153
#
# weight ZAR: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 814.5518785106954
#
# weight ZAR: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 837.5195989215746
#
# weight ZAR: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 860.4873193324545
#
# weight ZAR: 0.06666666666666667
# other weight(s): 0.08484848484848485
# new loss function value: 883.4550397433342
#
# weight ZAR: 0.075
# other weight(s): 0.08409090909090909
# new loss function value: 906.4227601542141
#
# weight ZAR: 0.08333333333333333
# other weight(s): 0.08333333333333333
# new loss function value: 929.3904805650935
#
#
# including CZK
#
# weight CZK: 0.008333333333333333
# other weight(s): 0.09015151515151515
# new loss function value: 745.6013890628667
#
# weight CZK: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 791.4895016694364
#
# weight CZK: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 837.3776142760065
#
# weight CZK: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 883.2657268825767
#
# weight CZK: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 929.1538394891464
#
# weight CZK: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 975.0419520957166
#
# weight CZK: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 1020.9300647022861
#
# weight CZK: 0.06666666666666667
# other weight(s): 0.08484848484848485
# new loss function value: 1066.818177308856
#
# weight CZK: 0.075
# other weight(s): 0.08409090909090909
# new loss function value: 1112.7062899154262
#
# weight CZK: 0.08333333333333333
# other weight(s): 0.08333333333333333
# new loss function value: 1158.594402521996
#
#
# including NOK
#
# weight NOK: 0.008333333333333333
# other weight(s): 0.09015151515151515
# new loss function value: 710.5429074967303
#
#
# better solution found by including NOK
# loss function decreased by 1.68% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.090
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.090
# HKD    0.000
# AUD    0.090
# RON    0.000
# SEK    0.090
# TRY    0.090
# CNY    0.000
# MYR    0.000
# CHF    0.090
# ZAR    0.000
# CZK    0.000
# SGD    0.090
# NOK    0.008
# GBP    0.090
# PLN    0.090
# DKK    0.090
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.090
# dtype: float64
# weight NOK: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 721.3725385371639
#
#
# better solution found by including NOK
# loss function decreased by -1.52% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.089
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.089
# HKD    0.000
# AUD    0.089
# RON    0.000
# SEK    0.089
# TRY    0.089
# CNY    0.000
# MYR    0.000
# CHF    0.089
# ZAR    0.000
# CZK    0.000
# SGD    0.089
# NOK    0.017
# GBP    0.089
# PLN    0.089
# DKK    0.089
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.089
# dtype: float64
# weight NOK: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 732.2021695775971
#
#
# better solution found by including NOK
# loss function decreased by -1.50% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.089
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.089
# HKD    0.000
# AUD    0.089
# RON    0.000
# SEK    0.089
# TRY    0.089
# CNY    0.000
# MYR    0.000
# CHF    0.089
# ZAR    0.000
# CZK    0.000
# SGD    0.089
# NOK    0.025
# GBP    0.089
# PLN    0.089
# DKK    0.089
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.089
# dtype: float64
# weight NOK: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 743.031800618031
#
# weight NOK: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 753.8614316584647
#
# weight NOK: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 764.6910626988979
#
# weight NOK: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 775.5206937393314
#
# weight NOK: 0.06666666666666667
# other weight(s): 0.08484848484848485
# new loss function value: 786.3503247797651
#
# weight NOK: 0.075
# other weight(s): 0.08409090909090909
# new loss function value: 797.1799558201986
#
# weight NOK: 0.08333333333333333
# other weight(s): 0.08333333333333333
# new loss function value: 808.0095868606322
#
#
# including RUB
#
# weight RUB: 0.008333333333333333
# other weight(s): 0.09015151515151515
# new loss function value: 760.9469497230994
#
# weight RUB: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 822.1806229899023
#
# weight RUB: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 883.4142962567053
#
# weight RUB: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 944.647969523508
#
# weight RUB: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 1005.8816427903109
#
# weight RUB: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 1067.1153160571137
#
# weight RUB: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 1128.3489893239164
#
# weight RUB: 0.06666666666666667
# other weight(s): 0.08484848484848485
# new loss function value: 1189.5826625907189
#
# weight RUB: 0.075
# other weight(s): 0.08409090909090909
# new loss function value: 1250.816335857522
#
# weight RUB: 0.08333333333333333
# other weight(s): 0.08333333333333333
# new loss function value: 1312.0500091243248
#
#
# including HUF
#
# weight HUF: 0.008333333333333333
# other weight(s): 0.09015151515151515
# new loss function value: 1345.4206926658348
#
# weight HUF: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 1991.128108875373
#
# weight HUF: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 2636.8355250849113
#
# weight HUF: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 3282.542941294452
#
# weight HUF: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 3928.250357503988
#
# weight HUF: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 4573.957773713526
#
# weight HUF: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 5219.6651899230665
#
# weight HUF: 0.06666666666666667
# other weight(s): 0.08484848484848485
# new loss function value: 5865.372606132604
#
# weight HUF: 0.075
# other weight(s): 0.08409090909090909
# new loss function value: 6511.080022342143
#
# weight HUF: 0.08333333333333333
# other weight(s): 0.08333333333333333
# new loss function value: 7156.787438551682
#
#
# including IDR
#
# weight IDR: 0.008333333333333333
# other weight(s): 0.09015151515151515
# new loss function value: 27924.303231704675
#
# weight IDR: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 55148.89318695306
#
# weight IDR: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 82373.48314220141
#
# weight IDR: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 109598.07309744987
#
# weight IDR: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 136822.66305269822
#
# weight IDR: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 164047.25300794654
#
# weight IDR: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 191271.842963195

# %%
assert get_libra_mix(reference_date_exhange_rate).sum() == 1
assert get_sdr_mix(reference_date_exhange_rate).sum() == 1
