# %%
"""
Description: Perform (backward and forward) selection in currency selection for final Duca basket.
Author: Jeroen van Dijk
Date: 11-11-2020
Maintainer: Jeroen van Dijk
Email: jeroen.vandijk@d-data.nl
Status: Dev
"""
# Out:
# '\nDescription: Perform (backward and forward) selection in currency selection for final Duca basket.\nAuthor: Jeroen van Dijk\nDate: 11-11-2020\nMaintainer: Jeroen van Dijk\nEmail: jeroen.vandijk@d-data.nl\nStatus: Dev\n'

# %%
# Load common imports
# %run ./CommonImports.ipynb

# %%
# Load common functions and currencies lists:
# - all_currencies
# - obsolete_currencies
# - p13_currencies
# - f_currencies
# - ff_currencies
# - currencies_per_continent
# %run ./Utilities.ipynb

# %%
# Load loss functions
# - calculate_loss_function_around_one(weights)
# - calculate_loss_function_vs_t_minus_one(weights)
# - calculate_loss_function_vs_t_minus_one_with_balancing(weights)
# - calculate_loss_function_vs_t_minus_one_for_period(weights, max_date)
# %run ./LossFunctions.ipynb

# %%
# Create dataframe with pre-defined base currency
df = create_original_df("EUR")

# %%
# Determine splits for dev- (train and test) and validation set
train_start = date(2005, 4, 1)
test_start = date(2012, 1, 1)
validation_start = date(2015, 1, 1)
validation_end = date(2020, 10, 1)

# Create dev (train and test) and validation set
train, test, dev, val = split_data(df, train_start, test_start, validation_start, validation_end)

# %%
results = pd.DataFrame()

# Calculate loss function score per currency
for base_currency in all_currencies:
    for currency in all_currencies:
        if currency == base_currency:
            continue
            
        rates = dev[base_currency] / dev[currency]
        normalized_rates = rates / rates.iloc[0]
        
        deviation = np.log(normalized_rates)
        loss_function_score = (deviation**2).mean()

        results = results.append({"currency": currency,
                                  "base_currency": base_currency,
                                  "loss_function_score": loss_function_score},
                                 ignore_index=True)
    
results = results.groupby("currency").median()
results.sort_values("loss_function_score", ascending=True)
# Out:
#           loss_function_score
# currency
# CAD                0.015
# MYR                0.016
# NOK                0.017
# HRK                0.020
# SEK                0.020
# CZK                0.021
# EUR                0.021
# DKK                0.021
# USD                0.021
# HKD                0.022
# PLN                0.022
# HUF                0.022
# IDR                0.023
# NZD                0.025
# AUD                0.025
# THB                0.026
# CHF                0.026
# RUB                0.026
# JPY                0.027
# RON                0.028
# PHP                0.028
# KRW                0.028
# SGD                0.031
# CNY                0.035
# GBP                0.036
# TRY                0.068
# ZAR                0.117

# %%
exchange_table = dict()

for base_currency in all_currencies:
    exchange_table[base_currency] = 1/train[all_currencies].divide(train[base_currency], axis=0)
    
reference_date_exhange_rate = train[all_currencies].iloc[0]

# %%
# Everything contains all currencies now
this_day_by_month = {}
previous_day_by_month = {}
diff_by_month = defaultdict(dict)

for base_currency, table in exchange_table.items():
    if base_currency not in all_currencies:
        continue
        
    exchange_table[base_currency]["month"] = exchange_table[base_currency].index.map(lambda x: int(x.strftime("%Y%m")))

    this_day = exchange_table[base_currency]
    previous_day = pd.DataFrame(exchange_table[base_currency].shift(1), 
                                index=exchange_table[base_currency].index)
    previous_day["month"] = previous_day.index.map(lambda x: int(x.strftime("%Y%m")))
    
    this_day_by_month[base_currency] = {month: values[all_currencies] for month, values in this_day.groupby("month")}
    previous_day_by_month[base_currency] = {month: values[all_currencies] for month, values in previous_day.groupby("month")}
    
    for month in this_day_by_month[base_currency].keys():
        diff_by_month[base_currency][month] = np.abs((this_day_by_month[base_currency][month] - previous_day_by_month[base_currency][month]) / 
                                                      previous_day_by_month[base_currency][month])
    
months = list(exchange_table["EUR"]["month"].unique())

# %%
def recalculate_weights(weights):
    """Helper function to recalculate weigths (baseline principle).
   
    Parameters
    ----------
    weights : array
        The initial weights given to all currencies."""
    weights[weights>0] = 1
    weights = weights/weights.sum()
    return weights

# %%
def evaluate_exclusion_of_currency(weights, 
                                   currency_set):
    """Perform backward selection of currencies.
   
    Parameters
    ----------
    weights : array
        The initial weights given to all currencies.
    currency_set : set
        The set containing all currencies of interest."""
    # Initialize string giving best currency to exclude
    best_to_exclude = "None"
    # Calculate initial loss function value
    starting_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(weights)
    
    # So far, this is the best solution
    best_loss_function_value = starting_loss_function_value
    print(f"starting loss function value: {best_loss_function_value}")
    print("")

    # Each time we eliminate one currency
    for excluded_currency in currency_set:
        print(f"evaluating {excluded_currency}")

        # We create the new weights,
        new_weights = weights.copy()
        new_weights[new_weights.index==excluded_currency] = 0
        new_weights = recalculate_weights(new_weights)
        
        # and calculate the new loss function value
        new_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(new_weights)
        print(f"new loss function value: {new_loss_function_value}")

        # Check whether the new loss function value is lower than the (so far) best one, and
        # the improvement needs to be > .5%
        if new_loss_function_value <= best_loss_function_value and new_loss_function_value < .995*starting_loss_function_value:
            print(f"better solution found by excluding {excluded_currency}")
            print(f"loss function decreased by {(starting_loss_function_value-new_loss_function_value)/starting_loss_function_value*100:.2f}% compared to starting value")
            # If so, save these results
            best_loss_function_value = new_loss_function_value
            best_to_exclude = excluded_currency
        print("")
        
    if best_to_exclude == "None":
        print("No currency needed to be removed.")
    else:
        print(f"\033[1m{best_to_exclude} is removed from currency set\n\033[0m")
    
    # Exclude the currency
    currency_set.remove(best_to_exclude)
    return starting_loss_function_value, best_loss_function_value, best_to_exclude, currency_set

# %%
weights = pd.Series(np.ones(len(all_currencies))/len(all_currencies), index=reference_date_exhange_rate.loc[all_currencies].index)
currency_set = set(all_currencies)
max_excluded_currencies = 23

# Create list to save results
backward_selection_result = []

for i in range(0, max_excluded_currencies):
    starting_loss_function_value, best_loss_function_value, best_to_exclude, currencies = evaluate_exclusion_of_currency(weights, currency_set)
    if best_to_exclude == "None":
        continue
    weights[weights.index==best_to_exclude] = 0
    weights = recalculate_weights(weights)
    
    backward_selection_result.append((best_to_exclude, starting_loss_function_value, best_loss_function_value))
    
print(f"\n\nFinal currency selection: {set(currencies)}")
    
backward_selection_result = pd.DataFrame(backward_selection_result)
backward_selection_result.columns = ["Removed currency", "Previous loss function value", "New loss function value"]
# Out:
# starting loss function value: 143338.79797809376
#
# evaluating KRW
# new loss function value: 132699.4163045596
# better solution found by excluding KRW
# loss function decreased by 7.42% compared to starting value
#
# evaluating THB
# new loss function value: 148423.37783083392
#
# evaluating EUR
# new loss function value: 148844.34486822717
#
# evaluating HRK
# new loss function value: 148794.9371427583
#
# evaluating NZD
# new loss function value: 148829.99458293835
#
# evaluating PHP
# new loss function value: 148283.47015382358
#
# evaluating JPY
# new loss function value: 147215.56846713944
#
# evaluating USD
# new loss function value: 148839.92590436334
#
# evaluating HKD
# new loss function value: 148760.2570556347
#
# evaluating AUD
# new loss function value: 148835.39485098462
#
# evaluating RON
# new loss function value: 148816.68141760238
#
# evaluating TRY
# new loss function value: 148829.91449319993
#
# evaluating MYR
# new loss function value: 148814.12712404708
#
# evaluating CNY
# new loss function value: 148768.67051414156
#
# evaluating CHF
# new loss function value: 148837.86436479178
#
# evaluating ZAR
# new loss function value: 148718.9117570296
#
# evaluating CZK
# new loss function value: 148613.12533151102
#
# evaluating SGD
# new loss function value: 148837.15387720184
#
# evaluating CAD
# new loss function value: 148837.22579296524
#
# evaluating NOK
# new loss function value: 148774.9337079701
#
# evaluating GBP
# new loss function value: 148844.59799098692
#
# evaluating PLN
# new loss function value: 148808.87698931835
#
# evaluating DKK
# new loss function value: 148796.06917962988
#
# evaluating RUB
# new loss function value: 148542.29966692533
#
# evaluating HUF
# new loss function value: 145844.72854565122
#
# evaluating IDR
# new loss function value: 23172.962980856504
# better solution found by excluding IDR
# loss function decreased by 83.83% compared to starting value
#
# evaluating SEK
# new loss function value: 148762.71451343966
#
# IDR is removed from currency set
#
# starting loss function value: 23172.962980856504
#
# evaluating KRW
# new loss function value: 7301.37264049148
# better solution found by excluding KRW
# loss function decreased by 68.49% compared to starting value
#
# evaluating THB
# new loss function value: 23654.292627816772
#
# evaluating EUR
# new loss function value: 24092.09834670576
#
# evaluating HRK
# new loss function value: 24040.714312218115
#
# evaluating NZD
# new loss function value: 24077.174050005422
#
# evaluating PHP
# new loss function value: 23508.788643726042
#
# evaluating JPY
# new loss function value: 22398.170889574583
#
# evaluating USD
# new loss function value: 24087.502624287445
#
# evaluating HKD
# new loss function value: 24004.64702160961
#
# evaluating AUD
# new loss function value: 24082.790328773513
#
# evaluating RON
# new loss function value: 24063.328358055966
#
# evaluating TRY
# new loss function value: 24077.090756677368
#
# evaluating MYR
# new loss function value: 24060.671892758473
#
# evaluating CNY
# new loss function value: 24013.39701845672
#
# evaluating CHF
# new loss function value: 24085.358623132946
#
# evaluating ZAR
# new loss function value: 23961.64791106028
#
# evaluating CZK
# new loss function value: 23851.630028520973
#
# evaluating SGD
# new loss function value: 24084.619716039408
#
# evaluating CAD
# new loss function value: 24084.69450843338
#
# evaluating NOK
# new loss function value: 24019.91074003843
#
# evaluating GBP
# new loss function value: 24092.3615943759
#
# evaluating PLN
# new loss function value: 24055.21175264057
#
# evaluating DKK
# new loss function value: 24041.89163056458
#
# evaluating RUB
# new loss function value: 23777.971337351853
#
# evaluating HUF
# new loss function value: 20972.497371226727
#
# evaluating SEK
# new loss function value: 24007.202777726743
#
# KRW is removed from currency set
#
# starting loss function value: 7301.37264049148
#
# evaluating THB
# new loss function value: 7141.441425226551
# better solution found by excluding THB
# loss function decreased by 2.19% compared to starting value
#
# evaluating EUR
# new loss function value: 7597.489049069248
#
# evaluating HRK
# new loss function value: 7543.964013144616
#
# evaluating NZD
# new loss function value: 7581.942906673056
#
# evaluating PHP
# new loss function value: 6989.874775132039
# better solution found by excluding PHP
# loss function decreased by 4.27% compared to starting value
#
# evaluating JPY
# new loss function value: 5832.981281224269
# better solution found by excluding JPY
# loss function decreased by 20.11% compared to starting value
#
# evaluating USD
# new loss function value: 7592.7018382168335
#
# evaluating HKD
# new loss function value: 7506.393918760753
#
# evaluating AUD
# new loss function value: 7587.7931970564905
#
# evaluating RON
# new loss function value: 7567.520310892374
#
# evaluating TRY
# new loss function value: 7581.85614278967
#
# evaluating MYR
# new loss function value: 7564.753159540818
#
# evaluating CNY
# new loss function value: 7515.5084988098315
#
# evaluating CHF
# new loss function value: 7590.468503680899
#
# evaluating ZAR
# new loss function value: 7461.603178605213
#
# evaluating CZK
# new loss function value: 7347.001217626763
#
# evaluating SGD
# new loss function value: 7589.69880879179
#
# evaluating CAD
# new loss function value: 7589.776717535518
#
# evaluating NOK
# new loss function value: 7522.293625457442
#
# evaluating GBP
# new loss function value: 7597.763265392313
#
# evaluating PLN
# new loss function value: 7559.065513584673
#
# evaluating DKK
# new loss function value: 7545.190386422183
#
# evaluating RUB
# new loss function value: 7270.273414325594
#
# evaluating HUF
# new loss function value: 4347.904699611918
# better solution found by excluding HUF
# loss function decreased by 40.45% compared to starting value
#
# evaluating SEK
# new loss function value: 7509.056164716099
#
# HUF is removed from currency set
#
# starting loss function value: 4347.904699611918
#
# evaluating THB
# new loss function value: 4052.608303645055
# better solution found by excluding THB
# loss function decreased by 6.79% compared to starting value
#
# evaluating EUR
# new loss function value: 4528.484085046131
#
# evaluating HRK
# new loss function value: 4472.631873646514
#
# evaluating NZD
# new loss function value: 4512.262023415324
#
# evaluating PHP
# new loss function value: 3894.4517991986113
# better solution found by excluding PHP
# loss function decreased by 10.43% compared to starting value
#
# evaluating JPY
# new loss function value: 2687.258588164414
# better solution found by excluding JPY
# loss function decreased by 38.19% compared to starting value
#
# evaluating USD
# new loss function value: 4523.4887345914385
#
# evaluating HKD
# new loss function value: 4433.428296898136
#
# evaluating AUD
# new loss function value: 4518.36667425021
#
# evaluating RON
# new loss function value: 4497.212358252872
#
# evaluating TRY
# new loss function value: 4512.17148718918
#
# evaluating MYR
# new loss function value: 4494.324895972986
#
# evaluating CNY
# new loss function value: 4442.939163036304
#
# evaluating CHF
# new loss function value: 4521.158298553943
#
# evaluating ZAR
# new loss function value: 4386.690133257572
#
# evaluating CZK
# new loss function value: 4267.105478323537
#
# evaluating SGD
# new loss function value: 4520.355138669653
#
# evaluating CAD
# new loss function value: 4520.436434750064
#
# evaluating NOK
# new loss function value: 4450.019295190335
#
# evaluating GBP
# new loss function value: 4528.770223818026
#
# evaluating PLN
# new loss function value: 4488.389961062226
#
# evaluating DKK
# new loss function value: 4473.91156750137
#
# evaluating RUB
# new loss function value: 4187.041683574495
#
# evaluating SEK
# new loss function value: 4436.206292677629
#
# JPY is removed from currency set
#
# starting loss function value: 2687.258588164414
#
# evaluating THB
# new loss function value: 2303.055714587806
# better solution found by excluding THB
# loss function decreased by 14.30% compared to starting value
#
# evaluating EUR
# new loss function value: 2800.5622133252964
#
# evaluating HRK
# new loss function value: 2742.1712650438785
#
# evaluating NZD
# new loss function value: 2783.6027852567245
#
# evaluating PHP
# new loss function value: 2137.710278121069
# better solution found by excluding PHP
# loss function decreased by 20.45% compared to starting value
#
# evaluating USD
# new loss function value: 2795.3398014862987
#
# evaluating HKD
# new loss function value: 2701.18570753421
#
# evaluating AUD
# new loss function value: 2789.984920220469
#
# evaluating RON
# new loss function value: 2767.8690444050694
#
# evaluating TRY
# new loss function value: 2783.508133747573
#
# evaluating MYR
# new loss function value: 2764.8503338397363
#
# evaluating CNY
# new loss function value: 2711.1288857695663
#
# evaluating CHF
# new loss function value: 2792.903436538007
#
# evaluating ZAR
# new loss function value: 2652.3230819099845
#
# evaluating CZK
# new loss function value: 2527.3027608425823
#
# evaluating SGD
# new loss function value: 2792.0637693862495
#
# evaluating CAD
# new loss function value: 2792.148760743044
#
# evaluating NOK
# new loss function value: 2718.5308421124173
#
# evaluating GBP
# new loss function value: 2800.8613584050036
#
# evaluating PLN
# new loss function value: 2758.6456291603045
#
# evaluating DKK
# new loss function value: 2743.509126801226
#
# evaluating RUB
# new loss function value: 2443.5997026958576
#
# evaluating SEK
# new loss function value: 2704.0899758491328
#
# PHP is removed from currency set
#
# starting loss function value: 2137.710278121069
#
# evaluating THB
# new loss function value: 1709.0430624673215
# better solution found by excluding THB
# loss function decreased by 20.05% compared to starting value
#
# evaluating EUR
# new loss function value: 2230.2403468589773
#
# evaluating HRK
# new loss function value: 2169.068877230825
#
# evaluating NZD
# new loss function value: 2212.473326977616
#
# evaluating USD
# new loss function value: 2224.7692487419326
#
# evaluating HKD
# new loss function value: 2126.1316265064106
#
# evaluating AUD
# new loss function value: 2219.1593731301105
#
# evaluating RON
# new loss function value: 2195.9903603711205
#
# evaluating TRY
# new loss function value: 2212.3741682537434
#
# evaluating MYR
# new loss function value: 2192.8279016836286
#
# evaluating CNY
# new loss function value: 2136.5482894196416
#
# evaluating CHF
# new loss function value: 2222.2168664151504
#
# evaluating ZAR
# new loss function value: 2074.942209185793
#
# evaluating CZK
# new loss function value: 1943.9685394961346
#
# evaluating SGD
# new loss function value: 2221.3372151133094
#
# evaluating CAD
# new loss function value: 2221.4262536775705
#
# evaluating NOK
# new loss function value: 2144.3027198740565
#
# evaluating GBP
# new loss function value: 2230.5537369424796
#
# evaluating PLN
# new loss function value: 2186.3277348766032
#
# evaluating DKK
# new loss function value: 2170.470446690904
#
# evaluating RUB
# new loss function value: 1856.2796214376608
#
# evaluating SEK
# new loss function value: 2129.174193312521
#
# THB is removed from currency set
#
# starting loss function value: 1709.0430624673215
#
# evaluating EUR
# new loss function value: 1784.766273859438
#
# evaluating HRK
# new loss function value: 1720.536230749878
#
# evaluating NZD
# new loss function value: 1766.110902984009
#
# evaluating USD
# new loss function value: 1779.0216208365416
#
# evaluating HKD
# new loss function value: 1675.4521174892432
# better solution found by excluding HKD
# loss function decreased by 1.97% compared to starting value
#
# evaluating AUD
# new loss function value: 1773.1312514441279
#
# evaluating RON
# new loss function value: 1748.8037880471882
#
# evaluating TRY
# new loss function value: 1766.0067863239433
#
# evaluating MYR
# new loss function value: 1745.4832064253212
#
# evaluating CNY
# new loss function value: 1686.3896135481355
#
# evaluating CHF
# new loss function value: 1776.3416193934197
#
# evaluating ZAR
# new loss function value: 1621.7032293025943
# better solution found by excluding ZAR
# loss function decreased by 5.11% compared to starting value
#
# evaluating CZK
# new loss function value: 1484.180876128453
# better solution found by excluding CZK
# loss function decreased by 13.16% compared to starting value
#
# evaluating SGD
# new loss function value: 1775.4179855264865
#
# evaluating CAD
# new loss function value: 1775.5114760189613
#
# evaluating NOK
# new loss function value: 1694.531765525271
#
# evaluating GBP
# new loss function value: 1785.0953334471167
#
# evaluating PLN
# new loss function value: 1738.658031277946
#
# evaluating DKK
# new loss function value: 1722.0078786829602
#
# evaluating RUB
# new loss function value: 1392.107512167056
# better solution found by excluding RUB
# loss function decreased by 18.54% compared to starting value
#
# evaluating SEK
# new loss function value: 1678.6468126356585
#
# RUB is removed from currency set
#
# starting loss function value: 1392.107512167056
#
# evaluating EUR
# new loss function value: 1455.1353373008476
#
# evaluating HRK
# new loss function value: 1387.5247656065746
#
# evaluating NZD
# new loss function value: 1435.498104800396
#
# evaluating USD
# new loss function value: 1449.0883341188517
#
# evaluating HKD
# new loss function value: 1340.0678042795907
# better solution found by excluding HKD
# loss function decreased by 3.74% compared to starting value
#
# evaluating AUD
# new loss function value: 1442.8879452847323
#
# evaluating RON
# new loss function value: 1417.2800890774279
#
# evaluating TRY
# new loss function value: 1435.388508316117
#
# evaluating MYR
# new loss function value: 1413.7847400017783
#
# evaluating CNY
# new loss function value: 1351.5809580257937
#
# evaluating CHF
# new loss function value: 1446.2672799681977
#
# evaluating ZAR
# new loss function value: 1283.4900272410134
# better solution found by excluding ZAR
# loss function decreased by 7.80% compared to starting value
#
# evaluating CZK
# new loss function value: 1138.729655478759
# better solution found by excluding CZK
# loss function decreased by 18.20% compared to starting value
#
# evaluating SGD
# new loss function value: 1445.2950337924785
#
# evaluating CAD
# new loss function value: 1445.393444837188
#
# evaluating NOK
# new loss function value: 1360.1516443175149
#
# evaluating GBP
# new loss function value: 1455.4817158141936
#
# evaluating PLN
# new loss function value: 1406.600345109804
#
# evaluating DKK
# new loss function value: 1389.0738686940301
#
# evaluating SEK
# new loss function value: 1343.4306412758178
#
# CZK is removed from currency set
#
# starting loss function value: 1138.729655478759
#
# evaluating EUR
# new loss function value: 1191.1824788595234
#
# evaluating HRK
# new loss function value: 1119.815764293346
# better solution found by excluding HRK
# loss function decreased by 1.66% compared to starting value
#
# evaluating NZD
# new loss function value: 1170.4542889979355
#
# evaluating USD
# new loss function value: 1184.7995310563053
#
# evaluating HKD
# new loss function value: 1069.7223051148628
# better solution found by excluding HKD
# loss function decreased by 6.06% compared to starting value
#
# evaluating AUD
# new loss function value: 1178.2546761758458
#
# evaluating RON
# new loss function value: 1151.2241612903574
#
# evaluating TRY
# new loss function value: 1170.3386038200845
#
# evaluating MYR
# new loss function value: 1147.53462615495
#
# evaluating CNY
# new loss function value: 1081.8750785136324
#
# evaluating CHF
# new loss function value: 1181.8217516750592
#
# evaluating ZAR
# new loss function value: 1010.0013182408086
# better solution found by excluding ZAR
# loss function decreased by 11.30% compared to starting value
#
# evaluating SGD
# new loss function value: 1180.795491822911
#
# evaluating CAD
# new loss function value: 1180.899370147882
#
# evaluating NOK
# new loss function value: 1090.9219140437826
#
# evaluating GBP
# new loss function value: 1191.5481006236103
#
# evaluating PLN
# new loss function value: 1139.9510982134213
#
# evaluating DKK
# new loss function value: 1121.4509286634377
#
# evaluating SEK
# new loss function value: 1073.2719663886583
#
# ZAR is removed from currency set
#
# starting loss function value: 1010.0013182408086
#
# evaluating EUR
# new loss function value: 1057.967346688798
#
# evaluating HRK
# new loss function value: 982.4025900893159
# better solution found by excluding HRK
# loss function decreased by 2.73% compared to starting value
#
# evaluating NZD
# new loss function value: 1036.019851541234
#
# evaluating USD
# new loss function value: 1051.2089313677434
#
# evaluating HKD
# new loss function value: 929.3624568415105
# better solution found by excluding HKD
# loss function decreased by 7.98% compared to starting value
#
# evaluating AUD
# new loss function value: 1044.2790850237275
#
# evaluating RON
# new loss function value: 1015.6585398508573
#
# evaluating TRY
# new loss function value: 1035.8973613529213
#
# evaluating MYR
# new loss function value: 1011.7519732368964
#
# evaluating CNY
# new loss function value: 942.2300992637365
#
# evaluating CHF
# new loss function value: 1048.0559884934826
#
# evaluating SGD
# new loss function value: 1046.9693604147378
#
# evaluating CAD
# new loss function value: 1047.0793492294135
#
# evaluating NOK
# new loss function value: 951.8091015897785
#
# evaluating GBP
# new loss function value: 1058.3544756154783
#
# evaluating PLN
# new loss function value: 1003.7223554164545
#
# evaluating DKK
# new loss function value: 984.1339405988249
#
# evaluating SEK
# new loss function value: 933.1209217196464
#
# HKD is removed from currency set
#
# starting loss function value: 929.3624568415105
#
# evaluating EUR
# new loss function value: 975.2864332300425
#
# evaluating HRK
# new loss function value: 894.998879343093
# better solution found by excluding HRK
# loss function decreased by 3.70% compared to starting value
#
# evaluating NZD
# new loss function value: 951.9672196357562
#
# evaluating USD
# new loss function value: 968.1056169514222
#
# evaluating AUD
# new loss function value: 960.7426552109054
#
# evaluating RON
# new loss function value: 930.3333259647308
#
# evaluating TRY
# new loss function value: 951.8370738106739
#
# evaluating MYR
# new loss function value: 926.1825989373976
#
# evaluating CNY
# new loss function value: 852.3156078409153
# better solution found by excluding CNY
# loss function decreased by 8.29% compared to starting value
#
# evaluating CHF
# new loss function value: 964.7556151475202
#
# evaluating SGD
# new loss function value: 963.6010728138533
#
# evaluating CAD
# new loss function value: 963.7179359294465
#
# evaluating NOK
# new loss function value: 862.4932978123345
#
# evaluating GBP
# new loss function value: 975.6977577146407
#
# evaluating PLN
# new loss function value: 917.651130003178
#
# evaluating DKK
# new loss function value: 896.8384392594461
#
# evaluating SEK
# new loss function value: 842.6371067003192
# better solution found by excluding SEK
# loss function decreased by 9.33% compared to starting value
#
# SEK is removed from currency set
#
# starting loss function value: 842.6371067003192
#
# evaluating EUR
# new loss function value: 885.8409915053409
#
# evaluating HRK
# new loss function value: 800.2009340259281
# better solution found by excluding HRK
# loss function decreased by 5.04% compared to starting value
#
# evaluating NZD
# new loss function value: 860.9671636714354
#
# evaluating USD
# new loss function value: 878.181454141479
#
# evaluating AUD
# new loss function value: 870.3276282849274
#
# evaluating RON
# new loss function value: 837.8910104223415
#
# evaluating TRY
# new loss function value: 860.828341458014
#
# evaluating MYR
# new loss function value: 833.4635682598524
#
# evaluating CNY
# new loss function value: 754.6721110902716
# better solution found by excluding CNY
# loss function decreased by 10.44% compared to starting value
#
# evaluating CHF
# new loss function value: 874.6081188839833
#
# evaluating SGD
# new loss function value: 873.3766070614058
#
# evaluating CAD
# new loss function value: 873.5012610513718
#
# evaluating NOK
# new loss function value: 765.5283137264521
#
# evaluating GBP
# new loss function value: 886.2797376222454
#
# evaluating PLN
# new loss function value: 824.3633347300183
#
# evaluating DKK
# new loss function value: 802.1631312700381
#
# CNY is removed from currency set
#
# starting loss function value: 754.6721110902716
#
# evaluating EUR
# new loss function value: 794.6787736949342
#
# evaluating HRK
# new loss function value: 702.9215692527065
# better solution found by excluding HRK
# loss function decreased by 6.86% compared to starting value
#
# evaluating NZD
# new loss function value: 768.0282438728927
#
# evaluating USD
# new loss function value: 786.4721265193685
#
# evaluating AUD
# new loss function value: 778.0573131016343
#
# evaluating RON
# new loss function value: 743.3037939631497
#
# evaluating TRY
# new loss function value: 767.8795057870848
#
# evaluating MYR
# new loss function value: 738.5601059319117
#
# evaluating CHF
# new loss function value: 782.6435530291945
#
# evaluating SGD
# new loss function value: 781.3240760764328
#
# evaluating CAD
# new loss function value: 781.4576339228248
#
# evaluating NOK
# new loss function value: 665.7723332175538
# better solution found by excluding NOK
# loss function decreased by 11.78% compared to starting value
#
# evaluating GBP
# new loss function value: 795.1488588201894
#
# evaluating PLN
# new loss function value: 728.8098557213749
#
# evaluating DKK
# new loss function value: 705.0239234428244
#
# NOK is removed from currency set
#
# starting loss function value: 665.7723332175538
#
# evaluating EUR
# new loss function value: 702.017986955443
#
# evaluating HRK
# new loss function value: 603.2025360176589
# better solution found by excluding HRK
# loss function decreased by 9.40% compared to starting value
#
# evaluating NZD
# new loss function value: 673.3174163778596
#
# evaluating USD
# new loss function value: 693.18005922791
#
# evaluating AUD
# new loss function value: 684.1179524703506
#
# evaluating RON
# new loss function value: 646.6910857058285
#
# evaluating TRY
# new loss function value: 673.1572369008353
#
# evaluating MYR
# new loss function value: 641.5824985952643
#
# evaluating CHF
# new loss function value: 689.0569800846459
#
# evaluating SGD
# new loss function value: 687.6360049047486
#
# evaluating CAD
# new loss function value: 687.7798364316325
#
# evaluating GBP
# new loss function value: 702.5242324749482
#
# evaluating PLN
# new loss function value: 631.0822291377633
#
# evaluating DKK
# new loss function value: 605.4666097608629
#
# HRK is removed from currency set
#
# starting loss function value: 603.2025360176589
#
# evaluating EUR
# new loss function value: 637.2545111337142
#
# evaluating NZD
# new loss function value: 606.1622263413325
#
# evaluating USD
# new loss function value: 627.680089428887
#
# evaluating AUD
# new loss function value: 617.8628071081977
#
# evaluating RON
# new loss function value: 577.3170347799653
# better solution found by excluding RON
# loss function decreased by 4.29% compared to starting value
#
# evaluating TRY
# new loss function value: 605.9886985745562
#
# evaluating MYR
# new loss function value: 571.7827320768544
# better solution found by excluding MYR
# loss function decreased by 5.21% compared to starting value
#
# evaluating CHF
# new loss function value: 623.2134203570179
#
# evaluating SGD
# new loss function value: 621.6740305787955
#
# evaluating CAD
# new loss function value: 621.8298480662529
#
# evaluating GBP
# new loss function value: 637.802943779845
#
# evaluating PLN
# new loss function value: 560.4074401645616
# better solution found by excluding PLN
# loss function decreased by 7.09% compared to starting value
#
# evaluating DKK
# new loss function value: 532.6571858395858
# better solution found by excluding DKK
# loss function decreased by 11.70% compared to starting value
#
# DKK is removed from currency set
#
# starting loss function value: 532.6571858395858
#
# evaluating EUR
# new loss function value: 563.3915814045486
#
# evaluating NZD
# new loss function value: 529.472725267405
# better solution found by excluding NZD
# loss function decreased by 0.60% compared to starting value
#
# evaluating USD
# new loss function value: 552.9467577265555
#
# evaluating AUD
# new loss function value: 542.2369951948943
#
# evaluating RON
# new loss function value: 498.0052435640954
# better solution found by excluding RON
# loss function decreased by 6.51% compared to starting value
#
# evaluating TRY
# new loss function value: 529.2834222491035
#
# evaluating MYR
# new loss function value: 491.9678224334288
# better solution found by excluding MYR
# loss function decreased by 7.64% compared to starting value
#
# evaluating CHF
# new loss function value: 548.0740278299706
#
# evaluating SGD
# new loss function value: 546.3946935264557
#
# evaluating CAD
# new loss function value: 546.5646762400455
#
# evaluating GBP
# new loss function value: 563.989871563964
#
# evaluating PLN
# new loss function value: 479.558413074564
# better solution found by excluding PLN
# loss function decreased by 9.97% compared to starting value
#
# PLN is removed from currency set
#
# starting loss function value: 479.558413074564
#
# evaluating EUR
# new loss function value: 508.05637091952065
#
# evaluating NZD
# new loss function value: 470.74562916866296
# better solution found by excluding NZD
# loss function decreased by 1.84% compared to starting value
#
# evaluating USD
# new loss function value: 496.5670648737284
#
# evaluating AUD
# new loss function value: 484.78632608890075
#
# evaluating RON
# new loss function value: 436.13139929502205
# better solution found by excluding RON
# loss function decreased by 9.06% compared to starting value
#
# evaluating TRY
# new loss function value: 470.53739584853116
#
# evaluating MYR
# new loss function value: 429.490236051289
# better solution found by excluding MYR
# loss function decreased by 10.44% compared to starting value
#
# evaluating CHF
# new loss function value: 491.20706198748525
#
# evaluating SGD
# new loss function value: 489.3597942536183
#
# evaluating CAD
# new loss function value: 489.54677523856736
#
# evaluating GBP
# new loss function value: 508.71449009487776
#
# MYR is removed from currency set
#
# starting loss function value: 429.490236051289
#
# evaluating EUR
# new loss function value: 455.5915028764326
#
# evaluating NZD
# new loss function value: 414.13512315325704
# better solution found by excluding NZD
# loss function decreased by 3.58% compared to starting value
#
# evaluating USD
# new loss function value: 442.8256072699963
#
# evaluating AUD
# new loss function value: 429.7358975090772
#
# evaluating RON
# new loss function value: 375.6748677381008
# better solution found by excluding RON
# loss function decreased by 12.53% compared to starting value
#
# evaluating TRY
# new loss function value: 413.90375279755534
#
# evaluating CHF
# new loss function value: 436.870048507504
#
# evaluating SGD
# new loss function value: 434.8175288032077
#
# evaluating CAD
# new loss function value: 435.0252854531509
#
# evaluating GBP
# new loss function value: 456.322746404607
#
# RON is removed from currency set
#
# starting loss function value: 375.6748677381008
#
# evaluating EUR
# new loss function value: 398.3118718772389
#
# evaluating NZD
# new loss function value: 351.67344468866645
# better solution found by excluding NZD
# loss function decreased by 6.39% compared to starting value
#
# evaluating USD
# new loss function value: 383.9502393199982
#
# evaluating AUD
# new loss function value: 369.2243158389642
#
# evaluating TRY
# new loss function value: 351.41315303850183
# better solution found by excluding TRY
# loss function decreased by 6.46% compared to starting value
#
# evaluating CHF
# new loss function value: 377.2502357121943
#
# evaluating SGD
# new loss function value: 374.941151044861
#
# evaluating CAD
# new loss function value: 375.1748772760469
#
# evaluating GBP
# new loss function value: 399.1345208464351
#
# TRY is removed from currency set
#
# starting loss function value: 351.41315303850183
#
# evaluating EUR
# new loss function value: 373.8180556690027
#
# evaluating NZD
# new loss function value: 320.5169960249198
# better solution found by excluding NZD
# loss function decreased by 8.79% compared to starting value
#
# evaluating USD
# new loss function value: 357.40476131787045
#
# evaluating AUD
# new loss function value: 340.575134482403
#
# evaluating CHF
# new loss function value: 349.7476143375232
#
# evaluating SGD
# new loss function value: 347.10866043199934
#
# evaluating CAD
# new loss function value: 347.37577612478333
#
# evaluating GBP
# new loss function value: 374.7582259195126
#
# NZD is removed from currency set
#
# starting loss function value: 320.5169960249198
#
# evaluating EUR
# new loss function value: 341.506689591574
#
# evaluating USD
# new loss function value: 322.35784618191974
#
# evaluating AUD
# new loss function value: 302.72328154054094
# better solution found by excluding AUD
# loss function decreased by 5.55% compared to starting value
#
# evaluating CHF
# new loss function value: 313.4245080381811
#
# evaluating SGD
# new loss function value: 310.34572848173667
#
# evaluating CAD
# new loss function value: 310.65736345665135
#
# evaluating GBP
# new loss function value: 342.6035548838355
#
# AUD is removed from currency set
#
# starting loss function value: 302.72328154054094
#
# evaluating EUR
# new loss function value: 324.35217092364996
#
# evaluating USD
# new loss function value: 301.37355883206493
#
# evaluating CHF
# new loss function value: 290.6535530595786
# better solution found by excluding CHF
# loss function decreased by 3.99% compared to starting value
#
# evaluating SGD
# new loss function value: 286.9590175918452
# better solution found by excluding SGD
# loss function decreased by 5.21% compared to starting value
#
# evaluating CAD
# new loss function value: 287.332979561743
#
# evaluating GBP
# new loss function value: 325.6684092743638
#
# SGD is removed from currency set
#
# starting loss function value: 286.9590175918452
#
# evaluating EUR
# new loss function value: 310.0540633335576
#
# evaluating USD
# new loss function value: 281.3307982190762
# better solution found by excluding USD
# loss function decreased by 1.96% compared to starting value
#
# evaluating CHF
# new loss function value: 267.93079100346836
# better solution found by excluding CHF
# loss function decreased by 6.63% compared to starting value
#
# evaluating CAD
# new loss function value: 263.78007413117376
# better solution found by excluding CAD
# loss function decreased by 8.08% compared to starting value
#
# evaluating GBP
# new loss function value: 311.6993612719498
#
# CAD is removed from currency set
#
#
#
# Final currency selection: {'GBP', 'USD', 'CHF', 'EUR'}

# %%
backward_selection_result
# Out:
#    Removed currency  Previous loss function value  New loss function value
# 0              IDR       143338.798                     23172.963
# 1              KRW        23172.963                      7301.373
# 2              HUF         7301.373                      4347.905
# 3              JPY         4347.905                      2687.259
# 4              PHP         2687.259                      2137.710
# 5              THB         2137.710                      1709.043
# 6              RUB         1709.043                      1392.108
# 7              CZK         1392.108                      1138.730
# 8              ZAR         1138.730                      1010.001
# 9              HKD         1010.001                       929.362
# 10             SEK          929.362                       842.637
# 11             CNY          842.637                       754.672
# 12             NOK          754.672                       665.772
# 13             HRK          665.772                       603.203
# 14             DKK          603.203                       532.657
# 15             PLN          532.657                       479.558
# 16             MYR          479.558                       429.490
# 17             RON          429.490                       375.675
# 18             TRY          375.675                       351.413
# 19             NZD          351.413                       320.517
# 20             AUD          320.517                       302.723
# 21             SGD          302.723                       286.959
# 22             CAD          286.959                       263.780

# %%
def evaluate_inclusion_of_currency(weights, 
                                   currency_set):
    """Perform forward selection of currencies.
   
    Parameters
    ----------
    weights : array
        The initial weights given to all currencies.
    currency_set : set
        The set containing all currencies of interest."""

    # Initialize string giving best currency to exclude
    best_to_include = "None"
    
    if weights.sum()>0:
        # Calculate initial loss function value
        starting_loss_function_value = calculate_loss_function_around_one(weights)
    else:
        starting_loss_function_value = 999999

    # So far, this is the best solution
    best_loss_function_value = starting_loss_function_value
    print(f"starting loss function value: {best_loss_function_value}")

    # Each time we include one currency
    for included_currency in currency_set:
        print(f"\nincluding {included_currency}")

        # We create the new weights,
        new_weights = weights.copy()
        new_weights[new_weights.index==included_currency] = 1
        new_weights = recalculate_weights(new_weights)

        # and calculate the new loss function value
        new_loss_function_value = calculate_loss_function_around_one(new_weights)
        print(f"new loss function value: {new_loss_function_value}")
        
        # Check whether the new loss function value is lower than the (so far) best one, and
        # the improvement needs to be > .5%
        if new_loss_function_value <= best_loss_function_value and new_loss_function_value < 0.995*starting_loss_function_value:
            print(f"\nnew best solution found by including {included_currency}")
            print(f"loss function decreased by {(starting_loss_function_value-new_loss_function_value)/starting_loss_function_value*100:.2f}% compared to starting value")
            # If so, save these results
            best_loss_function_value = new_loss_function_value
            best_to_include = included_currency
        print("")

    if best_to_include == "None":
        print("No currency needed to be included.")
    else:
        print(f"\033[1m{best_to_include} is added to currency set\n\033[0m")
        # Exclude the currency
        currency_set.remove(best_to_include)
    return starting_loss_function_value, best_loss_function_value, best_to_include, currency_set

# %%
# Create weights series and specificy first currency to include
weights = pd.Series(0, index=reference_date_exhange_rate.loc[all_currencies].index)
# TODO: Change starting currency
first_currency = "SEK"
weights[first_currency] = 1
currency_set = set(all_currencies)
currency_set.remove(first_currency)

# Create list to save results
forward_selection_result = []
forward_selection_result.append((first_currency, "-", "-"))

# Set maximum number of currencies to include
max_currencies_to_include = 10

for i in range(0, max_currencies_to_include):
    starting_loss_function_value, best_loss_function_value, best_to_include, currencies = evaluate_inclusion_of_currency(weights, currency_set)
    if best_to_include == "None":
        break
    weights[weights.index==best_to_include] = 1
    weights = recalculate_weights(weights)
    forward_selection_result.append((best_to_include, starting_loss_function_value, best_loss_function_value))
    
print(f"\n\nFinal currency selection: {set(all_currencies) - set(currencies)}")
    
forward_selection_result = pd.DataFrame(forward_selection_result)
forward_selection_result.columns = ["Added currency", "Previous loss function value", "New loss function value"]
# Out:
# starting loss function value: 0.30544466001356896
#
# including KRW
# new loss function value: 0.4032275841705278
#
#
# including THB
# new loss function value: 0.32657899368898563
#
#
# including EUR
# new loss function value: 0.27619116324345844
#
# new best solution found by including EUR
# loss function decreased by 9.58% compared to starting value
#
#
# including HRK
# new loss function value: 0.27456033743005426
#
# new best solution found by including HRK
# loss function decreased by 10.11% compared to starting value
#
#
# including NZD
# new loss function value: 0.32543444849922926
#
#
# including PHP
# new loss function value: 0.3216576981557385
#
#
# including JPY
# new loss function value: 0.3681702249752168
#
#
# including USD
# new loss function value: 0.2868145125361231
#
#
# including HKD
# new loss function value: 0.285376146722564
#
#
# including AUD
# new loss function value: 0.33193502967083427
#
#
# including RON
# new loss function value: 0.3391864020339294
#
#
# including TRY
# new loss function value: 0.377385404879553
#
#
# including MYR
# new loss function value: 0.28942699966467855
#
#
# including CNY
# new loss function value: 0.32487000958442686
#
#
# including CHF
# new loss function value: 0.33036654326080583
#
#
# including ZAR
# new loss function value: 0.5644519088342275
#
#
# including CZK
# new loss function value: 0.37155763495373184
#
#
# including SGD
# new loss function value: 0.31718957214978427
#
#
# including CAD
# new loss function value: 0.291723411766504
#
#
# including NOK
# new loss function value: 0.280707019123926
#
#
# including GBP
# new loss function value: 0.41343651450122565
#
#
# including PLN
# new loss function value: 0.30689467779152846
#
#
# including DKK
# new loss function value: 0.27628523616512873
#
#
# including RUB
# new loss function value: 0.3203388370381675
#
#
# including HUF
# new loss function value: 0.3274681381094383
#
#
# including IDR
# new loss function value: 0.29954950788814455
#
# HRK is added to currency set
#
# starting loss function value: 0.35635997487850446
#
# including KRW
# new loss function value: 0.403145788792039
#
#
# including THB
# new loss function value: 0.37822110195752595
#
#
# including EUR
# new loss function value: 0.3579077640218244
#
#
# including NZD
# new loss function value: 0.3605978070555408
#
#
# including PHP
# new loss function value: 0.37805904124404477
#
#
# including JPY
# new loss function value: 0.39308788864755634
#
#
# including USD
# new loss function value: 0.3513687388277703
#
# new best solution found by including USD
# loss function decreased by 1.40% compared to starting value
#
#
# including HKD
# new loss function value: 0.35075881817401267
#
# new best solution found by including HKD
# loss function decreased by 1.57% compared to starting value
#
#
# including AUD
# new loss function value: 0.36812197168199196
#
#
# including RON
# new loss function value: 0.3928555116894849
#
#
# including TRY
# new loss function value: 0.40833946543931926
#
#
# including MYR
# new loss function value: 0.3512986695212908
#
#
# including CNY
# new loss function value: 0.3801863120381765
#
#
# including CHF
# new loss function value: 0.37474439178214697
#
#
# including ZAR
# new loss function value: 0.47913187242375976
#
#
# including CZK
# new loss function value: 0.42055440360112095
#
#
# including SGD
# new loss function value: 0.37002586925769415
#
#
# including CAD
# new loss function value: 0.3527338350884481
#
#
# including NOK
# new loss function value: 0.35186328532581346
#
#
# including GBP
# new loss function value: 0.421822229297591
#
#
# including PLN
# new loss function value: 0.3819960857056758
#
#
# including DKK
# new loss function value: 0.3579697604360953
#
#
# including RUB
# new loss function value: 0.3752885284393947
#
#
# including HUF
# new loss function value: 0.3877442023217238
#
#
# including IDR
# new loss function value: 0.3472343006010848
#
# new best solution found by including IDR
# loss function decreased by 2.56% compared to starting value
#
# IDR is added to currency set
#
# starting loss function value: 0.34440276301654665
#
# including KRW
# new loss function value: 0.3921454543313306
#
#
# including THB
# new loss function value: 0.3432420083274374
#
#
# including EUR
# new loss function value: 0.3397253034165407
#
# new best solution found by including EUR
# loss function decreased by 1.36% compared to starting value
#
#
# including NZD
# new loss function value: 0.3567430169550016
#
#
# including PHP
# new loss function value: 0.34152638748385267
#
#
# including JPY
# new loss function value: 0.3586170719864308
#
#
# including USD
# new loss function value: 0.34815671868803366
#
#
# including HKD
# new loss function value: 0.34745347445455316
#
#
# including AUD
# new loss function value: 0.3486583033727681
#
#
# including RON
# new loss function value: 0.3679201116330953
#
#
# including TRY
# new loss function value: 0.3822775069615364
#
#
# including MYR
# new loss function value: 0.3355359529285708
#
# new best solution found by including MYR
# loss function decreased by 2.57% compared to starting value
#
#
# including CNY
# new loss function value: 0.34282410632170435
#
#
# including CHF
# new loss function value: 0.3475349722886729
#
#
# including ZAR
# new loss function value: 0.44504467174967594
#
#
# including CZK
# new loss function value: 0.3565324072487621
#
#
# including SGD
# new loss function value: 0.34144843598133673
#
#
# including CAD
# new loss function value: 0.336924167776674
#
#
# including NOK
# new loss function value: 0.33964850463264
#
#
# including GBP
# new loss function value: 0.39597116967054025
#
#
# including PLN
# new loss function value: 0.3475979444339328
#
#
# including DKK
# new loss function value: 0.339765413149149
#
#
# including RUB
# new loss function value: 0.36108755369411033
#
#
# including HUF
# new loss function value: 0.36244800618073303
#
# MYR is added to currency set
#
# starting loss function value: 0.3300376375239065
#
# including KRW
# new loss function value: 0.33809585091637545
#
#
# including THB
# new loss function value: 0.35332900646002985
#
#
# including EUR
# new loss function value: 0.32812451282485283
#
# new best solution found by including EUR
# loss function decreased by 0.58% compared to starting value
#
#
# including NZD
# new loss function value: 0.3315997658191403
#
#
# including PHP
# new loss function value: 0.3521779162892464
#
#
# including JPY
# new loss function value: 0.3584802714959728
#
#
# including USD
# new loss function value: 0.3281838899913798
#
#
# including HKD
# new loss function value: 0.3282617188157075
#
#
# including AUD
# new loss function value: 0.34806152073911073
#
#
# including RON
# new loss function value: 0.32880763664236196
#
#
# including TRY
# new loss function value: 0.3305985337492609
#
#
# including CNY
# new loss function value: 0.3540774878119129
#
#
# including CHF
# new loss function value: 0.34877163851008874
#
#
# including ZAR
# new loss function value: 0.35697420717000217
#
#
# including CZK
# new loss function value: 0.36271405902963716
#
#
# including SGD
# new loss function value: 0.3513706743986501
#
#
# including CAD
# new loss function value: 0.34168088402580393
#
#
# including NOK
# new loss function value: 0.32976202722993814
#
#
# including GBP
# new loss function value: 0.3355758818875988
#
#
# including PLN
# new loss function value: 0.3353350849090428
#
#
# including DKK
# new loss function value: 0.32813915781213776
#
#
# including RUB
# new loss function value: 0.32844868404723787
#
#
# including HUF
# new loss function value: 0.32680628198402045
#
# new best solution found by including HUF
# loss function decreased by 0.98% compared to starting value
#
# HUF is added to currency set
#
# starting loss function value: 0.3195293033064761
#
# including KRW
# new loss function value: 0.3352344795707689
#
#
# including THB
# new loss function value: 0.3215267355544037
#
#
# including EUR
# new loss function value: 0.3197627717751176
#
#
# including NZD
# new loss function value: 0.3238777082256855
#
#
# including PHP
# new loss function value: 0.320879190620962
#
#
# including JPY
# new loss function value: 0.32616851138528447
#
#
# including USD
# new loss function value: 0.32026259621505515
#
#
# including HKD
# new loss function value: 0.31998235449186724
#
#
# including AUD
# new loss function value: 0.3224933757563174
#
#
# including RON
# new loss function value: 0.33015410625744024
#
#
# including TRY
# new loss function value: 0.3347338366430292
#
#
# including CNY
# new loss function value: 0.32151717058668994
#
#
# including CHF
# new loss function value: 0.3226634226522116
#
#
# including ZAR
# new loss function value: 0.35453665726615163
#
#
# including CZK
# new loss function value: 0.33031949804969624
#
#
# including SGD
# new loss function value: 0.3205903213767728
#
#
# including CAD
# new loss function value: 0.3174852003351887
#
# new best solution found by including CAD
# loss function decreased by 0.64% compared to starting value
#
#
# including NOK
# new loss function value: 0.3190040337441325
#
#
# including GBP
# new loss function value: 0.3383742412631164
#
#
# including PLN
# new loss function value: 0.3256021854457076
#
#
# including DKK
# new loss function value: 0.3197708847191427
#
#
# including RUB
# new loss function value: 0.32685988860412035
#
# CAD is added to currency set
#
# starting loss function value: 0.31150294580398274
#
# including KRW
# new loss function value: 0.3130305095410709
#
#
# including THB
# new loss function value: 0.32396639311079145
#
#
# including EUR
# new loss function value: 0.3111745339528719
#
#
# including NZD
# new loss function value: 0.3112986393057689
#
#
# including PHP
# new loss function value: 0.3237321151209752
#
#
# including JPY
# new loss function value: 0.32215862244725535
#
#
# including USD
# new loss function value: 0.30805792909788465
#
# new best solution found by including USD
# loss function decreased by 1.11% compared to starting value
#
#
# including HKD
# new loss function value: 0.30812438279112453
#
#
# including AUD
# new loss function value: 0.32133901551971517
#
#
# including RON
# new loss function value: 0.31161303635152743
#
#
# including TRY
# new loss function value: 0.31137298981633166
#
#
# including CNY
# new loss function value: 0.3233711917265098
#
#
# including CHF
# new loss function value: 0.3198746423390091
#
#
# including ZAR
# new loss function value: 0.3188647400437174
#
#
# including CZK
# new loss function value: 0.3314254030677312
#
#
# including SGD
# new loss function value: 0.3223330264375964
#
#
# including NOK
# new loss function value: 0.31245702012962795
#
#
# including GBP
# new loss function value: 0.31210759587862075
#
#
# including PLN
# new loss function value: 0.31824733858122684
#
#
# including DKK
# new loss function value: 0.31116778282404467
#
#
# including RUB
# new loss function value: 0.31092402820995757
#
# USD is added to currency set
#
# starting loss function value: 0.30324938247146066
#
# including KRW
# new loss function value: 0.30863160150398455
#
#
# including THB
# new loss function value: 0.3088315905422871
#
#
# including EUR
# new loss function value: 0.3033072298516464
#
#
# including NZD
# new loss function value: 0.30367679668270986
#
#
# including PHP
# new loss function value: 0.30882114763699314
#
#
# including JPY
# new loss function value: 0.31118228765556694
#
#
# including HKD
# new loss function value: 0.3051405064892573
#
#
# including AUD
# new loss function value: 0.30659888948431313
#
#
# including RON
# new loss function value: 0.30542177571299134
#
#
# including TRY
# new loss function value: 0.30770193457750245
#
#
# including CNY
# new loss function value: 0.31037877671171543
#
#
# including CHF
# new loss function value: 0.30725038665916227
#
#
# including ZAR
# new loss function value: 0.31646433683698527
#
#
# including CZK
# new loss function value: 0.3118991696474715
#
#
# including SGD
# new loss function value: 0.3085278785858702
#
#
# including NOK
# new loss function value: 0.30299428219054525
#
#
# including GBP
# new loss function value: 0.3086122687272996
#
#
# including PLN
# new loss function value: 0.30536321871128763
#
#
# including DKK
# new loss function value: 0.30331015616338985
#
#
# including RUB
# new loss function value: 0.3050934710745486
#
# No currency needed to be included.
#
#
# Final currency selection: {'MYR', 'HRK', 'SEK', 'HUF', 'IDR', 'USD', 'CAD'}

# %%
forward_selection_currencies = list(forward_selection_result["Added currency"].unique())
forward_selection_result
# Out:
#   Added currency Previous loss function value New loss function value
# 0            SEK               -                            -
# 1            HRK           0.305                        0.275
# 2            IDR           0.356                        0.347
# 3            MYR           0.344                        0.336
# 4            HUF            0.33                        0.327
# 5            CAD            0.32                        0.317
# 6            USD           0.312                        0.308

# %%
def evaluate_inclusion_of_currency_differentiate_weights(weights, 
                                                         currency_set):
    """Perform forward selection of currencies.
   
    Parameters
    ----------
    weights : array
        The initial weights given to all currencies.
    currency_set : set
        The set containing all currencies of interest."""

    # Initialize string giving best currency to exclude
    best_to_include = "None"
    # Initialize string giving best currency weights
    best_weights = weights.copy()
    # Calculate initial loss function value
    starting_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(weights)

    # So far, this is the best solution
    best_loss_function_value = starting_loss_function_value
    print(f"starting loss function value: {best_loss_function_value}")

    # Each time we include one currency
    for included_currency in currency_set:
        print(f"\nincluding {included_currency}\n")
        
        new_weights = weights.copy()
        no_currencies = (new_weights>0).sum()+1
        possible_weights_included_currency = np.arange(0, 1/no_currencies, 1/no_currencies/10) + 1/no_currencies/10
        
        # We create the new weights,
        for possible_weight in possible_weights_included_currency:
            new_weights[new_weights>0] = (1-possible_weight)/(no_currencies-1)
            new_weights[included_currency] = possible_weight
        
            # and calculate the new loss function value
            new_loss_function_value = calculate_loss_function_vs_t_minus_one_with_balancing(new_weights)
            print(f"weight {included_currency}: {possible_weight}")
            print(f"other weight(s): {(1-possible_weight)/(no_currencies-1)}")
            print(f"new loss function value: {new_loss_function_value}\n")

            # Check whether the new loss function value is lower than the (so far) best one, and
            # the improvement needs to be > .5%
            if new_loss_function_value <= best_loss_function_value and new_loss_function_value < 0.995*starting_loss_function_value:
                print(f"\nbetter solution found by including {included_currency}")
                print(f"loss function decreased by {(best_loss_function_value-new_loss_function_value)/best_loss_function_value*100:.2f}% compared to current best solution\n")
                # If so, save these results
                best_weights = new_weights
                print(best_weights)
                best_loss_function_value = new_loss_function_value
                best_to_include = included_currency

    if best_to_include == "None":
        print("No currency needed to be included.")
    else:
        print(f"\033[1m{best_to_include} is added to currency set\n")
        # Exclude the currency
        currency_set.remove(best_to_include)
    return starting_loss_function_value, best_loss_function_value, best_to_include, best_weights, currency_set

# %%
# Create weights series and specificy first currency to include
weights = pd.Series(0, index=reference_date_exhange_rate.loc[all_currencies].index)
# TODO: Change starting currency
first_currency = "SEK"
weights[first_currency] = 1
currency_set = set(all_currencies)
currency_set.remove(first_currency)

# Create list to save results
forward_selection_weights_result = []
forward_selection_weights_result.append((first_currency, "-", "-"))

# Set maximum number of currencies to include
max_currencies_to_include = 14

for i in range(0, max_currencies_to_include):
    _, _, best_to_include, best_weights, currencies = evaluate_inclusion_of_currency_differentiate_weights(weights, currency_set)
    if best_to_include == "None":
        break
    weights = best_weights
    forward_selection_weights_result.append((best_to_include, starting_loss_function_value, best_loss_function_value))
    
forward_selection_weights_result = pd.DataFrame(forward_selection_weights_result)
forward_selection_weights_result.columns = ["Added currency", "Previous loss function value", "New loss function value"]
# Out:
# starting loss function value: 2316.9680591005704
#
# including KRW
#
# weight KRW: 0.05
# other weight(s): 0.95
# new loss function value: 23199.25573064465
#
# weight KRW: 0.1
# other weight(s): 0.9
# new loss function value: 44081.54340218873
#
# weight KRW: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 64963.83107373281
#
# weight KRW: 0.2
# other weight(s): 0.8
# new loss function value: 85846.11874527688
#
# weight KRW: 0.25
# other weight(s): 0.75
# new loss function value: 106728.40641682094
#
# weight KRW: 0.3
# other weight(s): 0.7
# new loss function value: 127610.694088365
#
# weight KRW: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 148492.98175990913
#
# weight KRW: 0.4
# other weight(s): 0.6
# new loss function value: 169375.26943145323
#
# weight KRW: 0.45
# other weight(s): 0.55
# new loss function value: 190257.5571029973
#
# weight KRW: 0.5
# other weight(s): 0.5
# new loss function value: 211139.84477454133
#
#
# including THB
#
# weight THB: 0.05
# other weight(s): 0.95
# new loss function value: 2758.1057464880296
#
# weight THB: 0.1
# other weight(s): 0.9
# new loss function value: 3199.2434338754906
#
# weight THB: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 3640.3811212629507
#
# weight THB: 0.2
# other weight(s): 0.8
# new loss function value: 4081.518808650411
#
# weight THB: 0.25
# other weight(s): 0.75
# new loss function value: 4522.65649603787
#
# weight THB: 0.3
# other weight(s): 0.7
# new loss function value: 4963.794183425329
#
# weight THB: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 5404.93187081279
#
# weight THB: 0.4
# other weight(s): 0.6
# new loss function value: 5846.069558200248
#
# weight THB: 0.45
# other weight(s): 0.55
# new loss function value: 6287.207245587711
#
# weight THB: 0.5
# other weight(s): 0.5
# new loss function value: 6728.344932975171
#
#
# including EUR
#
# weight EUR: 0.05
# other weight(s): 0.95
# new loss function value: 2210.848597876791
#
#
# better solution found by including EUR
# loss function decreased by 4.58% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.05
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.95
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.00
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight EUR: 0.1
# other weight(s): 0.9
# new loss function value: 2104.729136653012
#
#
# better solution found by including EUR
# loss function decreased by 4.80% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.1
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.9
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
# weight EUR: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 1998.609675429233
#
#
# better solution found by including EUR
# loss function decreased by 5.04% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.15
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.85
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.00
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight EUR: 0.2
# other weight(s): 0.8
# new loss function value: 1892.490214205455
#
#
# better solution found by including EUR
# loss function decreased by 5.31% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.2
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.8
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
# weight EUR: 0.25
# other weight(s): 0.75
# new loss function value: 1786.3707529816766
#
#
# better solution found by including EUR
# loss function decreased by 5.61% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.25
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.75
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.00
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight EUR: 0.3
# other weight(s): 0.7
# new loss function value: 1680.2512917578974
#
#
# better solution found by including EUR
# loss function decreased by 5.94% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.3
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.7
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
# weight EUR: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1574.1318305341185
#
#
# better solution found by including EUR
# loss function decreased by 6.32% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.35
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.65
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.00
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight EUR: 0.4
# other weight(s): 0.6
# new loss function value: 1468.01236931034
#
#
# better solution found by including EUR
# loss function decreased by 6.74% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.4
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.6
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
# weight EUR: 0.45
# other weight(s): 0.55
# new loss function value: 1361.8929080865614
#
#
# better solution found by including EUR
# loss function decreased by 7.23% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.45
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.55
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.00
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight EUR: 0.5
# other weight(s): 0.5
# new loss function value: 1255.7734468627825
#
#
# better solution found by including EUR
# loss function decreased by 7.79% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.5
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.5
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
#
# including HRK
#
# weight HRK: 0.05
# other weight(s): 0.95
# new loss function value: 2275.0786409863504
#
# weight HRK: 0.1
# other weight(s): 0.9
# new loss function value: 2233.1892228721313
#
# weight HRK: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2191.299804757912
#
# weight HRK: 0.2
# other weight(s): 0.8
# new loss function value: 2149.410386643693
#
# weight HRK: 0.25
# other weight(s): 0.75
# new loss function value: 2107.520968529474
#
# weight HRK: 0.3
# other weight(s): 0.7
# new loss function value: 2065.6315504152544
#
# weight HRK: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 2023.7421323010353
#
# weight HRK: 0.4
# other weight(s): 0.6
# new loss function value: 1981.852714186816
#
# weight HRK: 0.45
# other weight(s): 0.55
# new loss function value: 1939.9632960725971
#
# weight HRK: 0.5
# other weight(s): 0.5
# new loss function value: 1898.073877958378
#
#
# including NZD
#
# weight NZD: 0.05
# other weight(s): 0.95
# new loss function value: 2229.5039687522203
#
# weight NZD: 0.1
# other weight(s): 0.9
# new loss function value: 2142.0398784038707
#
# weight NZD: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2054.5757880555207
#
# weight NZD: 0.2
# other weight(s): 0.8
# new loss function value: 1967.1116977071708
#
# weight NZD: 0.25
# other weight(s): 0.75
# new loss function value: 1879.6476073588215
#
# weight NZD: 0.3
# other weight(s): 0.7
# new loss function value: 1792.1835170104716
#
# weight NZD: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1704.719426662122
#
# weight NZD: 0.4
# other weight(s): 0.6
# new loss function value: 1617.255336313772
#
# weight NZD: 0.45
# other weight(s): 0.55
# new loss function value: 1529.7912459654228
#
# weight NZD: 0.5
# other weight(s): 0.5
# new loss function value: 1442.3271556170725
#
#
# including PHP
#
# weight PHP: 0.05
# other weight(s): 0.95
# new loss function value: 2939.9857266014415
#
# weight PHP: 0.1
# other weight(s): 0.9
# new loss function value: 3563.003394102312
#
# weight PHP: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 4186.021061603183
#
# weight PHP: 0.2
# other weight(s): 0.8
# new loss function value: 4809.038729104054
#
# weight PHP: 0.25
# other weight(s): 0.75
# new loss function value: 5432.056396604926
#
# weight PHP: 0.3
# other weight(s): 0.7
# new loss function value: 6055.074064105796
#
# weight PHP: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 6678.091731606668
#
# weight PHP: 0.4
# other weight(s): 0.6
# new loss function value: 7301.109399107537
#
# weight PHP: 0.45
# other weight(s): 0.55
# new loss function value: 7924.127066608411
#
# weight PHP: 0.5
# other weight(s): 0.5
# new loss function value: 8547.144734109283
#
#
# including JPY
#
# weight JPY: 0.05
# other weight(s): 0.95
# new loss function value: 4328.257919290768
#
# weight JPY: 0.1
# other weight(s): 0.9
# new loss function value: 6339.547779480966
#
# weight JPY: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 8350.837639671163
#
# weight JPY: 0.2
# other weight(s): 0.8
# new loss function value: 10362.12749986136
#
# weight JPY: 0.25
# other weight(s): 0.75
# new loss function value: 12373.417360051559
#
# weight JPY: 0.3
# other weight(s): 0.7
# new loss function value: 14384.707220241758
#
# weight JPY: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 16395.997080431953
#
# weight JPY: 0.4
# other weight(s): 0.6
# new loss function value: 18407.28694062215
#
# weight JPY: 0.45
# other weight(s): 0.55
# new loss function value: 20418.57680081235
#
# weight JPY: 0.5
# other weight(s): 0.5
# new loss function value: 22429.866661002554
#
#
# including USD
#
# weight USD: 0.05
# other weight(s): 0.95
# new loss function value: 2216.593250899687
#
# weight USD: 0.1
# other weight(s): 0.9
# new loss function value: 2116.218442698805
#
# weight USD: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2015.8436344979227
#
# weight USD: 0.2
# other weight(s): 0.8
# new loss function value: 1915.4688262970399
#
# weight USD: 0.25
# other weight(s): 0.75
# new loss function value: 1815.094018096158
#
# weight USD: 0.3
# other weight(s): 0.7
# new loss function value: 1714.719209895275
#
# weight USD: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1614.3444016943927
#
# weight USD: 0.4
# other weight(s): 0.6
# new loss function value: 1513.9695934935103
#
# weight USD: 0.45
# other weight(s): 0.55
# new loss function value: 1413.5947852926276
#
# weight USD: 0.5
# other weight(s): 0.5
# new loss function value: 1313.2199770917455
#
#
# better solution found by including USD
# loss function decreased by -4.57% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.0
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.5
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.5
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
#
# including HKD
#
# weight HKD: 0.05
# other weight(s): 0.95
# new loss function value: 2320.1627542469855
#
# weight HKD: 0.1
# other weight(s): 0.9
# new loss function value: 2323.3574493934007
#
# weight HKD: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2326.552144539816
#
# weight HKD: 0.2
# other weight(s): 0.8
# new loss function value: 2329.7468396862323
#
# weight HKD: 0.25
# other weight(s): 0.75
# new loss function value: 2332.9415348326474
#
# weight HKD: 0.3
# other weight(s): 0.7
# new loss function value: 2336.136229979063
#
# weight HKD: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 2339.330925125479
#
# weight HKD: 0.4
# other weight(s): 0.6
# new loss function value: 2342.5256202718942
#
# weight HKD: 0.45
# other weight(s): 0.55
# new loss function value: 2345.72031541831
#
# weight HKD: 0.5
# other weight(s): 0.5
# new loss function value: 2348.915010564725
#
#
# including AUD
#
# weight AUD: 0.05
# other weight(s): 0.95
# new loss function value: 2222.4836202921006
#
# weight AUD: 0.1
# other weight(s): 0.9
# new loss function value: 2127.9991814836326
#
# weight AUD: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2033.5147426751632
#
# weight AUD: 0.2
# other weight(s): 0.8
# new loss function value: 1939.0303038666946
#
# weight AUD: 0.25
# other weight(s): 0.75
# new loss function value: 1844.5458650582261
#
# weight AUD: 0.3
# other weight(s): 0.7
# new loss function value: 1750.0614262497566
#
# weight AUD: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1655.5769874412883
#
# weight AUD: 0.4
# other weight(s): 0.6
# new loss function value: 1561.092548632819
#
# weight AUD: 0.45
# other weight(s): 0.55
# new loss function value: 1466.6081098243505
#
# weight AUD: 0.5
# other weight(s): 0.5
# new loss function value: 1372.1236710158819
#
#
# better solution found by including AUD
# loss function decreased by -4.49% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.0
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.5
# RON    0.0
# SEK    0.5
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
#
# including RON
#
# weight RON: 0.05
# other weight(s): 0.95
# new loss function value: 2246.811083689041
#
# weight RON: 0.1
# other weight(s): 0.9
# new loss function value: 2176.6541082775116
#
# weight RON: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2106.497132865982
#
# weight RON: 0.2
# other weight(s): 0.8
# new loss function value: 2036.3401574544525
#
# weight RON: 0.25
# other weight(s): 0.75
# new loss function value: 1966.1831820429234
#
# weight RON: 0.3
# other weight(s): 0.7
# new loss function value: 1896.0262066313937
#
# weight RON: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1825.8692312198643
#
# weight RON: 0.4
# other weight(s): 0.6
# new loss function value: 1755.7122558083352
#
# weight RON: 0.45
# other weight(s): 0.55
# new loss function value: 1685.555280396806
#
# weight RON: 0.5
# other weight(s): 0.5
# new loss function value: 1615.3983049852766
#
#
# including TRY
#
# weight TRY: 0.05
# other weight(s): 0.95
# new loss function value: 2229.6080854122856
#
# weight TRY: 0.1
# other weight(s): 0.9
# new loss function value: 2142.248111724002
#
# weight TRY: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2054.888138035718
#
# weight TRY: 0.2
# other weight(s): 0.8
# new loss function value: 1967.5281643474343
#
# weight TRY: 0.25
# other weight(s): 0.75
# new loss function value: 1880.1681906591505
#
# weight TRY: 0.3
# other weight(s): 0.7
# new loss function value: 1792.8082169708664
#
# weight TRY: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1705.4482432825823
#
# weight TRY: 0.4
# other weight(s): 0.6
# new loss function value: 1618.0882695942992
#
# weight TRY: 0.45
# other weight(s): 0.55
# new loss function value: 1530.7282959060155
#
# weight TRY: 0.5
# other weight(s): 0.5
# new loss function value: 1443.368322217731
#
#
# including MYR
#
# weight MYR: 0.05
# other weight(s): 0.95
# new loss function value: 2250.131665310907
#
# weight MYR: 0.1
# other weight(s): 0.9
# new loss function value: 2183.2952715212446
#
# weight MYR: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2116.458877731581
#
# weight MYR: 0.2
# other weight(s): 0.8
# new loss function value: 2049.6224839419187
#
# weight MYR: 0.25
# other weight(s): 0.75
# new loss function value: 1982.7860901522558
#
# weight MYR: 0.3
# other weight(s): 0.7
# new loss function value: 1915.9496963625934
#
# weight MYR: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1849.1133025729305
#
# weight MYR: 0.4
# other weight(s): 0.6
# new loss function value: 1782.2769087832676
#
# weight MYR: 0.45
# other weight(s): 0.55
# new loss function value: 1715.4405149936051
#
# weight MYR: 0.5
# other weight(s): 0.5
# new loss function value: 1648.6041212039418
#
#
# including CNY
#
# weight CNY: 0.05
# other weight(s): 0.95
# new loss function value: 2309.2252581880925
#
# weight CNY: 0.1
# other weight(s): 0.9
# new loss function value: 2301.4824572756165
#
# weight CNY: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2293.739656363139
#
# weight CNY: 0.2
# other weight(s): 0.8
# new loss function value: 2285.996855450662
#
# weight CNY: 0.25
# other weight(s): 0.75
# new loss function value: 2278.2540545381858
#
# weight CNY: 0.3
# other weight(s): 0.7
# new loss function value: 2270.511253625708
#
# weight CNY: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 2262.7684527132305
#
# weight CNY: 0.4
# other weight(s): 0.6
# new loss function value: 2255.0256518007545
#
# weight CNY: 0.45
# other weight(s): 0.55
# new loss function value: 2247.282850888277
#
# weight CNY: 0.5
# other weight(s): 0.5
# new loss function value: 2239.5400499758002
#
#
# including CHF
#
# weight CHF: 0.05
# other weight(s): 0.95
# new loss function value: 2219.273252342809
#
# weight CHF: 0.1
# other weight(s): 0.9
# new loss function value: 2121.5784455850485
#
# weight CHF: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2023.883638827287
#
# weight CHF: 0.2
# other weight(s): 0.8
# new loss function value: 1926.1888320695266
#
# weight CHF: 0.25
# other weight(s): 0.75
# new loss function value: 1828.4940253117652
#
# weight CHF: 0.3
# other weight(s): 0.7
# new loss function value: 1730.7992185540047
#
# weight CHF: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1633.1044117962433
#
# weight CHF: 0.4
# other weight(s): 0.6
# new loss function value: 1535.4096050384826
#
# weight CHF: 0.45
# other weight(s): 0.55
# new loss function value: 1437.7147982807219
#
#
# better solution found by including CHF
# loss function decreased by -4.78% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.00
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.55
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.45
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.00
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight CHF: 0.5
# other weight(s): 0.5
# new loss function value: 1340.019991522961
#
#
# better solution found by including CHF
# loss function decreased by 6.80% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.0
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.5
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.5
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
#
# including ZAR
#
# weight ZAR: 0.05
# other weight(s): 0.95
# new loss function value: 2373.9116424336344
#
# weight ZAR: 0.1
# other weight(s): 0.9
# new loss function value: 2430.8552257666984
#
# weight ZAR: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2487.7988090997633
#
# weight ZAR: 0.2
# other weight(s): 0.8
# new loss function value: 2544.742392432828
#
# weight ZAR: 0.25
# other weight(s): 0.75
# new loss function value: 2601.6859757658926
#
# weight ZAR: 0.3
# other weight(s): 0.7
# new loss function value: 2658.629559098957
#
# weight ZAR: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 2715.573142432021
#
# weight ZAR: 0.4
# other weight(s): 0.6
# new loss function value: 2772.5167257650864
#
# weight ZAR: 0.45
# other weight(s): 0.55
# new loss function value: 2829.4603090981504
#
# weight ZAR: 0.5
# other weight(s): 0.5
# new loss function value: 2886.4038924312154
#
#
# including CZK
#
# weight CZK: 0.05
# other weight(s): 0.95
# new loss function value: 2511.4339956077765
#
# weight CZK: 0.1
# other weight(s): 0.9
# new loss function value: 2705.8999321149813
#
# weight CZK: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2900.365868622188
#
# weight CZK: 0.2
# other weight(s): 0.8
# new loss function value: 3094.8318051293936
#
# weight CZK: 0.25
# other weight(s): 0.75
# new loss function value: 3289.2977416366007
#
# weight CZK: 0.3
# other weight(s): 0.7
# new loss function value: 3483.763678143807
#
# weight CZK: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 3678.2296146510125
#
# weight CZK: 0.4
# other weight(s): 0.6
# new loss function value: 3872.6955511582187
#
# weight CZK: 0.45
# other weight(s): 0.55
# new loss function value: 4067.1614876654253
#
# weight CZK: 0.5
# other weight(s): 0.5
# new loss function value: 4261.6274241726305
#
#
# including SGD
#
# weight SGD: 0.05
# other weight(s): 0.95
# new loss function value: 2220.1968862097424
#
# weight SGD: 0.1
# other weight(s): 0.9
# new loss function value: 2123.425713318915
#
# weight SGD: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2026.6545404280869
#
# weight SGD: 0.2
# other weight(s): 0.8
# new loss function value: 1929.8833675372603
#
# weight SGD: 0.25
# other weight(s): 0.75
# new loss function value: 1833.1121946464323
#
# weight SGD: 0.3
# other weight(s): 0.7
# new loss function value: 1736.3410217556047
#
# weight SGD: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1639.5698488647765
#
# weight SGD: 0.4
# other weight(s): 0.6
# new loss function value: 1542.7986759739501
#
# weight SGD: 0.45
# other weight(s): 0.55
# new loss function value: 1446.0275030831224
#
# weight SGD: 0.5
# other weight(s): 0.5
# new loss function value: 1349.2563301922946
#
#
# better solution found by including SGD
# loss function decreased by -0.69% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.0
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.5
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.5
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
#
# including CAD
#
# weight CAD: 0.05
# other weight(s): 0.95
# new loss function value: 2220.1033957172676
#
# weight CAD: 0.1
# other weight(s): 0.9
# new loss function value: 2123.2387323339663
#
# weight CAD: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2026.374068950664
#
# weight CAD: 0.2
# other weight(s): 0.8
# new loss function value: 1929.5094055673628
#
# weight CAD: 0.25
# other weight(s): 0.75
# new loss function value: 1832.6447421840603
#
# weight CAD: 0.3
# other weight(s): 0.7
# new loss function value: 1735.780078800758
#
# weight CAD: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1638.9154154174555
#
# weight CAD: 0.4
# other weight(s): 0.6
# new loss function value: 1542.0507520341541
#
# weight CAD: 0.45
# other weight(s): 0.55
# new loss function value: 1445.1860886508525
#
# weight CAD: 0.5
# other weight(s): 0.5
# new loss function value: 1348.3214252675502
#
#
# better solution found by including CAD
# loss function decreased by 0.07% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.0
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.5
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.0
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.5
# dtype: float64
#
# including NOK
#
# weight NOK: 0.05
# other weight(s): 0.95
# new loss function value: 2301.0831062109573
#
# weight NOK: 0.1
# other weight(s): 0.9
# new loss function value: 2285.198153321346
#
# weight NOK: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2269.3132004317335
#
# weight NOK: 0.2
# other weight(s): 0.8
# new loss function value: 2253.4282475421205
#
# weight NOK: 0.25
# other weight(s): 0.75
# new loss function value: 2237.543294652508
#
# weight NOK: 0.3
# other weight(s): 0.7
# new loss function value: 2221.658341762896
#
# weight NOK: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 2205.7733888732837
#
# weight NOK: 0.4
# other weight(s): 0.6
# new loss function value: 2189.8884359836716
#
# weight NOK: 0.45
# other weight(s): 0.55
# new loss function value: 2174.0034830940594
#
# weight NOK: 0.5
# other weight(s): 0.5
# new loss function value: 2158.1185302044464
#
#
# including GBP
#
# weight GBP: 0.05
# other weight(s): 0.95
# new loss function value: 2210.5195382891125
#
# weight GBP: 0.1
# other weight(s): 0.9
# new loss function value: 2104.071017477656
#
# weight GBP: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 1997.6224966661985
#
# weight GBP: 0.2
# other weight(s): 0.8
# new loss function value: 1891.173975854741
#
# weight GBP: 0.25
# other weight(s): 0.75
# new loss function value: 1784.725455043284
#
# weight GBP: 0.3
# other weight(s): 0.7
# new loss function value: 1678.2769342318265
#
# weight GBP: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1571.8284134203693
#
# weight GBP: 0.4
# other weight(s): 0.6
# new loss function value: 1465.3798926089125
#
# weight GBP: 0.45
# other weight(s): 0.55
# new loss function value: 1358.9313717974558
#
#
# better solution found by including GBP
# loss function decreased by -0.79% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.00
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.55
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.45
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight GBP: 0.5
# other weight(s): 0.5
# new loss function value: 1252.4828509859985
#
#
# better solution found by including GBP
# loss function decreased by 7.83% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.0
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.5
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.5
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
#
# including PLN
#
# weight PLN: 0.05
# other weight(s): 0.95
# new loss function value: 2256.9568404582833
#
# weight PLN: 0.1
# other weight(s): 0.9
# new loss function value: 2196.9456218159953
#
# weight PLN: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2136.934403173709
#
# weight PLN: 0.2
# other weight(s): 0.8
# new loss function value: 2076.9231845314216
#
# weight PLN: 0.25
# other weight(s): 0.75
# new loss function value: 2016.9119658891343
#
# weight PLN: 0.3
# other weight(s): 0.7
# new loss function value: 1956.9007472468468
#
# weight PLN: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1896.88952860456
#
# weight PLN: 0.4
# other weight(s): 0.6
# new loss function value: 1836.8783099622726
#
# weight PLN: 0.45
# other weight(s): 0.55
# new loss function value: 1776.8670913199858
#
# weight PLN: 0.5
# other weight(s): 0.5
# new loss function value: 1716.8558726776992
#
#
# including DKK
#
# weight DKK: 0.05
# other weight(s): 0.95
# new loss function value: 2273.606993053268
#
# weight DKK: 0.1
# other weight(s): 0.9
# new loss function value: 2230.2459270059667
#
# weight DKK: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 2186.8848609586644
#
# weight DKK: 0.2
# other weight(s): 0.8
# new loss function value: 2143.523794911363
#
# weight DKK: 0.25
# other weight(s): 0.75
# new loss function value: 2100.162728864061
#
# weight DKK: 0.3
# other weight(s): 0.7
# new loss function value: 2056.8016628167597
#
# weight DKK: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 2013.4405967694572
#
# weight DKK: 0.4
# other weight(s): 0.6
# new loss function value: 1970.079530722156
#
# weight DKK: 0.45
# other weight(s): 0.55
# new loss function value: 1926.7184646748542
#
# weight DKK: 0.5
# other weight(s): 0.5
# new loss function value: 1883.3573986275526
#
#
# including RUB
#
# weight RUB: 0.05
# other weight(s): 0.95
# new loss function value: 2603.5073595691733
#
# weight RUB: 0.1
# other weight(s): 0.9
# new loss function value: 2890.0466600377763
#
# weight RUB: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 3176.58596050638
#
# weight RUB: 0.2
# other weight(s): 0.8
# new loss function value: 3463.1252609749827
#
# weight RUB: 0.25
# other weight(s): 0.75
# new loss function value: 3749.664561443587
#
# weight RUB: 0.3
# other weight(s): 0.7
# new loss function value: 4036.2038619121904
#
# weight RUB: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 4322.7431623807925
#
# weight RUB: 0.4
# other weight(s): 0.6
# new loss function value: 4609.282462849397
#
# weight RUB: 0.45
# other weight(s): 0.55
# new loss function value: 4895.821763317999
#
# weight RUB: 0.5
# other weight(s): 0.5
# new loss function value: 5182.361063786604
#
#
# including HUF
#
# weight HUF: 0.05
# other weight(s): 0.95
# new loss function value: 6110.349817225589
#
# weight HUF: 0.1
# other weight(s): 0.9
# new loss function value: 9903.731575350605
#
# weight HUF: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 13697.113333475618
#
# weight HUF: 0.2
# other weight(s): 0.8
# new loss function value: 17490.49509160064
#
# weight HUF: 0.25
# other weight(s): 0.75
# new loss function value: 21283.876849725653
#
# weight HUF: 0.3
# other weight(s): 0.7
# new loss function value: 25077.25860785067
#
# weight HUF: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 28870.6403659757
#
# weight HUF: 0.4
# other weight(s): 0.6
# new loss function value: 32664.022124100706
#
# weight HUF: 0.45
# other weight(s): 0.55
# new loss function value: 36457.403882225735
#
# weight HUF: 0.5
# other weight(s): 0.5
# new loss function value: 40250.78564035073
#
#
# including IDR
#
# weight IDR: 0.05
# other weight(s): 0.95
# new loss function value: 165583.64505145865
#
# weight IDR: 0.1
# other weight(s): 0.9
# new loss function value: 328850.3220438168
#
# weight IDR: 0.15000000000000002
# other weight(s): 0.85
# new loss function value: 492116.99903617497
#
# weight IDR: 0.2
# other weight(s): 0.8
# new loss function value: 655383.6760285328
#
# weight IDR: 0.25
# other weight(s): 0.75
# new loss function value: 818650.3530208908
#
# weight IDR: 0.3
# other weight(s): 0.7
# new loss function value: 981917.0300132489
#
# weight IDR: 0.35000000000000003
# other weight(s): 0.6499999999999999
# new loss function value: 1145183.7070056072
#
# weight IDR: 0.4
# other weight(s): 0.6
# new loss function value: 1308450.3839979654
#
# weight IDR: 0.45
# other weight(s): 0.55
# new loss function value: 1471717.0609903235
#
# weight IDR: 0.5
# other weight(s): 0.5
# new loss function value: 1634983.7379826815
#
# GBP is added to currency set
#
# starting loss function value: 1252.4828509859985
#
# including KRW
#
# weight KRW: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 15209.490805619202
#
# weight KRW: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 29166.4987602524
#
# weight KRW: 0.1
# other weight(s): 0.45
# new loss function value: 43123.506714885596
#
# weight KRW: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 57080.514669518816
#
# weight KRW: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 71037.522624152
#
# weight KRW: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 84994.53057878523
#
# weight KRW: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 98951.53853341842
#
# weight KRW: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 112908.54648805161
#
# weight KRW: 0.3
# other weight(s): 0.35
# new loss function value: 126865.55444268485
#
# weight KRW: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 140822.562397318
#
#
# including THB
#
# weight THB: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1582.0574828481238
#
# weight THB: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1911.6321147102497
#
# weight THB: 0.1
# other weight(s): 0.45
# new loss function value: 2241.2067465723753
#
# weight THB: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 2570.781378434501
#
# weight THB: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 2900.356010296627
#
# weight THB: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 3229.9306421587526
#
# weight THB: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 3559.505274020878
#
# weight THB: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 3889.079905883004
#
# weight THB: 0.3
# other weight(s): 0.35
# new loss function value: 4218.65453774513
#
# weight THB: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 4548.229169607255
#
#
# including EUR
#
# weight EUR: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1217.2193837739646
#
#
# better solution found by including EUR
# loss function decreased by 2.82% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.033
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.483
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.483
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
# weight EUR: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1181.9559165619314
#
#
# better solution found by including EUR
# loss function decreased by 2.90% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.067
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.467
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.467
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
# weight EUR: 0.1
# other weight(s): 0.45
# new loss function value: 1146.6924493498982
#
#
# better solution found by including EUR
# loss function decreased by 2.98% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.10
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.45
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.45
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight EUR: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 1111.4289821378645
#
#
# better solution found by including EUR
# loss function decreased by 3.08% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.133
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.433
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.433
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
# weight EUR: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 1076.165514925831
#
#
# better solution found by including EUR
# loss function decreased by 3.17% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.167
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.417
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.417
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
# weight EUR: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 1040.9020477137976
#
#
# better solution found by including EUR
# loss function decreased by 3.28% compared to current best solution
#
# KRW    0.0
# THB    0.0
# EUR    0.2
# HRK    0.0
# NZD    0.0
# PHP    0.0
# JPY    0.0
# USD    0.0
# HKD    0.0
# AUD    0.0
# RON    0.0
# SEK    0.4
# TRY    0.0
# CNY    0.0
# MYR    0.0
# CHF    0.0
# ZAR    0.0
# CZK    0.0
# SGD    0.0
# NOK    0.0
# GBP    0.4
# PLN    0.0
# DKK    0.0
# RUB    0.0
# HUF    0.0
# IDR    0.0
# CAD    0.0
# dtype: float64
# weight EUR: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 1005.6385805017643
#
#
# better solution found by including EUR
# loss function decreased by 3.39% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.233
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.383
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.383
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
# weight EUR: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 970.375113289731
#
#
# better solution found by including EUR
# loss function decreased by 3.51% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.267
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.367
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.367
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
# weight EUR: 0.3
# other weight(s): 0.35
# new loss function value: 935.1116460776974
#
#
# better solution found by including EUR
# loss function decreased by 3.63% compared to current best solution
#
# KRW    0.00
# THB    0.00
# EUR    0.30
# HRK    0.00
# NZD    0.00
# PHP    0.00
# JPY    0.00
# USD    0.00
# HKD    0.00
# AUD    0.00
# RON    0.00
# SEK    0.35
# TRY    0.00
# CNY    0.00
# MYR    0.00
# CHF    0.00
# ZAR    0.00
# CZK    0.00
# SGD    0.00
# NOK    0.00
# GBP    0.35
# PLN    0.00
# DKK    0.00
# RUB    0.00
# HUF    0.00
# IDR    0.00
# CAD    0.00
# dtype: float64
# weight EUR: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 899.8481788656636
#
#
# better solution found by including EUR
# loss function decreased by 3.77% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.333
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.333
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.333
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
#
# including HRK
#
# weight HRK: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1260.0394125136709
#
# weight HRK: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1267.595974041344
#
# weight HRK: 0.1
# other weight(s): 0.45
# new loss function value: 1275.1525355690171
#
# weight HRK: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 1282.7090970966901
#
# weight HRK: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 1290.265658624363
#
# weight HRK: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 1297.8222201520355
#
# weight HRK: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 1305.3787816797085
#
# weight HRK: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 1312.9353432073815
#
# weight HRK: 0.3
# other weight(s): 0.35
# new loss function value: 1320.4919047350545
#
# weight HRK: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 1328.0484662627275
#
#
# including NZD
#
# weight NZD: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1229.6562976909172
#
# weight NZD: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1206.8297443958363
#
# weight NZD: 0.1
# other weight(s): 0.45
# new loss function value: 1184.003191100756
#
# weight NZD: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 1161.1766378056752
#
# weight NZD: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 1138.3500845105943
#
# weight NZD: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 1115.5235312155137
#
# weight NZD: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 1092.6969779204328
#
# weight NZD: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 1069.8704246253521
#
# weight NZD: 0.3
# other weight(s): 0.35
# new loss function value: 1047.0438713302715
#
# weight NZD: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 1024.2173180351906
#
#
# including PHP
#
# weight PHP: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1703.3108029237314
#
# weight PHP: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 2154.138754861465
#
# weight PHP: 0.1
# other weight(s): 0.45
# new loss function value: 2604.9667067991973
#
# weight PHP: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 3055.7946587369306
#
# weight PHP: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 3506.622610674663
#
# weight PHP: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 3957.450562612396
#
# weight PHP: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 4408.278514550129
#
# weight PHP: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 4859.106466487863
#
# weight PHP: 0.3
# other weight(s): 0.35
# new loss function value: 5309.934418425597
#
# weight PHP: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 5760.762370363327
#
#
# including JPY
#
# weight JPY: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 2628.825598049949
#
# weight JPY: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 4005.1683451139
#
# weight JPY: 0.1
# other weight(s): 0.45
# new loss function value: 5381.511092177852
#
# weight JPY: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 6757.8538392417995
#
# weight JPY: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 8134.196586305752
#
# weight JPY: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 9510.539333369703
#
# weight JPY: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 10886.882080433652
#
# weight JPY: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 12263.224827497603
#
# weight JPY: 0.3
# other weight(s): 0.35
# new loss function value: 13639.567574561559
#
# weight JPY: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 15015.91032162551
#
#
# including USD
#
# weight USD: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1221.0491524558959
#
# weight USD: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1189.6154539257927
#
# weight USD: 0.1
# other weight(s): 0.45
# new loss function value: 1158.1817553956907
#
# weight USD: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 1126.7480568655878
#
# weight USD: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 1095.3143583354852
#
# weight USD: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 1063.8806598053827
#
# weight USD: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 1032.4469612752803
#
# weight USD: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 1001.0132627451775
#
# weight USD: 0.3
# other weight(s): 0.35
# new loss function value: 969.579564215075
#
# weight USD: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 938.1458656849725
#
#
# better solution found by including USD
# loss function decreased by -4.26% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.000
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.333
# HKD    0.000
# AUD    0.000
# RON    0.000
# SEK    0.333
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.333
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
#
# including HKD
#
# weight HKD: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1290.0954880207605
#
# weight HKD: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1327.7081250555236
#
# weight HKD: 0.1
# other weight(s): 0.45
# new loss function value: 1365.3207620902863
#
# weight HKD: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 1402.933399125049
#
# weight HKD: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 1440.5460361598123
#
# weight HKD: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 1478.1586731945747
#
# weight HKD: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 1515.7713102293376
#
# weight HKD: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 1553.3839472641
#
# weight HKD: 0.3
# other weight(s): 0.35
# new loss function value: 1590.9965842988627
#
# weight HKD: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 1628.6092213336262
#
#
# including AUD
#
# weight AUD: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1224.9760653841713
#
# weight AUD: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1197.4692797823443
#
# weight AUD: 0.1
# other weight(s): 0.45
# new loss function value: 1169.9624941805178
#
# weight AUD: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 1142.4557085786907
#
# weight AUD: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 1114.9489229768644
#
# weight AUD: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 1087.4421373750372
#
# weight AUD: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 1059.9353517732102
#
# weight AUD: 0.26666666666666666
# other weight(s): 0.3666666666666667
# new loss function value: 1032.4285661713836
#
# weight AUD: 0.3
# other weight(s): 0.35
# new loss function value: 1004.9217805695571
#
# weight AUD: 0.3333333333333333
# other weight(s): 0.33333333333333337
# new loss function value: 977.41499496773
#
#
# better solution found by including AUD
# loss function decreased by -4.19% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.000
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.000
# HKD    0.000
# AUD    0.333
# RON    0.000
# SEK    0.333
# TRY    0.000
# CNY    0.000
# MYR    0.000
# CHF    0.000
# ZAR    0.000
# CZK    0.000
# SGD    0.000
# NOK    0.000
# GBP    0.333
# PLN    0.000
# DKK    0.000
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.000
# dtype: float64
#
# including RON
#
# weight RON: 0.03333333333333333
# other weight(s): 0.48333333333333334
# new loss function value: 1241.1943743154643
#
# weight RON: 0.06666666666666667
# other weight(s): 0.4666666666666667
# new loss function value: 1229.9058976449303
#
# weight RON: 0.1
# other weight(s): 0.45
# new loss function value: 1218.6174209743967
#
# weight RON: 0.13333333333333333
# other weight(s): 0.43333333333333335
# new loss function value: 1207.3289443038627
#
# weight RON: 0.16666666666666666
# other weight(s): 0.4166666666666667
# new loss function value: 1196.0404676333292
#
# weight RON: 0.19999999999999998
# other weight(s): 0.4
# new loss function value: 1184.7519909627952
#
# weight RON: 0.23333333333333334
# other weight(s): 0.3833333333333333
# new loss function value: 1173.463514292261
#
# weight RON: 0.26666666666666666
# ...
# EUR    0.090
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.090
# HKD    0.000
# AUD    0.090
# RON    0.000
# SEK    0.090
# TRY    0.090
# CNY    0.000
# MYR    0.008
# CHF    0.090
# ZAR    0.000
# CZK    0.000
# SGD    0.090
# NOK    0.000
# GBP    0.090
# PLN    0.090
# DKK    0.090
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.090
# dtype: float64
# weight MYR: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 704.3887249038138
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.089
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.089
# HKD    0.000
# AUD    0.089
# RON    0.000
# SEK    0.089
# TRY    0.089
# CNY    0.000
# MYR    0.017
# CHF    0.089
# ZAR    0.000
# CZK    0.000
# SGD    0.089
# NOK    0.000
# GBP    0.089
# PLN    0.089
# DKK    0.089
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.089
# dtype: float64
# weight MYR: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 706.726449127572
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.089
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.089
# HKD    0.000
# AUD    0.089
# RON    0.000
# SEK    0.089
# TRY    0.089
# CNY    0.000
# MYR    0.025
# CHF    0.089
# ZAR    0.000
# CZK    0.000
# SGD    0.089
# NOK    0.000
# GBP    0.089
# PLN    0.089
# DKK    0.089
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.089
# dtype: float64
# weight MYR: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 709.0641733513305
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.088
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.088
# HKD    0.000
# AUD    0.088
# RON    0.000
# SEK    0.088
# TRY    0.088
# CNY    0.000
# MYR    0.033
# CHF    0.088
# ZAR    0.000
# CZK    0.000
# SGD    0.088
# NOK    0.000
# GBP    0.088
# PLN    0.088
# DKK    0.088
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.088
# dtype: float64
# weight MYR: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 711.4018975750892
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.087
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.087
# HKD    0.000
# AUD    0.087
# RON    0.000
# SEK    0.087
# TRY    0.087
# CNY    0.000
# MYR    0.042
# CHF    0.087
# ZAR    0.000
# CZK    0.000
# SGD    0.087
# NOK    0.000
# GBP    0.087
# PLN    0.087
# DKK    0.087
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.087
# dtype: float64
# weight MYR: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 713.7396217988473
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.086
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.086
# HKD    0.000
# AUD    0.086
# RON    0.000
# SEK    0.086
# TRY    0.086
# CNY    0.000
# MYR    0.050
# CHF    0.086
# ZAR    0.000
# CZK    0.000
# SGD    0.086
# NOK    0.000
# GBP    0.086
# PLN    0.086
# DKK    0.086
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.086
# dtype: float64
# weight MYR: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 716.077346022606
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.086
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.086
# HKD    0.000
# AUD    0.086
# RON    0.000
# SEK    0.086
# TRY    0.086
# CNY    0.000
# MYR    0.058
# CHF    0.086
# ZAR    0.000
# CZK    0.000
# SGD    0.086
# NOK    0.000
# GBP    0.086
# PLN    0.086
# DKK    0.086
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.086
# dtype: float64
# weight MYR: 0.06666666666666667
# other weight(s): 0.08484848484848485
# new loss function value: 718.4150702463644
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.085
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.085
# HKD    0.000
# AUD    0.085
# RON    0.000
# SEK    0.085
# TRY    0.085
# CNY    0.000
# MYR    0.067
# CHF    0.085
# ZAR    0.000
# CZK    0.000
# SGD    0.085
# NOK    0.000
# GBP    0.085
# PLN    0.085
# DKK    0.085
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.085
# dtype: float64
# weight MYR: 0.075
# other weight(s): 0.08409090909090909
# new loss function value: 720.7527944701229
#
#
# better solution found by including MYR
# loss function decreased by -0.33% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.084
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.084
# HKD    0.000
# AUD    0.084
# RON    0.000
# SEK    0.084
# TRY    0.084
# CNY    0.000
# MYR    0.075
# CHF    0.084
# ZAR    0.000
# CZK    0.000
# SGD    0.084
# NOK    0.000
# GBP    0.084
# PLN    0.084
# DKK    0.084
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.084
# dtype: float64
# weight MYR: 0.08333333333333333
# other weight(s): 0.08333333333333333
# new loss function value: 723.0905186938814
#
#
# better solution found by including MYR
# loss function decreased by -0.32% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.083
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.083
# HKD    0.000
# AUD    0.083
# RON    0.000
# SEK    0.083
# TRY    0.083
# CNY    0.000
# MYR    0.083
# CHF    0.083
# ZAR    0.000
# CZK    0.000
# SGD    0.083
# NOK    0.000
# GBP    0.083
# PLN    0.083
# DKK    0.083
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.083
# dtype: float64
#
# including CNY
#
# weight CNY: 0.008333333333333333
# other weight(s): 0.09015151515151515
# new loss function value: 711.8999328262526
#
#
# better solution found by including CNY
# loss function decreased by 1.55% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.090
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.090
# HKD    0.000
# AUD    0.090
# RON    0.000
# SEK    0.090
# TRY    0.090
# CNY    0.008
# MYR    0.000
# CHF    0.090
# ZAR    0.000
# CZK    0.000
# SGD    0.090
# NOK    0.000
# GBP    0.090
# PLN    0.090
# DKK    0.090
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.090
# dtype: float64
# weight CNY: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 724.0865891962089
#
#
# better solution found by including CNY
# loss function decreased by -1.71% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.089
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.089
# HKD    0.000
# AUD    0.089
# RON    0.000
# SEK    0.089
# TRY    0.089
# CNY    0.017
# MYR    0.000
# CHF    0.089
# ZAR    0.000
# CZK    0.000
# SGD    0.089
# NOK    0.000
# GBP    0.089
# PLN    0.089
# DKK    0.089
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.089
# dtype: float64
# weight CNY: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 736.2732455661649
#
# weight CNY: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 748.459901936121
#
# weight CNY: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 760.6465583060773
#
# weight CNY: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 772.8332146760332
#
# weight CNY: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 785.0198710459896
#
# weight CNY: 0.06666666666666667
# other weight(s): 0.08484848484848485
# new loss function value: 797.2065274159456
#
# weight CNY: 0.075
# other weight(s): 0.08409090909090909
# new loss function value: 809.3931837859016
#
# weight CNY: 0.08333333333333333
# other weight(s): 0.08333333333333333
# new loss function value: 821.5798401558578
#
#
# including ZAR
#
# weight ZAR: 0.008333333333333333
# other weight(s): 0.09015151515151515
# new loss function value: 722.6809968671762
#
#
# better solution found by including ZAR
# loss function decreased by 0.19% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.090
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.090
# HKD    0.000
# AUD    0.090
# RON    0.000
# SEK    0.090
# TRY    0.090
# CNY    0.000
# MYR    0.000
# CHF    0.090
# ZAR    0.008
# CZK    0.000
# SGD    0.090
# NOK    0.000
# GBP    0.090
# PLN    0.090
# DKK    0.090
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.090
# dtype: float64
# weight ZAR: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 745.6487172780559
#
# weight ZAR: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 768.6164376889358
#
# weight ZAR: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 791.5841580998153
#
# weight ZAR: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 814.5518785106954
#
# weight ZAR: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 837.5195989215746
#
# weight ZAR: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 860.4873193324545
#
# weight ZAR: 0.06666666666666667
# other weight(s): 0.08484848484848485
# new loss function value: 883.4550397433342
#
# weight ZAR: 0.075
# other weight(s): 0.08409090909090909
# new loss function value: 906.4227601542141
#
# weight ZAR: 0.08333333333333333
# other weight(s): 0.08333333333333333
# new loss function value: 929.3904805650935
#
#
# including CZK
#
# weight CZK: 0.008333333333333333
# other weight(s): 0.09015151515151515
# new loss function value: 745.6013890628667
#
# weight CZK: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 791.4895016694364
#
# weight CZK: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 837.3776142760065
#
# weight CZK: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 883.2657268825767
#
# weight CZK: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 929.1538394891464
#
# weight CZK: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 975.0419520957166
#
# weight CZK: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 1020.9300647022861
#
# weight CZK: 0.06666666666666667
# other weight(s): 0.08484848484848485
# new loss function value: 1066.818177308856
#
# weight CZK: 0.075
# other weight(s): 0.08409090909090909
# new loss function value: 1112.7062899154262
#
# weight CZK: 0.08333333333333333
# other weight(s): 0.08333333333333333
# new loss function value: 1158.594402521996
#
#
# including NOK
#
# weight NOK: 0.008333333333333333
# other weight(s): 0.09015151515151515
# new loss function value: 710.5429074967303
#
#
# better solution found by including NOK
# loss function decreased by 1.68% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.090
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.090
# HKD    0.000
# AUD    0.090
# RON    0.000
# SEK    0.090
# TRY    0.090
# CNY    0.000
# MYR    0.000
# CHF    0.090
# ZAR    0.000
# CZK    0.000
# SGD    0.090
# NOK    0.008
# GBP    0.090
# PLN    0.090
# DKK    0.090
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.090
# dtype: float64
# weight NOK: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 721.3725385371639
#
#
# better solution found by including NOK
# loss function decreased by -1.52% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.089
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.089
# HKD    0.000
# AUD    0.089
# RON    0.000
# SEK    0.089
# TRY    0.089
# CNY    0.000
# MYR    0.000
# CHF    0.089
# ZAR    0.000
# CZK    0.000
# SGD    0.089
# NOK    0.017
# GBP    0.089
# PLN    0.089
# DKK    0.089
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.089
# dtype: float64
# weight NOK: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 732.2021695775971
#
#
# better solution found by including NOK
# loss function decreased by -1.50% compared to current best solution
#
# KRW    0.000
# THB    0.000
# EUR    0.089
# HRK    0.000
# NZD    0.000
# PHP    0.000
# JPY    0.000
# USD    0.089
# HKD    0.000
# AUD    0.089
# RON    0.000
# SEK    0.089
# TRY    0.089
# CNY    0.000
# MYR    0.000
# CHF    0.089
# ZAR    0.000
# CZK    0.000
# SGD    0.089
# NOK    0.025
# GBP    0.089
# PLN    0.089
# DKK    0.089
# RUB    0.000
# HUF    0.000
# IDR    0.000
# CAD    0.089
# dtype: float64
# weight NOK: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 743.031800618031
#
# weight NOK: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 753.8614316584647
#
# weight NOK: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 764.6910626988979
#
# weight NOK: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 775.5206937393314
#
# weight NOK: 0.06666666666666667
# other weight(s): 0.08484848484848485
# new loss function value: 786.3503247797651
#
# weight NOK: 0.075
# other weight(s): 0.08409090909090909
# new loss function value: 797.1799558201986
#
# weight NOK: 0.08333333333333333
# other weight(s): 0.08333333333333333
# new loss function value: 808.0095868606322
#
#
# including RUB
#
# weight RUB: 0.008333333333333333
# other weight(s): 0.09015151515151515
# new loss function value: 760.9469497230994
#
# weight RUB: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 822.1806229899023
#
# weight RUB: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 883.4142962567053
#
# weight RUB: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 944.647969523508
#
# weight RUB: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 1005.8816427903109
#
# weight RUB: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 1067.1153160571137
#
# weight RUB: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 1128.3489893239164
#
# weight RUB: 0.06666666666666667
# other weight(s): 0.08484848484848485
# new loss function value: 1189.5826625907189
#
# weight RUB: 0.075
# other weight(s): 0.08409090909090909
# new loss function value: 1250.816335857522
#
# weight RUB: 0.08333333333333333
# other weight(s): 0.08333333333333333
# new loss function value: 1312.0500091243248
#
#
# including HUF
#
# weight HUF: 0.008333333333333333
# other weight(s): 0.09015151515151515
# new loss function value: 1345.4206926658348
#
# weight HUF: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 1991.128108875373
#
# weight HUF: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 2636.8355250849113
#
# weight HUF: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 3282.542941294452
#
# weight HUF: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 3928.250357503988
#
# weight HUF: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 4573.957773713526
#
# weight HUF: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 5219.6651899230665
#
# weight HUF: 0.06666666666666667
# other weight(s): 0.08484848484848485
# new loss function value: 5865.372606132604
#
# weight HUF: 0.075
# other weight(s): 0.08409090909090909
# new loss function value: 6511.080022342143
#
# weight HUF: 0.08333333333333333
# other weight(s): 0.08333333333333333
# new loss function value: 7156.787438551682
#
#
# including IDR
#
# weight IDR: 0.008333333333333333
# other weight(s): 0.09015151515151515
# new loss function value: 27924.303231704675
#
# weight IDR: 0.016666666666666666
# other weight(s): 0.08939393939393939
# new loss function value: 55148.89318695306
#
# weight IDR: 0.025
# other weight(s): 0.08863636363636364
# new loss function value: 82373.48314220141
#
# weight IDR: 0.03333333333333333
# other weight(s): 0.08787878787878788
# new loss function value: 109598.07309744987
#
# weight IDR: 0.041666666666666664
# other weight(s): 0.08712121212121213
# new loss function value: 136822.66305269822
#
# weight IDR: 0.049999999999999996
# other weight(s): 0.08636363636363636
# new loss function value: 164047.25300794654
#
# weight IDR: 0.058333333333333334
# other weight(s): 0.0856060606060606
# new loss function value: 191271.842963195

# %%
assert get_libra_mix(reference_date_exhange_rate).sum() == 1
assert get_sdr_mix(reference_date_exhange_rate).sum() == 1
