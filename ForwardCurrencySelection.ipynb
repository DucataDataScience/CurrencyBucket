# %%
"""
Description: Script to optimize Duca's currency mix.
Author: Jeroen van Dijk & Victor de Graaff
Date: 04-11-2020
Maintainer: Jeroen van Dijk & Victor de Graaff
Email: jeroen.vandijk@d-data.nl & victor.degraaff@d-data.nl
Status: Dev
"""
# Out:
# "\nDescription: Script to optimize Duca's currency mix.\nAuthor: Jeroen van Dijk & Victor de Graaff\nDate: 04-11-2020\nMaintainer: Jeroen van Dijk & Victor de Graaff\nEmail: jeroen.vandijk@d-data.nl & victor.degraaff@d-data.nl\nStatus: Dev\n"

# %%
# Load common imports
# %run ./CommonImports.ipynb

# %%
# Load common functions and currencies lists:
# - all_currencies
# - obsolete_currencies
# - p13_currencies
# - f_currencies
# - ff_currencies
# - currencies_per_continent
# %run ./Utilities.ipynb

# %%
# Load loss functions
# - calculate_loss_function_around_one(weights)
# - calculate_loss_function_vs_t_minus_one(weights)
# - calculate_loss_function_vs_t_minus_one_with_balancing(weights)
# - calculate_loss_function_vs_t_minus_one_for_period(weights, max_date)
# %run ./LossFunctions.ipynb

# %%
# Create dataframe with pre-defined base currency
df = create_original_df("EUR")

# %%
# Determine splits for dev- (train and test) and validation set
train_start = date(2005, 4, 1)
test_start = date(2012, 1, 1)
validation_start = date(2015, 1, 1)
validation_end = date(2020, 10, 1)

# Create dev (train and test) and validation set
train, test, dev, val = split_data(df, train_start, test_start, validation_start, validation_end)

# %%
# Create exchange table for each currency
exchange_table = dict()
for base_currency in all_currencies:
    exchange_table[base_currency] = 1/train[all_currencies].divide(train[base_currency], axis=0)

# Preview USD exchange table
exchange_table["USD"]
# Out:
#                TRY     NZD     SEK     HKD     NOK     CAD     HUF     USD     IDR     AUD     DKK     EUR     PHP     KRW     CNY     THB     RUB     ZAR     GBP     HRK     SGD     JPY     PLN     CHF     MYR     CZK     RON
# date
# 2005-04-01 0.73963 0.71051 0.14134 0.12823 0.15813 0.82353 0.00524 1.00000 0.00011 0.77123 0.17394 1.29590 0.01827 0.00099 0.12082 0.02554 0.03588 0.16175 1.88728 0.17460 0.60418 0.00932 0.31703 0.83461 0.26316 0.04315 0.35967
# 2005-04-02 0.73758 0.70945 0.14100 0.12822 0.15780 0.82270 0.00523 1.00000 0.00011 0.77012 0.17360 1.29337 0.01826 0.00099 0.12082 0.02546 0.03587 0.16153 1.88327 0.17424 0.60293 0.00930 0.31580 0.83284 0.26316 0.04307 0.35897
# 2005-04-03 0.73553 0.70838 0.14065 0.12822 0.15748 0.82187 0.00522 1.00000 0.00011 0.76901 0.17326 1.29083 0.01825 0.00099 0.12082 0.02537 0.03586 0.16132 1.87926 0.17387 0.60168 0.00928 0.31458 0.83106 0.26317 0.04299 0.35827
# 2005-04-04 0.73349 0.70731 0.14031 0.12821 0.15715 0.82104 0.00521 1.00000 0.00011 0.76790 0.17292 1.28830 0.01824 0.00099 0.12082 0.02529 0.03585 0.16110 1.87525 0.17351 0.60044 0.00926 0.31336 0.82929 0.26317 0.04291 0.35756
# 2005-04-05 0.73137 0.70431 0.13960 0.12821 0.15691 0.81681 0.00518 1.00000 0.00011 0.76441 0.17195 1.28100 0.01824 0.00098 0.12082 0.02522 0.03579 0.16014 1.87253 0.17266 0.60059 0.00921 0.31019 0.82427 0.26316 0.04271 0.35554
# ...            ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2011-12-27 0.52632 0.77395 0.14564 0.12859 0.16767 0.98101 0.00428 1.00000 0.00011 1.01609 0.17582 1.30690 0.02285 0.00087 0.15816 0.03181 0.03197 0.12258 1.56797 0.17385 0.77144 0.01284 0.29675 1.07035 0.31511 0.05068 0.30464
# 2011-12-28 0.52633 0.77766 0.14578 0.12858 0.16764 0.98530 0.00426 1.00000 0.00011 1.01989 0.17583 1.30740 0.02274 0.00087 0.15827 0.03171 0.03159 0.12334 1.56725 0.17367 0.77197 0.01288 0.29749 1.07199 0.31596 0.05064 0.30502
# 2011-12-29 0.52288 0.76652 0.14415 0.12866 0.16580 0.97725 0.00415 1.00000 0.00011 1.00703 0.17337 1.28890 0.02281 0.00087 0.15822 0.03147 0.03103 0.12265 1.54175 0.17100 0.76697 0.01286 0.29022 1.05769 0.31451 0.04975 0.29957
# 2011-12-30 0.52959 0.77308 0.14519 0.12873 0.16687 0.97911 0.00411 1.00000 0.00011 1.01698 0.17405 1.29390 0.02280 0.00086 0.15859 0.03157 0.03098 0.12343 1.54902 0.17167 0.76931 0.01291 0.29024 1.06441 0.31516 0.05018 0.29929
# 2011-12-31 0.52994 0.77476 0.14509 0.12874 0.16685 0.97951 0.00411 1.00000 0.00011 1.01850 0.17403 1.29377 0.02280 0.00086 0.15861 0.03162 0.03101 0.12351 1.54896 0.17168 0.76981 0.01294 0.28988 1.06433 0.31519 0.05035 0.29904
#
# [2466 rows x 27 columns]

# %%
reference_date_exhange_rate = train[all_currencies].iloc[0]

# %%
def run_optimization(selected_currencies, 
                     max_iter=100, 
                     loss_function=calculate_loss_function_around_one):
    starting_point = np.ones(len(selected_currencies))/len(selected_currencies)
    bounds = [(0, 1) for _ in range(len(starting_point))]
    
    result = minimize(fun=loss_function, 
                      x0=starting_point, 
                      args=selected_currencies,
                      bounds=bounds,
                      options={"disp": True, 
                               "maxiter": max_iter})
    
    output = pd.Series(result.x/result.x.sum(), index=reference_date_exhange_rate.loc[selected_currencies].index)
    output = output.sort_values(ascending=False)
        
    return output

# %%
def try_currencies(currencies_to_try, currencies):
    for currency in currencies_to_try:
        if currency in currencies:
            return None, 1

    print(f"Evaluating {currencies} + {currencies_to_try}")
    new_mix = run_optimization(selected_currencies=currencies + currencies_to_try, 
                               max_iter=1, 
                               loss_function=calculate_loss_function_around_one)

    new_score = calculate_loss_function_around_one(new_mix, currencies + currencies_to_try)

    return new_mix, new_score

# %%
best_score = 1
last_score = 1
currencies = []

uncoupled_currencies = [[c] for c in all_currencies if c != "HKD"]
uncoupled_currencies.sort()

currency_pairs = [[c1[0], c2[0]] for c1 in uncoupled_currencies for c2 in uncoupled_currencies if c1 > c2]
currency_pairs.sort()

while best_score == 1 or currencies_to_add is not None:
    print(f"Attempting to improve set, starting from: {currencies}")
    currencies_to_add = None
    
    for currencies_to_try in uncoupled_currencies + currency_pairs:
        new_mix, new_score = try_currencies(currencies_to_try, currencies)

        if new_score < .9995 * last_score:
            if new_score < best_score:
                best_score = new_score
                currencies_to_add = currencies_to_try

                print(f"New best score found: {new_score}")
                print(new_mix)
            elif last_score < 1:
                print(f"Better than last score, but not better than best: {new_score}")
                print(new_mix)
    
    last_score = best_score
    
    if currencies_to_add is not None:
        currencies += currencies_to_add
        
print(f"Done. Best set: {currencies}")
# Out:
# Attempting to improve set, starting from: []
# Evaluating [] + ['AUD']
# New best score found: 0.02209449111512458
# AUD   1.00000
# dtype: float64
# Evaluating [] + ['CAD']
# New best score found: 0.01815195401505861
# CAD   1.00000
# dtype: float64
# Evaluating [] + ['CHF']
# Evaluating [] + ['CNY']
# Evaluating [] + ['CZK']
# Evaluating [] + ['DKK']
# New best score found: 0.009534298316224626
# DKK   1.00000
# dtype: float64
# Evaluating [] + ['EUR']
# Evaluating [] + ['GBP']
# Evaluating [] + ['HRK']
# Evaluating [] + ['HUF']
# Evaluating [] + ['IDR']
# Evaluating [] + ['JPY']
# Evaluating [] + ['KRW']
# Evaluating [] + ['MYR']
# Evaluating [] + ['NOK']
# Evaluating [] + ['NZD']
# Evaluating [] + ['PHP']
# Evaluating [] + ['PLN']
# Evaluating [] + ['RON']
# Evaluating [] + ['RUB']
# Evaluating [] + ['SEK']
# Evaluating [] + ['SGD']
# Evaluating [] + ['THB']
# Evaluating [] + ['TRY']
# Evaluating [] + ['USD']
# New best score found: 0.008417071281971677
# USD   1.00000
# dtype: float64
# Evaluating [] + ['ZAR']
# Evaluating [] + ['CAD', 'AUD']
# Evaluating [] + ['CHF', 'AUD']
# Evaluating [] + ['CHF', 'CAD']
# Evaluating [] + ['CNY', 'AUD']
# Evaluating [] + ['CNY', 'CAD']
# Evaluating [] + ['CNY', 'CHF']
# Evaluating [] + ['CZK', 'AUD']
# Evaluating [] + ['CZK', 'CAD']
# Evaluating [] + ['CZK', 'CHF']
# Evaluating [] + ['CZK', 'CNY']
# Evaluating [] + ['DKK', 'AUD']
# Evaluating [] + ['DKK', 'CAD']
# Evaluating [] + ['DKK', 'CHF']
# Evaluating [] + ['DKK', 'CNY']
# Evaluating [] + ['DKK', 'CZK']
# Evaluating [] + ['EUR', 'AUD']
# Evaluating [] + ['EUR', 'CAD']
# Evaluating [] + ['EUR', 'CHF']
# Evaluating [] + ['EUR', 'CNY']
# Evaluating [] + ['EUR', 'CZK']
# Evaluating [] + ['EUR', 'DKK']
# Evaluating [] + ['GBP', 'AUD']
# Evaluating [] + ['GBP', 'CAD']
# Evaluating [] + ['GBP', 'CHF']
# Evaluating [] + ['GBP', 'CNY']
# New best score found: 0.007814210377457458
# GBP   0.50141
# CNY   0.49859
# dtype: float64
# Evaluating [] + ['GBP', 'CZK']
# Evaluating [] + ['GBP', 'DKK']
# Evaluating [] + ['GBP', 'EUR']
# Evaluating [] + ['HRK', 'AUD']
# Evaluating [] + ['HRK', 'CAD']
# Evaluating [] + ['HRK', 'CHF']
# Evaluating [] + ['HRK', 'CNY']
# Evaluating [] + ['HRK', 'CZK']
# Evaluating [] + ['HRK', 'DKK']
# Evaluating [] + ['HRK', 'EUR']
# Evaluating [] + ['HRK', 'GBP']
# Evaluating [] + ['HUF', 'AUD']
# Evaluating [] + ['HUF', 'CAD']
# Evaluating [] + ['HUF', 'CHF']
# Evaluating [] + ['HUF', 'CNY']
# Evaluating [] + ['HUF', 'CZK']
# Evaluating [] + ['HUF', 'DKK']
# Evaluating [] + ['HUF', 'EUR']
# Evaluating [] + ['HUF', 'GBP']
# Evaluating [] + ['HUF', 'HRK']
# Evaluating [] + ['IDR', 'AUD']
# Evaluating [] + ['IDR', 'CAD']
# Evaluating [] + ['IDR', 'CHF']
# Evaluating [] + ['IDR', 'CNY']
# Evaluating [] + ['IDR', 'CZK']
# Evaluating [] + ['IDR', 'DKK']
# Evaluating [] + ['IDR', 'EUR']
# Evaluating [] + ['IDR', 'GBP']
# Evaluating [] + ['IDR', 'HRK']
# Evaluating [] + ['IDR', 'HUF']
# Evaluating [] + ['JPY', 'AUD']
# Evaluating [] + ['JPY', 'CAD']
# Evaluating [] + ['JPY', 'CHF']
# Evaluating [] + ['JPY', 'CNY']
# Evaluating [] + ['JPY', 'CZK']
# Evaluating [] + ['JPY', 'DKK']
# Evaluating [] + ['JPY', 'EUR']
# Evaluating [] + ['JPY', 'GBP']
# Evaluating [] + ['JPY', 'HRK']
# Evaluating [] + ['JPY', 'HUF']
# Evaluating [] + ['JPY', 'IDR']
# Evaluating [] + ['KRW', 'AUD']
# Evaluating [] + ['KRW', 'CAD']
# Evaluating [] + ['KRW', 'CHF']
# Evaluating [] + ['KRW', 'CNY']
# Evaluating [] + ['KRW', 'CZK']
# Evaluating [] + ['KRW', 'DKK']
# Evaluating [] + ['KRW', 'EUR']
# Evaluating [] + ['KRW', 'GBP']
# Evaluating [] + ['KRW', 'HRK']
# Evaluating [] + ['KRW', 'HUF']
# Evaluating [] + ['KRW', 'IDR']
# Evaluating [] + ['KRW', 'JPY']
# Evaluating [] + ['MYR', 'AUD']
# Evaluating [] + ['MYR', 'CAD']
# Evaluating [] + ['MYR', 'CHF']
# Evaluating [] + ['MYR', 'CNY']
# Evaluating [] + ['MYR', 'CZK']
# Evaluating [] + ['MYR', 'DKK']
# Evaluating [] + ['MYR', 'EUR']
# Evaluating [] + ['MYR', 'GBP']
# Evaluating [] + ['MYR', 'HRK']
# Evaluating [] + ['MYR', 'HUF']
# Evaluating [] + ['MYR', 'IDR']
# Evaluating [] + ['MYR', 'JPY']
# Evaluating [] + ['MYR', 'KRW']
# Evaluating [] + ['NOK', 'AUD']
# Evaluating [] + ['NOK', 'CAD']
# Evaluating [] + ['NOK', 'CHF']
# Evaluating [] + ['NOK', 'CNY']
# Evaluating [] + ['NOK', 'CZK']
# Evaluating [] + ['NOK', 'DKK']
# Evaluating [] + ['NOK', 'EUR']
# Evaluating [] + ['NOK', 'GBP']
# Evaluating [] + ['NOK', 'HRK']
# Evaluating [] + ['NOK', 'HUF']
# Evaluating [] + ['NOK', 'IDR']
# Evaluating [] + ['NOK', 'JPY']
# Evaluating [] + ['NOK', 'KRW']
# Evaluating [] + ['NOK', 'MYR']
# Evaluating [] + ['NZD', 'AUD']
# Evaluating [] + ['NZD', 'CAD']
# Evaluating [] + ['NZD', 'CHF']
# Evaluating [] + ['NZD', 'CNY']
# Evaluating [] + ['NZD', 'CZK']
# Evaluating [] + ['NZD', 'DKK']
# Evaluating [] + ['NZD', 'EUR']
# Evaluating [] + ['NZD', 'GBP']
# Evaluating [] + ['NZD', 'HRK']
# Evaluating [] + ['NZD', 'HUF']
# Evaluating [] + ['NZD', 'IDR']
# Evaluating [] + ['NZD', 'JPY']
# Evaluating [] + ['NZD', 'KRW']
# Evaluating [] + ['NZD', 'MYR']
# Evaluating [] + ['NZD', 'NOK']
# Evaluating [] + ['PHP', 'AUD']
# Evaluating [] + ['PHP', 'CAD']
# Evaluating [] + ['PHP', 'CHF']
# Evaluating [] + ['PHP', 'CNY']
# Evaluating [] + ['PHP', 'CZK']
# Evaluating [] + ['PHP', 'DKK']
# Evaluating [] + ['PHP', 'EUR']
# Evaluating [] + ['PHP', 'GBP']
# Evaluating [] + ['PHP', 'HRK']
# Evaluating [] + ['PHP', 'HUF']
# Evaluating [] + ['PHP', 'IDR']
# Evaluating [] + ['PHP', 'JPY']
# Evaluating [] + ['PHP', 'KRW']
# Evaluating [] + ['PHP', 'MYR']
# Evaluating [] + ['PHP', 'NOK']
# Evaluating [] + ['PHP', 'NZD']
# Evaluating [] + ['PLN', 'AUD']
# Evaluating [] + ['PLN', 'CAD']
# Evaluating [] + ['PLN', 'CHF']
# Evaluating [] + ['PLN', 'CNY']
# Evaluating [] + ['PLN', 'CZK']
# Evaluating [] + ['PLN', 'DKK']
# Evaluating [] + ['PLN', 'EUR']
# Evaluating [] + ['PLN', 'GBP']
# Evaluating [] + ['PLN', 'HRK']
# Evaluating [] + ['PLN', 'HUF']
# Evaluating [] + ['PLN', 'IDR']
# Evaluating [] + ['PLN', 'JPY']
# Evaluating [] + ['PLN', 'KRW']
# Evaluating [] + ['PLN', 'MYR']
# Evaluating [] + ['PLN', 'NOK']
# Evaluating [] + ['PLN', 'NZD']
# Evaluating [] + ['PLN', 'PHP']
# Evaluating [] + ['RON', 'AUD']
# Evaluating [] + ['RON', 'CAD']
# Evaluating [] + ['RON', 'CHF']
# Evaluating [] + ['RON', 'CNY']
# Evaluating [] + ['RON', 'CZK']
# Evaluating [] + ['RON', 'DKK']
# Evaluating [] + ['RON', 'EUR']
# Evaluating [] + ['RON', 'GBP']
# Evaluating [] + ['RON', 'HRK']
# Evaluating [] + ['RON', 'HUF']
# Evaluating [] + ['RON', 'IDR']
# Evaluating [] + ['RON', 'JPY']
# Evaluating [] + ['RON', 'KRW']
# Evaluating [] + ['RON', 'MYR']
# Evaluating [] + ['RON', 'NOK']
# Evaluating [] + ['RON', 'NZD']
# Evaluating [] + ['RON', 'PHP']
# Evaluating [] + ['RON', 'PLN']
# Evaluating [] + ['RUB', 'AUD']
# Evaluating [] + ['RUB', 'CAD']
# Evaluating [] + ['RUB', 'CHF']
# Evaluating [] + ['RUB', 'CNY']
# Evaluating [] + ['RUB', 'CZK']
# Evaluating [] + ['RUB', 'DKK']
# Evaluating [] + ['RUB', 'EUR']
# Evaluating [] + ['RUB', 'GBP']
# Evaluating [] + ['RUB', 'HRK']
# Evaluating [] + ['RUB', 'HUF']
# Evaluating [] + ['RUB', 'IDR']
# Evaluating [] + ['RUB', 'JPY']
# Evaluating [] + ['RUB', 'KRW']
# Evaluating [] + ['RUB', 'MYR']
# Evaluating [] + ['RUB', 'NOK']
# Evaluating [] + ['RUB', 'NZD']
# Evaluating [] + ['RUB', 'PHP']
# Evaluating [] + ['RUB', 'PLN']
# Evaluating [] + ['RUB', 'RON']
# Evaluating [] + ['SEK', 'AUD']
# Evaluating [] + ['SEK', 'CAD']
# Evaluating [] + ['SEK', 'CHF']
# Evaluating [] + ['SEK', 'CNY']
# Evaluating [] + ['SEK', 'CZK']
# Evaluating [] + ['SEK', 'DKK']
# Evaluating [] + ['SEK', 'EUR']
# Evaluating [] + ['SEK', 'GBP']
# Evaluating [] + ['SEK', 'HRK']
# Evaluating [] + ['SEK', 'HUF']
# Evaluating [] + ['SEK', 'IDR']
# Evaluating [] + ['SEK', 'JPY']
# Evaluating [] + ['SEK', 'KRW']
# Evaluating [] + ['SEK', 'MYR']
# Evaluating [] + ['SEK', 'NOK']
# Evaluating [] + ['SEK', 'NZD']
# Evaluating [] + ['SEK', 'PHP']
# Evaluating [] + ['SEK', 'PLN']
# Evaluating [] + ['SEK', 'RON']
# Evaluating [] + ['SEK', 'RUB']
# Evaluating [] + ['SGD', 'AUD']
# Evaluating [] + ['SGD', 'CAD']
# Evaluating [] + ['SGD', 'CHF']
# Evaluating [] + ['SGD', 'CNY']
# Evaluating [] + ['SGD', 'CZK']
# Evaluating [] + ['SGD', 'DKK']
# Evaluating [] + ['SGD', 'EUR']
# Evaluating [] + ['SGD', 'GBP']
# Evaluating [] + ['SGD', 'HRK']
# Evaluating [] + ['SGD', 'HUF']
# Evaluating [] + ['SGD', 'IDR']
# Evaluating [] + ['SGD', 'JPY']
# Evaluating [] + ['SGD', 'KRW']
# Evaluating [] + ['SGD', 'MYR']
# Evaluating [] + ['SGD', 'NOK']
# Evaluating [] + ['SGD', 'NZD']
# Evaluating [] + ['SGD', 'PHP']
# Evaluating [] + ['SGD', 'PLN']
# Evaluating [] + ['SGD', 'RON']
# Evaluating [] + ['SGD', 'RUB']
# Evaluating [] + ['SGD', 'SEK']
# Evaluating [] + ['THB', 'AUD']
# Evaluating [] + ['THB', 'CAD']
# Evaluating [] + ['THB', 'CHF']
# Evaluating [] + ['THB', 'CNY']
# Evaluating [] + ['THB', 'CZK']
# Evaluating [] + ['THB', 'DKK']
# Evaluating [] + ['THB', 'EUR']
# Evaluating [] + ['THB', 'GBP']
# Evaluating [] + ['THB', 'HRK']
# Evaluating [] + ['THB', 'HUF']
# Evaluating [] + ['THB', 'IDR']
# Evaluating [] + ['THB', 'JPY']
# Evaluating [] + ['THB', 'KRW']
# Evaluating [] + ['THB', 'MYR']
# Evaluating [] + ['THB', 'NOK']
# Evaluating [] + ['THB', 'NZD']
# Evaluating [] + ['THB', 'PHP']
# Evaluating [] + ['THB', 'PLN']
# Evaluating [] + ['THB', 'RON']
# Evaluating [] + ['THB', 'RUB']
# Evaluating [] + ['THB', 'SEK']
# Evaluating [] + ['THB', 'SGD']
# Evaluating [] + ['TRY', 'AUD']
# Evaluating [] + ['TRY', 'CAD']
# Evaluating [] + ['TRY', 'CHF']
# Evaluating [] + ['TRY', 'CNY']
# Evaluating [] + ['TRY', 'CZK']
# Evaluating [] + ['TRY', 'DKK']
# Evaluating [] + ['TRY', 'EUR']
# Evaluating [] + ['TRY', 'GBP']
# Evaluating [] + ['TRY', 'HRK']
# Evaluating [] + ['TRY', 'HUF']
# Evaluating [] + ['TRY', 'IDR']
# Evaluating [] + ['TRY', 'JPY']
# Evaluating [] + ['TRY', 'KRW']
# Evaluating [] + ['TRY', 'MYR']
# Evaluating [] + ['TRY', 'NOK']
# Evaluating [] + ['TRY', 'NZD']
# Evaluating [] + ['TRY', 'PHP']
# Evaluating [] + ['TRY', 'PLN']
# Evaluating [] + ['TRY', 'RON']
# Evaluating [] + ['TRY', 'RUB']
# Evaluating [] + ['TRY', 'SEK']
# Evaluating [] + ['TRY', 'SGD']
# Evaluating [] + ['TRY', 'THB']
# Evaluating [] + ['USD', 'AUD']
# Evaluating [] + ['USD', 'CAD']
# Evaluating [] + ['USD', 'CHF']
# Evaluating [] + ['USD', 'CNY']
# Evaluating [] + ['USD', 'CZK']
# Evaluating [] + ['USD', 'DKK']
# New best score found: 0.007330489266958231
# USD   0.50065
# DKK   0.49935
# dtype: float64
# Evaluating [] + ['USD', 'EUR']
# Evaluating [] + ['USD', 'GBP']
# Evaluating [] + ['USD', 'HRK']
# Evaluating [] + ['USD', 'HUF']
# Evaluating [] + ['USD', 'IDR']
# Evaluating [] + ['USD', 'JPY']
# Evaluating [] + ['USD', 'KRW']
# Evaluating [] + ['USD', 'MYR']
# Evaluating [] + ['USD', 'NOK']
# Evaluating [] + ['USD', 'NZD']
# Evaluating [] + ['USD', 'PHP']
# Evaluating [] + ['USD', 'PLN']
# Evaluating [] + ['USD', 'RON']
# Evaluating [] + ['USD', 'RUB']
# Evaluating [] + ['USD', 'SEK']
# Evaluating [] + ['USD', 'SGD']
# Evaluating [] + ['USD', 'THB']
# Evaluating [] + ['USD', 'TRY']
# Evaluating [] + ['ZAR', 'AUD']
# Evaluating [] + ['ZAR', 'CAD']
# Evaluating [] + ['ZAR', 'CHF']
# Evaluating [] + ['ZAR', 'CNY']
# Evaluating [] + ['ZAR', 'CZK']
# Evaluating [] + ['ZAR', 'DKK']
# Evaluating [] + ['ZAR', 'EUR']
# Evaluating [] + ['ZAR', 'GBP']
# Evaluating [] + ['ZAR', 'HRK']
# Evaluating [] + ['ZAR', 'HUF']
# Evaluating [] + ['ZAR', 'IDR']
# Evaluating [] + ['ZAR', 'JPY']
# Evaluating [] + ['ZAR', 'KRW']
# Evaluating [] + ['ZAR', 'MYR']
# Evaluating [] + ['ZAR', 'NOK']
# Evaluating [] + ['ZAR', 'NZD']
# Evaluating [] + ['ZAR', 'PHP']
# Evaluating [] + ['ZAR', 'PLN']
# Evaluating [] + ['ZAR', 'RON']
# Evaluating [] + ['ZAR', 'RUB']
# Evaluating [] + ['ZAR', 'SEK']
# Evaluating [] + ['ZAR', 'SGD']
# Evaluating [] + ['ZAR', 'THB']
# Evaluating [] + ['ZAR', 'TRY']
# Evaluating [] + ['ZAR', 'USD']
# Attempting to improve set, starting from: ['USD', 'DKK']
# Evaluating ['USD', 'DKK'] + ['AUD']
# Evaluating ['USD', 'DKK'] + ['CAD']
# Evaluating ['USD', 'DKK'] + ['CHF']
# Evaluating ['USD', 'DKK'] + ['CNY']
# Evaluating ['USD', 'DKK'] + ['CZK']
# Evaluating ['USD', 'DKK'] + ['EUR']
# Evaluating ['USD', 'DKK'] + ['GBP']
# Evaluating ['USD', 'DKK'] + ['HRK']
# Evaluating ['USD', 'DKK'] + ['HUF']
# Evaluating ['USD', 'DKK'] + ['IDR']
# New best score found: 0.007274029954165614
# USD   0.33384
# DKK   0.33382
# IDR   0.33233
# dtype: float64
# Evaluating ['USD', 'DKK'] + ['JPY']
# Evaluating ['USD', 'DKK'] + ['KRW']
# Evaluating ['USD', 'DKK'] + ['MYR']
# Evaluating ['USD', 'DKK'] + ['NOK']
# Evaluating ['USD', 'DKK'] + ['NZD']
# Evaluating ['USD', 'DKK'] + ['PHP']
# Evaluating ['USD', 'DKK'] + ['PLN']
# Evaluating ['USD', 'DKK'] + ['RON']
# Evaluating ['USD', 'DKK'] + ['RUB']
# Evaluating ['USD', 'DKK'] + ['SEK']
# Evaluating ['USD', 'DKK'] + ['SGD']
# Evaluating ['USD', 'DKK'] + ['THB']
# Evaluating ['USD', 'DKK'] + ['TRY']
# Evaluating ['USD', 'DKK'] + ['ZAR']
# Evaluating ['USD', 'DKK'] + ['CAD', 'AUD']
# Evaluating ['USD', 'DKK'] + ['CHF', 'AUD']
# Evaluating ['USD', 'DKK'] + ['CHF', 'CAD']
# Evaluating ['USD', 'DKK'] + ['CNY', 'AUD']
# Evaluating ['USD', 'DKK'] + ['CNY', 'CAD']
# Evaluating ['USD', 'DKK'] + ['CNY', 'CHF']
# Evaluating ['USD', 'DKK'] + ['CZK', 'AUD']
# Evaluating ['USD', 'DKK'] + ['CZK', 'CAD']
# Evaluating ['USD', 'DKK'] + ['CZK', 'CHF']
# Evaluating ['USD', 'DKK'] + ['CZK', 'CNY']
# Evaluating ['USD', 'DKK'] + ['EUR', 'AUD']
# Evaluating ['USD', 'DKK'] + ['EUR', 'CAD']
# Evaluating ['USD', 'DKK'] + ['EUR', 'CHF']
# Evaluating ['USD', 'DKK'] + ['EUR', 'CNY']
# Evaluating ['USD', 'DKK'] + ['EUR', 'CZK']
# Evaluating ['USD', 'DKK'] + ['GBP', 'AUD']
# Evaluating ['USD', 'DKK'] + ['GBP', 'CAD']
# Evaluating ['USD', 'DKK'] + ['GBP', 'CHF']
# Evaluating ['USD', 'DKK'] + ['GBP', 'CNY']
# Evaluating ['USD', 'DKK'] + ['GBP', 'CZK']
# Evaluating ['USD', 'DKK'] + ['GBP', 'EUR']
# Evaluating ['USD', 'DKK'] + ['HRK', 'AUD']
# Evaluating ['USD', 'DKK'] + ['HRK', 'CAD']
# Evaluating ['USD', 'DKK'] + ['HRK', 'CHF']
# Evaluating ['USD', 'DKK'] + ['HRK', 'CNY']
# Evaluating ['USD', 'DKK'] + ['HRK', 'CZK']
# Evaluating ['USD', 'DKK'] + ['HRK', 'EUR']
# Evaluating ['USD', 'DKK'] + ['HRK', 'GBP']
# Evaluating ['USD', 'DKK'] + ['HUF', 'AUD']
# Evaluating ['USD', 'DKK'] + ['HUF', 'CAD']
# Evaluating ['USD', 'DKK'] + ['HUF', 'CHF']
# Evaluating ['USD', 'DKK'] + ['HUF', 'CNY']
# Evaluating ['USD', 'DKK'] + ['HUF', 'CZK']
# Evaluating ['USD', 'DKK'] + ['HUF', 'EUR']
# Evaluating ['USD', 'DKK'] + ['HUF', 'GBP']
# Evaluating ['USD', 'DKK'] + ['HUF', 'HRK']
# Evaluating ['USD', 'DKK'] + ['IDR', 'AUD']
# Evaluating ['USD', 'DKK'] + ['IDR', 'CAD']
# Evaluating ['USD', 'DKK'] + ['IDR', 'CHF']
# Evaluating ['USD', 'DKK'] + ['IDR', 'CNY']
# Evaluating ['USD', 'DKK'] + ['IDR', 'CZK']
# Evaluating ['USD', 'DKK'] + ['IDR', 'EUR']
# Evaluating ['USD', 'DKK'] + ['IDR', 'GBP']
# Evaluating ['USD', 'DKK'] + ['IDR', 'HRK']
# Evaluating ['USD', 'DKK'] + ['IDR', 'HUF']
# Evaluating ['USD', 'DKK'] + ['JPY', 'AUD']
# Evaluating ['USD', 'DKK'] + ['JPY', 'CAD']
# Evaluating ['USD', 'DKK'] + ['JPY', 'CHF']
# Evaluating ['USD', 'DKK'] + ['JPY', 'CNY']
# Evaluating ['USD', 'DKK'] + ['JPY', 'CZK']
# Evaluating ['USD', 'DKK'] + ['JPY', 'EUR']
# Evaluating ['USD', 'DKK'] + ['JPY', 'GBP']
# New best score found: 0.007181092990753765
# USD   0.25054
# DKK   0.25021
# GBP   0.24968
# JPY   0.24957
# dtype: float64
# Evaluating ['USD', 'DKK'] + ['JPY', 'HRK']
# Evaluating ['USD', 'DKK'] + ['JPY', 'HUF']
# Evaluating ['USD', 'DKK'] + ['JPY', 'IDR']
# Evaluating ['USD', 'DKK'] + ['KRW', 'AUD']
# Evaluating ['USD', 'DKK'] + ['KRW', 'CAD']
# Evaluating ['USD', 'DKK'] + ['KRW', 'CHF']
# Evaluating ['USD', 'DKK'] + ['KRW', 'CNY']
# Evaluating ['USD', 'DKK'] + ['KRW', 'CZK']
# Evaluating ['USD', 'DKK'] + ['KRW', 'EUR']
# Evaluating ['USD', 'DKK'] + ['KRW', 'GBP']
# Evaluating ['USD', 'DKK'] + ['KRW', 'HRK']
# Evaluating ['USD', 'DKK'] + ['KRW', 'HUF']
# Evaluating ['USD', 'DKK'] + ['KRW', 'IDR']
# Evaluating ['USD', 'DKK'] + ['KRW', 'JPY']
# New best score found: 0.007173397973383812
# DKK   0.25071
# USD   0.25061
# KRW   0.24978
# JPY   0.24890
# dtype: float64
# Evaluating ['USD', 'DKK'] + ['MYR', 'AUD']
# Evaluating ['USD', 'DKK'] + ['MYR', 'CAD']
# Evaluating ['USD', 'DKK'] + ['MYR', 'CHF']
# Evaluating ['USD', 'DKK'] + ['MYR', 'CNY']
# Evaluating ['USD', 'DKK'] + ['MYR', 'CZK']
# Evaluating ['USD', 'DKK'] + ['MYR', 'EUR']
# Evaluating ['USD', 'DKK'] + ['MYR', 'GBP']
# Evaluating ['USD', 'DKK'] + ['MYR', 'HRK']
# Evaluating ['USD', 'DKK'] + ['MYR', 'HUF']
# Evaluating ['USD', 'DKK'] + ['MYR', 'IDR']
# Evaluating ['USD', 'DKK'] + ['MYR', 'JPY']
# Evaluating ['USD', 'DKK'] + ['MYR', 'KRW']
# Evaluating ['USD', 'DKK'] + ['NOK', 'AUD']
# Evaluating ['USD', 'DKK'] + ['NOK', 'CAD']
# Evaluating ['USD', 'DKK'] + ['NOK', 'CHF']
# Evaluating ['USD', 'DKK'] + ['NOK', 'CNY']
# Evaluating ['USD', 'DKK'] + ['NOK', 'CZK']
# Evaluating ['USD', 'DKK'] + ['NOK', 'EUR']
# Evaluating ['USD', 'DKK'] + ['NOK', 'GBP']
# Evaluating ['USD', 'DKK'] + ['NOK', 'HRK']
# Evaluating ['USD', 'DKK'] + ['NOK', 'HUF']
# Evaluating ['USD', 'DKK'] + ['NOK', 'IDR']
# Evaluating ['USD', 'DKK'] + ['NOK', 'JPY']
# Evaluating ['USD', 'DKK'] + ['NOK', 'KRW']
# Evaluating ['USD', 'DKK'] + ['NOK', 'MYR']
# Evaluating ['USD', 'DKK'] + ['NZD', 'AUD']
# Evaluating ['USD', 'DKK'] + ['NZD', 'CAD']
# Evaluating ['USD', 'DKK'] + ['NZD', 'CHF']
# Evaluating ['USD', 'DKK'] + ['NZD', 'CNY']
# Evaluating ['USD', 'DKK'] + ['NZD', 'CZK']
# Evaluating ['USD', 'DKK'] + ['NZD', 'EUR']
# Evaluating ['USD', 'DKK'] + ['NZD', 'GBP']
# Evaluating ['USD', 'DKK'] + ['NZD', 'HRK']
# Evaluating ['USD', 'DKK'] + ['NZD', 'HUF']
# Evaluating ['USD', 'DKK'] + ['NZD', 'IDR']
# Evaluating ['USD', 'DKK'] + ['NZD', 'JPY']
# Evaluating ['USD', 'DKK'] + ['NZD', 'KRW']
# Evaluating ['USD', 'DKK'] + ['NZD', 'MYR']
# Evaluating ['USD', 'DKK'] + ['NZD', 'NOK']
# Evaluating ['USD', 'DKK'] + ['PHP', 'AUD']
# Evaluating ['USD', 'DKK'] + ['PHP', 'CAD']
# Evaluating ['USD', 'DKK'] + ['PHP', 'CHF']
# Evaluating ['USD', 'DKK'] + ['PHP', 'CNY']
# Evaluating ['USD', 'DKK'] + ['PHP', 'CZK']
# Evaluating ['USD', 'DKK'] + ['PHP', 'EUR']
# Evaluating ['USD', 'DKK'] + ['PHP', 'GBP']
# Evaluating ['USD', 'DKK'] + ['PHP', 'HRK']
# Evaluating ['USD', 'DKK'] + ['PHP', 'HUF']
# Evaluating ['USD', 'DKK'] + ['PHP', 'IDR']
# Evaluating ['USD', 'DKK'] + ['PHP', 'JPY']
# Evaluating ['USD', 'DKK'] + ['PHP', 'KRW']
# Evaluating ['USD', 'DKK'] + ['PHP', 'MYR']
# Evaluating ['USD', 'DKK'] + ['PHP', 'NOK']
# Evaluating ['USD', 'DKK'] + ['PHP', 'NZD']
# Evaluating ['USD', 'DKK'] + ['PLN', 'AUD']
# Evaluating ['USD', 'DKK'] + ['PLN', 'CAD']
# Evaluating ['USD', 'DKK'] + ['PLN', 'CHF']
# Evaluating ['USD', 'DKK'] + ['PLN', 'CNY']
# Evaluating ['USD', 'DKK'] + ['PLN', 'CZK']
# Evaluating ['USD', 'DKK'] + ['PLN', 'EUR']
# Evaluating ['USD', 'DKK'] + ['PLN', 'GBP']
# Evaluating ['USD', 'DKK'] + ['PLN', 'HRK']
# Evaluating ['USD', 'DKK'] + ['PLN', 'HUF']
# Evaluating ['USD', 'DKK'] + ['PLN', 'IDR']
# Evaluating ['USD', 'DKK'] + ['PLN', 'JPY']
# Evaluating ['USD', 'DKK'] + ['PLN', 'KRW']
# Evaluating ['USD', 'DKK'] + ['PLN', 'MYR']
# Evaluating ['USD', 'DKK'] + ['PLN', 'NOK']
# Evaluating ['USD', 'DKK'] + ['PLN', 'NZD']
# Evaluating ['USD', 'DKK'] + ['PLN', 'PHP']
# Evaluating ['USD', 'DKK'] + ['RON', 'AUD']
# Evaluating ['USD', 'DKK'] + ['RON', 'CAD']
# Evaluating ['USD', 'DKK'] + ['RON', 'CHF']
# Evaluating ['USD', 'DKK'] + ['RON', 'CNY']
# Evaluating ['USD', 'DKK'] + ['RON', 'CZK']
# Evaluating ['USD', 'DKK'] + ['RON', 'EUR']
# Evaluating ['USD', 'DKK'] + ['RON', 'GBP']
# Evaluating ['USD', 'DKK'] + ['RON', 'HRK']
# Evaluating ['USD', 'DKK'] + ['RON', 'HUF']
# Evaluating ['USD', 'DKK'] + ['RON', 'IDR']
# Evaluating ['USD', 'DKK'] + ['RON', 'JPY']
# Evaluating ['USD', 'DKK'] + ['RON', 'KRW']
# Evaluating ['USD', 'DKK'] + ['RON', 'MYR']
# Evaluating ['USD', 'DKK'] + ['RON', 'NOK']
# Evaluating ['USD', 'DKK'] + ['RON', 'NZD']
# Evaluating ['USD', 'DKK'] + ['RON', 'PHP']
# Evaluating ['USD', 'DKK'] + ['RON', 'PLN']
# Evaluating ['USD', 'DKK'] + ['RUB', 'AUD']
# Evaluating ['USD', 'DKK'] + ['RUB', 'CAD']
# Evaluating ['USD', 'DKK'] + ['RUB', 'CHF']
# Evaluating ['USD', 'DKK'] + ['RUB', 'CNY']
# Evaluating ['USD', 'DKK'] + ['RUB', 'CZK']
# Evaluating ['USD', 'DKK'] + ['RUB', 'EUR']
# Evaluating ['USD', 'DKK'] + ['RUB', 'GBP']
# Evaluating ['USD', 'DKK'] + ['RUB', 'HRK']
# Evaluating ['USD', 'DKK'] + ['RUB', 'HUF']
# Evaluating ['USD', 'DKK'] + ['RUB', 'IDR']
# Evaluating ['USD', 'DKK'] + ['RUB', 'JPY']
# Evaluating ['USD', 'DKK'] + ['RUB', 'KRW']
# Evaluating ['USD', 'DKK'] + ['RUB', 'MYR']
# Evaluating ['USD', 'DKK'] + ['RUB', 'NOK']
# Evaluating ['USD', 'DKK'] + ['RUB', 'NZD']
# Evaluating ['USD', 'DKK'] + ['RUB', 'PHP']
# Evaluating ['USD', 'DKK'] + ['RUB', 'PLN']
# Evaluating ['USD', 'DKK'] + ['RUB', 'RON']
# Evaluating ['USD', 'DKK'] + ['SEK', 'AUD']
# Evaluating ['USD', 'DKK'] + ['SEK', 'CAD']
# Evaluating ['USD', 'DKK'] + ['SEK', 'CHF']
# Evaluating ['USD', 'DKK'] + ['SEK', 'CNY']
# Evaluating ['USD', 'DKK'] + ['SEK', 'CZK']
# Evaluating ['USD', 'DKK'] + ['SEK', 'EUR']
# Evaluating ['USD', 'DKK'] + ['SEK', 'GBP']
# Evaluating ['USD', 'DKK'] + ['SEK', 'HRK']
# Evaluating ['USD', 'DKK'] + ['SEK', 'HUF']
# Evaluating ['USD', 'DKK'] + ['SEK', 'IDR']
# Evaluating ['USD', 'DKK'] + ['SEK', 'JPY']
# Evaluating ['USD', 'DKK'] + ['SEK', 'KRW']
# Evaluating ['USD', 'DKK'] + ['SEK', 'MYR']
# Evaluating ['USD', 'DKK'] + ['SEK', 'NOK']
# Evaluating ['USD', 'DKK'] + ['SEK', 'NZD']
# Evaluating ['USD', 'DKK'] + ['SEK', 'PHP']
# Evaluating ['USD', 'DKK'] + ['SEK', 'PLN']
# Evaluating ['USD', 'DKK'] + ['SEK', 'RON']
# Evaluating ['USD', 'DKK'] + ['SEK', 'RUB']
# Evaluating ['USD', 'DKK'] + ['SGD', 'AUD']
# Evaluating ['USD', 'DKK'] + ['SGD', 'CAD']
# Evaluating ['USD', 'DKK'] + ['SGD', 'CHF']
# Evaluating ['USD', 'DKK'] + ['SGD', 'CNY']
# Evaluating ['USD', 'DKK'] + ['SGD', 'CZK']
# Evaluating ['USD', 'DKK'] + ['SGD', 'EUR']
# Evaluating ['USD', 'DKK'] + ['SGD', 'GBP']
# Evaluating ['USD', 'DKK'] + ['SGD', 'HRK']
# Evaluating ['USD', 'DKK'] + ['SGD', 'HUF']
# Evaluating ['USD', 'DKK'] + ['SGD', 'IDR']
# Evaluating ['USD', 'DKK'] + ['SGD', 'JPY']
# Evaluating ['USD', 'DKK'] + ['SGD', 'KRW']
# Evaluating ['USD', 'DKK'] + ['SGD', 'MYR']
# Evaluating ['USD', 'DKK'] + ['SGD', 'NOK']
# Evaluating ['USD', 'DKK'] + ['SGD', 'NZD']
# Evaluating ['USD', 'DKK'] + ['SGD', 'PHP']
# Evaluating ['USD', 'DKK'] + ['SGD', 'PLN']
# Evaluating ['USD', 'DKK'] + ['SGD', 'RON']
# Evaluating ['USD', 'DKK'] + ['SGD', 'RUB']
# Evaluating ['USD', 'DKK'] + ['SGD', 'SEK']
# Evaluating ['USD', 'DKK'] + ['THB', 'AUD']
# Evaluating ['USD', 'DKK'] + ['THB', 'CAD']
# Evaluating ['USD', 'DKK'] + ['THB', 'CHF']
# Evaluating ['USD', 'DKK'] + ['THB', 'CNY']
# Evaluating ['USD', 'DKK'] + ['THB', 'CZK']
# Evaluating ['USD', 'DKK'] + ['THB', 'EUR']
# Evaluating ['USD', 'DKK'] + ['THB', 'GBP']
# Evaluating ['USD', 'DKK'] + ['THB', 'HRK']
# Evaluating ['USD', 'DKK'] + ['THB', 'HUF']
# Evaluating ['USD', 'DKK'] + ['THB', 'IDR']
# Evaluating ['USD', 'DKK'] + ['THB', 'JPY']
# Evaluating ['USD', 'DKK'] + ['THB', 'KRW']
# Evaluating ['USD', 'DKK'] + ['THB', 'MYR']
# Evaluating ['USD', 'DKK'] + ['THB', 'NOK']
# Evaluating ['USD', 'DKK'] + ['THB', 'NZD']
# Evaluating ['USD', 'DKK'] + ['THB', 'PHP']
# Evaluating ['USD', 'DKK'] + ['THB', 'PLN']
# Evaluating ['USD', 'DKK'] + ['THB', 'RON']
# Evaluating ['USD', 'DKK'] + ['THB', 'RUB']
# Evaluating ['USD', 'DKK'] + ['THB', 'SEK']
# Evaluating ['USD', 'DKK'] + ['THB', 'SGD']
# Evaluating ['USD', 'DKK'] + ['TRY', 'AUD']
# Evaluating ['USD', 'DKK'] + ['TRY', 'CAD']
# Evaluating ['USD', 'DKK'] + ['TRY', 'CHF']
# Evaluating ['USD', 'DKK'] + ['TRY', 'CNY']
# Evaluating ['USD', 'DKK'] + ['TRY', 'CZK']
# Evaluating ['USD', 'DKK'] + ['TRY', 'EUR']
# Evaluating ['USD', 'DKK'] + ['TRY', 'GBP']
# Evaluating ['USD', 'DKK'] + ['TRY', 'HRK']
# Evaluating ['USD', 'DKK'] + ['TRY', 'HUF']
# Evaluating ['USD', 'DKK'] + ['TRY', 'IDR']
# Evaluating ['USD', 'DKK'] + ['TRY', 'JPY']
# Better than last score, but not better than best: 0.007306415884732553
# USD   0.25091
# DKK   0.25014
# TRY   0.24995
# JPY   0.24901
# dtype: float64
# Evaluating ['USD', 'DKK'] + ['TRY', 'KRW']
# Evaluating ['USD', 'DKK'] + ['TRY', 'MYR']
# Evaluating ['USD', 'DKK'] + ['TRY', 'NOK']
# Evaluating ['USD', 'DKK'] + ['TRY', 'NZD']
# Evaluating ['USD', 'DKK'] + ['TRY', 'PHP']
# Evaluating ['USD', 'DKK'] + ['TRY', 'PLN']
# Evaluating ['USD', 'DKK'] + ['TRY', 'RON']
# Evaluating ['USD', 'DKK'] + ['TRY', 'RUB']
# Evaluating ['USD', 'DKK'] + ['TRY', 'SEK']
# Evaluating ['USD', 'DKK'] + ['TRY', 'SGD']
# Evaluating ['USD', 'DKK'] + ['TRY', 'THB']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'AUD']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'CAD']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'CHF']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'CNY']
# Better than last score, but not better than best: 0.0071952724191450546
# CNY   0.25307
# DKK   0.25115
# USD   0.25000
# ZAR   0.24578
# dtype: float64
# Evaluating ['USD', 'DKK'] + ['ZAR', 'CZK']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'EUR']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'GBP']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'HRK']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'HUF']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'IDR']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'JPY']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'KRW']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'MYR']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'NOK']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'NZD']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'PHP']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'PLN']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'RON']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'RUB']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'SEK']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'SGD']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'THB']
# Evaluating ['USD', 'DKK'] + ['ZAR', 'TRY']
# Attempting to improve set, starting from: ['USD', 'DKK', 'KRW', 'JPY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['EUR']
# New best score found: 0.007161305701994816
# USD   0.20108
# KRW   0.20089
# EUR   0.19953
# DKK   0.19952
# JPY   0.19898
# dtype: float64
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['CAD', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['CHF', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['CHF', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['CNY', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['CNY', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['CNY', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['CZK', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['CZK', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['CZK', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['CZK', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['EUR', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['EUR', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['EUR', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['EUR', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['EUR', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['GBP', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['GBP', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['GBP', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['GBP', 'CNY']
# New best score found: 0.007100704007650479
# USD   0.16727
# GBP   0.16698
# JPY   0.16665
# DKK   0.16658
# KRW   0.16648
# CNY   0.16605
# dtype: float64
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['GBP', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['GBP', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HRK', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HRK', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HRK', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HRK', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HRK', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HRK', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HRK', 'GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HUF', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HUF', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HUF', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HUF', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HUF', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HUF', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HUF', 'GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['HUF', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['IDR', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['IDR', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['IDR', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['IDR', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['IDR', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['IDR', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['IDR', 'GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['IDR', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['IDR', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['MYR', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['MYR', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['MYR', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['MYR', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['MYR', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['MYR', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['MYR', 'GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['MYR', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['MYR', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['MYR', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NOK', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NOK', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NOK', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NOK', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NOK', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NOK', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NOK', 'GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NOK', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NOK', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NOK', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NOK', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NZD', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NZD', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NZD', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NZD', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NZD', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NZD', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NZD', 'GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NZD', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NZD', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NZD', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NZD', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['NZD', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PHP', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PHP', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PHP', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PHP', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PHP', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PHP', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PHP', 'GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PHP', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PHP', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PHP', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PHP', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PHP', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PHP', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PLN', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PLN', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PLN', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PLN', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PLN', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PLN', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PLN', 'GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PLN', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PLN', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PLN', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PLN', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PLN', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PLN', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['PLN', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON', 'GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RON', 'PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['RUB', 'RON']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'RON']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SEK', 'RUB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'RON']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'RUB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['SGD', 'SEK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'RON']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'RUB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'SEK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['THB', 'SGD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'CNY']
# Better than last score, but not better than best: 0.007129771168901288
# KRW   0.16772
# USD   0.16741
# TRY   0.16722
# DKK   0.16642
# JPY   0.16617
# CNY   0.16506
# dtype: float64
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'RON']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'RUB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'SEK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'SGD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['TRY', 'THB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'GBP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'RON']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'RUB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'SEK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'SGD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'THB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY'] + ['ZAR', 'TRY']
# Attempting to improve set, starting from: ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RON']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RUB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['CAD', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['CHF', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['CHF', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['CZK', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['CZK', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['CZK', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['EUR', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['EUR', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['EUR', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['EUR', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['HRK', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['HRK', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['HRK', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['HRK', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['HRK', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['HUF', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['HUF', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['HUF', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['HUF', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['HUF', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['HUF', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['IDR', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['IDR', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['IDR', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['IDR', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['IDR', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['IDR', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['IDR', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['MYR', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['MYR', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['MYR', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['MYR', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['MYR', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['MYR', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['MYR', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['MYR', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NOK', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NOK', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NOK', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NOK', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NOK', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NOK', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NOK', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NOK', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NOK', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NZD', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NZD', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NZD', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NZD', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NZD', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NZD', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NZD', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NZD', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NZD', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['NZD', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PHP', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PHP', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PHP', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PHP', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PHP', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PHP', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PHP', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PHP', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PHP', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PHP', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PHP', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PLN', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PLN', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PLN', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PLN', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PLN', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PLN', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PLN', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PLN', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PLN', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PLN', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PLN', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['PLN', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RON', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RON', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RON', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RON', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RON', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RON', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RON', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RON', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RON', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RON', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RON', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RON', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RON', 'PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RUB', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RUB', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RUB', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RUB', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RUB', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RUB', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RUB', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RUB', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RUB', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RUB', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RUB', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RUB', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RUB', 'PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['RUB', 'RON']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK', 'PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK', 'RON']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SEK', 'RUB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'RON']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'RUB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['SGD', 'SEK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'RON']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'RUB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'SEK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['THB', 'SGD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'RON']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'RUB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'SEK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'SGD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['TRY', 'THB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'AUD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'CAD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'CHF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'CZK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'EUR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'HRK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'HUF']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'IDR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'MYR']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'NOK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'NZD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'PHP']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'PLN']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'RON']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'RUB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'SEK']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'SGD']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'THB']
# Evaluating ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'] + ['ZAR', 'TRY']
# Done. Best set: ['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY']

# %%
mix6 = run_optimization(selected_currencies=['USD', 'DKK', 'KRW', 'JPY', 'GBP', 'CNY'], 
                                   max_iter=100, 
                                   loss_function=calculate_loss_function_around_one)

# %%
calculate_loss_function_around_one(mix6.values, mix6.index) / 0.007002770452103174
# Out:
# 1.0019627412414622

# %%
# Create initial loss function values,
# to find find most/least stable currencies
results = pd.DataFrame()

# Calculate loss function score per currency
for base_currency in all_currencies:
    for currency in all_currencies:
        if currency == base_currency:
            continue
            
        rates = dev[base_currency] / dev[currency]
        normalized_rates = rates / rates.iloc[0]
        
        deviation = np.log(normalized_rates)
        loss_function_score = (deviation**2).mean()

        results = results.append({"currency": currency,
                                  "base_currency": base_currency,
                                  "loss_function_score": loss_function_score},
                                 ignore_index=True)
    
results = results.groupby("currency").median()
results = results.sort_values("loss_function_score", ascending=True)
# Out:
#           loss_function_score
# currency
# CAD              0.01460
# MYR              0.01597
# NOK              0.01745
# HRK              0.02022
# SEK              0.02037
# CZK              0.02069
# EUR              0.02119
# DKK              0.02121
# USD              0.02143
# HKD              0.02162
# PLN              0.02177
# HUF              0.02201
# IDR              0.02337
# NZD              0.02515
# AUD              0.02546
# THB              0.02555
# CHF              0.02625
# RUB              0.02638
# JPY              0.02678
# RON              0.02789
# PHP              0.02824
# KRW              0.02831
# SGD              0.03115
# CNY              0.03542
# GBP              0.03633
# TRY              0.06832
# ZAR              0.11749

# %%
# Select currencies where loss function should be calculated on:
# we exclude 2 least stable currencies
currencies_loss_function = list(results[:-2].index)

# %%
# Loss function is edited:
# not all currencies are used to calculate the loss function score

def calculate_loss_function_around_one(weights, selected_currencies):
    weights = weights / weights.sum()
    amounts = pd.Series(weights, index=selected_currencies) * reference_date_exhange_rate

    loss_function_score = 0

    for base_currency in currencies_loss_function:
        amounts_through_time = amounts * exchange_table[base_currency]
        normalized_amounts_through_time = amounts_through_time.sum(axis=1) / reference_date_exhange_rate[base_currency]
        
        deviation = np.log(normalized_amounts_through_time)
        loss_function_score += trading_volumes[base_currency] * (deviation**2).mean()
    
    return loss_function_score

# %%
best_score = 1
last_score = 1
currencies = []

uncoupled_currencies = [[c] for c in all_currencies if c != "HKD"]
uncoupled_currencies.sort()

currency_pairs = [[c1[0], c2[0]] for c1 in uncoupled_currencies for c2 in uncoupled_currencies if c1 > c2]
currency_pairs.sort()

while best_score == 1 or currencies_to_add is not None:
    print(f"Attempting to improve set, starting from: {currencies}")
    currencies_to_add = None
    
    for currencies_to_try in uncoupled_currencies + currency_pairs:
        new_mix, new_score = try_currencies(currencies_to_try, currencies)

        if new_score < .9995 * last_score:
            if new_score < best_score:
                best_score = new_score
                currencies_to_add = currencies_to_try

                print(f"New best score found: {new_score}")
                print(new_mix)
            elif last_score < 1:
                print(f"Better than last score, but not better than best: {new_score}")
                print(new_mix)
    
    last_score = best_score
    
    if currencies_to_add is not None:
        currencies += currencies_to_add
        
print(f"Done. Best set: {currencies}")
# Out:
# Attempting to improve set, starting from: []
# Evaluating [] + ['AUD']
# New best score found: 0.021259912367901715
# AUD   1.00000
# dtype: float64
# Evaluating [] + ['CAD']
# New best score found: 0.017334239923574413
# CAD   1.00000
# dtype: float64
# Evaluating [] + ['CHF']
# Evaluating [] + ['CNY']
# Evaluating [] + ['CZK']
# Evaluating [] + ['DKK']
# New best score found: 0.009018412226329936
# DKK   1.00000
# dtype: float64
# Evaluating [] + ['EUR']
# Evaluating [] + ['GBP']
# Evaluating [] + ['HRK']
# Evaluating [] + ['HUF']
# Evaluating [] + ['IDR']
# Evaluating [] + ['JPY']
# Evaluating [] + ['KRW']
# Evaluating [] + ['MYR']
# Evaluating [] + ['NOK']
# Evaluating [] + ['NZD']
# Evaluating [] + ['PHP']
# Evaluating [] + ['PLN']
# Evaluating [] + ['RON']
# Evaluating [] + ['RUB']
# Evaluating [] + ['SEK']
# Evaluating [] + ['SGD']
# Evaluating [] + ['THB']
# Evaluating [] + ['TRY']
# Evaluating [] + ['USD']
# New best score found: 0.008085068258062714
# USD   1.00000
# dtype: float64
# Evaluating [] + ['ZAR']
# Evaluating [] + ['CAD', 'AUD']
# Evaluating [] + ['CHF', 'AUD']
# Evaluating [] + ['CHF', 'CAD']
# Evaluating [] + ['CNY', 'AUD']
# Evaluating [] + ['CNY', 'CAD']
# Evaluating [] + ['CNY', 'CHF']
# Evaluating [] + ['CZK', 'AUD']
# Evaluating [] + ['CZK', 'CAD']
# Evaluating [] + ['CZK', 'CHF']
# Evaluating [] + ['CZK', 'CNY']
# Evaluating [] + ['DKK', 'AUD']
# Evaluating [] + ['DKK', 'CAD']
# Evaluating [] + ['DKK', 'CHF']
# Evaluating [] + ['DKK', 'CNY']
# Evaluating [] + ['DKK', 'CZK']
# Evaluating [] + ['EUR', 'AUD']
# Evaluating [] + ['EUR', 'CAD']
# Evaluating [] + ['EUR', 'CHF']
# Evaluating [] + ['EUR', 'CNY']
# Evaluating [] + ['EUR', 'CZK']
# Evaluating [] + ['EUR', 'DKK']
# Evaluating [] + ['GBP', 'AUD']
# Evaluating [] + ['GBP', 'CAD']
# Evaluating [] + ['GBP', 'CHF']
# Evaluating [] + ['GBP', 'CNY']
# New best score found: 0.0073641173760931695
# GBP   0.50090
# CNY   0.49910
# dtype: float64
# Evaluating [] + ['GBP', 'CZK']
# Evaluating [] + ['GBP', 'DKK']
# Evaluating [] + ['GBP', 'EUR']
# Evaluating [] + ['HRK', 'AUD']
# Evaluating [] + ['HRK', 'CAD']
# Evaluating [] + ['HRK', 'CHF']
# Evaluating [] + ['HRK', 'CNY']
# Evaluating [] + ['HRK', 'CZK']
# Evaluating [] + ['HRK', 'DKK']
# Evaluating [] + ['HRK', 'EUR']
# Evaluating [] + ['HRK', 'GBP']
# Evaluating [] + ['HUF', 'AUD']
# Evaluating [] + ['HUF', 'CAD']
# Evaluating [] + ['HUF', 'CHF']
# Evaluating [] + ['HUF', 'CNY']
# Evaluating [] + ['HUF', 'CZK']
# Evaluating [] + ['HUF', 'DKK']
# Evaluating [] + ['HUF', 'EUR']
# Evaluating [] + ['HUF', 'GBP']
# Evaluating [] + ['HUF', 'HRK']
# Evaluating [] + ['IDR', 'AUD']
# Evaluating [] + ['IDR', 'CAD']
# Evaluating [] + ['IDR', 'CHF']
# Evaluating [] + ['IDR', 'CNY']
# Evaluating [] + ['IDR', 'CZK']
# Evaluating [] + ['IDR', 'DKK']
# Evaluating [] + ['IDR', 'EUR']
# Evaluating [] + ['IDR', 'GBP']
# Evaluating [] + ['IDR', 'HRK']
# Evaluating [] + ['IDR', 'HUF']
# Evaluating [] + ['JPY', 'AUD']
# Evaluating [] + ['JPY', 'CAD']
# Evaluating [] + ['JPY', 'CHF']
# Evaluating [] + ['JPY', 'CNY']
# Evaluating [] + ['JPY', 'CZK']
# Evaluating [] + ['JPY', 'DKK']
# Evaluating [] + ['JPY', 'EUR']
# Evaluating [] + ['JPY', 'GBP']
# Evaluating [] + ['JPY', 'HRK']
# Evaluating [] + ['JPY', 'HUF']
# Evaluating [] + ['JPY', 'IDR']
# Evaluating [] + ['KRW', 'AUD']
# Evaluating [] + ['KRW', 'CAD']
# Evaluating [] + ['KRW', 'CHF']
# Evaluating [] + ['KRW', 'CNY']
# Evaluating [] + ['KRW', 'CZK']
# Evaluating [] + ['KRW', 'DKK']
# Evaluating [] + ['KRW', 'EUR']
# Evaluating [] + ['KRW', 'GBP']
# Evaluating [] + ['KRW', 'HRK']
# Evaluating [] + ['KRW', 'HUF']
# Evaluating [] + ['KRW', 'IDR']
# Evaluating [] + ['KRW', 'JPY']
# Evaluating [] + ['MYR', 'AUD']
# Evaluating [] + ['MYR', 'CAD']
# Evaluating [] + ['MYR', 'CHF']
# Evaluating [] + ['MYR', 'CNY']
# Evaluating [] + ['MYR', 'CZK']
# Evaluating [] + ['MYR', 'DKK']
# Evaluating [] + ['MYR', 'EUR']
# Evaluating [] + ['MYR', 'GBP']
# Evaluating [] + ['MYR', 'HRK']
# Evaluating [] + ['MYR', 'HUF']
# Evaluating [] + ['MYR', 'IDR']
# Evaluating [] + ['MYR', 'JPY']
# Evaluating [] + ['MYR', 'KRW']
# Evaluating [] + ['NOK', 'AUD']
# Evaluating [] + ['NOK', 'CAD']
# Evaluating [] + ['NOK', 'CHF']
# Evaluating [] + ['NOK', 'CNY']
# Evaluating [] + ['NOK', 'CZK']
# Evaluating [] + ['NOK', 'DKK']
# Evaluating [] + ['NOK', 'EUR']
# Evaluating [] + ['NOK', 'GBP']
# Evaluating [] + ['NOK', 'HRK']
# Evaluating [] + ['NOK', 'HUF']
# Evaluating [] + ['NOK', 'IDR']
# Evaluating [] + ['NOK', 'JPY']
# Evaluating [] + ['NOK', 'KRW']
# Evaluating [] + ['NOK', 'MYR']
# Evaluating [] + ['NZD', 'AUD']
# Evaluating [] + ['NZD', 'CAD']
# Evaluating [] + ['NZD', 'CHF']
# Evaluating [] + ['NZD', 'CNY']
# Evaluating [] + ['NZD', 'CZK']
# Evaluating [] + ['NZD', 'DKK']
# Evaluating [] + ['NZD', 'EUR']
# Evaluating [] + ['NZD', 'GBP']
# Evaluating [] + ['NZD', 'HRK']
# Evaluating [] + ['NZD', 'HUF']
# Evaluating [] + ['NZD', 'IDR']
# Evaluating [] + ['NZD', 'JPY']
# Evaluating [] + ['NZD', 'KRW']
# Evaluating [] + ['NZD', 'MYR']
# Evaluating [] + ['NZD', 'NOK']
# Evaluating [] + ['PHP', 'AUD']
# Evaluating [] + ['PHP', 'CAD']
# Evaluating [] + ['PHP', 'CHF']
# Evaluating [] + ['PHP', 'CNY']
# Evaluating [] + ['PHP', 'CZK']
# Evaluating [] + ['PHP', 'DKK']
# Evaluating [] + ['PHP', 'EUR']
# Evaluating [] + ['PHP', 'GBP']
# Evaluating [] + ['PHP', 'HRK']
# Evaluating [] + ['PHP', 'HUF']
# Evaluating [] + ['PHP', 'IDR']
# Evaluating [] + ['PHP', 'JPY']
# Evaluating [] + ['PHP', 'KRW']
# Evaluating [] + ['PHP', 'MYR']
# Evaluating [] + ['PHP', 'NOK']
# Evaluating [] + ['PHP', 'NZD']
# Evaluating [] + ['PLN', 'AUD']
# Evaluating [] + ['PLN', 'CAD']
# Evaluating [] + ['PLN', 'CHF']
# Evaluating [] + ['PLN', 'CNY']
# Evaluating [] + ['PLN', 'CZK']
# Evaluating [] + ['PLN', 'DKK']
# Evaluating [] + ['PLN', 'EUR']
# Evaluating [] + ['PLN', 'GBP']
# Evaluating [] + ['PLN', 'HRK']
# Evaluating [] + ['PLN', 'HUF']
# Evaluating [] + ['PLN', 'IDR']
# Evaluating [] + ['PLN', 'JPY']
# Evaluating [] + ['PLN', 'KRW']
# Evaluating [] + ['PLN', 'MYR']
# Evaluating [] + ['PLN', 'NOK']
# Evaluating [] + ['PLN', 'NZD']
# Evaluating [] + ['PLN', 'PHP']
# Evaluating [] + ['RON', 'AUD']
# Evaluating [] + ['RON', 'CAD']
# Evaluating [] + ['RON', 'CHF']
# Evaluating [] + ['RON', 'CNY']
# Evaluating [] + ['RON', 'CZK']
# Evaluating [] + ['RON', 'DKK']
# Evaluating [] + ['RON', 'EUR']
# Evaluating [] + ['RON', 'GBP']
# Evaluating [] + ['RON', 'HRK']
# Evaluating [] + ['RON', 'HUF']
# Evaluating [] + ['RON', 'IDR']
# Evaluating [] + ['RON', 'JPY']
# Evaluating [] + ['RON', 'KRW']
# Evaluating [] + ['RON', 'MYR']
# Evaluating [] + ['RON', 'NOK']
# Evaluating [] + ['RON', 'NZD']
# Evaluating [] + ['RON', 'PHP']
# Evaluating [] + ['RON', 'PLN']
# Evaluating [] + ['RUB', 'AUD']
# Evaluating [] + ['RUB', 'CAD']
# Evaluating [] + ['RUB', 'CHF']
# Evaluating [] + ['RUB', 'CNY']
# Evaluating [] + ['RUB', 'CZK']
# Evaluating [] + ['RUB', 'DKK']
# Evaluating [] + ['RUB', 'EUR']
# Evaluating [] + ['RUB', 'GBP']
# Evaluating [] + ['RUB', 'HRK']
# Evaluating [] + ['RUB', 'HUF']
# Evaluating [] + ['RUB', 'IDR']
# Evaluating [] + ['RUB', 'JPY']
# Evaluating [] + ['RUB', 'KRW']
# Evaluating [] + ['RUB', 'MYR']
# Evaluating [] + ['RUB', 'NOK']
# Evaluating [] + ['RUB', 'NZD']
# Evaluating [] + ['RUB', 'PHP']
# Evaluating [] + ['RUB', 'PLN']
# Evaluating [] + ['RUB', 'RON']
# Evaluating [] + ['SEK', 'AUD']
# Evaluating [] + ['SEK', 'CAD']
# Evaluating [] + ['SEK', 'CHF']
# Evaluating [] + ['SEK', 'CNY']
# Evaluating [] + ['SEK', 'CZK']
# Evaluating [] + ['SEK', 'DKK']
# Evaluating [] + ['SEK', 'EUR']
# Evaluating [] + ['SEK', 'GBP']
# Evaluating [] + ['SEK', 'HRK']
# Evaluating [] + ['SEK', 'HUF']
# Evaluating [] + ['SEK', 'IDR']
# Evaluating [] + ['SEK', 'JPY']
# Evaluating [] + ['SEK', 'KRW']
# Evaluating [] + ['SEK', 'MYR']
# Evaluating [] + ['SEK', 'NOK']
# Evaluating [] + ['SEK', 'NZD']
# Evaluating [] + ['SEK', 'PHP']
# Evaluating [] + ['SEK', 'PLN']
# Evaluating [] + ['SEK', 'RON']
# Evaluating [] + ['SEK', 'RUB']
# Evaluating [] + ['SGD', 'AUD']
# Evaluating [] + ['SGD', 'CAD']
# Evaluating [] + ['SGD', 'CHF']
# Evaluating [] + ['SGD', 'CNY']
# Evaluating [] + ['SGD', 'CZK']
# Evaluating [] + ['SGD', 'DKK']
# Evaluating [] + ['SGD', 'EUR']
# Evaluating [] + ['SGD', 'GBP']
# Evaluating [] + ['SGD', 'HRK']
# Evaluating [] + ['SGD', 'HUF']
# Evaluating [] + ['SGD', 'IDR']
# Evaluating [] + ['SGD', 'JPY']
# Evaluating [] + ['SGD', 'KRW']
# Evaluating [] + ['SGD', 'MYR']
# Evaluating [] + ['SGD', 'NOK']
# Evaluating [] + ['SGD', 'NZD']
# Evaluating [] + ['SGD', 'PHP']
# Evaluating [] + ['SGD', 'PLN']
# Evaluating [] + ['SGD', 'RON']
# Evaluating [] + ['SGD', 'RUB']
# Evaluating [] + ['SGD', 'SEK']
# Evaluating [] + ['THB', 'AUD']
# Evaluating [] + ['THB', 'CAD']
# Evaluating [] + ['THB', 'CHF']
# Evaluating [] + ['THB', 'CNY']
# Evaluating [] + ['THB', 'CZK']
# Evaluating [] + ['THB', 'DKK']
# Evaluating [] + ['THB', 'EUR']
# Evaluating [] + ['THB', 'GBP']
# Evaluating [] + ['THB', 'HRK']
# Evaluating [] + ['THB', 'HUF']
# Evaluating [] + ['THB', 'IDR']
# Evaluating [] + ['THB', 'JPY']
# Evaluating [] + ['THB', 'KRW']
# Evaluating [] + ['THB', 'MYR']
# Evaluating [] + ['THB', 'NOK']
# Evaluating [] + ['THB', 'NZD']
# Evaluating [] + ['THB', 'PHP']
# Evaluating [] + ['THB', 'PLN']
# Evaluating [] + ['THB', 'RON']
# Evaluating [] + ['THB', 'RUB']
# Evaluating [] + ['THB', 'SEK']
# Evaluating [] + ['THB', 'SGD']
# Evaluating [] + ['TRY', 'AUD']
# Evaluating [] + ['TRY', 'CAD']
# Evaluating [] + ['TRY', 'CHF']
# Evaluating [] + ['TRY', 'CNY']
# Evaluating [] + ['TRY', 'CZK']
# Evaluating [] + ['TRY', 'DKK']
# Evaluating [] + ['TRY', 'EUR']
# Evaluating [] + ['TRY', 'GBP']
# Evaluating [] + ['TRY', 'HRK']
# Evaluating [] + ['TRY', 'HUF']
# Evaluating [] + ['TRY', 'IDR']
# Evaluating [] + ['TRY', 'JPY']
# Evaluating [] + ['TRY', 'KRW']
# Evaluating [] + ['TRY', 'MYR']
# Evaluating [] + ['TRY', 'NOK']
# Evaluating [] + ['TRY', 'NZD']
# Evaluating [] + ['TRY', 'PHP']
# Evaluating [] + ['TRY', 'PLN']
# Evaluating [] + ['TRY', 'RON']
# Evaluating [] + ['TRY', 'RUB']
# Evaluating [] + ['TRY', 'SEK']
# Evaluating [] + ['TRY', 'SGD']
# Evaluating [] + ['TRY', 'THB']
# Evaluating [] + ['USD', 'AUD']
# Evaluating [] + ['USD', 'CAD']
# Evaluating [] + ['USD', 'CHF']
# Evaluating [] + ['USD', 'CNY']
# Evaluating [] + ['USD', 'CZK']
# Evaluating [] + ['USD', 'DKK']
# New best score found: 0.0069231538856829545
# USD   0.50056
# DKK   0.49944
# dtype: float64
# Evaluating [] + ['USD', 'EUR']
# Evaluating [] + ['USD', 'GBP']
# Evaluating [] + ['USD', 'HRK']
# Evaluating [] + ['USD', 'HUF']
# Evaluating [] + ['USD', 'IDR']
# Evaluating [] + ['USD', 'JPY']
# Evaluating [] + ['USD', 'KRW']
# Evaluating [] + ['USD', 'MYR']
# Evaluating [] + ['USD', 'NOK']
# Evaluating [] + ['USD', 'NZD']
# Evaluating [] + ['USD', 'PHP']
# Evaluating [] + ['USD', 'PLN']
# Evaluating [] + ['USD', 'RON']
# Evaluating [] + ['USD', 'RUB']
# Evaluating [] + ['USD', 'SEK']
# Evaluating [] + ['USD', 'SGD']
# Evaluating [] + ['USD', 'THB']
# Evaluating [] + ['USD', 'TRY']
# Evaluating [] + ['ZAR', 'AUD']
# Evaluating [] + ['ZAR', 'CAD']
# Evaluating [] + ['ZAR', 'CHF']
# Evaluating [] + ['ZAR', 'CNY']
# Evaluating [] + ['ZAR', 'CZK']
# Evaluating [] + ['ZAR', 'DKK']
# Evaluating [] + ['ZAR', 'EUR']
# Evaluating [] + ['ZAR', 'GBP']
# Evaluating [] + ['ZAR', 'HRK']
# Evaluating [] + ['ZAR', 'HUF']
# Evaluating [] + ['ZAR', 'IDR']
# Evaluating [] + ['ZAR', 'JPY']
# Evaluating [] + ['ZAR', 'KRW']
# Evaluating [] + ['ZAR', 'MYR']
# Evaluating [] + ['ZAR', 'NOK']
# Evaluating [] + ['ZAR', 'NZD']
# Evaluating [] + ['ZAR', 'PHP']
# Evaluating [] + ['ZAR', 'PLN']
# Evaluating [] + ['ZAR', 'RON']
# Evaluating [] + ['ZAR', 'RUB']
# Evaluating [] + ['ZAR', 'SEK']
# Evaluating [] + ['ZAR', 'SGD']
# Evaluating [] + ['ZAR', 'THB']
# Evaluating [] + ['ZAR', 'TRY']
# Evaluating [] + ['ZAR', 'USD']
# Attempting to improve set, starting from: ['USD', 'DKK']
# Evaluating ['USD', 'DKK'] + ['AUD']
# Evaluating ['USD', 'DKK'] + ['CAD']
# Evaluating ['USD', 'DKK'] + ['CHF']
# Evaluating ['USD', 'DKK'] + ['CNY']
# Evaluating ['USD', 'DKK'] + ['CZK']
# Evaluating ['USD', 'DKK'] + ['EUR']
# Evaluating ['USD', 'DKK'] + ['GBP']
# Evaluating ['USD', 'DKK'] + ['HRK']
# Evaluating ['USD', 'DKK'] + ['HUF']
# Evaluating ['USD', 'DKK'] + ['IDR']
# New best score found: 0.00689918424297668
# DKK   0.33394
# USD   0.33379
# IDR   0.33228
# dtype: float64
# Evaluating ['USD', 'DKK'] + ['JPY']
# Evaluating ['USD', 'DKK'] + ['KRW']
# Evaluating ['USD', 'DKK'] + ['MYR']
# Evaluating ['USD', 'DKK'] + ['NOK']
# Evaluating ['USD', 'DKK'] + ['NZD']
# Evaluating ['USD', 'DKK'] + ['PHP']
# Evaluating ['USD', 'DKK'] + ['PLN']
# Evaluating ['USD', 'DKK'] + ['RON']
# Evaluating ['USD', 'DKK'] + ['RUB']
# Evaluating ['USD', 'DKK'] + ['SEK']
# Evaluating ['USD', 'DKK'] + ['SGD']
# Evaluating ['USD', 'DKK'] + ['THB']
# Evaluating ['USD', 'DKK'] + ['TRY']
# Evaluating ['USD', 'DKK'] + ['ZAR']
# Evaluating ['USD', 'DKK'] + ['CAD', 'AUD']
# Evaluating ['USD', 'DKK'] + ['CHF', 'AUD']
# Evaluating ['USD', 'DKK'] + ['CHF', 'CAD']
# Evaluating ['USD', 'DKK'] + ['CNY', 'AUD']
# Evaluating ['USD', 'DKK'] + ['CNY', 'CAD']
# Evaluating ['USD', 'DKK'] + ['CNY', 'CHF']
# Evaluating ['USD', 'DKK'] + ['CZK', 'AUD']
# Evaluating ['USD', 'DKK'] + ['CZK', 'CAD']
# Evaluating ['USD', 'DKK'] + ['CZK', 'CHF']
# Evaluating ['USD', 'DKK'] + ['CZK', 'CNY']
# Evaluating ['USD', 'DKK'] + ['EUR', 'AUD']
# Evaluating ['USD', 'DKK'] + ['EUR', 'CAD']
# Evaluating ['USD', 'DKK'] + ['EUR', 'CHF']
# Evaluating ['USD', 'DKK'] + ['EUR', 'CNY']
# Evaluating ['USD', 'DKK'] + ['EUR', 'CZK']
# Evaluating ['USD', 'DKK'] + ['GBP', 'AUD']
# Evaluating ['USD', 'DKK'] + ['GBP', 'CAD']
# Evaluating ['USD', 'DKK'] + ['GBP', 'CHF']
# Evaluating ['USD', 'DKK'] + ['GBP', 'CNY']
# Evaluating ['USD', 'DKK'] + ['GBP', 'CZK']
# Evaluating ['USD', 'DKK'] + ['GBP', 'EUR']
# Evaluating ['USD', 'DKK'] + ['HRK', 'AUD']
