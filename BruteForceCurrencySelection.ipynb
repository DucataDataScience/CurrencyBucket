# %%
"""
Description: Script to optimize Duca's currency mix.
Author: Jeroen van Dijk & Victor de Graaff
Date: 04-11-2020
Maintainer: Jeroen van Dijk & Victor de Graaff
Email: jeroen.vandijk@d-data.nl & victor.degraaff@d-data.nl
Status: Dev
"""
# Out:
# "\nDescription: Script to optimize Duca's currency mix.\nAuthor: Jeroen van Dijk & Victor de Graaff\nDate: 04-11-2020\nMaintainer: Jeroen van Dijk & Victor de Graaff\nEmail: jeroen.vandijk@d-data.nl & victor.degraaff@d-data.nl\nStatus: Dev\n"

# %%
# Load common imports
# %run ./CommonImports.ipynb

# %%
# Load common functions and currencies lists:
# - all_currencies
# - obsolete_currencies
# - p13_currencies
# - f_currencies
# - ff_currencies
# - currencies_per_continent
# %run ./Utilities.ipynb

# %%
# Load loss functions
# - calculate_loss_function_around_one(weights)
# - calculate_loss_function_vs_t_minus_one(weights)
# - calculate_loss_function_vs_t_minus_one_with_balancing(weights)
# - calculate_loss_function_vs_t_minus_one_for_period(weights, max_date)
# %run ./LossFunctions.ipynb

# %%
# Create dataframe with pre-defined base currency
df = create_original_df("EUR")

# %%
# Determine splits for dev- (train and test) and validation set
train_start = date(2005, 4, 1)
test_start = date(2012, 1, 1)
validation_start = date(2015, 1, 1)
validation_end = date(2020, 10, 1)

# Create dev (train and test) and validation set
train, test, dev, val = split_data(df, train_start, test_start, validation_start, validation_end)

# %%
# Create exchange table for each currency
exchange_table = dict()
for base_currency in all_currencies:
    exchange_table[base_currency] = 1/train[all_currencies].divide(train[base_currency], axis=0)

# Preview USD exchange table
exchange_table["USD"]
# Out:
#                AUD     EUR     NOK     HRK     NZD     PHP     ZAR     GBP     MYR     RUB     TRY     SGD     RON     CAD     USD     CNY     CHF     HUF     PLN     IDR     HKD     THB     CZK     SEK     JPY     DKK     KRW
# date
# 2005-04-01 0.77123 1.29590 0.15813 0.17460 0.71051 0.01827 0.16175 1.88728 0.26316 0.03588 0.73963 0.60418 0.35967 0.82353 1.00000 0.12082 0.83461 0.00524 0.31703 0.00011 0.12823 0.02554 0.04315 0.14134 0.00932 0.17394 0.00099
# 2005-04-02 0.77012 1.29337 0.15780 0.17424 0.70945 0.01826 0.16153 1.88327 0.26316 0.03587 0.73758 0.60293 0.35897 0.82270 1.00000 0.12082 0.83284 0.00523 0.31580 0.00011 0.12822 0.02546 0.04307 0.14100 0.00930 0.17360 0.00099
# 2005-04-03 0.76901 1.29083 0.15748 0.17387 0.70838 0.01825 0.16132 1.87926 0.26317 0.03586 0.73553 0.60168 0.35827 0.82187 1.00000 0.12082 0.83106 0.00522 0.31458 0.00011 0.12822 0.02537 0.04299 0.14065 0.00928 0.17326 0.00099
# 2005-04-04 0.76790 1.28830 0.15715 0.17351 0.70731 0.01824 0.16110 1.87525 0.26317 0.03585 0.73349 0.60044 0.35756 0.82104 1.00000 0.12082 0.82929 0.00521 0.31336 0.00011 0.12821 0.02529 0.04291 0.14031 0.00926 0.17292 0.00099
# 2005-04-05 0.76441 1.28100 0.15691 0.17266 0.70431 0.01824 0.16014 1.87253 0.26316 0.03579 0.73137 0.60059 0.35554 0.81681 1.00000 0.12082 0.82427 0.00518 0.31019 0.00011 0.12821 0.02522 0.04271 0.13960 0.00921 0.17195 0.00098
# ...            ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2011-12-27 1.01609 1.30690 0.16767 0.17385 0.77395 0.02285 0.12258 1.56797 0.31511 0.03197 0.52632 0.77144 0.30464 0.98101 1.00000 0.15816 1.07035 0.00428 0.29675 0.00011 0.12859 0.03181 0.05068 0.14564 0.01284 0.17582 0.00087
# 2011-12-28 1.01989 1.30740 0.16764 0.17367 0.77766 0.02274 0.12334 1.56725 0.31596 0.03159 0.52633 0.77197 0.30502 0.98530 1.00000 0.15827 1.07199 0.00426 0.29749 0.00011 0.12858 0.03171 0.05064 0.14578 0.01288 0.17583 0.00087
# 2011-12-29 1.00703 1.28890 0.16580 0.17100 0.76652 0.02281 0.12265 1.54175 0.31451 0.03103 0.52288 0.76697 0.29957 0.97725 1.00000 0.15822 1.05769 0.00415 0.29022 0.00011 0.12866 0.03147 0.04975 0.14415 0.01286 0.17337 0.00087
# 2011-12-30 1.01698 1.29390 0.16687 0.17167 0.77308 0.02280 0.12343 1.54902 0.31516 0.03098 0.52959 0.76931 0.29929 0.97911 1.00000 0.15859 1.06441 0.00411 0.29024 0.00011 0.12873 0.03157 0.05018 0.14519 0.01291 0.17405 0.00086
# 2011-12-31 1.01850 1.29377 0.16685 0.17168 0.77476 0.02280 0.12351 1.54896 0.31519 0.03101 0.52994 0.76981 0.29904 0.97951 1.00000 0.15861 1.06433 0.00411 0.28988 0.00011 0.12874 0.03162 0.05035 0.14509 0.01294 0.17403 0.00086
#
# [2466 rows x 27 columns]

# %%
reference_date_exhange_rate = train[all_currencies].iloc[0]

# %%
def run_optimization(selected_currencies, 
                     max_iter=100, 
                     loss_function=calculate_loss_function_around_one):
    starting_point = np.ones(len(selected_currencies))/len(selected_currencies)
    bounds = [(0, 1) for _ in range(len(starting_point))]
    
    result = minimize(fun=loss_function, 
                      x0=starting_point, 
                      args=selected_currencies,
                      bounds=bounds,
                      options={"disp": True, 
                               "maxiter": max_iter})
    
    output = pd.Series(result.x/result.x.sum(), index=reference_date_exhange_rate.loc[selected_currencies].index)
    output = output.sort_values(ascending=False)
        
    return output

# %%
def try_currencies(currencies_to_try, currencies):
    for currency in currencies_to_try:
        if currency in currencies:
            return None, 1

    print(f"Evaluating {currencies} + {currencies_to_try}")
    new_mix = run_optimization(selected_currencies=currencies + currencies_to_try, 
                               max_iter=100, 
                               loss_function=calculate_loss_function_around_one)

    new_score = calculate_loss_function_around_one(new_mix, currencies + currencies_to_try)

    return new_mix, new_score

# %%
best_score = 1
last_score = 1
currencies = []

uncoupled_currencies = [[c] for c in all_currencies if c != "HKD"]
uncoupled_currencies.sort()

currency_pairs = [[c1[0], c2[0]] for c1 in uncoupled_currencies for c2 in uncoupled_currencies if c1 > c2]
currency_pairs.sort()

while best_score == 1 or currencies_to_add is not None:
    print(f"Attempting to improve set, starting from: {currencies}")
    currencies_to_add = None
    
    for currencies_to_try in uncoupled_currencies + currency_pairs:
        new_mix, new_score = try_currencies(currencies_to_try, currencies)

        if new_score < .9995 * last_score:
            if new_score < best_score:
                best_score = new_score
                currencies_to_add = currencies_to_try

                print(f"New best score found: {new_score}")
                print(new_mix)
            elif last_score < 1:
                print(f"Better than last score, but not better than best: {new_score}")
                print(new_mix)
    
    last_score = best_score
    
    if currencies_to_add is not None:
        currencies += currencies_to_add
        
print(f"Done. Best set: {currencies}")
# Out:
# Attempting to improve set, starting from: []
# Evaluating [] + ['AUD']
# New best score found: 0.022094491115124584
# AUD   1.00000
# dtype: float64
# Evaluating [] + ['CAD']
# New best score found: 0.018151954015058612
# CAD   1.00000
# dtype: float64
# Evaluating [] + ['CHF']
# Evaluating [] + ['CNY']
# Evaluating [] + ['CZK']
# Evaluating [] + ['DKK']
# New best score found: 0.009534298316224625
# DKK   1.00000
# dtype: float64
# Evaluating [] + ['EUR']
# Evaluating [] + ['GBP']
# Evaluating [] + ['HRK']
# Evaluating [] + ['HUF']
# Evaluating [] + ['IDR']
# Evaluating [] + ['JPY']
# Evaluating [] + ['KRW']
# Evaluating [] + ['MYR']
# Evaluating [] + ['NOK']
# Evaluating [] + ['NZD']
# Evaluating [] + ['PHP']
# Evaluating [] + ['PLN']
# Evaluating [] + ['RON']
# Evaluating [] + ['RUB']
# Evaluating [] + ['SEK']
# Evaluating [] + ['SGD']
# Evaluating [] + ['THB']
# Evaluating [] + ['TRY']
# Evaluating [] + ['USD']
# New best score found: 0.008417071281971677
# USD   1.00000
# dtype: float64
# Evaluating [] + ['ZAR']
# Evaluating [] + ['CAD', 'AUD']
# Evaluating [] + ['CHF', 'AUD']
# Evaluating [] + ['CHF', 'CAD']
# Evaluating [] + ['CNY', 'AUD']
# Evaluating [] + ['CNY', 'CAD']
# Evaluating [] + ['CNY', 'CHF']
# Evaluating [] + ['CZK', 'AUD']
# Evaluating [] + ['CZK', 'CAD']
# Evaluating [] + ['CZK', 'CHF']
# Evaluating [] + ['CZK', 'CNY']
# Evaluating [] + ['DKK', 'AUD']
# Evaluating [] + ['DKK', 'CAD']
# Evaluating [] + ['DKK', 'CHF']
# Evaluating [] + ['DKK', 'CNY']
# Evaluating [] + ['DKK', 'CZK']
# Evaluating [] + ['EUR', 'AUD']
# Evaluating [] + ['EUR', 'CAD']
# Evaluating [] + ['EUR', 'CHF']
# Evaluating [] + ['EUR', 'CNY']
# Evaluating [] + ['EUR', 'CZK']
# Evaluating [] + ['EUR', 'DKK']
# Evaluating [] + ['GBP', 'AUD']
# Evaluating [] + ['GBP', 'CAD']
# Evaluating [] + ['GBP', 'CHF']
# Evaluating [] + ['GBP', 'CNY']
# New best score found: 0.0077914455701317414
# GBP   0.51876
# CNY   0.48124
# dtype: float64
# Evaluating [] + ['GBP', 'CZK']
# Evaluating [] + ['GBP', 'DKK']
# Evaluating [] + ['GBP', 'EUR']
# Evaluating [] + ['HRK', 'AUD']
# Evaluating [] + ['HRK', 'CAD']
# Evaluating [] + ['HRK', 'CHF']
# Evaluating [] + ['HRK', 'CNY']
# Evaluating [] + ['HRK', 'CZK']
# Evaluating [] + ['HRK', 'DKK']
# Evaluating [] + ['HRK', 'EUR']
# Evaluating [] + ['HRK', 'GBP']
# Evaluating [] + ['HUF', 'AUD']
# Evaluating [] + ['HUF', 'CAD']
# Evaluating [] + ['HUF', 'CHF']
# Evaluating [] + ['HUF', 'CNY']
# Evaluating [] + ['HUF', 'CZK']
# Evaluating [] + ['HUF', 'DKK']
# Evaluating [] + ['HUF', 'EUR']
# Evaluating [] + ['HUF', 'GBP']
# Evaluating [] + ['HUF', 'HRK']
# Evaluating [] + ['IDR', 'AUD']
# Evaluating [] + ['IDR', 'CAD']
# Evaluating [] + ['IDR', 'CHF']
# Evaluating [] + ['IDR', 'CNY']
# Evaluating [] + ['IDR', 'CZK']
# Evaluating [] + ['IDR', 'DKK']
# Evaluating [] + ['IDR', 'EUR']
# Evaluating [] + ['IDR', 'GBP']
# Evaluating [] + ['IDR', 'HRK']
# Evaluating [] + ['IDR', 'HUF']
# Evaluating [] + ['JPY', 'AUD']
# Evaluating [] + ['JPY', 'CAD']
# Evaluating [] + ['JPY', 'CHF']
# Evaluating [] + ['JPY', 'CNY']
# Evaluating [] + ['JPY', 'CZK']
# Evaluating [] + ['JPY', 'DKK']
# Evaluating [] + ['JPY', 'EUR']
# Evaluating [] + ['JPY', 'GBP']
# Evaluating [] + ['JPY', 'HRK']
# Evaluating [] + ['JPY', 'HUF']
# Evaluating [] + ['JPY', 'IDR']
# Evaluating [] + ['KRW', 'AUD']
# Evaluating [] + ['KRW', 'CAD']
# Evaluating [] + ['KRW', 'CHF']
# Evaluating [] + ['KRW', 'CNY']
# Evaluating [] + ['KRW', 'CZK']
# Evaluating [] + ['KRW', 'DKK']
# Evaluating [] + ['KRW', 'EUR']
# Evaluating [] + ['KRW', 'GBP']
# Evaluating [] + ['KRW', 'HRK']
# Evaluating [] + ['KRW', 'HUF']
# Evaluating [] + ['KRW', 'IDR']
# Evaluating [] + ['KRW', 'JPY']
# Evaluating [] + ['MYR', 'AUD']
# Evaluating [] + ['MYR', 'CAD']
# Evaluating [] + ['MYR', 'CHF']
# Evaluating [] + ['MYR', 'CNY']
# Evaluating [] + ['MYR', 'CZK']
# Evaluating [] + ['MYR', 'DKK']
# Evaluating [] + ['MYR', 'EUR']
# Evaluating [] + ['MYR', 'GBP']
# Evaluating [] + ['MYR', 'HRK']
# Evaluating [] + ['MYR', 'HUF']
# Evaluating [] + ['MYR', 'IDR']
# Evaluating [] + ['MYR', 'JPY']
# Evaluating [] + ['MYR', 'KRW']
# Evaluating [] + ['NOK', 'AUD']
# Evaluating [] + ['NOK', 'CAD']
# Evaluating [] + ['NOK', 'CHF']
# Evaluating [] + ['NOK', 'CNY']
# Evaluating [] + ['NOK', 'CZK']
# Evaluating [] + ['NOK', 'DKK']
# Evaluating [] + ['NOK', 'EUR']
# Evaluating [] + ['NOK', 'GBP']
# Evaluating [] + ['NOK', 'HRK']
# Evaluating [] + ['NOK', 'HUF']
# Evaluating [] + ['NOK', 'IDR']
# Evaluating [] + ['NOK', 'JPY']
# Evaluating [] + ['NOK', 'KRW']
# Evaluating [] + ['NOK', 'MYR']
# Evaluating [] + ['NZD', 'AUD']
# Evaluating [] + ['NZD', 'CAD']
# Evaluating [] + ['NZD', 'CHF']
# Evaluating [] + ['NZD', 'CNY']
# Evaluating [] + ['NZD', 'CZK']
# Evaluating [] + ['NZD', 'DKK']
# Evaluating [] + ['NZD', 'EUR']
# Evaluating [] + ['NZD', 'GBP']
# Evaluating [] + ['NZD', 'HRK']
# Evaluating [] + ['NZD', 'HUF']
# Evaluating [] + ['NZD', 'IDR']
# Evaluating [] + ['NZD', 'JPY']
# Evaluating [] + ['NZD', 'KRW']
# Evaluating [] + ['NZD', 'MYR']
# Evaluating [] + ['NZD', 'NOK']
# Evaluating [] + ['PHP', 'AUD']
# Evaluating [] + ['PHP', 'CAD']
# Evaluating [] + ['PHP', 'CHF']
# Evaluating [] + ['PHP', 'CNY']
# Evaluating [] + ['PHP', 'CZK']
# Evaluating [] + ['PHP', 'DKK']
# Evaluating [] + ['PHP', 'EUR']
# Evaluating [] + ['PHP', 'GBP']
# Evaluating [] + ['PHP', 'HRK']
# Evaluating [] + ['PHP', 'HUF']
# Evaluating [] + ['PHP', 'IDR']
# Evaluating [] + ['PHP', 'JPY']
# Evaluating [] + ['PHP', 'KRW']
# Evaluating [] + ['PHP', 'MYR']
# Evaluating [] + ['PHP', 'NOK']
# Evaluating [] + ['PHP', 'NZD']
# Evaluating [] + ['PLN', 'AUD']
# Evaluating [] + ['PLN', 'CAD']
# Evaluating [] + ['PLN', 'CHF']
# Evaluating [] + ['PLN', 'CNY']
# Evaluating [] + ['PLN', 'CZK']
# Evaluating [] + ['PLN', 'DKK']
# Evaluating [] + ['PLN', 'EUR']
# Evaluating [] + ['PLN', 'GBP']
# Evaluating [] + ['PLN', 'HRK']
# Evaluating [] + ['PLN', 'HUF']
# Evaluating [] + ['PLN', 'IDR']
# Evaluating [] + ['PLN', 'JPY']
# Evaluating [] + ['PLN', 'KRW']
# Evaluating [] + ['PLN', 'MYR']
# Evaluating [] + ['PLN', 'NOK']
# Evaluating [] + ['PLN', 'NZD']
# Evaluating [] + ['PLN', 'PHP']
# Evaluating [] + ['RON', 'AUD']
# Evaluating [] + ['RON', 'CAD']
# Evaluating [] + ['RON', 'CHF']
# Evaluating [] + ['RON', 'CNY']
# Evaluating [] + ['RON', 'CZK']
# Evaluating [] + ['RON', 'DKK']
# Evaluating [] + ['RON', 'EUR']
# Evaluating [] + ['RON', 'GBP']
# Evaluating [] + ['RON', 'HRK']
# Evaluating [] + ['RON', 'HUF']
# Evaluating [] + ['RON', 'IDR']
# Evaluating [] + ['RON', 'JPY']
# Evaluating [] + ['RON', 'KRW']
# Evaluating [] + ['RON', 'MYR']
# Evaluating [] + ['RON', 'NOK']
# Evaluating [] + ['RON', 'NZD']
# Evaluating [] + ['RON', 'PHP']
# Evaluating [] + ['RON', 'PLN']
# Evaluating [] + ['RUB', 'AUD']
# Evaluating [] + ['RUB', 'CAD']
# Evaluating [] + ['RUB', 'CHF']
# Evaluating [] + ['RUB', 'CNY']
# Evaluating [] + ['RUB', 'CZK']
# Evaluating [] + ['RUB', 'DKK']
# Evaluating [] + ['RUB', 'EUR']
# Evaluating [] + ['RUB', 'GBP']
# Evaluating [] + ['RUB', 'HRK']
# Evaluating [] + ['RUB', 'HUF']
# Evaluating [] + ['RUB', 'IDR']
# Evaluating [] + ['RUB', 'JPY']
# Evaluating [] + ['RUB', 'KRW']
# Evaluating [] + ['RUB', 'MYR']
# Evaluating [] + ['RUB', 'NOK']
# Evaluating [] + ['RUB', 'NZD']
# Evaluating [] + ['RUB', 'PHP']
# Evaluating [] + ['RUB', 'PLN']
# Evaluating [] + ['RUB', 'RON']
# Evaluating [] + ['SEK', 'AUD']
# Evaluating [] + ['SEK', 'CAD']
# Evaluating [] + ['SEK', 'CHF']
# Evaluating [] + ['SEK', 'CNY']
# Evaluating [] + ['SEK', 'CZK']
# Evaluating [] + ['SEK', 'DKK']
# Evaluating [] + ['SEK', 'EUR']
# Evaluating [] + ['SEK', 'GBP']
# Evaluating [] + ['SEK', 'HRK']
# Evaluating [] + ['SEK', 'HUF']
# Evaluating [] + ['SEK', 'IDR']
# Evaluating [] + ['SEK', 'JPY']
# Evaluating [] + ['SEK', 'KRW']
# Evaluating [] + ['SEK', 'MYR']
# Evaluating [] + ['SEK', 'NOK']
# Evaluating [] + ['SEK', 'NZD']
# Evaluating [] + ['SEK', 'PHP']
# Evaluating [] + ['SEK', 'PLN']
# Evaluating [] + ['SEK', 'RON']
# Evaluating [] + ['SEK', 'RUB']
# Evaluating [] + ['SGD', 'AUD']
# Evaluating [] + ['SGD', 'CAD']
# Evaluating [] + ['SGD', 'CHF']
# Evaluating [] + ['SGD', 'CNY']
# Evaluating [] + ['SGD', 'CZK']
# Evaluating [] + ['SGD', 'DKK']
# Evaluating [] + ['SGD', 'EUR']
# Evaluating [] + ['SGD', 'GBP']
# Evaluating [] + ['SGD', 'HRK']
# Evaluating [] + ['SGD', 'HUF']
# Evaluating [] + ['SGD', 'IDR']
# Evaluating [] + ['SGD', 'JPY']
# Evaluating [] + ['SGD', 'KRW']
# Evaluating [] + ['SGD', 'MYR']
# Evaluating [] + ['SGD', 'NOK']
# Evaluating [] + ['SGD', 'NZD']
# Evaluating [] + ['SGD', 'PHP']
# Evaluating [] + ['SGD', 'PLN']
# Evaluating [] + ['SGD', 'RON']
# Evaluating [] + ['SGD', 'RUB']
# Evaluating [] + ['SGD', 'SEK']
# Evaluating [] + ['THB', 'AUD']
# Evaluating [] + ['THB', 'CAD']
# Evaluating [] + ['THB', 'CHF']
# Evaluating [] + ['THB', 'CNY']
# Evaluating [] + ['THB', 'CZK']
# Evaluating [] + ['THB', 'DKK']
# Evaluating [] + ['THB', 'EUR']
# Evaluating [] + ['THB', 'GBP']
# Evaluating [] + ['THB', 'HRK']
# Evaluating [] + ['THB', 'HUF']
# Evaluating [] + ['THB', 'IDR']
# Evaluating [] + ['THB', 'JPY']
# Evaluating [] + ['THB', 'KRW']
# Evaluating [] + ['THB', 'MYR']
# Evaluating [] + ['THB', 'NOK']
# Evaluating [] + ['THB', 'NZD']
# Evaluating [] + ['THB', 'PHP']
# Evaluating [] + ['THB', 'PLN']
# Evaluating [] + ['THB', 'RON']
# Evaluating [] + ['THB', 'RUB']
# Evaluating [] + ['THB', 'SEK']
# Evaluating [] + ['THB', 'SGD']
# Evaluating [] + ['TRY', 'AUD']
# Evaluating [] + ['TRY', 'CAD']
# Evaluating [] + ['TRY', 'CHF']
# Evaluating [] + ['TRY', 'CNY']
# Evaluating [] + ['TRY', 'CZK']
# Evaluating [] + ['TRY', 'DKK']
# Evaluating [] + ['TRY', 'EUR']
# Evaluating [] + ['TRY', 'GBP']
# Evaluating [] + ['TRY', 'HRK']
# Evaluating [] + ['TRY', 'HUF']
# Evaluating [] + ['TRY', 'IDR']
# Evaluating [] + ['TRY', 'JPY']
# Evaluating [] + ['TRY', 'KRW']
# Evaluating [] + ['TRY', 'MYR']
# Evaluating [] + ['TRY', 'NOK']
# Evaluating [] + ['TRY', 'NZD']
# Evaluating [] + ['TRY', 'PHP']
# Evaluating [] + ['TRY', 'PLN']
# Evaluating [] + ['TRY', 'RON']
# Evaluating [] + ['TRY', 'RUB']
# Evaluating [] + ['TRY', 'SEK']
# Evaluating [] + ['TRY', 'SGD']
# Evaluating [] + ['TRY', 'THB']
# Evaluating [] + ['USD', 'AUD']
# New best score found: 0.007199877555682415
# USD   0.79624
# AUD   0.20376
# dtype: float64
# Evaluating [] + ['USD', 'CAD']
# Evaluating [] + ['USD', 'CHF']
# Evaluating [] + ['USD', 'CNY']
# Evaluating [] + ['USD', 'CZK']
# Evaluating [] + ['USD', 'DKK']
# Evaluating [] + ['USD', 'EUR']
# Evaluating [] + ['USD', 'GBP']
# Evaluating [] + ['USD', 'HRK']
# Evaluating [] + ['USD', 'HUF']
# Evaluating [] + ['USD', 'IDR']
# Evaluating [] + ['USD', 'JPY']
# Evaluating [] + ['USD', 'KRW']
# Evaluating [] + ['USD', 'MYR']
# Evaluating [] + ['USD', 'NOK']
# New best score found: 0.007195815536390938
# USD   0.65180
# NOK   0.34820
# dtype: float64
# Evaluating [] + ['USD', 'NZD']
# Evaluating [] + ['USD', 'PHP']
# Evaluating [] + ['USD', 'PLN']
# Evaluating [] + ['USD', 'RON']
# Evaluating [] + ['USD', 'RUB']
# Evaluating [] + ['USD', 'SEK']
# Evaluating [] + ['USD', 'SGD']
# Evaluating [] + ['USD', 'THB']
# Evaluating [] + ['USD', 'TRY']
# Evaluating [] + ['ZAR', 'AUD']
# Evaluating [] + ['ZAR', 'CAD']
# Evaluating [] + ['ZAR', 'CHF']
# Evaluating [] + ['ZAR', 'CNY']
# Evaluating [] + ['ZAR', 'CZK']
# Evaluating [] + ['ZAR', 'DKK']
# Evaluating [] + ['ZAR', 'EUR']
# Evaluating [] + ['ZAR', 'GBP']
# Evaluating [] + ['ZAR', 'HRK']
# Evaluating [] + ['ZAR', 'HUF']
# Evaluating [] + ['ZAR', 'IDR']
# Evaluating [] + ['ZAR', 'JPY']
# Evaluating [] + ['ZAR', 'KRW']
# Evaluating [] + ['ZAR', 'MYR']
# Evaluating [] + ['ZAR', 'NOK']
# Evaluating [] + ['ZAR', 'NZD']
# Evaluating [] + ['ZAR', 'PHP']
# Evaluating [] + ['ZAR', 'PLN']
# Evaluating [] + ['ZAR', 'RON']
# Evaluating [] + ['ZAR', 'RUB']
# Evaluating [] + ['ZAR', 'SEK']
# Evaluating [] + ['ZAR', 'SGD']
# Evaluating [] + ['ZAR', 'THB']
# Evaluating [] + ['ZAR', 'TRY']
# Evaluating [] + ['ZAR', 'USD']
# Attempting to improve set, starting from: ['USD', 'NOK']
# Evaluating ['USD', 'NOK'] + ['AUD']
# New best score found: 0.00710484484865174
# USD   0.70240
# NOK   0.18914
# AUD   0.10846
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['CAD']
# Better than last score, but not better than best: 0.007173385622863142
# USD   0.66391
# NOK   0.27683
# CAD   0.05926
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['CHF']
# New best score found: 0.007051177873175599
# USD   0.66925
# NOK   0.22230
# CHF   0.10845
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['CNY']
# Better than last score, but not better than best: 0.007134696386934886
# USD   0.65628
# NOK   0.28604
# CNY   0.05769
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['CZK']
# Better than last score, but not better than best: 0.007137101309661466
# USD   0.70818
# NOK   0.23019
# CZK   0.06163
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['DKK']
# Better than last score, but not better than best: 0.007157801585630197
# USD   0.60940
# NOK   0.22965
# DKK   0.16095
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['EUR']
# Better than last score, but not better than best: 0.007159029219637594
# USD   0.61108
# NOK   0.23110
# EUR   0.15782
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['GBP']
# Evaluating ['USD', 'NOK'] + ['HRK']
# Better than last score, but not better than best: 0.007174374158303568
# USD   0.63353
# NOK   0.26471
# HRK   0.10176
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HUF']
# Evaluating ['USD', 'NOK'] + ['IDR']
# Evaluating ['USD', 'NOK'] + ['JPY']
# Better than last score, but not better than best: 0.007056366662666123
# USD   0.63209
# NOK   0.29178
# JPY   0.07613
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['KRW']
# Evaluating ['USD', 'NOK'] + ['MYR']
# Better than last score, but not better than best: 0.007139764185238954
# USD   0.65498
# NOK   0.25932
# MYR   0.08571
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['NZD']
# Evaluating ['USD', 'NOK'] + ['PHP']
# Better than last score, but not better than best: 0.007165333997696982
# USD   0.66994
# NOK   0.28377
# PHP   0.04628
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PLN']
# Evaluating ['USD', 'NOK'] + ['RON']
# Evaluating ['USD', 'NOK'] + ['RUB']
# Evaluating ['USD', 'NOK'] + ['SEK']
# Evaluating ['USD', 'NOK'] + ['SGD']
# Better than last score, but not better than best: 0.007115774492427241
# USD   0.67178
# NOK   0.24972
# SGD   0.07850
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['THB']
# Better than last score, but not better than best: 0.007144374555822244
# USD   0.67436
# NOK   0.26674
# THB   0.05889
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['TRY']
# Evaluating ['USD', 'NOK'] + ['ZAR']
# Evaluating ['USD', 'NOK'] + ['CAD', 'AUD']
# Better than last score, but not better than best: 0.007104848156603502
# USD   0.70189
# NOK   0.19026
# AUD   0.10786
# CAD   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['CHF', 'AUD']
# Better than last score, but not better than best: 0.007051177883488846
# USD   0.66922
# NOK   0.22227
# CHF   0.10845
# AUD   0.00006
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['CHF', 'CAD']
# Better than last score, but not better than best: 0.007051188310315894
# USD   0.66988
# NOK   0.22086
# CHF   0.10926
# CAD   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['CNY', 'AUD']
# Better than last score, but not better than best: 0.007096532274309873
# USD   0.69372
# NOK   0.19461
# AUD   0.08586
# CNY   0.02580
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['CNY', 'CAD']
# Better than last score, but not better than best: 0.007134696764671254
# USD   0.65643
# NOK   0.28593
# CNY   0.05764
# CAD   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['CNY', 'CHF']
# Better than last score, but not better than best: 0.007051177874872778
# USD   0.66923
# NOK   0.22233
# CHF   0.10844
# CNY   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['CZK', 'AUD']
# Better than last score, but not better than best: 0.007084039619701247
# USD   0.72908
# NOK   0.14281
# AUD   0.08897
# CZK   0.03913
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['CZK', 'CAD']
# Better than last score, but not better than best: 0.007137101284762842
# USD   0.70829
# NOK   0.23006
# CZK   0.06165
# CAD   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['CZK', 'CHF']
# New best score found: 0.00705085122949208
# USD   0.67380
# NOK   0.21586
# CHF   0.10474
# CZK   0.00560
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['CZK', 'CNY']
# Better than last score, but not better than best: 0.0071332533441149735
# USD   0.67715
# NOK   0.26137
# CNY   0.03707
# CZK   0.02441
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['DKK', 'AUD']
# New best score found: 0.0070310498174457085
# USD   0.65328
# DKK   0.21934
# AUD   0.12738
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['DKK', 'CAD']
# Better than last score, but not better than best: 0.007129063893760516
# USD   0.62077
# DKK   0.17455
# NOK   0.13680
# CAD   0.06788
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['DKK', 'CHF']
# Better than last score, but not better than best: 0.0070334525991577615
# USD   0.64010
# NOK   0.14631
# DKK   0.11160
# CHF   0.10199
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['DKK', 'CNY']
# Better than last score, but not better than best: 0.007118005055546173
# USD   0.62687
# NOK   0.21290
# DKK   0.11155
# CNY   0.04867
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['DKK', 'CZK']
# Better than last score, but not better than best: 0.0071315783037095406
# USD   0.67806
# NOK   0.19945
# DKK   0.07316
# CZK   0.04933
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['EUR', 'AUD']
# Better than last score, but not better than best: 0.0070314484608370725
# USD   0.65433
# EUR   0.21777
# AUD   0.12790
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['EUR', 'CAD']
# Better than last score, but not better than best: 0.007130439696627712
# USD   0.62154
# EUR   0.17262
# NOK   0.13812
# CAD   0.06773
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['EUR', 'CHF']
# Better than last score, but not better than best: 0.007033827247742892
# USD   0.64052
# NOK   0.14633
# EUR   0.11087
# CHF   0.10228
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['EUR', 'CNY']
# Better than last score, but not better than best: 0.007118787083907796
# USD   0.62763
# NOK   0.21407
# EUR   0.10937
# CNY   0.04893
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['EUR', 'CZK']
# Better than last score, but not better than best: 0.007132217201129128
# USD   0.67979
# NOK   0.20097
# EUR   0.06925
# CZK   0.04999
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['EUR', 'DKK']
# Better than last score, but not better than best: 0.007158383096780659
# USD   0.61046
# NOK   0.23035
# DKK   0.08285
# EUR   0.07634
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['GBP', 'AUD']
# Better than last score, but not better than best: 0.0071048448929554595
# USD   0.70243
# NOK   0.18919
# AUD   0.10837
# GBP   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['GBP', 'CAD']
# Better than last score, but not better than best: 0.007173385725230951
# USD   0.66383
# NOK   0.27689
# CAD   0.05928
# GBP   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['GBP', 'CHF']
# Better than last score, but not better than best: 0.0070451293890487435
# USD   0.63763
# NOK   0.19274
# CHF   0.13662
# GBP   0.03302
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['GBP', 'CNY']
# Better than last score, but not better than best: 0.007134696424694881
# USD   0.65632
# NOK   0.28597
# CNY   0.05771
# GBP   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['GBP', 'CZK']
# Better than last score, but not better than best: 0.007137101295792761
# USD   0.70832
# NOK   0.23001
# CZK   0.06167
# GBP   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['GBP', 'DKK']
# Better than last score, but not better than best: 0.007157796498533868
# USD   0.61076
# NOK   0.22975
# DKK   0.15949
# GBP   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['GBP', 'EUR']
# Better than last score, but not better than best: 0.007159030384838594
# USD   0.61152
# NOK   0.23087
# EUR   0.15761
# GBP   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HRK', 'AUD']
# Better than last score, but not better than best: 0.007052587537209267
# USD   0.68287
# HRK   0.16803
# AUD   0.12974
# NOK   0.01937
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HRK', 'CAD']
# Better than last score, but not better than best: 0.0071552423999835715
# USD   0.64604
# NOK   0.20321
# HRK   0.09583
# CAD   0.05492
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HRK', 'CHF']
# Better than last score, but not better than best: 0.007040443429564775
# USD   0.65592
# NOK   0.16450
# CHF   0.10501
# HRK   0.07457
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HRK', 'CNY']
# Better than last score, but not better than best: 0.00713236565816244
# USD   0.64923
# NOK   0.26048
# CNY   0.05256
# HRK   0.03772
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HRK', 'CZK']
# Better than last score, but not better than best: 0.007137103086492681
# USD   0.70880
# NOK   0.22932
# CZK   0.06189
# HRK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HRK', 'DKK']
# Better than last score, but not better than best: 0.0071577968938501425
# USD   0.61084
# NOK   0.23015
# DKK   0.15901
# HRK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HRK', 'EUR']
# Better than last score, but not better than best: 0.0071590297055769535
# USD   0.61084
# NOK   0.23108
# EUR   0.15807
# HRK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HRK', 'GBP']
# Better than last score, but not better than best: 0.007174369392057015
# USD   0.63319
# NOK   0.26347
# HRK   0.10334
# GBP   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HUF', 'AUD']
# Better than last score, but not better than best: 0.007095166144728006
# USD   0.69270
# AUD   0.13806
# NOK   0.12111
# HUF   0.04812
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HUF', 'CAD']
# Better than last score, but not better than best: 0.007173387427295629
# USD   0.66438
# NOK   0.27633
# CAD   0.05929
# HUF   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HUF', 'CHF']
# Better than last score, but not better than best: 0.007035571099370931
# USD   0.64492
# NOK   0.16362
# CHF   0.13374
# HUF   0.05772
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HUF', 'CNY']
# Better than last score, but not better than best: 0.007127506326034339
# USD   0.63492
# NOK   0.24036
# CNY   0.07856
# HUF   0.04616
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HUF', 'CZK']
# Better than last score, but not better than best: 0.007137101527144832
# USD   0.70813
# NOK   0.23019
# CZK   0.06169
# HUF   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HUF', 'DKK']
# Better than last score, but not better than best: 0.007157795489251958
# USD   0.61051
# NOK   0.22992
# DKK   0.15957
# HUF   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HUF', 'EUR']
# Better than last score, but not better than best: 0.007159029362052538
# USD   0.61127
# NOK   0.23103
# EUR   0.15770
# HUF   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['HUF', 'GBP']
# Evaluating ['USD', 'NOK'] + ['HUF', 'HRK']
# Better than last score, but not better than best: 0.007174369381739578
# USD   0.63328
# NOK   0.26343
# HRK   0.10330
# HUF   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['IDR', 'AUD']
# Better than last score, but not better than best: 0.007104844863092373
# USD   0.70245
# NOK   0.18906
# AUD   0.10850
# IDR   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['IDR', 'CAD']
# Better than last score, but not better than best: 0.007173385606946689
# USD   0.66392
# NOK   0.27673
# CAD   0.05935
# IDR   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['IDR', 'CHF']
# Better than last score, but not better than best: 0.00705117787415089
# USD   0.66925
# NOK   0.22229
# CHF   0.10846
# IDR   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['IDR', 'CNY']
# Better than last score, but not better than best: 0.0071284504553908315
# USD   0.62767
# NOK   0.26153
# CNY   0.06386
# IDR   0.04693
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['IDR', 'CZK']
# Better than last score, but not better than best: 0.007124366700432058
# USD   0.67722
# NOK   0.17686
# CZK   0.07540
# IDR   0.07052
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['IDR', 'DKK']
# Better than last score, but not better than best: 0.007135992664436187
# USD   0.52215
# DKK   0.25328
# NOK   0.12029
# IDR   0.10429
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['IDR', 'EUR']
# Better than last score, but not better than best: 0.007137704081700414
# USD   0.52369
# EUR   0.25237
# NOK   0.12137
# IDR   0.10257
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['IDR', 'GBP']
# Evaluating ['USD', 'NOK'] + ['IDR', 'HRK']
# Better than last score, but not better than best: 0.007160978631085989
# USD   0.56998
# NOK   0.17625
# HRK   0.17021
# IDR   0.08356
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['IDR', 'HUF']
# Evaluating ['USD', 'NOK'] + ['JPY', 'AUD']
# Better than last score, but not better than best: 0.007056184743542118
# USD   0.63690
# NOK   0.28248
# JPY   0.07277
# AUD   0.00785
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['JPY', 'CAD']
# Better than last score, but not better than best: 0.0070563671043622715
# USD   0.63202
# NOK   0.29170
# JPY   0.07627
# CAD   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['JPY', 'CHF']
# Better than last score, but not better than best: 0.00704970491023623
# USD   0.65754
# NOK   0.24212
# CHF   0.07524
# JPY   0.02510
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['JPY', 'CNY']
# Better than last score, but not better than best: 0.0070563665886141875
# USD   0.63221
# NOK   0.29159
# JPY   0.07619
# CNY   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['JPY', 'CZK']
# Better than last score, but not better than best: 0.007055973494598759
# USD   0.63876
# NOK   0.28183
# JPY   0.07311
# CZK   0.00630
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['JPY', 'DKK']
# Better than last score, but not better than best: 0.007037233082616117
# USD   0.60394
# NOK   0.20867
# DKK   0.11574
# JPY   0.07165
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['JPY', 'EUR']
# Better than last score, but not better than best: 0.007037410556934953
# USD   0.60410
# NOK   0.20835
# EUR   0.11566
# JPY   0.07188
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['JPY', 'GBP']
# Better than last score, but not better than best: 0.007041090193033164
# USD   0.55443
# NOK   0.26791
# JPY   0.11629
# GBP   0.06137
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['JPY', 'HRK']
# Better than last score, but not better than best: 0.007046404849388234
# USD   0.62049
# NOK   0.23383
# JPY   0.07349
# HRK   0.07219
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['JPY', 'HUF']
# Better than last score, but not better than best: 0.007036170891614294
# USD   0.59312
# NOK   0.24031
# JPY   0.09888
# HUF   0.06769
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['JPY', 'IDR']
# Better than last score, but not better than best: 0.0070556807829984065
# USD   0.62308
# NOK   0.28572
# JPY   0.07659
# IDR   0.01461
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['KRW', 'AUD']
# Better than last score, but not better than best: 0.007104845103908566
# USD   0.70234
# NOK   0.18910
# AUD   0.10856
# KRW   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['KRW', 'CAD']
# Better than last score, but not better than best: 0.007173385613831408
# USD   0.66398
# NOK   0.27673
# CAD   0.05929
# KRW   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['KRW', 'CHF']
# Better than last score, but not better than best: 0.007051174272270255
# USD   0.66862
# NOK   0.22167
# CHF   0.10900
# KRW   0.00071
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['KRW', 'CNY']
# Better than last score, but not better than best: 0.007134696427773205
# USD   0.65628
# NOK   0.28596
# CNY   0.05776
# KRW   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['KRW', 'CZK']
# Better than last score, but not better than best: 0.007137102255623189
# USD   0.70860
# NOK   0.22972
# CZK   0.06168
# KRW   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['KRW', 'DKK']
# Better than last score, but not better than best: 0.007157796668867203
# USD   0.60994
# NOK   0.23008
# DKK   0.15998
# KRW   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['KRW', 'EUR']
# Better than last score, but not better than best: 0.007159030187021726
# USD   0.61075
# NOK   0.23117
# EUR   0.15808
# KRW   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['KRW', 'GBP']
# Evaluating ['USD', 'NOK'] + ['KRW', 'HRK']
# Better than last score, but not better than best: 0.007174371903064602
# USD   0.63282
# NOK   0.26425
# HRK   0.10293
# KRW   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['KRW', 'HUF']
# Evaluating ['USD', 'NOK'] + ['KRW', 'IDR']
# Evaluating ['USD', 'NOK'] + ['KRW', 'JPY']
# Better than last score, but not better than best: 0.007054535933866001
# USD   0.61053
# NOK   0.28351
# JPY   0.08747
# KRW   0.01849
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['MYR', 'AUD']
# Better than last score, but not better than best: 0.007104136057524521
# USD   0.69836
# NOK   0.18888
# AUD   0.09797
# MYR   0.01478
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['MYR', 'CAD']
# Better than last score, but not better than best: 0.007139766232544117
# USD   0.65497
# NOK   0.25982
# MYR   0.08521
# CAD   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['MYR', 'CHF']
# Better than last score, but not better than best: 0.0070511806624636245
# USD   0.66878
# NOK   0.22307
# CHF   0.10815
# MYR   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['MYR', 'CNY']
# Better than last score, but not better than best: 0.007134013027742819
# USD   0.65606
# NOK   0.27653
# CNY   0.04386
# MYR   0.02355
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['MYR', 'CZK']
# Better than last score, but not better than best: 0.007131459283170263
# USD   0.68783
# NOK   0.23077
# MYR   0.04395
# CZK   0.03745
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['MYR', 'DKK']
# Better than last score, but not better than best: 0.007103936744728378
# USD   0.61466
# DKK   0.15678
# NOK   0.14441
# MYR   0.08415
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['MYR', 'EUR']
# Better than last score, but not better than best: 0.007105134343522659
# USD   0.61541
# EUR   0.15488
# NOK   0.14552
# MYR   0.08418
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['MYR', 'GBP']
# Better than last score, but not better than best: 0.00713976479625414
# USD   0.65475
# NOK   0.25960
# MYR   0.08565
# GBP   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['MYR', 'HRK']
# Better than last score, but not better than best: 0.007127668048454732
# USD   0.64091
# NOK   0.20050
# MYR   0.07934
# HRK   0.07925
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['MYR', 'HUF']
# Better than last score, but not better than best: 0.007127862221822429
# USD   0.62378
# NOK   0.17255
# MYR   0.13681
# HUF   0.06686
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['MYR', 'IDR']
# Better than last score, but not better than best: 0.0071397641756152696
# USD   0.65500
# NOK   0.25927
# MYR   0.08574
# IDR   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['MYR', 'JPY']
# Better than last score, but not better than best: 0.007056366774017486
# USD   0.63206
# NOK   0.29173
# JPY   0.07621
# MYR   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['MYR', 'KRW']
# Better than last score, but not better than best: 0.007139764352306586
# USD   0.65513
# NOK   0.25914
# MYR   0.08572
# KRW   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['NZD', 'AUD']
# Better than last score, but not better than best: 0.007104845572589028
# USD   0.70234
# NOK   0.18899
# AUD   0.10867
# NZD   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['NZD', 'CAD']
# Better than last score, but not better than best: 0.007163571425541901
# USD   0.65053
# NOK   0.23345
# CAD   0.07244
# NZD   0.04358
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['NZD', 'CHF']
# Better than last score, but not better than best: 0.007048365236806096
# USD   0.66084
# NOK   0.20817
# CHF   0.10868
# NZD   0.02231
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['NZD', 'CNY']
# Better than last score, but not better than best: 0.007090494018083503
# USD   0.61944
# NOK   0.18789
# NZD   0.10419
# CNY   0.08848
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['NZD', 'CZK']
# Better than last score, but not better than best: 0.007069763757924618
# USD   0.70559
# NZD   0.14084
# CZK   0.11591
# NOK   0.03766
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['NZD', 'DKK']
# Better than last score, but not better than best: 0.007135594891340811
# USD   0.56968
# DKK   0.21875
# NOK   0.14242
# NZD   0.06915
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['NZD', 'EUR']
# Better than last score, but not better than best: 0.007136614077958858
# USD   0.57007
# EUR   0.21876
# NOK   0.14108
# NZD   0.07010
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['NZD', 'GBP']
# Evaluating ['USD', 'NOK'] + ['NZD', 'HRK']
# Better than last score, but not better than best: 0.007143946388278425
# USD   0.58273
# HRK   0.20019
# NOK   0.12477
# NZD   0.09231
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['NZD', 'HUF']
# Evaluating ['USD', 'NOK'] + ['NZD', 'IDR']
# Evaluating ['USD', 'NOK'] + ['NZD', 'JPY']
# Better than last score, but not better than best: 0.007051367906723405
# USD   0.62075
# NOK   0.27232
# JPY   0.07717
# NZD   0.02977
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['NZD', 'KRW']
# Evaluating ['USD', 'NOK'] + ['NZD', 'MYR']
# Better than last score, but not better than best: 0.007123456135845351
# USD   0.63442
# NOK   0.20794
# MYR   0.10104
# NZD   0.05659
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PHP', 'AUD']
# Better than last score, but not better than best: 0.007103381262721426
# USD   0.70365
# NOK   0.18381
# AUD   0.10120
# PHP   0.01133
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PHP', 'CAD']
# Better than last score, but not better than best: 0.007165349169479132
# USD   0.67056
# NOK   0.28203
# PHP   0.04570
# CAD   0.00171
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PHP', 'CHF']
# Better than last score, but not better than best: 0.007051178220165904
# USD   0.66910
# NOK   0.22235
# CHF   0.10856
# PHP   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PHP', 'CNY']
# Better than last score, but not better than best: 0.007134696507834828
# USD   0.65618
# NOK   0.28604
# CNY   0.05777
# PHP   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PHP', 'CZK']
# Better than last score, but not better than best: 0.007137101278247834
# USD   0.70829
# NOK   0.23006
# CZK   0.06166
# PHP   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PHP', 'DKK']
# Better than last score, but not better than best: 0.0071391940832979135
# USD   0.63123
# NOK   0.19518
# DKK   0.13629
# PHP   0.03730
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PHP', 'EUR']
# Better than last score, but not better than best: 0.007140286266415123
# USD   0.63209
# NOK   0.19637
# EUR   0.13408
# PHP   0.03745
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PHP', 'GBP']
# Better than last score, but not better than best: 0.007165333429394241
# USD   0.67004
# NOK   0.28347
# PHP   0.04649
# GBP   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PHP', 'HRK']
# Better than last score, but not better than best: 0.00715742699520847
# USD   0.65439
# NOK   0.24066
# HRK   0.06750
# PHP   0.03745
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PHP', 'HUF']
# Better than last score, but not better than best: 0.007165292004665096
# USD   0.66895
# NOK   0.27911
# PHP   0.04826
# HUF   0.00368
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PHP', 'IDR']
# Better than last score, but not better than best: 0.007163888110503619
# USD   0.65761
# NOK   0.27187
# PHP   0.04889
# IDR   0.02163
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PHP', 'JPY']
# Better than last score, but not better than best: 0.007056366562130912
# USD   0.63217
# NOK   0.29165
# JPY   0.07618
# PHP   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PHP', 'KRW']
# Better than last score, but not better than best: 0.007165333298404699
# USD   0.66995
# NOK   0.28357
# PHP   0.04648
# KRW   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PHP', 'MYR']
# Better than last score, but not better than best: 0.007139764353111357
# USD   0.65486
# NOK   0.25939
# MYR   0.08575
# PHP   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PHP', 'NZD']
# Better than last score, but not better than best: 0.0071400621417309134
# USD   0.65066
# NOK   0.19971
# NZD   0.07784
# PHP   0.07179
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PLN', 'AUD']
# Better than last score, but not better than best: 0.007101727019613651
# USD   0.71703
# NOK   0.13582
# AUD   0.12087
# PLN   0.02628
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PLN', 'CAD']
# Better than last score, but not better than best: 0.0071733869946466935
# USD   0.66356
# NOK   0.27717
# CAD   0.05927
# PLN   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PLN', 'CHF']
# Better than last score, but not better than best: 0.007049041709582687
# USD   0.67704
# NOK   0.18841
# CHF   0.11453
# PLN   0.02003
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PLN', 'CNY']
# Better than last score, but not better than best: 0.007134696461001958
# USD   0.65616
# NOK   0.28612
# CNY   0.05772
# PLN   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PLN', 'CZK']
# Better than last score, but not better than best: 0.007137101282570774
# USD   0.70823
# NOK   0.23014
# CZK   0.06163
# PLN   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PLN', 'DKK']
# Better than last score, but not better than best: 0.00715779614950388
# USD   0.61071
# NOK   0.22994
# DKK   0.15935
# PLN   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PLN', 'EUR']
# Better than last score, but not better than best: 0.007159030553412068
# USD   0.61156
# NOK   0.23104
# EUR   0.15740
# PLN   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PLN', 'GBP']
# Evaluating ['USD', 'NOK'] + ['PLN', 'HRK']
# Better than last score, but not better than best: 0.007174369979967028
# USD   0.63310
# NOK   0.26306
# HRK   0.10385
# PLN   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PLN', 'HUF']
# Evaluating ['USD', 'NOK'] + ['PLN', 'IDR']
# Evaluating ['USD', 'NOK'] + ['PLN', 'JPY']
# Better than last score, but not better than best: 0.007053683777191377
# USD   0.63877
# NOK   0.25704
# JPY   0.08109
# PLN   0.02310
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PLN', 'KRW']
# Evaluating ['USD', 'NOK'] + ['PLN', 'MYR']
# Better than last score, but not better than best: 0.007139764227859554
# USD   0.65493
# NOK   0.25936
# MYR   0.08571
# PLN   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['PLN', 'NZD']
# Evaluating ['USD', 'NOK'] + ['PLN', 'PHP']
# Better than last score, but not better than best: 0.007165333465883547
# USD   0.66979
# NOK   0.28372
# PHP   0.04650
# PLN   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RON', 'AUD']
# Better than last score, but not better than best: 0.007104845952715713
# USD   0.70209
# NOK   0.18944
# AUD   0.10847
# RON   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RON', 'CAD']
# Better than last score, but not better than best: 0.007173391086241258
# USD   0.66455
# NOK   0.27537
# CAD   0.06008
# RON   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RON', 'CHF']
# Better than last score, but not better than best: 0.007043410971174811
# USD   0.64632
# NOK   0.15782
# CHF   0.14547
# RON   0.05039
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RON', 'CNY']
# Better than last score, but not better than best: 0.007134696471282753
# USD   0.65635
# NOK   0.28592
# CNY   0.05773
# RON   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RON', 'CZK']
# Better than last score, but not better than best: 0.007137101304041762
# USD   0.70827
# NOK   0.23002
# CZK   0.06170
# RON   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RON', 'DKK']
# Better than last score, but not better than best: 0.007157795357174933
# USD   0.61036
# NOK   0.22998
# DKK   0.15966
# RON   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RON', 'EUR']
# Better than last score, but not better than best: 0.0071590292053641666
# USD   0.61112
# NOK   0.23109
# EUR   0.15779
# RON   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RON', 'GBP']
# Evaluating ['USD', 'NOK'] + ['RON', 'HRK']
# Better than last score, but not better than best: 0.007174369389469923
# USD   0.63321
# NOK   0.26352
# HRK   0.10327
# RON   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RON', 'HUF']
# Evaluating ['USD', 'NOK'] + ['RON', 'IDR']
# Evaluating ['USD', 'NOK'] + ['RON', 'JPY']
# Better than last score, but not better than best: 0.007032222311956144
# USD   0.55267
# NOK   0.19626
# JPY   0.13944
# RON   0.11163
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RON', 'KRW']
# Evaluating ['USD', 'NOK'] + ['RON', 'MYR']
# Better than last score, but not better than best: 0.007139769714669375
# USD   0.65534
# NOK   0.25815
# MYR   0.08652
# RON   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RON', 'NZD']
# Evaluating ['USD', 'NOK'] + ['RON', 'PHP']
# Better than last score, but not better than best: 0.007165333860002488
# USD   0.67009
# NOK   0.28353
# PHP   0.04638
# RON   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RON', 'PLN']
# Evaluating ['USD', 'NOK'] + ['RUB', 'AUD']
# Better than last score, but not better than best: 0.0071048456628627675
# USD   0.70214
# NOK   0.18940
# AUD   0.10846
# RUB   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RUB', 'CAD']
# Better than last score, but not better than best: 0.007173393855899274
# USD   0.66452
# NOK   0.27510
# CAD   0.06038
# RUB   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RUB', 'CHF']
# Better than last score, but not better than best: 0.007050454892995979
# USD   0.66007
# NOK   0.20472
# CHF   0.11826
# RUB   0.01694
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RUB', 'CNY']
# Better than last score, but not better than best: 0.0071346967178083365
# USD   0.65642
# NOK   0.28580
# CNY   0.05777
# RUB   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RUB', 'CZK']
# Better than last score, but not better than best: 0.00713711294487112
# USD   0.70699
# NOK   0.23209
# CZK   0.06092
# RUB   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RUB', 'DKK']
# Better than last score, but not better than best: 0.0071577955357024145
# USD   0.61045
# NOK   0.22967
# DKK   0.15988
# RUB   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RUB', 'EUR']
# Better than last score, but not better than best: 0.00715902939104871
# USD   0.61119
# NOK   0.23077
# EUR   0.15803
# RUB   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RUB', 'GBP']
# Evaluating ['USD', 'NOK'] + ['RUB', 'HRK']
# Better than last score, but not better than best: 0.007174369615272668
# USD   0.63341
# NOK   0.26337
# HRK   0.10322
# RUB   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RUB', 'HUF']
# Evaluating ['USD', 'NOK'] + ['RUB', 'IDR']
# Evaluating ['USD', 'NOK'] + ['RUB', 'JPY']
# Better than last score, but not better than best: 0.007050747827946888
# USD   0.58885
# NOK   0.25008
# JPY   0.10249
# RUB   0.05858
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RUB', 'KRW']
# Evaluating ['USD', 'NOK'] + ['RUB', 'MYR']
# Better than last score, but not better than best: 0.007139767109044758
# USD   0.65555
# NOK   0.25877
# MYR   0.08568
# RUB   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RUB', 'NZD']
# Evaluating ['USD', 'NOK'] + ['RUB', 'PHP']
# Better than last score, but not better than best: 0.007165333421365751
# USD   0.66987
# NOK   0.28356
# PHP   0.04657
# RUB   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['RUB', 'PLN']
# Evaluating ['USD', 'NOK'] + ['RUB', 'RON']
# Evaluating ['USD', 'NOK'] + ['SEK', 'AUD']
# Better than last score, but not better than best: 0.007101513129231516
# USD   0.69329
# NOK   0.15617
# AUD   0.11224
# SEK   0.03830
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SEK', 'CAD']
# Better than last score, but not better than best: 0.007157472056141565
# USD   0.64157
# NOK   0.15069
# SEK   0.10788
# CAD   0.09986
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SEK', 'CHF']
# Better than last score, but not better than best: 0.007040530285558648
# USD   0.65045
# NOK   0.16313
# CHF   0.11604
# SEK   0.07038
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SEK', 'CNY']
# Better than last score, but not better than best: 0.007068247508219035
# USD   0.59165
# SEK   0.24410
# CNY   0.11932
# NOK   0.04493
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SEK', 'CZK']
# Better than last score, but not better than best: 0.007098790449743167
# USD   0.69771
# SEK   0.16481
# CZK   0.10102
# NOK   0.03645
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SEK', 'DKK']
# Better than last score, but not better than best: 0.007157132944623125
# USD   0.60493
# NOK   0.21607
# DKK   0.16191
# SEK   0.01709
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SEK', 'EUR']
# Better than last score, but not better than best: 0.007158390659543781
# USD   0.60577
# NOK   0.21743
# EUR   0.16001
# SEK   0.01678
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SEK', 'GBP']
# Evaluating ['USD', 'NOK'] + ['SEK', 'HRK']
# Better than last score, but not better than best: 0.007171871838248755
# USD   0.62185
# NOK   0.22941
# HRK   0.11390
# SEK   0.03485
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SEK', 'HUF']
# Evaluating ['USD', 'NOK'] + ['SEK', 'IDR']
# Evaluating ['USD', 'NOK'] + ['SEK', 'JPY']
# Better than last score, but not better than best: 0.007038177529566334
# USD   0.60296
# NOK   0.21719
# SEK   0.09419
# JPY   0.08565
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SEK', 'KRW']
# Evaluating ['USD', 'NOK'] + ['SEK', 'MYR']
# Better than last score, but not better than best: 0.007111701132753449
# USD   0.61841
# SEK   0.13459
# MYR   0.12743
# NOK   0.11958
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SEK', 'NZD']
# Evaluating ['USD', 'NOK'] + ['SEK', 'PHP']
# Better than last score, but not better than best: 0.007138752456686755
# USD   0.64415
# SEK   0.14519
# NOK   0.12482
# PHP   0.08584
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SEK', 'PLN']
# Evaluating ['USD', 'NOK'] + ['SEK', 'RON']
# Evaluating ['USD', 'NOK'] + ['SEK', 'RUB']
# Evaluating ['USD', 'NOK'] + ['SGD', 'AUD']
# Better than last score, but not better than best: 0.007096274131281682
# USD   0.69553
# NOK   0.19378
# AUD   0.07341
# SGD   0.03727
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'CAD']
# Better than last score, but not better than best: 0.007115775097301921
# USD   0.67152
# NOK   0.24982
# SGD   0.07866
# CAD   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'CHF']
# Better than last score, but not better than best: 0.007051178978478298
# USD   0.66945
# NOK   0.22231
# CHF   0.10825
# SGD   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'CNY']
# Better than last score, but not better than best: 0.007115774022375677
# USD   0.67203
# NOK   0.24928
# SGD   0.07868
# CNY   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'CZK']
# Better than last score, but not better than best: 0.007115767292551797
# USD   0.67229
# NOK   0.24892
# SGD   0.07813
# CZK   0.00065
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'DKK']
# Better than last score, but not better than best: 0.007092401423107506
# USD   0.63781
# NOK   0.16211
# DKK   0.12800
# SGD   0.07209
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'EUR']
# Better than last score, but not better than best: 0.00709329688797895
# USD   0.63857
# NOK   0.16307
# EUR   0.12610
# SGD   0.07226
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'GBP']
# Better than last score, but not better than best: 0.007115362054705543
# USD   0.66064
# NOK   0.23451
# SGD   0.09160
# GBP   0.01326
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'HRK']
# Better than last score, but not better than best: 0.007110139580627552
# USD   0.66166
# NOK   0.21029
# SGD   0.07338
# HRK   0.05468
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'HUF']
# Better than last score, but not better than best: 0.007091387778290175
# USD   0.63894
# NOK   0.13491
# SGD   0.13254
# HUF   0.09361
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'IDR']
# Better than last score, but not better than best: 0.0071152351164904095
# USD   0.66395
# NOK   0.24363
# SGD   0.07931
# IDR   0.01310
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'JPY']
# Better than last score, but not better than best: 0.007056367163328318
# USD   0.63202
# NOK   0.29169
# JPY   0.07628
# SGD   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'KRW']
# Better than last score, but not better than best: 0.007115774154081392
# USD   0.67209
# NOK   0.24921
# SGD   0.07870
# KRW   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'MYR']
# Better than last score, but not better than best: 0.007115773798725988
# USD   0.67191
# NOK   0.24938
# SGD   0.07871
# MYR   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'NZD']
# Better than last score, but not better than best: 0.007089316911111349
# USD   0.64865
# NOK   0.18094
# SGD   0.09677
# NZD   0.07364
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'PHP']
# Better than last score, but not better than best: 0.007115773870873924
# USD   0.67186
# NOK   0.24949
# SGD   0.07865
# PHP   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'PLN']
# Better than last score, but not better than best: 0.007115774043685543
# USD   0.67173
# NOK   0.24957
# SGD   0.07870
# PLN   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'RON']
# Better than last score, but not better than best: 0.00711577415924018
# USD   0.67207
# NOK   0.24927
# SGD   0.07866
# RON   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'RUB']
# Better than last score, but not better than best: 0.00711577381313415
# USD   0.67185
# NOK   0.24940
# SGD   0.07874
# RUB   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['SGD', 'SEK']
# Better than last score, but not better than best: 0.00707210220496485
# USD   0.63424
# SEK   0.16859
# SGD   0.12011
# NOK   0.07706
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['THB', 'AUD']
# Better than last score, but not better than best: 0.007100943581907641
# USD   0.70248
# NOK   0.18514
# AUD   0.09245
# THB   0.01994
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['THB', 'CAD']
# Better than last score, but not better than best: 0.007144374476404961
# USD   0.67423
# NOK   0.26674
# THB   0.05903
# CAD   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK'] + ['THB', 'CHF']
# Better than last score, but not better than best: 0.0070511778803037375
# ...
# USD   0.60070
# DKK   0.17966
# SEK   0.09094
# AUD   0.06983
# JPY   0.04707
# NOK   0.01180
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SEK', 'KRW']
# Better than last score, but not better than best: 0.007025599744935008
# USD   0.63953
# DKK   0.19888
# AUD   0.12126
# SEK   0.04033
# KRW   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SEK', 'MYR']
# Better than last score, but not better than best: 0.007025598329002907
# USD   0.63941
# DKK   0.19888
# AUD   0.12114
# SEK   0.04056
# MYR   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SEK', 'NZD']
# Better than last score, but not better than best: 0.007025597542196279
# USD   0.63882
# DKK   0.19943
# AUD   0.12056
# SEK   0.04120
# NZD   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SEK', 'PHP']
# Better than last score, but not better than best: 0.007025601439050336
# USD   0.64004
# DKK   0.19897
# AUD   0.12108
# SEK   0.03992
# PHP   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SEK', 'PLN']
# Better than last score, but not better than best: 0.007025597067518422
# USD   0.63891
# DKK   0.19944
# AUD   0.12079
# SEK   0.04086
# PLN   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SEK', 'RON']
# Better than last score, but not better than best: 0.00702559719155393
# USD   0.63925
# DKK   0.19873
# AUD   0.12079
# SEK   0.04123
# RON   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SEK', 'RUB']
# Better than last score, but not better than best: 0.007025596820498466
# USD   0.63896
# DKK   0.19928
# AUD   0.12076
# SEK   0.04100
# RUB   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'CAD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'CHF']
# Better than last score, but not better than best: 0.007023159788520472
# USD   0.65008
# DKK   0.17640
# AUD   0.07587
# CHF   0.05045
# NOK   0.04721
# SGD   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'CNY']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'CZK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'EUR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'GBP']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'HRK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'HUF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'IDR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'JPY']
# Better than last score, but not better than best: 0.0070241510385913065
# USD   0.63378
# DKK   0.18537
# AUD   0.08205
# NOK   0.06644
# JPY   0.03236
# SGD   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'KRW']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'MYR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'NZD']
# Better than last score, but not better than best: 0.00702623727765825
# USD   0.61479
# DKK   0.21713
# AUD   0.07546
# NZD   0.05752
# SGD   0.03509
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'PHP']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'PLN']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'RON']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'RUB']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['SGD', 'SEK']
# Better than last score, but not better than best: 0.007024455622543804
# USD   0.63412
# DKK   0.18051
# AUD   0.10104
# SEK   0.06285
# SGD   0.02148
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'CAD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'CHF']
# Better than last score, but not better than best: 0.00702315934550225
# USD   0.65004
# DKK   0.17666
# AUD   0.07578
# CHF   0.05043
# NOK   0.04709
# THB   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'CNY']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'CZK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'EUR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'GBP']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'HRK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'HUF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'IDR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'JPY']
# Better than last score, but not better than best: 0.007024147313834762
# USD   0.63450
# DKK   0.18444
# AUD   0.08232
# NOK   0.06639
# JPY   0.03235
# THB   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'KRW']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'MYR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'NZD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'PHP']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'PLN']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'RON']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'RUB']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'SEK']
# Better than last score, but not better than best: 0.007025602197417685
# USD   0.63997
# DKK   0.19844
# AUD   0.12136
# SEK   0.04023
# THB   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['THB', 'SGD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'CAD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'CHF']
# Better than last score, but not better than best: 0.007016485379615025
# USD   0.61496
# DKK   0.17162
# CHF   0.08640
# AUD   0.07573
# TRY   0.04148
# NOK   0.00982
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'CNY']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'CZK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'EUR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'GBP']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'HRK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'HUF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'IDR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'JPY']
# Better than last score, but not better than best: 0.007019296040187289
# USD   0.59814
# DKK   0.18488
# AUD   0.08805
# JPY   0.05005
# NOK   0.04498
# TRY   0.03390
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'KRW']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'MYR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'NZD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'PHP']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'PLN']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'RON']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'RUB']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'SEK']
# Better than last score, but not better than best: 0.007025599618035417
# USD   0.63852
# DKK   0.20008
# AUD   0.12050
# SEK   0.04090
# TRY   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'SGD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['TRY', 'THB']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'CAD']
# Better than last score, but not better than best: 0.007027218900820031
# USD   0.62505
# DKK   0.23338
# AUD   0.12812
# ZAR   0.01344
# CAD   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'CHF']
# Better than last score, but not better than best: 0.007014244429773322
# USD   0.60633
# DKK   0.20949
# AUD   0.07404
# CHF   0.06216
# NOK   0.02608
# ZAR   0.02190
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'CNY']
# Better than last score, but not better than best: 0.007025749055937654
# USD   0.57924
# DKK   0.23796
# AUD   0.10903
# ZAR   0.03778
# CNY   0.03599
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'CZK']
# Better than last score, but not better than best: 0.007027213577810136
# USD   0.62619
# DKK   0.23218
# AUD   0.12846
# ZAR   0.01317
# CZK   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'EUR']
# Better than last score, but not better than best: 0.0070274022576145775
# USD   0.62662
# AUD   0.12832
# DKK   0.11700
# EUR   0.11509
# ZAR   0.01297
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'GBP']
# Better than last score, but not better than best: 0.0070272240408378326
# USD   0.62803
# DKK   0.23033
# AUD   0.12887
# ZAR   0.01276
# GBP   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'HRK']
# Better than last score, but not better than best: 0.00702721373529144
# USD   0.62618
# DKK   0.23225
# AUD   0.12847
# ZAR   0.01309
# HRK   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'HUF']
# Better than last score, but not better than best: 0.007027214022130167
# USD   0.62613
# DKK   0.23233
# AUD   0.12833
# ZAR   0.01321
# HUF   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'IDR']
# Better than last score, but not better than best: 0.007027213704209326
# USD   0.62631
# DKK   0.23222
# AUD   0.12835
# ZAR   0.01312
# IDR   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'JPY']
# Better than last score, but not better than best: 0.0070138970124565235
# USD   0.58047
# DKK   0.21655
# AUD   0.07640
# NOK   0.05786
# JPY   0.04457
# ZAR   0.02416
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'KRW']
# Better than last score, but not better than best: 0.007027213589436421
# USD   0.62631
# DKK   0.23219
# AUD   0.12840
# ZAR   0.01309
# KRW   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'MYR']
# Better than last score, but not better than best: 0.007027074123202956
# USD   0.61427
# DKK   0.23444
# AUD   0.12043
# ZAR   0.01775
# MYR   0.01311
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'NZD']
# Better than last score, but not better than best: 0.0070270984024976505
# USD   0.62742
# DKK   0.22998
# AUD   0.12438
# ZAR   0.00950
# NZD   0.00872
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'PHP']
# Better than last score, but not better than best: 0.007027215776276696
# USD   0.62709
# DKK   0.23130
# AUD   0.12863
# ZAR   0.01297
# PHP   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'PLN']
# Better than last score, but not better than best: 0.007027214277933519
# USD   0.62650
# DKK   0.23214
# AUD   0.12828
# ZAR   0.01308
# PLN   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'RON']
# Better than last score, but not better than best: 0.007027214080302697
# USD   0.62636
# DKK   0.23230
# AUD   0.12832
# ZAR   0.01301
# RON   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'RUB']
# Better than last score, but not better than best: 0.007027213931677928
# USD   0.62624
# DKK   0.23237
# AUD   0.12829
# ZAR   0.01309
# RUB   0.00000
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'SEK']
# Better than last score, but not better than best: 0.007025545864488511
# USD   0.63538
# DKK   0.20443
# AUD   0.12162
# SEK   0.03611
# ZAR   0.00245
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'SGD']
# Better than last score, but not better than best: 0.00702345605894901
# USD   0.56698
# DKK   0.24081
# AUD   0.07923
# SGD   0.06792
# ZAR   0.04506
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'THB']
# Better than last score, but not better than best: 0.007027198753933402
# USD   0.62549
# DKK   0.23094
# AUD   0.12682
# ZAR   0.01419
# THB   0.00256
# NOK   0.00000
# dtype: float64
# Evaluating ['USD', 'NOK', 'DKK', 'AUD'] + ['ZAR', 'TRY']
# Better than last score, but not better than best: 0.007027220913089896
# USD   0.62767
# DKK   0.23060
# AUD   0.12887
# ZAR   0.01286
# TRY   0.00000
# NOK   0.00000
# dtype: float64
# Attempting to improve set, starting from: ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['CAD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['CHF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['CNY']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['CZK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['EUR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['HRK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['HUF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['IDR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['KRW']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['MYR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['NZD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['PHP']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['PLN']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['RON']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['RUB']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['SEK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['SGD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['THB']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['TRY']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['ZAR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['CHF', 'CAD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['CNY', 'CAD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['CNY', 'CHF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['CZK', 'CAD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['CZK', 'CHF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['CZK', 'CNY']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['EUR', 'CAD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['EUR', 'CHF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['EUR', 'CNY']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['EUR', 'CZK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['HRK', 'CAD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['HRK', 'CHF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['HRK', 'CNY']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['HRK', 'CZK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['HRK', 'EUR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['HUF', 'CAD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['HUF', 'CHF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['HUF', 'CNY']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['HUF', 'CZK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['HUF', 'EUR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['HUF', 'HRK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['IDR', 'CAD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['IDR', 'CHF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['IDR', 'CNY']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['IDR', 'CZK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['IDR', 'EUR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['IDR', 'HRK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['IDR', 'HUF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['KRW', 'CAD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['KRW', 'CHF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['KRW', 'CNY']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['KRW', 'CZK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['KRW', 'EUR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['KRW', 'HRK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['KRW', 'HUF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['KRW', 'IDR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['MYR', 'CAD']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['MYR', 'CHF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['MYR', 'CNY']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['MYR', 'CZK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['MYR', 'EUR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['MYR', 'HRK']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['MYR', 'HUF']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['MYR', 'IDR']
# Evaluating ['USD', 'NOK', 'DKK', 'AUD', 'JPY', 'GBP'] + ['MYR', 'KRW']

# %%
# New best score found: 0.007005720087502464
# USD   0.54671
# DKK   0.19379
# AUD   0.08139
# JPY   0.07595
# GBP   0.06701
# NOK   0.03515

# %%
mix3 = run_optimization(selected_currencies=['NZD', 'EUR', 'HRK'], 
                                   max_iter=100, 
                                   loss_function=calculate_loss_function_around_one)

# %%
calculate_loss_function_around_one(mix3.values, mix3.index) / 0.007002770452103174
# Out:
# 1.2428404205248926
