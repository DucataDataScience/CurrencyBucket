# %%
# Working modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly
import plotly.express
import scipy
import sklearn
import seaborn
import yfinance as yf

# %%
data = yf.download("AUD=X ZAR=X", start="2014-01-01", end="2017-04-30")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
data.sort_values("Date").head(20)
# Out:
#            Adj Close            Close             High              Low  \
#                AUD=X    ZAR=X   AUD=X    ZAR=X   AUD=X    ZAR=X   AUD=X
# Date
# 2014-01-01    1.1217  10.3500  1.1217  10.3500  1.1217  10.3500  1.1204
# 2014-01-02    1.1246  10.4726  1.1246  10.4726  1.1306  10.6736  1.1184
# 2014-01-03    1.1228  10.6739  1.1228  10.6739  1.1252  10.6745  1.1105
# 2014-01-06    1.1154  10.6578  1.1154  10.6578  1.1190  10.7325  1.1132
# 2014-01-07    1.1152  10.6277  1.1152  10.6277  1.1240  10.6710  1.1150
# 2014-01-08    1.1214  10.6346  1.1214  10.6346  1.1230  10.7263  1.1171
# 2014-01-09    1.1248  10.7583  1.1248  10.7583  1.1276  10.8329  1.1219
# 2014-01-10    1.1239  10.7895  1.1239  10.7895  1.1264  10.8093  1.1112
# 2014-01-13    1.1095      NaN  1.1095      NaN  1.1126      NaN  1.1007
# 2014-01-14    1.1050  10.8017  1.1050  10.8017  1.1146  10.8892  1.1044
# 2014-01-15    1.1159  10.8204  1.1159  10.8204  1.1248  10.9310  1.1146
# ...
